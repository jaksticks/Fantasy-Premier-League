# %%
import soccerdata as sd

# %%
fbref = sd.FBref('ENG-Premier League', '2025')

# %%
games = fbref.read_schedule()

# %%
games.head()

# %%
games.tail()

# %%
games[games.home_xg.notnull()]

# %%
understat = sd.Understat('ENG-Premier League', '2025')

# %%
games = understat.read_schedule()
games

# %%
sofascore = sd.Sofascore('ENG-Premier League', '2025')
games = sofascore.read_schedule()
games
