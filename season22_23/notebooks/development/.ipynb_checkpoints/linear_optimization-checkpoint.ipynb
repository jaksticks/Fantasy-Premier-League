# %% [markdown]
# TO DO
#
# - is it possible to add captaincy bonus?
# - add an optional constraint to allow only one defender from any given team (risk mitigation)?

# %%
import pandas as pd
import numpy as np
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable
import json
import requests

# %%
# function to solve the optimization problem
def optimize(df, max_price, expected_column):
    
    # PRELIMINARIES

    # Create the model
    model = LpProblem(name="FPL", sense=LpMaximize)    
    variables = [LpVariable(name=f'{ix}', cat='Binary') for ix in df.index]
    captaincy_variables = [LpVariable(name=f'cap_{ix}', cat='Binary') for ix in df.index]
    prices = [df.loc[ix,'price'] for ix in df.index]
    # measure of player quality
    expected_points = [df.loc[ix,expected_column] for ix in df.index]
    goalkeepers = [1.0 if df.loc[ix,'position']=='GK' else 0.0 for ix in df.index]
    defenders = [1.0 if df.loc[ix,'position']=='DEF' else 0.0 for ix in df.index]
    midfielders = [1.0 if df.loc[ix,'position']=='MID' else 0.0 for ix in df.index]
    forwards = [1.0 if df.loc[ix,'position']=='FWD' else 0.0 for ix in df.index]
    teams = []
    for team in df['team'].unique():
        teams.append( [1.0 if df.loc[ix,'team']==team else 0.0 for ix in df.index] )

    # CONSTRAINTS

    # select 11 players
    model += lpSum(variables) == 11
    # select 1 captain
    model += lpSum(captaincy_variables) == 1
    # captain must be one of the 11 players in the team
    for i in range(0,len(variables)):
        model += captaincy_variables[i] <= variables[i]
    # set maximum price for starting 11
    model += np.dot(prices,variables) <= max_price
    # only 1 goalkeeper
    model += np.dot(goalkeepers,variables) == 1
    # at least 3 defenders
    model += np.dot(defenders,variables) >= 3
    # at most 5 defenders
    model += np.dot(defenders,variables) <= 5
    # at most 5 midfielders
    model += np.dot(midfielders,variables) <= 5
    # at least 1 forward
    model += np.dot(forwards,variables) >= 1
    # at most 3 forwards
    model += np.dot(forwards,variables) <= 3
    # max 3 players from any given team
    for team in teams:
        model += np.dot(team,variables) <= 3

    # OBJECTIVE
    # the second part doubles the captain's points
    model += np.dot(expected_points,variables) + np.dot(expected_points,captaincy_variables)

    # SOLVE OPTIMIZATION

    status = model.solve()
    print(f'Status: {LpStatus[model.status]}')
    #print(f'Mean total points per gameweek: {model.objective.value()}')

    players = [str(var) for var in model.variables() if var.value()==1]
    captain = [player for player in players if 'cap' in player]
    captain = int(captain[0].replace('cap_', ''))
    players = [int(player) for player in players if 'cap' not in player]
    dream_team = df.loc[players]
    cost = (dream_team['price']).sum()
    exp_points = dream_team[expected_column].sum() + df.loc[captain, expected_column]
    print(f'Cost: {cost}')
    if expected_column == 'xPpg_10':
        print(f'Expected points per week: {exp_points}')
    #elif expected_column == 'xPoints_next10':
    #    exp_points = exp_points / np.min((10, 38-gameweek))
    #    print(f'Expected points per week: {exp_points}')
    #else:
    #    print(f'Expected points: {exp_points}')
    display(dream_team[['position','name','price',expected_column]].sort_values('position'))

# %%
df = pd.read_csv('../../data/xPpg_10.csv', index_col=0)
df['position'] = pd.Categorical(df['position'], ['GK','DEF','MID','FWD'])
df
# Out:
#                    name   xPpg_10  price     value  geometric_valuePoints  \
# 0       Aaron Cresswell  2.829919    5.0  0.565984               1.265578
# 1        Aaron Ramsdale  3.321927    5.0  0.664385               1.485611
# 2     Aaron Wan-Bissaka  2.732612    4.5  0.607247               1.288166
# 3    Abdoulaye Doucoure  2.499481    5.5  0.454451               1.065782
# 4        Adam Armstrong  2.587388    5.5  0.470434               1.103266
# ..                  ...       ...    ...       ...                    ...
# 374          Yerry Mina  2.477446    4.5  0.550543               1.167879
# 375         Yoane Wissa  2.623370    5.5  0.476976               1.118609
# 376     Youri Tielemans  2.865826    6.5  0.440896               1.124069
# 377       Yves Bissouma  2.509924    5.0  0.501985               1.122472
# 378        Zack Steffen  3.765350    4.0  0.941337               1.882675
#
#     position             team
# 0        DEF         West Ham
# 1         GK          Arsenal
# 2        DEF   Manchester Utd
# 3        MID          Everton
# 4        FWD      Southampton
# ..       ...              ...
# 374      DEF          Everton
# 375      MID        Brentford
# 376      MID   Leicester City
# 377      MID        Tottenham
# 378       GK  Manchester City
#
# [379 rows x 7 columns]

# %%
# only consider players that have played at least some minimum number of games
#df = df[df['games played']>=5]
#df

# %%
optimize(df, 82.5, 'xPpg_10')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/46e402947e5f4540b3ff662477f0c441-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/46e402947e5f4540b3ff662477f0c441-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 413 COLUMNS
# At line 5523 RHS
# At line 5932 BOUNDS
# At line 6691 ENDATA
# Problem MODEL has 408 rows, 758 columns and 2835 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 62.7665 - 0.01 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 405 rows, 758 columns (758 integer (758 of which binary)) and 2653 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.45455
# Cbc0038I Solution found of -62.3553
# Cbc0038I Before mini branch and bound, 754 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 405 rows 758 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -62.3964
# Cbc0038I Reduced cost fixing fixed 729 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.08279 (2) obj. -62.3964 iterations 8
# Cbc0038I Pass   2: suminf.    0.72727 (2) obj. -62.7166 iterations 3
# Cbc0038I Pass   3: suminf.    1.09732 (4) obj. -62.3964 iterations 6
# Cbc0038I Pass   4: suminf.    1.09732 (4) obj. -62.3964 iterations 1
# Cbc0038I Pass   5: suminf.    1.70790 (6) obj. -62.3964 iterations 2
# Cbc0038I Pass   6: suminf.    1.70790 (6) obj. -62.3964 iterations 0
# Cbc0038I Pass   7: suminf.    1.70790 (6) obj. -62.3964 iterations 0
# Cbc0038I Pass   8: suminf.    1.70790 (6) obj. -62.3964 iterations 0
# Cbc0038I Pass   9: suminf.    0.08279 (2) obj. -62.3964 iterations 9
# Cbc0038I Pass  10: suminf.    0.72727 (2) obj. -62.7166 iterations 4
# Cbc0038I Pass  11: suminf.    0.97614 (3) obj. -62.3964 iterations 3
# Cbc0038I Pass  12: suminf.    1.76005 (6) obj. -62.3964 iterations 6
# Cbc0038I Pass  13: suminf.    1.58062 (4) obj. -62.3964 iterations 1
# Cbc0038I Pass  14: suminf.    1.00493 (4) obj. -62.3964 iterations 6
# Cbc0038I Pass  15: suminf.    0.99591 (2) obj. -62.3964 iterations 3
# Cbc0038I Pass  16: suminf.    0.99579 (3) obj. -62.3964 iterations 9
# Cbc0038I Pass  17: suminf.    1.08250 (5) obj. -62.3964 iterations 9
# Cbc0038I Pass  18: suminf.    1.22487 (5) obj. -62.3964 iterations 6
# Cbc0038I Pass  19: suminf.    3.27107 (8) obj. -62.3964 iterations 8
# Cbc0038I Pass  20: suminf.    0.08279 (2) obj. -62.3964 iterations 5
# Cbc0038I Pass  21: suminf.    0.72727 (2) obj. -62.7166 iterations 4
# Cbc0038I Pass  22: suminf.    0.51655 (2) obj. -62.3964 iterations 4
# Cbc0038I Solution found of -62.6487
# Cbc0038I Before mini branch and bound, 739 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 405 rows 758 columns, reduced to 8 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -62.6723
# Cbc0038I Reduced cost fixing fixed 747 variables on major pass 3
# Cbc0038I Pass  23: suminf.    0.71402 (2) obj. -62.6723 iterations 1
# Cbc0038I Pass  24: suminf.    0.80000 (2) obj. -62.7105 iterations 4
# Cbc0038I Pass  25: suminf.    0.29325 (2) obj. -62.6723 iterations 3
# Cbc0038I Pass  26: suminf.    0.29325 (2) obj. -62.6723 iterations 0
# Cbc0038I Pass  27: suminf.    0.55655 (3) obj. -62.6723 iterations 3
# Cbc0038I Pass  28: suminf.    0.40000 (2) obj. -62.7197 iterations 3
# Cbc0038I Pass  29: suminf.    0.29325 (2) obj. -62.6723 iterations 4
# Cbc0038I Pass  30: suminf.    0.55655 (3) obj. -62.6723 iterations 4
# Cbc0038I Pass  31: suminf.    0.80000 (2) obj. -62.7105 iterations 4
# Cbc0038I Pass  32: suminf.    0.71402 (2) obj. -62.6723 iterations 4
# Cbc0038I Pass  33: suminf.    0.80000 (2) obj. -62.7105 iterations 2
# Cbc0038I Pass  34: suminf.    1.92119 (5) obj. -62.6723 iterations 4
# Cbc0038I Pass  35: suminf.    0.71402 (2) obj. -62.6723 iterations 4
# Cbc0038I Pass  36: suminf.    0.80000 (2) obj. -62.7105 iterations 2
# Cbc0038I Pass  37: suminf.    0.88889 (2) obj. -62.698 iterations 6
# Cbc0038I Pass  38: suminf.    1.65374 (4) obj. -62.6723 iterations 3
# Cbc0038I Pass  39: suminf.    1.65374 (4) obj. -62.6723 iterations 1
# Cbc0038I Pass  40: suminf.    1.45455 (4) obj. -62.7665 iterations 5
# Cbc0038I Pass  41: suminf.    0.71402 (2) obj. -62.6723 iterations 3
# Cbc0038I Pass  42: suminf.    0.80000 (2) obj. -62.7105 iterations 4
# Cbc0038I Pass  43: suminf.    0.71402 (2) obj. -62.6723 iterations 2
# Cbc0038I Pass  44: suminf.    0.80000 (2) obj. -62.7105 iterations 2
# Cbc0038I Pass  45: suminf.    0.71402 (2) obj. -62.6723 iterations 4
# Cbc0038I Pass  46: suminf.    0.71402 (2) obj. -62.6723 iterations 1
# Cbc0038I Pass  47: suminf.    1.65097 (6) obj. -62.6723 iterations 4
# Cbc0038I Pass  48: suminf.    1.65374 (4) obj. -62.6723 iterations 3
# Cbc0038I Pass  49: suminf.    1.65374 (4) obj. -62.6723 iterations 1
# Cbc0038I Pass  50: suminf.    1.45455 (4) obj. -62.7665 iterations 5
# Cbc0038I Pass  51: suminf.    0.71402 (2) obj. -62.6723 iterations 3
# Cbc0038I Pass  52: suminf.    0.55163 (4) obj. -62.6723 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 749 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 405 rows 758 columns, reduced to 6 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I After 0.08 seconds - Feasibility pump exiting with objective of -62.6487 - took 0.04 seconds
# Cbc0012I Integer solution of -62.648748 found by feasibility pump after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0031I 1 added rows had average density of 6
# Cbc0013I At root node, 7 cuts changed objective from -62.766544 to -62.542115 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 11.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 9.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -62.64874825999999, took 0 iterations and 0 nodes (0.09 seconds)
# Cbc0035I Maximum depth 0, 745 variables fixed on reduced cost
# Cuts at root node changed objective from -62.7665 to -62.5421
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                62.64874826
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.11
#
# Status: Optimal
# Cost: 82.5
# Expected points per week: 62.64874825999999
#     position                       name  price   xPpg_10
# 324       GK               Scott Carson    4.0  4.256209
# 136      DEF               Ivan Perisic    5.5  4.353928
# 170      DEF               Joao Cancelo    7.0  4.913126
# 233      DEF              Marcos Alonso    5.5  4.365412
# 33       DEF               Ben Chilwell    6.0  4.668050
# 354      DEF     Trent Alexander-Arnold    7.5  4.680426
# 219      MID                  Luis Diaz    8.0  4.946331
# 255      MID              Mohamed Salah   13.0  7.254785
# 294      MID            Raheem Sterling   10.0  6.347255
# 304      MID               Riyad Mahrez    8.0  5.306034
# 116      FWD  Gabriel Fernando de Jesus    8.0  4.302405

# %%
ban = []
# ban goalkeepers under 4.5 price
ban = ban + [ix for ix in df.index if (df.loc[ix,'position']=='GK') & (df.loc[ix,'price']<4.5)]
# ban given players
ban = ban + [233, 304, 46, ]#294, 206]#, 31, 176, 196, 289, 270]
my_df = df.drop(ban).copy()

# %%
optimize(my_df, 82.5, 'xPpg_10')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/cf4bc3bba4414d068839a62f7db466e1-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/cf4bc3bba4414d068839a62f7db466e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 397 COLUMNS
# At line 5297 RHS
# At line 5690 BOUNDS
# At line 6417 ENDATA
# Problem MODEL has 392 rows, 726 columns and 2721 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 61.3245 - 0.01 seconds
# Cgl0004I processed model has 388 rows, 726 columns (726 integer (726 of which binary)) and 2537 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -61.3245
# Cbc0038I Before mini branch and bound, 726 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -61.3245 - took 0.00 seconds
# Cbc0012I Integer solution of -61.324457 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective -61.32445703999999, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -61.3245 to -61.3245
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                61.32445704
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.04
#
# Status: Optimal
# Cost: 82.5
# Expected points per week: 61.32445704
#     position                       name  price   xPpg_10
# 97        GK  Ederson Santana de Moraes    5.5  4.042407
# 136      DEF               Ivan Perisic    5.5  4.353928
# 170      DEF               Joao Cancelo    7.0  4.913126
# 299      DEF                Reece James    6.0  4.202483
# 33       DEF               Ben Chilwell    6.0  4.668050
# 354      DEF     Trent Alexander-Arnold    7.5  4.680426
# 139      MID              Jack Grealish    7.0  4.465107
# 219      MID                  Luis Diaz    8.0  4.946331
# 255      MID              Mohamed Salah   13.0  7.254785
# 294      MID            Raheem Sterling   10.0  6.347255
# 137      FWD                 Ivan Toney    7.0  4.195772

# %% [markdown]
# ## With decay

# %%
projections = pd.read_csv('../../data/pre_season_projections.csv', index_col=0)
projections
# Out:
#                    name       team         opp_team  was_home  gameweek  \
# 0   Cedric Alves Soares    Arsenal   Crystal Palace         0         1
# 1   Cedric Alves Soares    Arsenal   Leicester City         1         2
# 2   Cedric Alves Soares    Arsenal      Bournemouth         0         3
# 3   Cedric Alves Soares    Arsenal           Fulham         1         4
# 4   Cedric Alves Soares    Arsenal      Aston Villa         1         5
# ..                  ...        ...              ...       ...       ...
# 5          Ivan Perisic  Tottenham           Fulham         1         6
# 6          Ivan Perisic  Tottenham  Manchester City         0         7
# 7          Ivan Perisic  Tottenham   Leicester City         1         8
# 8          Ivan Perisic  Tottenham          Arsenal         0         9
# 9          Ivan Perisic  Tottenham         Brighton         0        10
#
#           xP
# 0   2.535732
# 1   2.939537
# 2   2.762569
# 3   3.002753
# 4   2.849209
# ..       ...
# 5   5.022785
# 6   3.032787
# 7   4.320365
# 8   3.500115
# 9   3.468761
#
# [3790 rows x 6 columns]

# %%
fpl_data = json.loads(requests.get('https://fantasy.premierleague.com/api/bootstrap-static/').text)
fpl_df = pd.DataFrame(fpl_data['elements'])
fpl_df.set_index('id',inplace=True)
fpl_df['name'] = fpl_df['first_name'] + ' ' + fpl_df['second_name']
fpl_df['name'] = fpl_df['name'].str.normalize('NFD').str.encode('ascii','ignore').str.decode('ascii')
fpl_df['now_cost'] = fpl_df['now_cost'] / 10.0
fpl_df
# Out:
#      chance_of_playing_next_round chance_of_playing_this_round    code  \
# id
# 1                             NaN                         None   58822
# 3                             NaN                         None   84450
# 4                             NaN                         None  153256
# 5                             NaN                         None  156074
# 6                             NaN                         None  167199
# ..                            ...                          ...     ...
# 494                           NaN                         None  501837
# 503                           NaN                         None   19624
# 516                           NaN                         None  432830
# 557                           NaN                         None  246799
# 558                           NaN                         None  530332
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# id
# 1                    0                       0                  0
# 3                    0                       0                  0
# 4                    0                       0                  0
# 5                    0                       0                  0
# 6                    0                       0                  0
# ..                 ...                     ...                ...
# 494                  0                       0                  0
# 503                  0                       0                  0
# 516                  0                       0                  0
# 557                  0                       0                  0
# 558                  0                       0                  0
#
#      cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# id                                                                  ...
# 1                         0                0             2     2.3  ...
# 3                         0                0             3     2.0  ...
# 4                         0                0             3     1.5  ...
# 5                         0                0             2     2.3  ...
# 6                         0                0             3     2.0  ...
# ..                      ...              ...           ...     ...  ...
# 494                       0                0             2     1.5  ...
# 503                       0                0             3     2.0  ...
# 516                       0                0             2     2.3  ...
# 557                       0                0             1     1.5  ...
# 558                       0                0             2     1.5  ...
#
#     threat_rank_type  ict_index_rank ict_index_rank_type  \
# id
# 1                 81             199                  63
# 3                 85             102                  63
# 4                145             287                 130
# 5                113             296                 108
# 6                 60             132                  76
# ..               ...             ...                 ...
# 494              166             426                 166
# 503              111              74                  47
# 516               32             193                  60
# 557               25             417                  47
# 558              167             427                 167
#
#     corners_and_indirect_freekicks_order  corners_and_indirect_freekicks_text  \
# id
# 1                                    2.0
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# ..                                   ...                                  ...
# 494                                  NaN
# 503                                  1.0
# 516                                  NaN
# 557                                  NaN
# 558                                  NaN
#
#     direct_freekicks_order direct_freekicks_text  penalties_order  \
# id
# 1                      3.0                                    NaN
# 3                      NaN                                    NaN
# 4                      NaN                                    NaN
# 5                      NaN                                    NaN
# 6                      4.0                                    NaN
# ..                     ...                   ...              ...
# 494                    NaN                                    NaN
# 503                    1.0                                    NaN
# 516                    NaN                                    NaN
# 557                    NaN                                    NaN
# 558                    NaN                                    NaN
#
#     penalties_text                              name
# id
# 1                                Cedric Alves Soares
# 3                                       Granit Xhaka
# 4                                     Mohamed Elneny
# 5                                        Rob Holding
# 6                                      Thomas Partey
# ..             ...                               ...
# 494                       Yerson Mosquera Valdelamar
# 503                 Joao Filipe Iria Santos Moutinho
# 516                                   Nathan Collins
# 557                                    Jackson Smith
# 558                                 Hugo Bueno Lopez
#
# [558 rows x 67 columns]

# %%
0.925**9
# Out:
# 0.4957646934321482

# %%
first_gameweek = 1
projections['xP_decay'] = projections['xP']*0.925**(projections['gameweek']-first_gameweek)
projections
# Out:
#                    name       team         opp_team  was_home  gameweek  \
# 0   Cedric Alves Soares    Arsenal   Crystal Palace         0         1
# 1   Cedric Alves Soares    Arsenal   Leicester City         1         2
# 2   Cedric Alves Soares    Arsenal      Bournemouth         0         3
# 3   Cedric Alves Soares    Arsenal           Fulham         1         4
# 4   Cedric Alves Soares    Arsenal      Aston Villa         1         5
# ..                  ...        ...              ...       ...       ...
# 5          Ivan Perisic  Tottenham           Fulham         1         6
# 6          Ivan Perisic  Tottenham  Manchester City         0         7
# 7          Ivan Perisic  Tottenham   Leicester City         1         8
# 8          Ivan Perisic  Tottenham          Arsenal         0         9
# 9          Ivan Perisic  Tottenham         Brighton         0        10
#
#           xP  xP_decay
# 0   2.535732  2.535732
# 1   2.939537  2.719071
# 2   2.762569  2.363723
# 3   3.002753  2.376538
# 4   2.849209  2.085889
# ..       ...       ...
# 5   5.022785  3.401365
# 6   3.032787  1.899732
# 7   4.320365  2.503298
# 8   3.500115  1.875928
# 9   3.468761  1.719689
#
# [3790 rows x 7 columns]

# %%
# calculate ppg over 10 game horizon and geometric mean of ppg and cost
xPpg_10_decay = projections[projections['gameweek']<=11].groupby(by=['name']).sum()['xP_decay'] 
xPpg_10_decay = xPpg_10_decay.to_frame()
xPpg_10_decay = xPpg_10_decay.reset_index()
#xPpg_10_decay = xPpg_10_decay.rename(columns={'xP_decay':'xPpg_10_decay'})
xPpg_10_decay['price'] = [fpl_df.loc[fpl_df['name']==name, 'now_cost'].values[0] for name in xPpg_10_decay['name']]
xPpg_10_decay['value'] = xPpg_10_decay['xP_decay'] / xPpg_10_decay['price']
xPpg_10_decay['geometric_valuePoints'] = np.sqrt(xPpg_10_decay['xP_decay'] * xPpg_10_decay['value'])
xPpg_10_decay['position'] = [fpl_df.loc[fpl_df['name']==name, 'element_type'].values[0] for name in xPpg_10_decay['name']]
position_dict={1:'GK', 2:'DEF', 3:'MID', 4:'FWD'}
xPpg_10_decay['position'] = xPpg_10_decay['position'].map(position_dict)
xPpg_10_decay['position'] = pd.Categorical(xPpg_10_decay['position'], ['GK','DEF','MID','FWD'])
xPpg_10_decay['team'] = [projections.loc[projections['name']==name, 'team'].head(1).values[0] for name in xPpg_10_decay['name']]
xPpg_10_decay
# Out:
#                    name   xP_decay  price     value  geometric_valuePoints  \
# 0       Aaron Cresswell  20.139688    5.0  4.027938               9.006742
# 1        Aaron Ramsdale  24.251080    5.0  4.850216              10.845413
# 2     Aaron Wan-Bissaka  19.873680    4.5  4.416373               9.368543
# 3    Abdoulaye Doucoure  17.992720    5.5  3.271404               7.672122
# 4        Adam Armstrong  18.573375    5.5  3.376977               7.919714
# ..                  ...        ...    ...       ...                    ...
# 374          Yerry Mina  17.765440    4.5  3.947876               8.374709
# 375         Yoane Wissa  18.854317    5.5  3.428058               8.039508
# 376     Youri Tielemans  20.822449    6.5  3.203454               8.167236
# 377       Yves Bissouma  18.279336    5.0  3.655867               8.174768
# 378        Zack Steffen  27.122230    4.0  6.780557              13.561115
#
#     position             team
# 0        DEF         West Ham
# 1         GK          Arsenal
# 2        DEF   Manchester Utd
# 3        MID          Everton
# 4        FWD      Southampton
# ..       ...              ...
# 374      DEF          Everton
# 375      MID        Brentford
# 376      MID   Leicester City
# 377      MID        Tottenham
# 378       GK  Manchester City
#
# [379 rows x 7 columns]

# %%
optimize(xPpg_10_decay, 82.5, 'xP_decay')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/9c9e308328304c1aa9a39438f51014ad-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/9c9e308328304c1aa9a39438f51014ad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 413 COLUMNS
# At line 5523 RHS
# At line 5932 BOUNDS
# At line 6691 ENDATA
# Problem MODEL has 408 rows, 758 columns and 2835 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 455.814 - 0.01 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 405 rows, 758 columns (758 integer (758 of which binary)) and 2653 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.45455
# Cbc0038I Solution found of -452.536
# Cbc0038I Before mini branch and bound, 754 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 405 rows 758 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -452.863
# Cbc0038I Reduced cost fixing fixed 718 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.08373 (2) obj. -452.863 iterations 6
# Cbc0038I Pass   2: suminf.    0.72727 (2) obj. -455.383 iterations 5
# Cbc0038I Pass   3: suminf.    1.21228 (4) obj. -452.863 iterations 9
# Cbc0038I Pass   4: suminf.    0.76116 (3) obj. -452.863 iterations 4
# Cbc0038I Pass   5: suminf.    0.87915 (2) obj. -452.863 iterations 3
# Cbc0038I Pass   6: suminf.    0.84781 (3) obj. -452.863 iterations 3
# Cbc0038I Pass   7: suminf.    0.83766 (3) obj. -452.863 iterations 7
# Cbc0038I Pass   8: suminf.    0.72248 (2) obj. -452.863 iterations 4
# Cbc0038I Pass   9: suminf.    1.08323 (5) obj. -452.863 iterations 5
# Cbc0038I Pass  10: suminf.    0.72248 (2) obj. -452.863 iterations 4
# Cbc0038I Pass  11: suminf.    1.09004 (4) obj. -452.863 iterations 2
# Cbc0038I Pass  12: suminf.    2.00000 (6) obj. -452.863 iterations 9
# Cbc0038I Pass  13: suminf.    0.10325 (2) obj. -452.863 iterations 5
# Cbc0038I Pass  14: suminf.    0.08373 (2) obj. -452.863 iterations 4
# Cbc0038I Pass  15: suminf.    0.72727 (2) obj. -455.383 iterations 3
# Cbc0038I Pass  16: suminf.    1.03310 (5) obj. -452.863 iterations 7
# Cbc0038I Pass  17: suminf.    0.63752 (3) obj. -452.863 iterations 5
# Cbc0038I Pass  18: suminf.    0.87358 (2) obj. -452.863 iterations 5
# Cbc0038I Pass  19: suminf.    0.76860 (3) obj. -452.863 iterations 5
# Cbc0038I Pass  20: suminf.    1.00801 (5) obj. -452.863 iterations 5
# Cbc0038I Pass  21: suminf.    0.76860 (3) obj. -452.863 iterations 4
# Cbc0038I Pass  22: suminf.    1.61844 (4) obj. -452.863 iterations 8
# Cbc0038I Pass  23: suminf.    1.61844 (4) obj. -452.863 iterations 1
# Cbc0038I Pass  24: suminf.    0.08373 (2) obj. -452.863 iterations 4
# Cbc0038I Pass  25: suminf.    0.72727 (2) obj. -455.383 iterations 4
# Cbc0038I Pass  26: suminf.    1.05675 (4) obj. -452.863 iterations 7
# Cbc0038I Pass  27: suminf.    0.25000 (2) obj. -454.512 iterations 5
# Cbc0038I Pass  28: suminf.    1.00000 (3) obj. -452.863 iterations 5
# Cbc0038I Pass  29: suminf.    0.33333 (2) obj. -453.71 iterations 2
# Cbc0038I Pass  30: suminf.    1.64992 (4) obj. -452.863 iterations 10
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 734 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 405 rows 758 columns, reduced to 9 rows 24 columns
# Cbc0038I Mini branch and bound improved solution from -452.536 to -454.976 (0.06 seconds)
# Cbc0038I Round again with cutoff of -455.144
# Cbc0038I Reduced cost fixing fixed 747 variables on major pass 3
# Cbc0038I Pass  30: suminf.    1.15708 (4) obj. -455.144 iterations 3
# Cbc0038I Pass  31: suminf.    1.56011 (4) obj. -455.144 iterations 4
# Cbc0038I Pass  32: suminf.    1.56011 (4) obj. -455.144 iterations 2
# Cbc0038I Pass  33: suminf.    1.45455 (4) obj. -455.814 iterations 3
# Cbc0038I Pass  34: suminf.    1.56011 (4) obj. -455.144 iterations 1
# Cbc0038I Pass  35: suminf.    1.95871 (5) obj. -455.144 iterations 5
# Cbc0038I Pass  36: suminf.    1.85105 (5) obj. -455.144 iterations 2
# Cbc0038I Pass  37: suminf.    0.57936 (4) obj. -455.144 iterations 7
# Cbc0038I Pass  38: suminf.    0.57936 (4) obj. -455.144 iterations 0
# Cbc0038I Pass  39: suminf.    1.56011 (4) obj. -455.144 iterations 5
# Cbc0038I Pass  40: suminf.    1.56011 (4) obj. -455.144 iterations 1
# Cbc0038I Pass  41: suminf.    1.45455 (4) obj. -455.814 iterations 3
# Cbc0038I Pass  42: suminf.    1.15708 (4) obj. -455.144 iterations 1
# Cbc0038I Pass  43: suminf.    1.54920 (4) obj. -455.144 iterations 4
# Cbc0038I Pass  44: suminf.    1.15708 (4) obj. -455.144 iterations 4
# Cbc0038I Pass  45: suminf.    1.56011 (4) obj. -455.144 iterations 2
# Cbc0038I Pass  46: suminf.    1.56011 (4) obj. -455.144 iterations 1
# Cbc0038I Pass  47: suminf.    1.45455 (4) obj. -455.814 iterations 3
# Cbc0038I Pass  48: suminf.    2.00000 (4) obj. -455.389 iterations 6
# Cbc0038I Pass  49: suminf.    1.85105 (5) obj. -455.144 iterations 3
# Cbc0038I Pass  50: suminf.    0.57936 (4) obj. -455.144 iterations 7
# Cbc0038I Pass  51: suminf.    0.57936 (4) obj. -455.144 iterations 0
# Cbc0038I Pass  52: suminf.    1.56011 (4) obj. -455.144 iterations 5
# Cbc0038I Pass  53: suminf.    1.56011 (4) obj. -455.144 iterations 2
# Cbc0038I Pass  54: suminf.    1.45455 (4) obj. -455.814 iterations 3
# Cbc0038I Pass  55: suminf.    1.15708 (4) obj. -455.144 iterations 1
# Cbc0038I Pass  56: suminf.    1.54920 (4) obj. -455.144 iterations 4
# Cbc0038I Pass  57: suminf.    1.15708 (4) obj. -455.144 iterations 3
# Cbc0038I Pass  58: suminf.    1.56011 (4) obj. -455.144 iterations 4
# Cbc0038I Pass  59: suminf.    1.56011 (4) obj. -455.144 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 750 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 405 rows 758 columns, reduced to 6 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I After 0.08 seconds - Feasibility pump exiting with objective of -454.976 - took 0.04 seconds
# Cbc0012I Integer solution of -454.97611 found by feasibility pump after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0031I 1 added rows had average density of 6
# Cbc0013I At root node, 9 cuts changed objective from -455.81424 to -454.05839 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 11.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 5 row cuts average 9.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -454.97610756212, took 0 iterations and 0 nodes (0.09 seconds)
# Cbc0035I Maximum depth 0, 745 variables fixed on reduced cost
# Cuts at root node changed objective from -455.814 to -454.058
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                454.97610756
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.11
#
# Status: Optimal
# Cost: 82.5
#     position                       name  price   xP_decay
# 324       GK               Scott Carson    4.0  30.406021
# 136      DEF               Ivan Perisic    5.5  32.228440
# 170      DEF               Joao Cancelo    7.0  35.607784
# 233      DEF              Marcos Alonso    5.5  31.497759
# 33       DEF               Ben Chilwell    6.0  33.762470
# 354      DEF     Trent Alexander-Arnold    7.5  34.076957
# 219      MID                  Luis Diaz    8.0  36.364580
# 255      MID              Mohamed Salah   13.0  52.878728
# 294      MID            Raheem Sterling   10.0  45.669921
# 304      MID               Riyad Mahrez    8.0  38.297042
# 116      FWD  Gabriel Fernando de Jesus    8.0  31.307677

# %%
ban = []
# ban goalkeepers under 4.5 price
ban = ban + [ix for ix in df.index if (df.loc[ix,'position']=='GK') & (df.loc[ix,'price']<4.5)]
# ban given players
ban = ban + [233, 304, 46, 294, 270, 289, 206, 176]#, 31, 137, 369, 139, , 181, 196]
my_df = xPpg_10_decay.drop(ban).copy()

# %%
optimize(my_df, 82.5, 'xP_decay')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/0f9bfbdfc0fa4b55819124656294ee22-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/0f9bfbdfc0fa4b55819124656294ee22-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 392 COLUMNS
# At line 5224 RHS
# At line 5612 BOUNDS
# At line 6329 ENDATA
# Problem MODEL has 387 rows, 716 columns and 2683 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 438.647 - 0.01 seconds
# Cgl0004I processed model has 383 rows, 716 columns (716 integer (716 of which binary)) and 2502 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.8
# Cbc0038I Solution found of -434.875
# Cbc0038I Before mini branch and bound, 714 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 383 rows 716 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -435.252
# Cbc0038I Reduced cost fixing fixed 667 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.08000 (2) obj. -435.252 iterations 5
# Cbc0038I Pass   2: suminf.    1.00000 (2) obj. -436.437 iterations 5
# Cbc0038I Pass   3: suminf.    0.84934 (2) obj. -435.252 iterations 3
# Cbc0038I Pass   4: suminf.    0.98914 (3) obj. -435.252 iterations 4
# Cbc0038I Pass   5: suminf.    0.98914 (3) obj. -435.252 iterations 3
# Cbc0038I Pass   6: suminf.    0.08000 (2) obj. -435.252 iterations 4
# Cbc0038I Pass   7: suminf.    0.08000 (2) obj. -435.252 iterations 0
# Cbc0038I Pass   8: suminf.    1.00000 (2) obj. -436.437 iterations 5
# Cbc0038I Pass   9: suminf.    0.84934 (2) obj. -435.252 iterations 2
# Cbc0038I Pass  10: suminf.    1.00000 (3) obj. -435.252 iterations 4
# Cbc0038I Pass  11: suminf.    1.00000 (3) obj. -435.252 iterations 4
# Cbc0038I Pass  12: suminf.    0.75000 (3) obj. -435.252 iterations 5
# Cbc0038I Pass  13: suminf.    0.58527 (3) obj. -435.252 iterations 3
# Cbc0038I Pass  14: suminf.    0.63452 (2) obj. -435.252 iterations 3
# Cbc0038I Pass  15: suminf.    0.95526 (3) obj. -435.252 iterations 9
# Cbc0038I Pass  16: suminf.    0.16667 (2) obj. -435.857 iterations 6
# Cbc0038I Pass  17: suminf.    0.24350 (2) obj. -435.252 iterations 4
# Cbc0038I Pass  18: suminf.    1.14671 (4) obj. -435.252 iterations 6
# Cbc0038I Pass  19: suminf.    1.14671 (4) obj. -435.252 iterations 1
# Cbc0038I Pass  20: suminf.    0.08000 (2) obj. -435.252 iterations 3
# Cbc0038I Pass  21: suminf.    1.00000 (2) obj. -436.437 iterations 5
# Cbc0038I Pass  22: suminf.    0.84934 (2) obj. -435.252 iterations 4
# Cbc0038I Pass  23: suminf.    0.08000 (2) obj. -435.252 iterations 4
# Cbc0038I Pass  24: suminf.    1.54554 (5) obj. -435.252 iterations 7
# Cbc0038I Pass  25: suminf.    0.57143 (3) obj. -435.252 iterations 5
# Cbc0038I Pass  26: suminf.    0.66836 (2) obj. -435.252 iterations 2
# Cbc0038I Pass  27: suminf.    0.66667 (3) obj. -435.252 iterations 2
# Cbc0038I Pass  28: suminf.    1.21970 (6) obj. -435.252 iterations 8
# Cbc0038I Pass  29: suminf.    0.50000 (2) obj. -435.497 iterations 6
# Cbc0038I Pass  30: suminf.    0.53118 (2) obj. -435.252 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 694 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 383 rows 716 columns, reduced to 9 rows 22 columns
# Cbc0038I Mini branch and bound improved solution from -434.875 to -436.585 (0.07 seconds)
# Cbc0038I Round again with cutoff of -436.997
# Cbc0038I Reduced cost fixing fixed 691 variables on major pass 3
# Cbc0038I Pass  30: suminf.    0.45017 (2) obj. -436.997 iterations 0
# Cbc0038I Pass  31: suminf.    0.90909 (2) obj. -436.999 iterations 4
# Cbc0038I Pass  32: suminf.    0.90889 (2) obj. -436.997 iterations 2
# Cbc0038I Pass  33: suminf.    2.00000 (6) obj. -436.997 iterations 8
# Cbc0038I Pass  34: suminf.    0.89601 (3) obj. -436.997 iterations 3
# Cbc0038I Pass  35: suminf.    0.25552 (2) obj. -436.997 iterations 3
# Cbc0038I Pass  36: suminf.    0.89601 (3) obj. -436.997 iterations 4
# Cbc0038I Pass  37: suminf.    0.79639 (5) obj. -436.997 iterations 11
# Cbc0038I Pass  38: suminf.    0.12888 (2) obj. -436.997 iterations 9
# Cbc0038I Pass  39: suminf.    0.44416 (3) obj. -436.997 iterations 5
# Cbc0038I Pass  40: suminf.    3.16279 (8) obj. -436.997 iterations 10
# Cbc0038I Pass  41: suminf.    0.76973 (2) obj. -436.997 iterations 5
# Cbc0038I Pass  42: suminf.    0.92814 (3) obj. -436.997 iterations 6
# Cbc0038I Pass  43: suminf.    0.76973 (2) obj. -436.997 iterations 3
# Cbc0038I Pass  44: suminf.    0.45426 (4) obj. -436.997 iterations 7
# Cbc0038I Pass  45: suminf.    0.39366 (3) obj. -436.997 iterations 5
# Cbc0038I Pass  46: suminf.    0.87339 (3) obj. -436.997 iterations 5
# Cbc0038I Pass  47: suminf.    0.66667 (2) obj. -437.173 iterations 2
# Cbc0038I Pass  48: suminf.    0.68735 (2) obj. -436.997 iterations 1
# Cbc0038I Pass  49: suminf.    2.57051 (6) obj. -436.997 iterations 5
# Cbc0038I Pass  50: suminf.    0.90909 (2) obj. -436.999 iterations 6
# Cbc0038I Pass  51: suminf.    0.90889 (2) obj. -436.997 iterations 3
# Cbc0038I Pass  52: suminf.    1.03821 (5) obj. -436.997 iterations 4
# Cbc0038I Pass  53: suminf.    0.75275 (3) obj. -436.997 iterations 2
# Cbc0038I Pass  54: suminf.    1.46356 (4) obj. -436.997 iterations 3
# Cbc0038I Pass  55: suminf.    1.46356 (4) obj. -436.997 iterations 2
# Cbc0038I Pass  56: suminf.    0.45017 (2) obj. -436.997 iterations 3
# Cbc0038I Pass  57: suminf.    0.90909 (2) obj. -436.999 iterations 5
# Cbc0038I Pass  58: suminf.    0.90889 (2) obj. -436.997 iterations 3
# Cbc0038I Pass  59: suminf.    0.90889 (2) obj. -436.997 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 700 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 383 rows 716 columns, reduced to 9 rows 16 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I After 0.08 seconds - Feasibility pump exiting with objective of -436.585 - took 0.05 seconds
# Cbc0012I Integer solution of -436.58498 found by feasibility pump after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0038I Full problem 383 rows 716 columns, reduced to 6 rows 7 columns
# Cbc0031I 6 added rows had average density of 19.333333
# Cbc0013I At root node, 6 cuts changed objective from -438.64664 to -436.93098 in 14 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 98 row cuts average 19.8 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 12 row cuts average 9.7 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 6 row cuts average 20.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 54 row cuts average 20.3 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -436.58498 best solution, best possible -436.93009 (0.13 seconds)
# Cbc0016I Integer solution of -436.67654 found by strong branching after 131 iterations and 1 nodes (0.13 seconds)
# Cbc0001I Search completed - best objective -436.67654121333, took 142 iterations and 2 nodes (0.13 seconds)
# Cbc0032I Strong branching done 36 times (153 iterations), fathomed 2 nodes and fixed 1 variables
# Cbc0035I Maximum depth 0, 706 variables fixed on reduced cost
# Cuts at root node changed objective from -438.647 to -436.93
# Probing was tried 14 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Gomory was tried 17 times and created 98 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Knapsack was tried 17 times and created 16 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# Clique was tried 14 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 14 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 14 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 14 times and created 54 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
#
# Result - Optimal solution found
#
# Objective value:                436.67654121
# Enumerated nodes:               2
# Total iterations:               142
# Time (CPU seconds):             0.13
# Time (Wallclock seconds):       0.14
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.14   (Wallclock seconds):       0.15
#
# Status: Optimal
# Cost: 82.5
#     position                   name  price   xP_decay
# 16        GK  Alisson Ramses Becker    5.5  29.342055
# 136      DEF           Ivan Perisic    5.5  32.228440
# 170      DEF           Joao Cancelo    7.0  35.607784
# 231      DEF  Marc Cucurella Saseta    5.0  25.257593
# 299      DEF            Reece James    6.0  30.269099
# 33       DEF           Ben Chilwell    6.0  33.762470
# 139      MID          Jack Grealish    7.0  32.529421
# 219      MID              Luis Diaz    8.0  36.364580
# 241      MID            Mason Mount    8.0  34.625704
# 255      MID          Mohamed Salah   13.0  52.878728
# 106      FWD          Erling Haland   11.5  40.931938
