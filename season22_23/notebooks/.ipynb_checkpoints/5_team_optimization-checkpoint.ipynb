# %% [markdown]
# TO DO:
# - Add option to force players into the team, i.e., optimize given certain player are already locked in

# %%
# previous gameweek
gameweek=25

# %%
import pandas as pd
import numpy as np
import json
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable

# %%
# fetch player_dict 
with open('../data/player_name_dict.txt', 'r') as f:
    player_name_dict_as_text = f.read()
    player_name_dict = json.loads(player_name_dict_as_text)

# %% [markdown]
# # Solver definition

# %%
# function to solve the optimization problem
def optimize(df, max_price, expected_column):
    
    # PRELIMINARIES

    # Create the model
    model = LpProblem(name="FPL", sense=LpMaximize)    
    variables = [LpVariable(name=f'{ix}', cat='Binary') for ix in df.index]
    captaincy_variables = [LpVariable(name=f'cap_{ix}', cat='Binary') for ix in df.index]
    prices = [df.loc[ix,'price'] for ix in df.index]
    # measure of player quality
    expected_points = [df.loc[ix,expected_column] for ix in df.index]
    goalkeepers = [1.0 if df.loc[ix,'position']=='GK' else 0.0 for ix in df.index]
    defenders = [1.0 if df.loc[ix,'position']=='DEF' else 0.0 for ix in df.index]
    midfielders = [1.0 if df.loc[ix,'position']=='MID' else 0.0 for ix in df.index]
    forwards = [1.0 if df.loc[ix,'position']=='FWD' else 0.0 for ix in df.index]
    teams = []
    for team in df['team'].unique():
        teams.append( [1.0 if df.loc[ix,'team']==team else 0.0 for ix in df.index] )

    # CONSTRAINTS

    # select 11 players
    model += lpSum(variables) == 11
    # select 1 captain
    model += lpSum(captaincy_variables) == 1
    # captain must be one of the 11 players in the team
    for i in range(0,len(variables)):
        model += captaincy_variables[i] <= variables[i]
    # set maximum price for starting 11
    model += np.dot(prices,variables) <= max_price
    # only 1 goalkeeper
    model += np.dot(goalkeepers,variables) == 1
    # at least 3 defenders
    model += np.dot(defenders,variables) >= 3
    # at most 5 defenders
    model += np.dot(defenders,variables) <= 5
    # at most 5 midfielders
    model += np.dot(midfielders,variables) <= 5
    # at least 1 forward
    model += np.dot(forwards,variables) >= 1
    # at most 3 forwards
    model += np.dot(forwards,variables) <= 3
    # max 3 players from any given team
    for team in teams:
        model += np.dot(team,variables) <= 3

    # OBJECTIVE
    # the second part doubles the captain's points
    model += np.dot(expected_points,variables) + np.dot(expected_points,captaincy_variables)

    # SOLVE OPTIMIZATION

    status = model.solve()
    print(f'Status: {LpStatus[model.status]}')
    #print(f'Mean total points per gameweek: {model.objective.value()}')

    players = [str(var) for var in model.variables() if var.value()==1]
    captain = [player for player in players if 'cap' in player]
    captain = int(captain[0].replace('cap_', ''))
    players = [int(player) for player in players if 'cap' not in player]
    dream_team = df.loc[players]
    cost = (dream_team['price']).sum()
    exp_points = dream_team[expected_column].sum() + df.loc[captain, expected_column]
    print(f'Cost: {cost}')
    print(f'Expected points per week: {exp_points}')
    
    display(dream_team[['position','name', 'team', 'price',expected_column]].sort_values('position'))
    
    return players

# %% [markdown]
# # Data

# %%
#projections = pd.read_csv(f'../point_projections/xP_projections_week{gameweek}.csv', index_col=0)
projections = pd.read_csv(f'../point_projections/collective_xP_projections_week{gameweek}.csv', index_col=0)
projections = projections.rename(columns={'xP':'projected_points'})
projections.head(5)
# Out:
#            name     team        opp_team  was_home  gameweek  \
# 0  Granit Xhaka  Arsenal     Bournemouth         1        26
# 1  Granit Xhaka  Arsenal          Fulham         0        27
# 2  Granit Xhaka  Arsenal  Crystal Palace         1        28
# 3  Granit Xhaka  Arsenal    Leeds United         1        29
# 4  Granit Xhaka  Arsenal       Liverpool         0        30
#
#    projected_points       std
# 0          3.605445  0.220236
# 1          3.195131  0.224736
# 2          3.579107  0.198305
# 3          3.320841  0.155277
# 4          2.510845  0.133115

# %%
# decay for future projected points to model uncertainty increasing over time
decay_coeff = 0.875
projections['projected_points_with_decay'] = ( projections['projected_points']*decay_coeff
                                              **(projections['gameweek']-(gameweek+1)) )
projections.head(5)
# Out:
#            name     team        opp_team  was_home  gameweek  \
# 0  Granit Xhaka  Arsenal     Bournemouth         1        26
# 1  Granit Xhaka  Arsenal          Fulham         0        27
# 2  Granit Xhaka  Arsenal  Crystal Palace         1        28
# 3  Granit Xhaka  Arsenal    Leeds United         1        29
# 4  Granit Xhaka  Arsenal       Liverpool         0        30
#
#    projected_points       std  projected_points_with_decay
# 0          3.605445  0.220236                     3.605445
# 1          3.195131  0.224736                     2.795739
# 2          3.579107  0.198305                     2.740254
# 3          3.320841  0.155277                     2.224704
# 4          2.510845  0.133115                     1.471811

# %%
fpl_df = pd.read_csv(f'../data/fpl_data/fpl_week_{gameweek}.csv', index_col=0)
fpl_df['name'] = fpl_df['name'].map(player_name_dict).fillna(fpl_df['name'])
fpl_df.head(5)
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                           NaN                           NaN   84450
# 1                           0.0                           0.0  153256
# 2                           NaN                           NaN  156074
# 3                         100.0                          75.0  167199
# 4                         100.0                         100.0  184029
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                 -1
# 1                  0                       0                 -4
# 2                  0                       0                 -3
# 3                  0                       0                 -3
# 4                  0                       0                  5
#
#    cost_change_start_fall  dreamteam_count  element_type  ep_next  ...  \
# 0                       1                1             3      3.3  ...
# 1                       4                1             3      0.0  ...
# 2                       3                0             2      1.2  ...
# 3                       3                0             3      2.0  ...
# 4                      -5                4             3      5.2  ...
#
#     season            name position  GW  value    selected transfers_balance  \
# 0  2022-23    Granit Xhaka      MID  25    4.9   303765.39             -7902
# 1  2022-23  Mohamed Elneny      MID  25    4.1    67503.42             -1275
# 2  2022-23     Rob Holding      DEF  25    4.2    11250.57               -54
# 3  2022-23   Thomas Partey      MID  25    4.7    45002.28              -348
# 4  2022-23  Martin degaard      MID  25    7.0  4308968.31            -29215
#
#   opp_team_name  kickoff_time was_home
# 0           NaN           NaN      1.0
# 1           NaN           NaN      1.0
# 2           NaN           NaN      1.0
# 3           NaN           NaN      1.0
# 4           NaN           NaN      1.0
#
# [5 rows x 98 columns]

# %%
# choose time horizon for optimization
horizon = 10

# create dataframe to be given as input for optimization
df = projections[projections['gameweek']<=gameweek+horizon].groupby(by=['name']).mean()\
                                                        [['projected_points','projected_points_with_decay', 'std']] 
#df = df.to_frame()
df = df.reset_index()
df = df.rename(columns={'projected_points':'projected_points_per_game'})
#df['team'] = [fpl_df.loc[fpl_df['name']==name, 'team'].values[0] for name in df['name']]
df['price'] = [fpl_df.loc[fpl_df['name']==name, 'value'].values[0] for name in df['name']]
df['position'] = [fpl_df.loc[fpl_df['name']==name, 'element_type'].values[0] for name in df['name']]
position_dict={1:'GK', 2:'DEF', 3:'MID', 4:'FWD'}
df['position'] = df['position'].map(position_dict)
df['position'] = pd.Categorical(df['position'], ['GK','DEF','MID','FWD'])
df['team'] = [projections.loc[projections['name']==name, 'team'].head(1).values[0] for name in df['name']]
df['minutes'] = [fpl_df.loc[fpl_df['name']==name, 'minutes'].values[0] for name in df['name']]
# re-order columns
df = df[['name', 'team', 'position', 'price', 'minutes', 'projected_points_per_game', 'projected_points_with_decay', 'std']]
df.head(5)
# Out:
# /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/ipykernel_76602/2245439599.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = projections[projections['gameweek']<=gameweek+horizon].groupby(by=['name']).mean()\
#                  name            team position  price  minutes  \
# 0     Aaron Cresswell        West Ham      DEF    4.7     1578
# 1        Aaron Hickey       Brentford      DEF    4.9      815
# 2      Aaron Ramsdale         Arsenal       GK    4.9     2250
# 3   Aaron Wan-Bissaka  Manchester Utd      DEF    4.3      646
# 4  Abdoulaye Doucoure         Everton      MID    5.3      660
#
#    projected_points_per_game  projected_points_with_decay       std
# 0                   2.982367                     1.730514  0.109547
# 1                   2.543225                     1.598735  0.086609
# 2                   3.458309                     2.109378  0.167265
# 3                   2.840811                     1.643773  0.115318
# 4                   2.248236                     1.329925  0.131267

# %%
# remove players who do not have enough minutes played
cutoff = 450
df = df[df['minutes']>=cutoff]

# edit some player prices according to my selling price
df.loc[df['name']=='Erling Haaland', 'price'] = 11.8
df.loc[df['name']=='Martinelli', 'price'] = 6.3

# %% [markdown]
# # Optimization

# %%
team_value = 101.7
money_in_the_bank = 0.6
allowed_bench_value = 17.5
max_price = team_value + money_in_the_bank - allowed_bench_value

# %% [markdown]
# ## Without decay

# %%
players = optimize(df, max_price, 'projected_points_per_game')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/91e01f958ce24c5c839ff68ad77dc08a-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/91e01f958ce24c5c839ff68ad77dc08a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 333 COLUMNS
# At line 4367 RHS
# At line 4696 BOUNDS
# At line 5295 ENDATA
# Problem MODEL has 328 rows, 598 columns and 2239 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 59.3616 - 0.00 seconds
# Cgl0004I processed model has 326 rows, 598 columns (598 integer (598 of which binary)) and 2093 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.285714
# Cbc0038I Pass   1: suminf.    0.05063 (2) obj. -59.3079 iterations 6
# Cbc0038I Solution found of -56.0714
# Cbc0038I Before mini branch and bound, 594 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 326 rows 598 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -56.0714 to -59.1795 (0.04 seconds)
# Cbc0038I Round again with cutoff of -59.1977
# Cbc0038I Reduced cost fixing fixed 581 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.13793 (2) obj. -59.3304 iterations 5
# Cbc0038I Pass   3: suminf.    0.99849 (3) obj. -59.1977 iterations 4
# Cbc0038I Pass   4: suminf.    0.27092 (2) obj. -59.1977 iterations 4
# Cbc0038I Pass   5: suminf.    0.07407 (2) obj. -59.2353 iterations 2
# Cbc0038I Pass   6: suminf.    0.27210 (3) obj. -59.1977 iterations 2
# Cbc0038I Pass   7: suminf.    1.26438 (5) obj. -59.1977 iterations 7
# Cbc0038I Pass   8: suminf.    0.44716 (2) obj. -59.1977 iterations 3
# Cbc0038I Pass   9: suminf.    0.91215 (3) obj. -59.1977 iterations 5
# Cbc0038I Pass  10: suminf.    0.95006 (2) obj. -59.1977 iterations 2
# Cbc0038I Pass  11: suminf.    0.95006 (2) obj. -59.1977 iterations 0
# Cbc0038I Pass  12: suminf.    1.29329 (4) obj. -59.1977 iterations 2
# Cbc0038I Pass  13: suminf.    0.92620 (5) obj. -59.1977 iterations 2
# Cbc0038I Pass  14: suminf.    0.90259 (4) obj. -59.1977 iterations 1
# Cbc0038I Pass  15: suminf.    1.00000 (3) obj. -59.1977 iterations 3
# Cbc0038I Pass  16: suminf.    0.10482 (2) obj. -59.1977 iterations 3
# Cbc0038I Solution found of -59.2483
# Cbc0038I Rounding solution of -59.2561 is better than previous of -59.2483
#
# Cbc0038I Before mini branch and bound, 585 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 326 rows 598 columns, reduced to 6 rows 11 columns
# Cbc0038I Mini branch and bound improved solution from -59.2561 to -59.2778 (0.06 seconds)
# Cbc0038I Round again with cutoff of -59.2945
# Cbc0038I Reduced cost fixing fixed 585 variables on major pass 3
# Cbc0038I Pass  17: suminf.    0.13793 (2) obj. -59.3304 iterations 0
# Cbc0038I Pass  18: suminf.    0.21820 (2) obj. -59.2945 iterations 3
# Cbc0038I Pass  19: suminf.    0.82039 (3) obj. -59.2945 iterations 4
# Cbc0038I Pass  20: suminf.    0.80305 (4) obj. -59.2945 iterations 2
# Cbc0038I Pass  21: suminf.    0.48012 (2) obj. -59.2945 iterations 2
# Cbc0038I Pass  22: suminf.    0.13793 (2) obj. -59.3304 iterations 4
# Cbc0038I Pass  23: suminf.    0.25000 (2) obj. -59.3498 iterations 1
# Cbc0038I Pass  24: suminf.    0.80305 (4) obj. -59.2945 iterations 3
# Cbc0038I Pass  25: suminf.    0.83269 (4) obj. -59.2945 iterations 1
# Cbc0038I Pass  26: suminf.    0.40025 (2) obj. -59.2945 iterations 4
# Cbc0038I Pass  27: suminf.    0.40025 (2) obj. -59.2945 iterations 0
# Cbc0038I Pass  28: suminf.    1.00000 (3) obj. -59.2945 iterations 2
# Cbc0038I Pass  29: suminf.    0.40025 (2) obj. -59.2945 iterations 2
# Cbc0038I Pass  30: suminf.    1.00000 (3) obj. -59.2945 iterations 2
# Cbc0038I Pass  31: suminf.    1.00000 (3) obj. -59.2945 iterations 0
# Cbc0038I Pass  32: suminf.    0.40025 (2) obj. -59.2945 iterations 1
# Cbc0038I Pass  33: suminf.    0.40025 (2) obj. -59.2945 iterations 0
# Cbc0038I Pass  34: suminf.    1.00000 (3) obj. -59.2945 iterations 2
# Cbc0038I Pass  35: suminf.    0.40025 (2) obj. -59.2945 iterations 2
# Cbc0038I Pass  36: suminf.    0.82039 (3) obj. -59.2945 iterations 3
# Cbc0038I Pass  37: suminf.    0.80305 (4) obj. -59.2945 iterations 1
# Cbc0038I Pass  38: suminf.    0.48012 (2) obj. -59.2945 iterations 2
# Cbc0038I Pass  39: suminf.    0.13793 (2) obj. -59.3304 iterations 4
# Cbc0038I Pass  40: suminf.    0.21820 (2) obj. -59.2945 iterations 2
# Cbc0038I Pass  41: suminf.    1.18343 (4) obj. -59.2945 iterations 8
# Cbc0038I Pass  42: suminf.    0.56000 (2) obj. -59.3036 iterations 5
# Cbc0038I Pass  43: suminf.    0.60767 (2) obj. -59.2945 iterations 2
# Cbc0038I Pass  44: suminf.    0.99664 (2) obj. -59.2945 iterations 1
# Cbc0038I Pass  45: suminf.    0.99664 (2) obj. -59.2945 iterations 0
# Cbc0038I Pass  46: suminf.    0.99664 (2) obj. -59.2945 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 588 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 326 rows 598 columns, reduced to 6 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -59.2778 - took 0.04 seconds
# Cbc0012I Integer solution of -59.277753 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 326 rows 598 columns, reduced to 3 rows 5 columns
# Cbc0031I 2 added rows had average density of 7.5
# Cbc0013I At root node, 13 cuts changed objective from -59.361646 to -59.275309 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 8.7 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 3 row cuts average 8.3 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 7 row cuts average 7.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -59.277752590658, took 6 iterations and 0 nodes (0.09 seconds)
# Cbc0035I Maximum depth 0, 588 variables fixed on reduced cost
# Cuts at root node changed objective from -59.3616 to -59.2753
# Probing was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 2 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 2 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 2 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                59.27775259
# Enumerated nodes:               0
# Total iterations:               6
# Time (CPU seconds):             0.09
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.10
#
# Status: Optimal
# Cost: 85.69999999999999
# Expected points per week: 59.27775259065656
#     position                    name             team  price  \
# 118       GK              David Raya        Brentford    4.7
# 265      DEF             John Stones  Manchester City    5.4
# 297      DEF         Kieran Trippier    Newcastle Utd    6.1
# 520      DEF  Trent Alexander-Arnold        Liverpool    7.3
# 354      MID          Martin degaard          Arsenal    7.0
# 379      MID           Mohamed Salah        Liverpool   12.7
# 447      MID            Riyad Mahrez  Manchester City    7.7
# 69       MID             Bukayo Saka          Arsenal    8.3
# 14       FWD     Aleksandar Mitrovic           Fulham    7.0
# 185      FWD              Harry Kane        Tottenham   11.8
# 206      FWD              Ivan Toney        Brentford    7.7
#
#      projected_points_per_game
# 118                   3.692618
# 265                   3.909687
# 297                   4.504202
# 520                   4.140502
# 354                   4.999818
# 379                   6.528418
# 447                   4.652731
# 69                    4.979669
# 14                    4.902477
# 185                   5.664962
# 206                   4.774251

# %%
ban = []
# ban some cheap keepers in good teams who don't actually play
cheap_keepers = ['Scott Carson', 'Zack Steffen', 'Jason Steele', 'Caoimhin Kelleher', 'Wayne Hennessey', 
                 'Karl Darlow', 'Darren Randolph']
cheap_keepers_ix = df[df['name'].isin(cheap_keepers)].index
ban = ban + list(cheap_keepers_ix)
# ban given players
ban_field = ['Marcos Alonso', 'Ben Chilwell', 'Riyad Mahrez', 'Darwin Nunez', 'Aymeric Laporte', 'Emil Krafth', 
             'Sergio Gomez', 'Nathaniel Phillips']
ban_field_ix = df[df['name'].isin(ban_field)].index
ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
players = optimize(my_df, max_price, 'projected_points_per_game')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/3597031289b64eda9f26d5b5f4986aaa-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/3597031289b64eda9f26d5b5f4986aaa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 331 COLUMNS
# At line 4338 RHS
# At line 4665 BOUNDS
# At line 5260 ENDATA
# Problem MODEL has 326 rows, 594 columns and 2224 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 59.3472 - 0.00 seconds
# Cgl0004I processed model has 324 rows, 594 columns (594 integer (594 of which binary)) and 2079 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.393443
# Cbc0038I Solution found of -59.1795
# Cbc0038I Before mini branch and bound, 592 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 324 rows 594 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -59.1963
# Cbc0038I Reduced cost fixing fixed 580 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.03937 (2) obj. -59.1963 iterations 2
# Cbc0038I Pass   2: suminf.    1.00000 (3) obj. -59.1963 iterations 4
# Cbc0038I Pass   3: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass   4: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass   5: suminf.    0.81133 (2) obj. -59.1963 iterations 1
# Cbc0038I Pass   6: suminf.    0.40212 (2) obj. -59.1963 iterations 2
# Cbc0038I Pass   7: suminf.    1.00000 (3) obj. -59.1963 iterations 3
# Cbc0038I Pass   8: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass   9: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  10: suminf.    0.81133 (2) obj. -59.1963 iterations 1
# Cbc0038I Pass  11: suminf.    0.40212 (2) obj. -59.1963 iterations 2
# Cbc0038I Pass  12: suminf.    1.00000 (3) obj. -59.1963 iterations 3
# Cbc0038I Pass  13: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  14: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  15: suminf.    0.81133 (2) obj. -59.1963 iterations 1
# Cbc0038I Pass  16: suminf.    0.40212 (2) obj. -59.1963 iterations 2
# Cbc0038I Pass  17: suminf.    1.00000 (3) obj. -59.1963 iterations 3
# Cbc0038I Pass  18: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  19: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  20: suminf.    0.81133 (2) obj. -59.1963 iterations 1
# Cbc0038I Pass  21: suminf.    0.40212 (2) obj. -59.1963 iterations 2
# Cbc0038I Pass  22: suminf.    1.00000 (3) obj. -59.1963 iterations 3
# Cbc0038I Pass  23: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  24: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  25: suminf.    0.81133 (2) obj. -59.1963 iterations 1
# Cbc0038I Pass  26: suminf.    0.40212 (2) obj. -59.1963 iterations 2
# Cbc0038I Pass  27: suminf.    1.00000 (3) obj. -59.1963 iterations 3
# Cbc0038I Pass  28: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  29: suminf.    1.00000 (3) obj. -59.1963 iterations 1
# Cbc0038I Pass  30: suminf.    0.81133 (2) obj. -59.1963 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 588 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 324 rows 594 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -59.1795 - took 0.02 seconds
# Cbc0012I Integer solution of -59.179519 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0012I Integer solution of -59.216827 found by DiveCoefficient after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 324 rows 594 columns, reduced to 4 rows 5 columns
# Cbc0012I Integer solution of -59.266681 found by DiveCoefficient after 17 iterations and 0 nodes (0.07 seconds)
# Cbc0031I 3 added rows had average density of 7.6666667
# Cbc0013I At root node, 3 cuts changed objective from -59.347199 to -59.266681 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 12 row cuts average 9.8 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 6.7 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 2 row cuts average 10.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 17 row cuts average 9.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -59.26668069444601, took 17 iterations and 0 nodes (0.07 seconds)
# Cbc0035I Maximum depth 0, 584 variables fixed on reduced cost
# Cuts at root node changed objective from -59.3472 to -59.2667
# Probing was tried 5 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Gomory was tried 5 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Knapsack was tried 5 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 5 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 5 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                59.26668069
# Enumerated nodes:               0
# Total iterations:               17
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.08
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.08   (Wallclock seconds):       0.09
#
# Status: Optimal
# Cost: 85.69999999999999
# Expected points per week: 59.26668069444444
#     position                    name           team  price  \
# 118       GK              David Raya      Brentford    4.7
# 29       DEF        Andrew Robertson      Liverpool    6.8
# 297      DEF         Kieran Trippier  Newcastle Utd    6.1
# 520      DEF  Trent Alexander-Arnold      Liverpool    7.3
# 354      MID          Martin degaard        Arsenal    7.0
# 355      MID              Martinelli        Arsenal    6.3
# 379      MID           Mohamed Salah      Liverpool   12.7
# 69       MID             Bukayo Saka        Arsenal    8.3
# 14       FWD     Aleksandar Mitrovic         Fulham    7.0
# 185      FWD              Harry Kane      Tottenham   11.8
# 206      FWD              Ivan Toney      Brentford    7.7
#
#      projected_points_per_game
# 118                   3.692618
# 29                    4.111096
# 297                   4.504202
# 520                   4.140502
# 354                   4.999818
# 355                   4.440250
# 379                   6.528418
# 69                    4.979669
# 14                    4.902477
# 185                   5.664962
# 206                   4.774251

# %% [markdown]
# ## With decay

# %%
#players = optimize(df, max_price, 'projected_points_with_decay')

# %%
ban = []
# ban some cheap keepers in good teams who don't actually play
#cheap_keepers = ['Scott Carson', 'Zack Steffen', 'Jason Steele', 'Caoimhin Kelleher', 'Wayne Hennessey', 
#                 'Karl Darlow', 'Darren Randolph', 'Alphonse Areola', 'Asmir Begovic', 
#                'Sam Johnstone', 'Jack Butland']
#cheap_keepers_ix = df[df['name'].isin(cheap_keepers)].index
#ban = ban + list(cheap_keepers_ix)
# ban given players
#ban_field = ['Marcos Alonso', 'Riyad Mahrez', 'Nathaniel Phillips', 'Alexander Isak', 'Stefan Bajcetic',]
#ban_field_ix = df[df['name'].isin(ban_field)].index
#ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
players = optimize(my_df, max_price, 'projected_points_with_decay')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/85ca9ed321cd4b36b4b7fa175783c26d-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/85ca9ed321cd4b36b4b7fa175783c26d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 34.8264 - 0.01 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.508475
# Cbc0038I Pass   1: suminf.    0.36145 (2) obj. -34.6471 iterations 5
# Cbc0038I Solution found of -33.3191
# Cbc0038I Before mini branch and bound, 641 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from -33.3191 to -34.4931 (0.03 seconds)
# Cbc0038I Round again with cutoff of -34.5265
# Cbc0038I Reduced cost fixing fixed 586 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.38961 (2) obj. -34.7118 iterations 2
# Cbc0038I Pass   3: suminf.    0.70608 (2) obj. -34.5265 iterations 3
# Cbc0038I Pass   4: suminf.    1.82400 (4) obj. -34.5265 iterations 9
# Cbc0038I Pass   5: suminf.    0.25000 (2) obj. -34.5532 iterations 4
# Cbc0038I Pass   6: suminf.    0.28791 (2) obj. -34.5265 iterations 1
# Cbc0038I Pass   7: suminf.    1.11494 (4) obj. -34.5265 iterations 6
# Cbc0038I Pass   8: suminf.    1.00000 (3) obj. -34.5265 iterations 3
# Cbc0038I Pass   9: suminf.    0.91815 (3) obj. -34.5265 iterations 4
# Cbc0038I Solution found of -34.6557
# Cbc0038I Rounding solution of -34.6715 is better than previous of -34.6557
#
# Cbc0038I Before mini branch and bound, 630 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 5 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of -34.7025
# Cbc0038I Reduced cost fixing fixed 623 variables on major pass 3
# Cbc0038I Pass  10: suminf.    0.42254 (2) obj. -34.7484 iterations 1
# Cbc0038I Pass  11: suminf.    0.52392 (2) obj. -34.7025 iterations 3
# Cbc0038I Pass  12: suminf.    1.00000 (3) obj. -34.7025 iterations 8
# Cbc0038I Pass  13: suminf.    0.83048 (3) obj. -34.7025 iterations 3
# Cbc0038I Pass  14: suminf.    0.76152 (3) obj. -34.7025 iterations 2
# Cbc0038I Pass  15: suminf.    0.92500 (2) obj. -34.7025 iterations 2
# Cbc0038I Pass  16: suminf.    0.85468 (3) obj. -34.7025 iterations 4
# Cbc0038I Pass  17: suminf.    0.42254 (2) obj. -34.7484 iterations 2
# Cbc0038I Pass  18: suminf.    0.52392 (2) obj. -34.7025 iterations 1
# Cbc0038I Pass  19: suminf.    1.00000 (3) obj. -34.7025 iterations 4
# Cbc0038I Pass  20: suminf.    0.97339 (2) obj. -34.7025 iterations 3
# Cbc0038I Pass  21: suminf.    0.93572 (2) obj. -34.7025 iterations 1
# Cbc0038I Pass  22: suminf.    0.52778 (2) obj. -34.7112 iterations 3
# Cbc0038I Pass  23: suminf.    0.56462 (2) obj. -34.7025 iterations 2
# Cbc0038I Pass  24: suminf.    0.42254 (2) obj. -34.7484 iterations 2
# Cbc0038I Pass  25: suminf.    0.52392 (2) obj. -34.7025 iterations 1
# Cbc0038I Pass  26: suminf.    0.56416 (2) obj. -34.7025 iterations 7
# Cbc0038I Pass  27: suminf.    0.56416 (2) obj. -34.7025 iterations 0
# Cbc0038I Pass  28: suminf.    0.28169 (2) obj. -34.7678 iterations 4
# Cbc0038I Pass  29: suminf.    0.42610 (2) obj. -34.7025 iterations 2
# Cbc0038I Pass  30: suminf.    0.79341 (2) obj. -34.7025 iterations 3
# Cbc0038I Pass  31: suminf.    0.79341 (2) obj. -34.7025 iterations 1
# Cbc0038I Pass  32: suminf.    0.76152 (3) obj. -34.7025 iterations 4
# Cbc0038I Pass  33: suminf.    0.92500 (2) obj. -34.7025 iterations 2
# Cbc0038I Pass  34: suminf.    0.83048 (3) obj. -34.7025 iterations 3
# Cbc0038I Pass  35: suminf.    0.95637 (4) obj. -34.7025 iterations 4
# Cbc0038I Pass  36: suminf.    0.32334 (3) obj. -34.7025 iterations 3
# Cbc0038I Pass  37: suminf.    0.83210 (2) obj. -34.7025 iterations 3
# Cbc0038I Pass  38: suminf.    0.83210 (2) obj. -34.7025 iterations 0
# Cbc0038I Pass  39: suminf.    0.90159 (3) obj. -34.7025 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 629 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 5 rows 15 columns
# Cbc0038I Mini branch and bound improved solution from -34.6715 to -34.6875 (0.07 seconds)
# Cbc0038I Round again with cutoff of -34.7396
# Cbc0038I Reduced cost fixing fixed 628 variables on major pass 4
# Cbc0038I Pass  39: suminf.    0.42254 (2) obj. -34.7484 iterations 0
# Cbc0038I Pass  40: suminf.    0.44192 (2) obj. -34.7396 iterations 3
# Cbc0038I Pass  41: suminf.    1.97414 (4) obj. -34.7396 iterations 6
# Cbc0038I Pass  42: suminf.    0.54867 (2) obj. -34.7396 iterations 3
# Cbc0038I Pass  43: suminf.    1.00000 (3) obj. -34.7396 iterations 6
# Cbc0038I Pass  44: suminf.    0.96940 (3) obj. -34.7396 iterations 2
# Cbc0038I Pass  45: suminf.    0.61432 (3) obj. -34.7396 iterations 4
# Cbc0038I Pass  46: suminf.    0.47222 (2) obj. -34.7429 iterations 5
# Cbc0038I Pass  47: suminf.    0.48114 (2) obj. -34.7396 iterations 2
# Cbc0038I Pass  48: suminf.    0.42254 (2) obj. -34.7484 iterations 2
# Cbc0038I Pass  49: suminf.    0.44192 (2) obj. -34.7396 iterations 1
# Cbc0038I Pass  50: suminf.    0.58378 (3) obj. -34.7396 iterations 3
# Cbc0038I Pass  51: suminf.    0.10468 (2) obj. -34.7396 iterations 4
# Cbc0038I Pass  52: suminf.    0.10468 (2) obj. -34.7396 iterations 1
# Cbc0038I Pass  53: suminf.    1.00000 (3) obj. -34.7396 iterations 5
# Cbc0038I Pass  54: suminf.    0.96940 (3) obj. -34.7396 iterations 2
# Cbc0038I Pass  55: suminf.    0.54867 (2) obj. -34.7396 iterations 2
# Cbc0038I Pass  56: suminf.    1.79341 (4) obj. -34.7396 iterations 3
# Cbc0038I Pass  57: suminf.    1.79341 (4) obj. -34.7396 iterations 1
# Cbc0038I Pass  58: suminf.    1.41123 (4) obj. -34.7396 iterations 4
# Cbc0038I Pass  59: suminf.    1.41123 (4) obj. -34.7396 iterations 1
# Cbc0038I Pass  60: suminf.    0.65818 (2) obj. -34.7396 iterations 3
# Cbc0038I Pass  61: suminf.    0.34026 (3) obj. -34.7396 iterations 5
# Cbc0038I Pass  62: suminf.    0.54121 (2) obj. -34.7396 iterations 2
# Cbc0038I Pass  63: suminf.    0.90469 (2) obj. -34.7396 iterations 5
# Cbc0038I Pass  64: suminf.    0.90469 (2) obj. -34.7396 iterations 1
# Cbc0038I Pass  65: suminf.    0.90469 (2) obj. -34.7396 iterations 0
# Cbc0038I Pass  66: suminf.    1.06709 (4) obj. -34.7396 iterations 2
# Cbc0038I Pass  67: suminf.    0.90469 (2) obj. -34.7396 iterations 2
# Cbc0038I Pass  68: suminf.    1.00000 (3) obj. -34.7396 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 630 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 6 rows 14 columns
# Cbc0038I Mini branch and bound improved solution from -34.6875 to -34.7217 (0.08 seconds)
# Cbc0038I Round again with cutoff of -34.7657
# Cbc0038I Reduced cost fixing fixed 632 variables on major pass 5
# Cbc0038I Pass  68: suminf.    0.42997 (3) obj. -34.7657 iterations 4
# Cbc0038I Pass  69: suminf.    0.64158 (2) obj. -34.7657 iterations 3
# Cbc0038I Pass  70: suminf.    0.51457 (2) obj. -34.7657 iterations 6
# Cbc0038I Pass  71: suminf.    0.51457 (2) obj. -34.7657 iterations 1
# Cbc0038I Pass  72: suminf.    0.92446 (3) obj. -34.7657 iterations 4
# Cbc0038I Pass  73: suminf.    0.93531 (2) obj. -34.7657 iterations 2
# Cbc0038I Pass  74: suminf.    0.47688 (2) obj. -34.7657 iterations 2
# Cbc0038I Pass  75: suminf.    0.29412 (2) obj. -34.7715 iterations 3
# Cbc0038I Pass  76: suminf.    0.30801 (2) obj. -34.7657 iterations 1
# Cbc0038I Pass  77: suminf.    0.77996 (2) obj. -34.7657 iterations 6
# Cbc0038I Pass  78: suminf.    0.77996 (2) obj. -34.7657 iterations 0
# Cbc0038I Pass  79: suminf.    0.92446 (3) obj. -34.7657 iterations 5
# Cbc0038I Pass  80: suminf.    0.93531 (2) obj. -34.7657 iterations 2
# Cbc0038I Pass  81: suminf.    1.29342 (4) obj. -34.7657 iterations 2
# Cbc0038I Pass  82: suminf.    1.29342 (4) obj. -34.7657 iterations 0
# Cbc0038I Pass  83: suminf.    0.42997 (3) obj. -34.7657 iterations 2
# Cbc0038I Pass  84: suminf.    0.64158 (2) obj. -34.7657 iterations 2
# Cbc0038I Pass  85: suminf.    0.60775 (2) obj. -34.7657 iterations 2
# Cbc0038I Pass  86: suminf.    0.56053 (3) obj. -34.7657 iterations 4
# Cbc0038I Pass  87: suminf.    0.64158 (2) obj. -34.7657 iterations 3
# Cbc0038I Pass  88: suminf.    0.98106 (2) obj. -34.7657 iterations 3
# Cbc0038I Pass  89: suminf.    0.98106 (2) obj. -34.7657 iterations 0
# Cbc0038I Pass  90: suminf.    0.42997 (3) obj. -34.7657 iterations 4
# Cbc0038I Pass  91: suminf.    0.64158 (2) obj. -34.7657 iterations 2
# Cbc0038I Pass  92: suminf.    0.58104 (2) obj. -34.7657 iterations 3
# Cbc0038I Pass  93: suminf.    0.35020 (3) obj. -34.7657 iterations 4
# Cbc0038I Pass  94: suminf.    0.47688 (2) obj. -34.7657 iterations 3
# Cbc0038I Pass  95: suminf.    0.29412 (2) obj. -34.7715 iterations 2
# Cbc0038I Pass  96: suminf.    0.30801 (2) obj. -34.7657 iterations 1
# Cbc0038I Pass  97: suminf.    0.47688 (2) obj. -34.7657 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 634 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 6 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.09 seconds)
# Cbc0038I After 0.09 seconds - Feasibility pump exiting with objective of -34.7217 - took 0.07 seconds
# Cbc0012I Integer solution of -34.721737 found by feasibility pump after 0 iterations and 0 nodes (0.09 seconds)
# Cbc0038I Full problem 349 rows 644 columns, reduced to 5 rows 5 columns
# Cbc0031I 4 added rows had average density of 9
# Cbc0013I At root node, 14 cuts changed objective from -34.826399 to -34.721737 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 10 row cuts average 10.8 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 6.3 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 14.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 14 row cuts average 10.4 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -34.721737458534, took 10 iterations and 0 nodes (0.12 seconds)
# Cbc0035I Maximum depth 0, 635 variables fixed on reduced cost
# Cuts at root node changed objective from -34.8264 to -34.7217
# Probing was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 3 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Knapsack was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 3 times and created 14 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                34.72173746
# Enumerated nodes:               0
# Total iterations:               10
# Time (CPU seconds):             0.12
# Time (Wallclock seconds):       0.13
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.13   (Wallclock seconds):       0.14
#
# Status: Optimal
# Cost: 84.29999999999998
# Expected points per week: 34.72173745853262
#     position                    name             team  price  \
# 119       GK              David Raya        Brentford    4.8
# 300      DEF         Kieran Trippier    Newcastle Utd    6.0
# 45       DEF         Aymeric Laporte  Manchester City    5.7
# 529      DEF  Trent Alexander-Arnold        Liverpool    7.3
# 360      MID          Martin degaard          Arsenal    7.0
# 386      MID           Mohamed Salah        Liverpool   12.7
# 498      MID             Solly March         Brighton    5.1
# 70       MID             Bukayo Saka          Arsenal    8.5
# 175      FWD           Gabriel Jesus          Arsenal    7.9
# 187      FWD              Harry Kane        Tottenham   11.7
# 208      FWD              Ivan Toney        Brentford    7.6
#
#      projected_points_with_decay
# 119                     2.299865
# 300                     2.857040
# 45                      2.278872
# 529                     2.358687
# 360                     3.107672
# 386                     3.437400
# 498                     2.996761
# 70                      2.902839
# 175                     2.724801
# 187                     3.305258
# 208                     3.015145

# %% [markdown]
# # Sensitivity analysis
#
# Here we add small random Gaussian noise to each players' projected points and run the optimization with these new estimates. We repeat the process n times and keep a list of how many times each player appeared in the optimal team.

# %%
ban = []
# ban some cheap keepers in good teams who don't actually play
#cheap_keepers = ['Scott Carson', 'Zack Steffen', 'Jason Steele', 'Caoimhin Kelleher', 'Wayne Hennessey', 
#                 'Karl Darlow', 'Darren Randolph', 'Alphonse Areola', 'Asmir Begovic', 
#                'Sam Johnstone', 'Jack Butland']
#cheap_keepers_ix = df[df['name'].isin(cheap_keepers)].index
#ban = ban + list(cheap_keepers_ix)
# ban given players
#ban_field = ['Kyle Walker']
#ban_field_ix = df[df['name'].isin(ban_field)].index
#ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
metric = 'projected_points_with_decay'
# set the standard deviation of the Gaussian noise to be a fraction of each players' projected points
#sigma_factor = 0.1
simulation_rounds = 100
results = []
for i in range(0,simulation_rounds):
    df_with_noise = my_df.copy()
    #df_with_noise[metric] = df_with_noise[metric] + np.random.normal(0, df_with_noise[metric]*sigma_factor)
    df_with_noise[metric] = df_with_noise[metric] + np.random.normal(0, df_with_noise['std'])
    players = optimize(df_with_noise, max_price, metric)
    results.append(players)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/2e8789aab2ae4a7eb36f0b0a85ad8f15-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/2e8789aab2ae4a7eb36f0b0a85ad8f15-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 36.6125 - 0.00 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -36.6125
# Cbc0038I Before mini branch and bound, 644 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -36.6125 - took 0.00 seconds
# Cbc0012I Integer solution of -36.612523 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -36.61252259409599, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -36.6125 to -36.6125
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                36.61252259
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: Optimal
# Cost: 83.69999999999999
# Expected points per week: 36.61252259409559
#     position                    name             team  price  \
# 119       GK              David Raya        Brentford    4.8
# 168      DEF            Fabian Schar    Newcastle Utd    5.1
# 319      DEF              Lewis Dunk         Brighton    4.7
# 529      DEF  Trent Alexander-Arnold        Liverpool    7.3
# 360      MID          Martin degaard          Arsenal    7.0
# 386      MID           Mohamed Salah        Liverpool   12.7
# 455      MID            Riyad Mahrez  Manchester City    7.8
# 498      MID             Solly March         Brighton    5.1
# 67       MID         Bruno Fernandes   Manchester Utd    9.8
# 162      FWD          Erling Haaland  Manchester City   11.8
# 208      FWD              Ivan Toney        Brentford    7.6
#
#      projected_points_with_decay
# 119                     2.346453
# 168                     2.351252
# 319                     2.488585
# 529                     2.448172
# 360                     4.049825
# 386                     3.292872
# 455                     2.959123
# 498                     3.127866
# 67                      2.903698
# 162                     3.556551
# 208                     3.038299
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/597f7e23d32a46ffb718797a620ec7b7-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/597f7e23d32a46ffb718797a620ec7b7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 36.1505 - 0.01 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.142857
# Cbc0038I Pass   1: suminf.    0.06818 (2) obj. -36.1048 iterations 9
# Cbc0038I Solution found of -33.9869
# Cbc0038I Before mini branch and bound, 640 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -33.9869 to -35.7727 (0.04 seconds)
# Cbc0038I Round again with cutoff of -35.8105
# Cbc0038I Reduced cost fixing fixed 604 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.07059 (2) obj. -36.1248 iterations 1
# Cbc0038I Pass   3: suminf.    0.47575 (2) obj. -35.8105 iterations 4
# Cbc0038I Pass   4: suminf.    0.83755 (2) obj. -35.8105 iterations 4
# Cbc0038I Pass   5: suminf.    0.83755 (2) obj. -35.8105 iterations 1
# Cbc0038I Pass   6: suminf.    0.83755 (2) obj. -35.8105 iterations 4
# Cbc0038I Pass   7: suminf.    0.83755 (2) obj. -35.8105 iterations 5
# Cbc0038I Pass   8: suminf.    0.69949 (2) obj. -35.8105 iterations 5
# Cbc0038I Pass   9: suminf.    0.34038 (3) obj. -35.8105 iterations 6
# Cbc0038I Pass  10: suminf.    0.43926 (2) obj. -35.8105 iterations 2
# Cbc0038I Pass  11: suminf.    1.33487 (4) obj. -35.8105 iterations 8
# Cbc0038I Pass  12: suminf.    0.53553 (6) obj. -35.8105 iterations 8
# Cbc0038I Pass  13: suminf.    0.09412 (2) obj. -35.8753 iterations 6
# Cbc0038I Pass  14: suminf.    0.17766 (2) obj. -35.8105 iterations 1
# Cbc0038I Pass  15: suminf.    0.47487 (2) obj. -35.8105 iterations 5
# Cbc0038I Pass  16: suminf.    0.47487 (2) obj. -35.8105 iterations 1
# Cbc0038I Pass  17: suminf.    0.58824 (2) obj. -35.8384 iterations 4
# Cbc0038I Pass  18: suminf.    0.62418 (2) obj. -35.8105 iterations 1
# Cbc0038I Pass  19: suminf.    0.76743 (3) obj. -35.8105 iterations 6
# Cbc0038I Pass  20: suminf.    0.65319 (4) obj. -35.8105 iterations 3
# Cbc0038I Pass  21: suminf.    0.92848 (2) obj. -35.8105 iterations 3
# Cbc0038I Pass  22: suminf.    0.92848 (2) obj. -35.8105 iterations 1
# Cbc0038I Pass  23: suminf.    0.53817 (3) obj. -35.8105 iterations 5
# Cbc0038I Pass  24: suminf.    0.67039 (2) obj. -35.8105 iterations 2
# Cbc0038I Pass  25: suminf.    1.15865 (4) obj. -35.8105 iterations 7
# Cbc0038I Pass  26: suminf.    0.21176 (2) obj. -35.9009 iterations 5
# Cbc0038I Pass  27: suminf.    0.32829 (2) obj. -35.8105 iterations 3
# Cbc0038I Pass  28: suminf.    0.84245 (3) obj. -35.8105 iterations 10
# Cbc0038I Pass  29: suminf.    0.84245 (3) obj. -35.8105 iterations 1
# Cbc0038I Pass  30: suminf.    0.51493 (2) obj. -35.8105 iterations 5
# Cbc0038I Pass  31: suminf.    0.25882 (2) obj. -35.8822 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 622 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 7 rows 19 columns
# Cbc0038I Mini branch and bound improved solution from -35.7727 to -35.9306 (0.06 seconds)
# Cbc0038I Round again with cutoff of -35.9746
# Cbc0038I Reduced cost fixing fixed 623 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.07595 (2) obj. -36.1412 iterations 1
# Cbc0038I Pass  32: suminf.    0.40537 (2) obj. -35.9746 iterations 5
# Cbc0038I Pass  33: suminf.    0.39077 (4) obj. -35.9746 iterations 6
# Cbc0038I Pass  34: suminf.    0.39077 (4) obj. -35.9746 iterations 0
# Cbc0038I Pass  35: suminf.    0.47309 (2) obj. -35.9746 iterations 4
# Cbc0038I Pass  36: suminf.    0.50342 (2) obj. -35.9746 iterations 3
# Cbc0038I Pass  37: suminf.    0.52205 (6) obj. -35.9746 iterations 9
# Cbc0038I Pass  38: suminf.    0.18673 (5) obj. -35.9746 iterations 4
# Cbc0038I Pass  39: suminf.    0.99253 (2) obj. -35.9746 iterations 4
# Cbc0038I Pass  40: suminf.    0.99253 (2) obj. -35.9746 iterations 0
# Cbc0038I Pass  41: suminf.    0.07595 (2) obj. -36.1412 iterations 4
# Cbc0038I Pass  42: suminf.    0.40537 (2) obj. -35.9746 iterations 2
# Cbc0038I Pass  43: suminf.    0.50342 (2) obj. -35.9746 iterations 5
# Cbc0038I Pass  44: suminf.    0.50342 (2) obj. -35.9746 iterations 2
# Cbc0038I Pass  45: suminf.    0.39526 (6) obj. -35.9746 iterations 5
# Cbc0038I Pass  46: suminf.    0.39526 (6) obj. -35.9746 iterations 0
# Cbc0038I Pass  47: suminf.    0.77229 (6) obj. -35.9746 iterations 3
# Cbc0038I Pass  48: suminf.    0.39526 (6) obj. -35.9746 iterations 4
# Cbc0038I Pass  49: suminf.    0.99253 (2) obj. -35.9746 iterations 4
# Cbc0038I Pass  50: suminf.    0.07595 (2) obj. -36.1412 iterations 4
# Cbc0038I Pass  51: suminf.    0.40537 (2) obj. -35.9746 iterations 2
# Cbc0038I Pass  52: suminf.    0.47309 (2) obj. -35.9746 iterations 1
# Cbc0038I Pass  53: suminf.    0.39425 (3) obj. -35.9746 iterations 4
# Cbc0038I Pass  54: suminf.    0.39077 (4) obj. -35.9746 iterations 2
# Cbc0038I Pass  55: suminf.    0.47309 (2) obj. -35.9746 iterations 2
# Cbc0038I Pass  56: suminf.    0.52528 (4) obj. -35.9746 iterations 4
# Cbc0038I Pass  57: suminf.    0.70412 (6) obj. -35.9746 iterations 4
# Cbc0038I Pass  58: suminf.    0.50572 (3) obj. -35.9746 iterations 2
# Cbc0038I Pass  59: suminf.    0.53254 (2) obj. -35.9746 iterations 4
# Cbc0038I Pass  60: suminf.    0.53254 (2) obj. -35.9746 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 628 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 6 rows 14 columns
# Cbc0038I Mini branch and bound improved solution from -35.9306 to -35.9554 (0.08 seconds)
# Cbc0038I Round again with cutoff of -36.0274
# Cbc0038I Reduced cost fixing fixed 631 variables on major pass 4
# Cbc0038I Pass  60: suminf.    0.11111 (2) obj. -36.1251 iterations 1
# Cbc0038I Pass  61: suminf.    1.00000 (3) obj. -36.0274 iterations 5
# Cbc0038I Pass  62: suminf.    0.84327 (3) obj. -36.0274 iterations 1
# Cbc0038I Pass  63: suminf.    0.63392 (3) obj. -36.0274 iterations 2
# Cbc0038I Pass  64: suminf.    0.95302 (2) obj. -36.0274 iterations 1
# Cbc0038I Pass  65: suminf.    0.95302 (2) obj. -36.0274 iterations 0
# Cbc0038I Pass  66: suminf.    0.95238 (2) obj. -36.1157 iterations 5
# Cbc0038I Pass  67: suminf.    0.51815 (2) obj. -36.0274 iterations 2
# Cbc0038I Pass  68: suminf.    0.51815 (2) obj. -36.0274 iterations 2
# Cbc0038I Pass  69: suminf.    0.51815 (2) obj. -36.0274 iterations 2
# Cbc0038I Pass  70: suminf.    0.51815 (2) obj. -36.0274 iterations 1
# Cbc0038I Pass  71: suminf.    1.05630 (4) obj. -36.0274 iterations 6
# Cbc0038I Pass  72: suminf.    0.11111 (2) obj. -36.1251 iterations 4
# Cbc0038I Pass  73: suminf.    1.00000 (3) obj. -36.0274 iterations 2
# Cbc0038I Pass  74: suminf.    0.84327 (3) obj. -36.0274 iterations 1
# Cbc0038I Pass  75: suminf.    0.63392 (3) obj. -36.0274 iterations 2
# Cbc0038I Pass  76: suminf.    0.95302 (2) obj. -36.0274 iterations 1
# Cbc0038I Pass  77: suminf.    0.63392 (3) obj. -36.0274 iterations 2
# Cbc0038I Pass  78: suminf.    0.77753 (2) obj. -36.0274 iterations 5
# Cbc0038I Pass  79: suminf.    0.75463 (3) obj. -36.0274 iterations 4
# Cbc0038I Pass  80: suminf.    0.84346 (2) obj. -36.0274 iterations 3
# Cbc0038I Pass  81: suminf.    0.67429 (3) obj. -36.0274 iterations 3
# Cbc0038I Pass  82: suminf.    0.14286 (2) obj. -36.1159 iterations 7
# Cbc0038I Pass  83: suminf.    0.12245 (2) obj. -36.0938 iterations 4
# Cbc0038I Pass  84: suminf.    1.00000 (3) obj. -36.0274 iterations 3
# Cbc0038I Pass  85: suminf.    1.00000 (3) obj. -36.0274 iterations 0
# Cbc0038I Pass  86: suminf.    0.28134 (2) obj. -36.0274 iterations 1
# Cbc0038I Pass  87: suminf.    0.12245 (2) obj. -36.0938 iterations 2
# Cbc0038I Pass  88: suminf.    0.12245 (2) obj. -36.0938 iterations 0
# Cbc0038I Pass  89: suminf.    1.11646 (4) obj. -36.0274 iterations 8
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 632 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 5 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.09 seconds)
# Cbc0038I After 0.09 seconds - Feasibility pump exiting with objective of -35.9554 - took 0.07 seconds
# Cbc0012I Integer solution of -35.955389 found by feasibility pump after 0 iterations and 0 nodes (0.09 seconds)
# Cbc0038I Full problem 349 rows 644 columns, reduced to 5 rows 6 columns
# Cbc0012I Integer solution of -35.9951 found by DiveCoefficient after 23 iterations and 0 nodes (0.11 seconds)
# Cbc0031I 5 added rows had average density of 12
# Cbc0013I At root node, 5 cuts changed objective from -36.150526 to -35.9951 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 21 row cuts average 13.6 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 10.2 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 5 row cuts average 13.4 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 32 row cuts average 13.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -35.99510026941, took 23 iterations and 0 nodes (0.11 seconds)
# Cbc0035I Maximum depth 0, 629 variables fixed on reduced cost
# Cuts at root node changed objective from -36.1505 to -35.9951
# Probing was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 5 times and created 21 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Knapsack was tried 5 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 5 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 5 times and created 32 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                35.99510027
# Enumerated nodes:               0
# Total iterations:               23
# Time (CPU seconds):             0.11
# Time (Wallclock seconds):       0.12
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.12   (Wallclock seconds):       0.12
#
# Status: Optimal
# Cost: 84.79999999999998
# Expected points per week: 35.995100269411786
#     position                 name             team  price  \
# 119       GK           David Raya        Brentford    4.8
# 161      DEF            Eric Dier        Tottenham    5.1
# 417      DEF  Oleksandr Zinchenko          Arsenal    5.1
# 55       DEF    Benoit Badiashile          Chelsea    5.0
# 294      MID      Kevin De Bruyne  Manchester City   12.2
# 360      MID       Martin degaard          Arsenal    7.0
# 386      MID        Mohamed Salah        Liverpool   12.7
# 498      MID          Solly March         Brighton    5.1
# 70       MID          Bukayo Saka          Arsenal    8.5
# 187      FWD           Harry Kane        Tottenham   11.7
# 208      FWD           Ivan Toney        Brentford    7.6
#
#      projected_points_with_decay
# 119                     2.386817
# 161                     2.212554
# 417                     2.431168
# 55                      2.560602
# 294                     3.381887
# 360                     3.164768
# 386                     3.526651
# 498                     3.106654
# 70                      3.561311
# 187                     3.029739
# 208                     3.071638
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/4abf55ba5c7a42df863f6f78e3f3566e-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/4abf55ba5c7a42df863f6f78e3f3566e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 38.3159 - 0.01 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.193548
# Cbc0038I Solution found of -38.283
# Cbc0038I Before mini branch and bound, 642 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -38.2863
# Cbc0038I Reduced cost fixing fixed 637 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.01941 (2) obj. -38.2863 iterations 3
# Cbc0038I Pass   2: suminf.    0.19355 (2) obj. -38.3159 iterations 2
# Cbc0038I Pass   3: suminf.    0.01941 (2) obj. -38.2863 iterations 2
# Cbc0038I Pass   4: suminf.    0.19355 (2) obj. -38.3159 iterations 2
# Cbc0038I Pass   5: suminf.    0.19355 (2) obj. -38.3159 iterations 1
# Cbc0038I Pass   6: suminf.    0.01941 (2) obj. -38.2863 iterations 2
# Cbc0038I Pass   7: suminf.    0.01941 (2) obj. -38.2863 iterations 1
# Cbc0038I Pass   8: suminf.    0.01941 (2) obj. -38.2863 iterations 0
# Cbc0038I Pass   9: suminf.    0.80000 (2) obj. -38.3091 iterations 2
# Cbc0038I Pass  10: suminf.    0.19355 (2) obj. -38.3159 iterations 1
# Cbc0038I Pass  11: suminf.    0.01941 (2) obj. -38.2863 iterations 1
# Cbc0038I Pass  12: suminf.    0.01941 (2) obj. -38.2863 iterations 0
# Cbc0038I Pass  13: suminf.    0.19355 (2) obj. -38.3159 iterations 1
# Cbc0038I Pass  14: suminf.    0.80000 (2) obj. -38.3091 iterations 1
# Cbc0038I Pass  15: suminf.    0.19355 (2) obj. -38.3159 iterations 2
# Cbc0038I Pass  16: suminf.    0.19355 (2) obj. -38.3159 iterations 1
# Cbc0038I Pass  17: suminf.    0.01941 (2) obj. -38.2863 iterations 1
# Cbc0038I Pass  18: suminf.    0.01941 (2) obj. -38.2863 iterations 0
# Cbc0038I Pass  19: suminf.    0.80000 (2) obj. -38.3091 iterations 3
# Cbc0038I Pass  20: suminf.    0.80000 (2) obj. -38.3091 iterations 0
# Cbc0038I Pass  21: suminf.    0.80000 (2) obj. -38.3091 iterations 0
# Cbc0038I Pass  22: suminf.    0.01941 (2) obj. -38.2863 iterations 3
# Cbc0038I Pass  23: suminf.    0.01941 (2) obj. -38.2863 iterations 0
# Cbc0038I Pass  24: suminf.    0.01941 (2) obj. -38.2863 iterations 0
# Cbc0038I Pass  25: suminf.    0.01941 (2) obj. -38.2863 iterations 1
# Cbc0038I Pass  26: suminf.    0.01941 (2) obj. -38.2863 iterations 1
# Cbc0038I Pass  27: suminf.    0.01941 (2) obj. -38.2863 iterations 0
# Cbc0038I Pass  28: suminf.    0.01941 (2) obj. -38.2863 iterations 1
# Cbc0038I Pass  29: suminf.    0.01941 (2) obj. -38.2863 iterations 1
# Cbc0038I Pass  30: suminf.    0.01941 (2) obj. -38.2863 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 641 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting with objective of -38.283 - took 0.02 seconds
# Cbc0012I Integer solution of -38.282997 found by feasibility pump after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0013I At root node, 10 cuts changed objective from -38.31595 to -38.31595 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 6 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -38.28299662311399, took 0 iterations and 0 nodes (0.05 seconds)
# Cbc0035I Maximum depth 0, 637 variables fixed on reduced cost
# Cuts at root node changed objective from -38.3159 to -38.3159
# Probing was tried 1 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                38.28299662
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.05
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.07
#
# Status: Optimal
# Cost: 84.19999999999999
# Expected points per week: 38.282996623115174
#     position                    name             team  price  \
# 119       GK              David Raya        Brentford    4.8
# 417      DEF     Oleksandr Zinchenko          Arsenal    5.1
# 45       DEF         Aymeric Laporte  Manchester City    5.7
# 529      DEF  Trent Alexander-Arnold        Liverpool    7.3
# 294      MID         Kevin De Bruyne  Manchester City   12.2
# 381      MID          Miguel Almiron    Newcastle Utd    5.5
# 386      MID           Mohamed Salah        Liverpool   12.7
# 498      MID             Solly March         Brighton    5.1
# 547      MID           Wilfried Zaha   Crystal Palace    7.2
# 14       FWD     Aleksandar Mitrovic           Fulham    6.8
# 162      FWD          Erling Haaland  Manchester City   11.8
#
#      projected_points_with_decay
# 119                     2.584668
# 417                     2.274158
# 45                      2.310839
# 529                     2.561744
# 294                     4.450801
# 381                     2.874270
# 386                     3.412166
# 498                     3.407527
# 547                     3.041854
# 14                      3.067968
# 162                     3.846200
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/8dcb89801a9a4b74a3ebf89f4bc43bba-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/8dcb89801a9a4b74a3ebf89f4bc43bba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 42.6338 - 0.00 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.340426
# Cbc0038I Solution found of -42.6219
# Cbc0038I Before mini branch and bound, 642 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -42.6231
# Cbc0038I Reduced cost fixing fixed 638 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.03430 (2) obj. -42.6231 iterations 3
# Cbc0038I Pass   2: suminf.    0.40493 (3) obj. -42.6231 iterations 2
# Cbc0038I Pass   3: suminf.    0.03430 (2) obj. -42.6231 iterations 2
# Cbc0038I Pass   4: suminf.    0.03430 (2) obj. -42.6231 iterations 0
# Cbc0038I Pass   5: suminf.    0.03430 (2) obj. -42.6231 iterations 0
# Cbc0038I Pass   6: suminf.    0.40493 (3) obj. -42.6231 iterations 3
# Cbc0038I Pass   7: suminf.    0.03430 (2) obj. -42.6231 iterations 2
# Cbc0038I Pass   8: suminf.    0.03430 (2) obj. -42.6231 iterations 0
# Cbc0038I Pass   9: suminf.    0.40493 (3) obj. -42.6231 iterations 3
# Cbc0038I Pass  10: suminf.    0.00000 (0) obj. -42.6244 iterations 5
# Cbc0038I Solution found of -42.6244
# Cbc0038I Before mini branch and bound, 640 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -42.6263
# Cbc0038I Reduced cost fixing fixed 638 variables on major pass 3
# Cbc0038I Pass  11: suminf.    0.12653 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  12: suminf.    0.38550 (3) obj. -42.6263 iterations 4
# Cbc0038I Pass  13: suminf.    0.38550 (3) obj. -42.6263 iterations 0
# Cbc0038I Pass  14: suminf.    0.05376 (2) obj. -42.6263 iterations 3
# Cbc0038I Pass  15: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  16: suminf.    0.24802 (3) obj. -42.6263 iterations 2
# Cbc0038I Pass  17: suminf.    0.05376 (2) obj. -42.6263 iterations 2
# Cbc0038I Pass  18: suminf.    0.24802 (3) obj. -42.6263 iterations 3
# Cbc0038I Pass  19: suminf.    0.05376 (2) obj. -42.6263 iterations 2
# Cbc0038I Pass  20: suminf.    0.24802 (3) obj. -42.6263 iterations 3
# Cbc0038I Pass  21: suminf.    0.05376 (2) obj. -42.6263 iterations 2
# Cbc0038I Pass  22: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  23: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  24: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  25: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  26: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  27: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  28: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  29: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  30: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  31: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  32: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  33: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  34: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  35: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  36: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  37: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  38: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  39: suminf.    0.05376 (2) obj. -42.6263 iterations 0
# Cbc0038I Pass  40: suminf.    0.12653 (2) obj. -42.6263 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 640 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -42.6244 - took 0.02 seconds
# Cbc0012I Integer solution of -42.62444 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 349 rows 644 columns, reduced to 3 rows 4 columns
# Cbc0013I At root node, 10 cuts changed objective from -42.633765 to -42.633765 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 3.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -42.624439553722, took 0 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 638 variables fixed on reduced cost
# Cuts at root node changed objective from -42.6338 to -42.6338
# Probing was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                42.62443955
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.07
#
# Status: Optimal
# Cost: 84.3
# Expected points per week: 42.624439553721714
#     position             name             team  price  \
# 119       GK       David Raya        Brentford    4.8
# 143      DEF  Duje Caleta-Car      Southampton    4.5
# 268      DEF      John Stones  Manchester City    5.4
# 300      DEF  Kieran Trippier    Newcastle Utd    6.0
# 294      MID  Kevin De Bruyne  Manchester City   12.2
# 360      MID   Martin degaard          Arsenal    7.0
# 386      MID    Mohamed Salah        Liverpool   12.7
# 498      MID      Solly March         Brighton    5.1
# 547      MID    Wilfried Zaha   Crystal Palace    7.2
# 162      FWD   Erling Haaland  Manchester City   11.8
# 208      FWD       Ivan Toney        Brentford    7.6
#
#      projected_points_with_decay
# 119                     2.248328
# 143                     3.131141
# 268                     2.476161
# 300                     6.258026
# 294                     3.348745
# 360                     2.943144
# 386                     3.778444
# 498                     2.976535
# 547                     3.056375
# 162                     3.080158
# 208                     3.069357
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/a63aac26afa74796972002bb8ae30157-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/a63aac26afa74796972002bb8ae30157-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 36.0695 - 0.00 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -36.0695
# Cbc0038I Before mini branch and bound, 644 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -36.0695 - took 0.00 seconds
# Cbc0012I Integer solution of -36.069544 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective -36.069544113065, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -36.0695 to -36.0695
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                36.06954411
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.04
#
# Status: Optimal
# Cost: 83.6
# Expected points per week: 36.06954411306558
#     position                    name             team  price  \
# 119       GK              David Raya        Brentford    4.8
# 29       DEF        Andrew Robertson        Liverpool    6.8
# 300      DEF         Kieran Trippier    Newcastle Utd    6.0
# 529      DEF  Trent Alexander-Arnold        Liverpool    7.3
# 360      MID          Martin degaard          Arsenal    7.0
# 455      MID            Riyad Mahrez  Manchester City    7.8
# 498      MID             Solly March         Brighton    5.1
# 70       MID             Bukayo Saka          Arsenal    8.5
# 14       FWD     Aleksandar Mitrovic           Fulham    6.8
# 162      FWD          Erling Haaland  Manchester City   11.8
# 187      FWD              Harry Kane        Tottenham   11.7
#
#      projected_points_with_decay
# 119                     2.681171
# 29                      2.411010
# 300                     2.706436
# 529                     2.342486
# 360                     3.353609
# 455                     2.986628
# 498                     3.174095
# 70                      2.878892
# 14                      3.019189
# 162                     2.951795
# 187                     3.782118
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/b068907dc5f1414a89ddbd6c2fc9c380-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/b068907dc5f1414a89ddbd6c2fc9c380-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 36.2475 - 0.01 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -36.2475
# Cbc0038I Before mini branch and bound, 644 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -36.2475 - took 0.00 seconds
# Cbc0012I Integer solution of -36.247533 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective -36.247533009055, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -36.2475 to -36.2475
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                36.24753301
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.04
#
# Status: Optimal
# Cost: 83.39999999999999
# Expected points per week: 36.24753300905578
#     position                 name             team  price  \
# 119       GK           David Raya        Brentford    4.8
# 143      DEF      Duje Caleta-Car      Southampton    4.5
# 29       DEF     Andrew Robertson        Liverpool    6.8
# 55       DEF    Benoit Badiashile          Chelsea    5.0
# 211      MID        Jack Grealish  Manchester City    6.8
# 294      MID      Kevin De Bruyne  Manchester City   12.2
# 360      MID       Martin degaard          Arsenal    7.0
# 386      MID        Mohamed Salah        Liverpool   12.7
# 498      MID          Solly March         Brighton    5.1
# 14       FWD  Aleksandar Mitrovic           Fulham    6.8
# 187      FWD           Harry Kane        Tottenham   11.7
#
#      projected_points_with_decay
# 119                     2.282940
# 143                     3.167444
# 29                      2.370267
# 55                      2.365942
# 211                     2.911919
# 294                     2.982529
# 360                     2.942945
# 386                     3.463247
# 498                     3.526669
# 14                      2.863470
# 187                     3.685081
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/985394f99ec546b4b5e5497d7d8c4830-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/985394f99ec546b4b5e5497d7d8c4830-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 35.4099 - 0.01 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.28125
# Cbc0038I Solution found of -35.3662
# Cbc0038I Before mini branch and bound, 642 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -35.3706
# Cbc0038I Reduced cost fixing fixed 630 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.02818 (2) obj. -35.3706 iterations 4
# Cbc0038I Pass   2: suminf.    0.56719 (3) obj. -35.3706 iterations 6
# Cbc0038I Pass   3: suminf.    0.46667 (2) obj. -35.3756 iterations 4
# Cbc0038I Pass   4: suminf.    0.44246 (3) obj. -35.3706 iterations 3
# Cbc0038I Pass   5: suminf.    1.00000 (3) obj. -35.3706 iterations 4
# Cbc0038I Pass   6: suminf.    0.95833 (2) obj. -35.3804 iterations 4
# Cbc0038I Pass   7: suminf.    0.88360 (2) obj. -35.3706 iterations 3
# Cbc0038I Pass   8: suminf.    0.77076 (3) obj. -35.3706 iterations 5
# Cbc0038I Pass   9: suminf.    0.94939 (4) obj. -35.3706 iterations 5
# Cbc0038I Pass  10: suminf.    0.83451 (4) obj. -35.3706 iterations 1
# Cbc0038I Pass  11: suminf.    0.56719 (3) obj. -35.3706 iterations 4
# Cbc0038I Pass  12: suminf.    0.02818 (2) obj. -35.3706 iterations 5
# Cbc0038I Pass  13: suminf.    0.02818 (2) obj. -35.3706 iterations 1
# Cbc0038I Pass  14: suminf.    0.02818 (2) obj. -35.3706 iterations 2
# Cbc0038I Pass  15: suminf.    0.02818 (2) obj. -35.3706 iterations 0
# Cbc0038I Pass  16: suminf.    0.02818 (2) obj. -35.3706 iterations 0
# Cbc0038I Pass  17: suminf.    0.02818 (2) obj. -35.3706 iterations 0
# Cbc0038I Pass  18: suminf.    0.02818 (2) obj. -35.3706 iterations 0
# Cbc0038I Pass  19: suminf.    0.28125 (2) obj. -35.4099 iterations 4
# Cbc0038I Pass  20: suminf.    0.97872 (3) obj. -35.3706 iterations 10
# Cbc0038I Pass  21: suminf.    0.71401 (3) obj. -35.3706 iterations 1
# Cbc0038I Pass  22: suminf.    0.95445 (3) obj. -35.3706 iterations 4
# Cbc0038I Pass  23: suminf.    0.95445 (3) obj. -35.3706 iterations 0
# Cbc0038I Pass  24: suminf.    0.71401 (3) obj. -35.3706 iterations 3
# Cbc0038I Pass  25: suminf.    0.18049 (5) obj. -35.3706 iterations 9
# Cbc0038I Pass  26: suminf.    0.05224 (2) obj. -35.3706 iterations 6
# Cbc0038I Pass  27: suminf.    0.75099 (3) obj. -35.3706 iterations 6
# Cbc0038I Pass  28: suminf.    0.34342 (2) obj. -35.3706 iterations 3
# Cbc0038I Pass  29: suminf.    0.55948 (2) obj. -35.3706 iterations 3
# Cbc0038I Pass  30: suminf.    0.55948 (2) obj. -35.3706 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 633 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 7 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of -35.3662 - took 0.03 seconds
# Cbc0012I Integer solution of -35.366183 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0012I Integer solution of -35.374642 found by DiveCoefficient after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0031I 3 added rows had average density of 12
# Cbc0013I At root node, 3 cuts changed objective from -35.409887 to -35.376628 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 64 row cuts average 12.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 7 row cuts average 5.1 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 9 row cuts average 8.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 42 row cuts average 11.7 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -35.374642 best solution, best possible -35.376628 (0.09 seconds)
# Cbc0001I Search completed - best objective -35.374642377576, took 93 iterations and 2 nodes (0.10 seconds)
# Cbc0032I Strong branching done 18 times (55 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 635 variables fixed on reduced cost
# Cuts at root node changed objective from -35.4099 to -35.3766
# Probing was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Gomory was tried 13 times and created 64 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Knapsack was tried 13 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 13 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 10 times and created 42 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Optimal solution found
#
# Objective value:                35.37464238
# Enumerated nodes:               2
# Total iterations:               93
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.11   (Wallclock seconds):       0.11
#
# Status: Optimal
# Cost: 84.39999999999999
# Expected points per week: 35.37464237757525
#     position                    name             team  price  \
# 198       GK             Hugo Lloris        Tottenham    5.4
# 308      DEF             Kyle Walker  Manchester City    4.8
# 45       DEF         Aymeric Laporte  Manchester City    5.7
# 529      DEF  Trent Alexander-Arnold        Liverpool    7.3
# 294      MID         Kevin De Bruyne  Manchester City   12.2
# 361      MID              Martinelli          Arsenal    6.3
# 498      MID             Solly March         Brighton    5.1
# 67       MID         Bruno Fernandes   Manchester Utd    9.8
# 70       MID             Bukayo Saka          Arsenal    8.5
# 187      FWD              Harry Kane        Tottenham   11.7
# 208      FWD              Ivan Toney        Brentford    7.6
#
#      projected_points_with_decay
# ...
# Cbc0038I Pass  25: suminf.    0.04151 (2) obj. -35.4596 iterations 3
# Cbc0038I Pass  26: suminf.    0.04151 (2) obj. -35.4596 iterations 1
# Cbc0038I Pass  27: suminf.    0.41379 (2) obj. -35.4843 iterations 3
# Cbc0038I Pass  28: suminf.    0.07739 (2) obj. -35.4596 iterations 3
# Cbc0038I Pass  29: suminf.    0.75000 (2) obj. -35.4836 iterations 3
# Cbc0038I Pass  30: suminf.    0.04151 (2) obj. -35.4596 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 640 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 2 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -35.4568 - took 0.02 seconds
# Cbc0012I Integer solution of -35.456794 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 1 cuts changed objective from -35.484335 to -35.380585 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -35.456794370254, took 5 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 636 variables fixed on reduced cost
# Cuts at root node changed objective from -35.4843 to -35.3806
# Probing was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                35.45679437
# Enumerated nodes:               0
# Total iterations:               5
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.07
#
# Status: Optimal
# Cost: 84.19999999999999
# Expected points per week: 35.45679437025524
#     position                 name             team  price  \
# 148       GK              Ederson  Manchester City    5.4
# 165      DEF        Ethan Pinnock        Brentford    4.4
# 417      DEF  Oleksandr Zinchenko          Arsenal    5.1
# 45       DEF      Aymeric Laporte  Manchester City    5.7
# 360      MID       Martin degaard          Arsenal    7.0
# 381      MID       Miguel Almiron    Newcastle Utd    5.5
# 386      MID        Mohamed Salah        Liverpool   12.7
# 498      MID          Solly March         Brighton    5.1
# 67       MID      Bruno Fernandes   Manchester Utd    9.8
# 162      FWD       Erling Haaland  Manchester City   11.8
# 187      FWD           Harry Kane        Tottenham   11.7
#
#      projected_points_with_decay
# 148                     2.306590
# 165                     2.176092
# 417                     2.366836
# 45                      2.237799
# 360                     3.337616
# 381                     2.917559
# 386                     3.336385
# 498                     2.904060
# 67                      3.417298
# 162                     3.528482
# 187                     3.399595
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/af399589d9c94d4dac354d78ee15059c-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/af399589d9c94d4dac354d78ee15059c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 36.6251 - 0.00 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -36.6251
# Cbc0038I Before mini branch and bound, 644 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -36.6251 - took 0.00 seconds
# Cbc0012I Integer solution of -36.625078 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective -36.625077904714, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -36.6251 to -36.6251
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                36.62507790
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: Optimal
# Cost: 83.69999999999999
# Expected points per week: 36.62507790471254
#     position               name             team  price  \
# 119       GK         David Raya        Brentford    4.8
# 143      DEF    Duje Caleta-Car      Southampton    4.5
# 214      DEF      Jack Stephens      Bournemouth    4.3
# 55       DEF  Benoit Badiashile          Chelsea    5.0
# 294      MID    Kevin De Bruyne  Manchester City   12.2
# 360      MID     Martin degaard          Arsenal    7.0
# 386      MID      Mohamed Salah        Liverpool   12.7
# 498      MID        Solly March         Brighton    5.1
# 117      FWD       Darwin Nunez        Liverpool    8.8
# 187      FWD         Harry Kane        Tottenham   11.7
# 208      FWD         Ivan Toney        Brentford    7.6
#
#      projected_points_with_decay
# 119                     2.369177
# 143                     2.894503
# 214                     2.742810
# 55                      2.417071
# 294                     3.584119
# 360                     3.506624
# 386                     3.149789
# 498                     3.050379
# 117                     3.097168
# 187                     3.021802
# 208                     3.207516
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/923ec421ffa74da99d0c368c53fd1da8-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/923ec421ffa74da99d0c368c53fd1da8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 356 COLUMNS
# At line 4707 RHS
# At line 5059 BOUNDS
# At line 5704 ENDATA
# Problem MODEL has 351 rows, 644 columns and 2418 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 35.68 - 0.00 seconds
# Cgl0004I processed model has 349 rows, 644 columns (644 integer (644 of which binary)) and 2254 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.861538
# Cbc0038I Solution found of -35.6793
# Cbc0038I Before mini branch and bound, 642 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -35.6794
# Cbc0038I Reduced cost fixing fixed 638 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.09723 (2) obj. -35.6794 iterations 3
# Cbc0038I Pass   2: suminf.    0.86154 (2) obj. -35.68 iterations 3
# Cbc0038I Pass   3: suminf.    0.92526 (3) obj. -35.6794 iterations 2
# Cbc0038I Pass   4: suminf.    0.09723 (2) obj. -35.6794 iterations 2
# Cbc0038I Pass   5: suminf.    0.09723 (2) obj. -35.6794 iterations 0
# Cbc0038I Pass   6: suminf.    0.09723 (2) obj. -35.6794 iterations 2
# Cbc0038I Pass   7: suminf.    0.86154 (2) obj. -35.68 iterations 3
# Cbc0038I Pass   8: suminf.    0.09723 (2) obj. -35.6794 iterations 1
# Cbc0038I Pass   9: suminf.    0.09723 (2) obj. -35.6794 iterations 1
# Cbc0038I Pass  10: suminf.    0.09723 (2) obj. -35.6794 iterations 0
# Cbc0038I Pass  11: suminf.    0.09723 (2) obj. -35.6794 iterations 0
# Cbc0038I Pass  12: suminf.    0.09723 (2) obj. -35.6794 iterations 0
# Cbc0038I Pass  13: suminf.    0.86154 (2) obj. -35.68 iterations 1
# Cbc0038I Pass  14: suminf.    0.09723 (2) obj. -35.6794 iterations 2
# Cbc0038I Pass  15: suminf.    0.09723 (2) obj. -35.6794 iterations 1
# Cbc0038I Pass  16: suminf.    0.86154 (2) obj. -35.68 iterations 1
# Cbc0038I Pass  17: suminf.    0.86154 (2) obj. -35.68 iterations 1
# Cbc0038I Pass  18: suminf.    0.09723 (2) obj. -35.6794 iterations 1
# Cbc0038I Pass  19: suminf.    0.92526 (3) obj. -35.6794 iterations 2
# Cbc0038I Pass  20: suminf.    0.86154 (2) obj. -35.68 iterations 2
# Cbc0038I Pass  21: suminf.    0.09723 (2) obj. -35.6794 iterations 1
# Cbc0038I Pass  22: suminf.    0.09723 (2) obj. -35.6794 iterations 0
# Cbc0038I Pass  23: suminf.    0.86154 (2) obj. -35.68 iterations 2
# Cbc0038I Pass  24: suminf.    0.92526 (3) obj. -35.6794 iterations 3
# Cbc0038I Pass  25: suminf.    0.92526 (3) obj. -35.6794 iterations 0
# Cbc0038I Pass  26: suminf.    0.92526 (3) obj. -35.6794 iterations 0
# Cbc0038I Pass  27: suminf.    0.92526 (3) obj. -35.6794 iterations 0
# Cbc0038I Pass  28: suminf.    0.86154 (2) obj. -35.68 iterations 2
# Cbc0038I Pass  29: suminf.    0.09723 (2) obj. -35.6794 iterations 1
# Cbc0038I Pass  30: suminf.    0.09723 (2) obj. -35.6794 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 641 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 349 rows 644 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting with objective of -35.6793 - took 0.02 seconds
# Cbc0012I Integer solution of -35.679329 found by feasibility pump after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0031I 2 added rows had average density of 3
# Cbc0013I At root node, 11 cuts changed objective from -35.680029 to -35.665284 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 6 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 2.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -35.679328662538, took 1 iterations and 0 nodes (0.05 seconds)
# Cbc0035I Maximum depth 0, 638 variables fixed on reduced cost
# Cuts at root node changed objective from -35.68 to -35.6653
# Probing was tried 1 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                35.67932866
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.07
#
# Status: Optimal
# Cost: 82.0
# Expected points per week: 35.67932866253494
#     position                    name           team  price  \
# 119       GK              David Raya      Brentford    4.8
# 29       DEF        Andrew Robertson      Liverpool    6.8
# 529      DEF  Trent Alexander-Arnold      Liverpool    7.3
# 55       DEF       Benoit Badiashile        Chelsea    5.0
# 360      MID          Martin degaard        Arsenal    7.0
# 381      MID          Miguel Almiron  Newcastle Utd    5.5
# 386      MID           Mohamed Salah      Liverpool   12.7
# 498      MID             Solly March       Brighton    5.1
# 70       MID             Bukayo Saka        Arsenal    8.5
# 187      FWD              Harry Kane      Tottenham   11.7
# 208      FWD              Ivan Toney      Brentford    7.6
#
#      projected_points_with_decay
# 119                     2.426891
# 29                      2.543134
# 529                     2.588031
# 55                      2.493454
# 360                     3.065932
# 381                     3.046896
# 386                     3.742312
# 498                     2.760461
# 70                      3.495263
# 187                     2.869622
# 208                     2.905023

# %%
my_df['dream_team_appearances'] = [sum(team.count(player_id) for team in results) for player_id in my_df.index]
my_df.head(5)
# Out:
#                  name            team position  price  minutes  \
# 0     Aaron Cresswell        West Ham      DEF    4.7     1578
# 1        Aaron Hickey       Brentford      DEF    4.9      815
# 2      Aaron Ramsdale         Arsenal       GK    4.9     2250
# 3   Aaron Wan-Bissaka  Manchester Utd      DEF    4.3      646
# 4  Abdoulaye Doucoure         Everton      MID    5.3      660
#
#    projected_points_per_game  projected_points_with_decay       std  \
# 0                   2.982367                     1.730514  0.109547
# 1                   2.543225                     1.598735  0.086609
# 2                   3.458309                     2.109378  0.167265
# 3                   2.840811                     1.643773  0.115318
# 4                   2.248236                     1.329925  0.131267
#
#    dream_team_appearances
# 0                       0
# 1                       0
# 2                       7
# 3                       0
# 4                       0

# %%
print('Most appearances, all players:')
display(my_df.sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# Most appearances, all players:
#                        name             team position  price  minutes  \
# 208              Ivan Toney        Brentford      FWD    7.6     1881
# 498             Solly March         Brighton      MID    5.1     1900
# 187              Harry Kane        Tottenham      FWD   11.7     2236
# 386           Mohamed Salah        Liverpool      MID   12.7     2136
# 360          Martin degaard          Arsenal      MID    7.0     2041
# 300         Kieran Trippier    Newcastle Utd      DEF    6.0     2017
# 70              Bukayo Saka          Arsenal      MID    8.5     2155
# 119              David Raya        Brentford       GK    4.8     2070
# 294         Kevin De Bruyne  Manchester City      MID   12.2     1860
# 162          Erling Haaland  Manchester City      FWD   11.8     1931
# 67          Bruno Fernandes   Manchester Utd      MID    9.8     2069
# 143         Duje Caleta-Car      Southampton      DEF    4.5      713
# 14      Aleksandar Mitrovic           Fulham      FWD    6.8     1636
# 268             John Stones  Manchester City      DEF    5.4     1180
# 529  Trent Alexander-Arnold        Liverpool      DEF    7.3     1778
# 455            Riyad Mahrez  Manchester City      MID    7.8     1055
# 381          Miguel Almiron    Newcastle Utd      MID    5.5     1879
# 45          Aymeric Laporte  Manchester City      DEF    5.7      555
# 547           Wilfried Zaha   Crystal Palace      MID    7.2     1661
# 29         Andrew Robertson        Liverpool      DEF    6.8     1590
#
#      projected_points_per_game  projected_points_with_decay       std  \
# 208                   4.780048                     3.015145  0.205603
# 498                   4.959797                     2.996761  0.391536
# 187                   5.445996                     3.305258  0.354251
# 386                   5.910157                     3.437400  0.661048
# 360                   5.117631                     3.107672  0.348813
# 300                   4.834021                     2.857040  0.819507
# 70                    4.776881                     2.902839  0.408151
# 119                   3.657949                     2.299865  0.230263
# 294                   5.449208                     3.066999  0.585238
# 162                   5.038960                     2.852106  0.654890
# 67                    4.838812                     2.798462  0.591538
# 143                   2.709165                     1.661914  0.883469
# 14                    4.733273                     2.650365  0.339496
# 268                   3.906857                     2.225572  0.178296
# 529                   4.080194                     2.358687  0.193538
# 455                   4.475142                     2.550843  0.451207
# 381                   4.268262                     2.523532  0.294568
# 45                    4.002408                     2.278872  0.140618
# 547                   4.235273                     2.578925  0.322303
# 29                    3.962584                     2.292681  0.209754
#
#      dream_team_appearances
# 208                      76
# 498                      72
# 187                      72
# 386                      68
# 360                      66
# 300                      56
# 70                       52
# 119                      45
# 294                      43
# 162                      38
# 67                       30
# 143                      27
# 14                       26
# 268                      25
# 529                      24
# 455                      24
# 381                      23
# 45                       23
# 547                      21
# 29                       20

# %%
print('GOALKEEPERS')
display(my_df[my_df['position']=='GK'].sort_values(by='dream_team_appearances', ascending=False).head(10))
# Out:
# GOALKEEPERS
#                   name             team position  price  minutes  \
# 119         David Raya        Brentford       GK    4.8     2070
# 198        Hugo Lloris        Tottenham       GK    5.4     1890
# 148            Ederson  Manchester City       GK    5.4     2250
# 2       Aaron Ramsdale          Arsenal       GK    4.9     2250
# 293  Kepa Arrizabalaga          Chelsea       GK    4.7     1395
# 21             Alisson        Liverpool       GK    5.4     2160
# 457     Robert Sanchez         Brighton       GK    4.6     1980
# 537     Vicente Guaita   Crystal Palace       GK    4.4     2160
# 120       David de Gea   Manchester Utd       GK    5.0     2160
# 332   Lukasz Fabianski         West Ham       GK    5.0     2031
#
#      projected_points_per_game  projected_points_with_decay       std  \
# 119                   3.657949                     2.299865  0.230263
# 198                   3.552668                     2.135678  0.229504
# 148                   3.787019                     2.157567  0.228948
# 2                     3.458309                     2.109378  0.167265
# 293                   3.503630                     2.124479  0.155217
# 21                    3.557529                     2.058575  0.185813
# 457                   3.226446                     1.951964  0.139907
# 537                   3.206831                     1.936294  0.116409
# 120                   3.358385                     1.939216  0.141171
# 332                   3.364935                     1.953914  0.134849
#
#      dream_team_appearances
# 119                      45
# 198                      16
# 148                      13
# 2                         7
# 293                       7
# 21                        4
# 457                       3
# 537                       2
# 120                       1
# 332                       1

# %%
print('DEFENDERS')
display(my_df[my_df['position']=='DEF'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# DEFENDERS
#                        name             team position  price  minutes  \
# 300         Kieran Trippier    Newcastle Utd      DEF    6.0     2017
# 143         Duje Caleta-Car      Southampton      DEF    4.5      713
# 268             John Stones  Manchester City      DEF    5.4     1180
# 529  Trent Alexander-Arnold        Liverpool      DEF    7.3     1778
# 45          Aymeric Laporte  Manchester City      DEF    5.7      555
# 29         Andrew Robertson        Liverpool      DEF    6.8     1590
# 55        Benoit Badiashile          Chelsea      DEF    5.0      450
# 174      Gabriel Dos Santos          Arsenal      DEF    5.2     2250
# 214           Jack Stephens      Bournemouth      DEF    4.3      498
# 168            Fabian Schar    Newcastle Utd      DEF    5.1     1964
# 417     Oleksandr Zinchenko          Arsenal      DEF    5.1     1432
# 308             Kyle Walker  Manchester City      DEF    4.8     1072
# 448             Reece James          Chelsea      DEF    5.8      849
# 467              Ruben Dias  Manchester City      DEF    5.9     1187
# 319              Lewis Dunk         Brighton      DEF    4.7     1980
# 549          William Saliba          Arsenal      DEF    5.3     2235
# 251            Joao Cancelo  Manchester City      DEF    7.1     1273
# 165           Ethan Pinnock        Brentford      DEF    4.4     1350
# 47             Ben Chilwell          Chelsea      DEF    5.8      617
# 506             Sven Botman    Newcastle Utd      DEF    4.5     1777
#
#      projected_points_per_game  projected_points_with_decay       std  \
# 300                   4.834021                     2.857040  0.819507
# 143                   2.709165                     1.661914  0.883469
# 268                   3.906857                     2.225572  0.178296
# 529                   4.080194                     2.358687  0.193538
# 45                    4.002408                     2.278872  0.140618
# 29                    3.962584                     2.292681  0.209754
# 55                    3.687317                     2.234765  0.161131
# 174                   3.667989                     2.234116  0.130861
# 214                   2.679700                     1.573698  0.650025
# 168                   3.673984                     2.162098  0.173161
# 417                   3.538235                     2.160208  0.154605
# 308                   3.618385                     2.065665  0.228865
# 448                   3.594116                     2.176536  0.123739
# 467                   3.749153                     2.138132  0.149276
# 319                   3.214404                     1.946538  0.252320
# 549                   3.539169                     2.160973  0.128536
# 251                   3.632995                     2.073646  0.268753
# 165                   3.082758                     1.943534  0.141907
# 47                    3.443854                     2.084254  0.155881
# 506                   3.323401                     1.950209  0.132832
#
#      dream_team_appearances
# 300                      56
# 143                      27
# 268                      25
# 529                      24
# 45                       23
# 29                       20
# 55                       19
# 174                      17
# 214                      15
# 168                      12
# 417                      12
# 308                      10
# 448                       7
# 467                       6
# 319                       4
# 549                       4
# 251                       3
# 165                       3
# 47                        3
# 506                       2

# %%
print('MIDFIELDERS')
display(my_df[my_df['position']=='MID'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# MIDFIELDERS
#                   name             team position  price  minutes  \
# 498        Solly March         Brighton      MID    5.1     1900
# 386      Mohamed Salah        Liverpool      MID   12.7     2136
# 360     Martin degaard          Arsenal      MID    7.0     2041
# 70         Bukayo Saka          Arsenal      MID    8.5     2155
# 294    Kevin De Bruyne  Manchester City      MID   12.2     1860
# 67     Bruno Fernandes   Manchester Utd      MID    9.8     2069
# 455       Riyad Mahrez  Manchester City      MID    7.8     1055
# 381     Miguel Almiron    Newcastle Utd      MID    5.5     1879
# 547      Wilfried Zaha   Crystal Palace      MID    7.2     1661
# 442    Raheem Sterling          Chelsea      MID    9.7     1268
# 240       Jarrod Bowen         West Ham      MID    8.0     2151
# 361         Martinelli          Arsenal      MID    6.3     2005
# 95          Cody Gakpo        Liverpool      MID    7.8      490
# 435         Phil Foden  Manchester City      MID    8.0     1252
# 130       Dennis Praet   Leicester City      MID    4.8      460
# 232  James Ward-Prowse      Southampton      MID    6.3     2160
# 312   Leandro Trossard          Arsenal      MID    6.6     1604
# 523        Tom Cairney           Fulham      MID    4.7      455
# 211      Jack Grealish  Manchester City      MID    6.8     1342
# 38              Antony   Manchester Utd      MID    7.3      910
#
#      projected_points_per_game  projected_points_with_decay       std  \
# 498                   4.959797                     2.996761  0.391536
# 386                   5.910157                     3.437400  0.661048
# 360                   5.117631                     3.107672  0.348813
# 70                    4.776881                     2.902839  0.408151
# 294                   5.449208                     3.066999  0.585238
# 67                    4.838812                     2.798462  0.591538
# 455                   4.475142                     2.550843  0.451207
# 381                   4.268262                     2.523532  0.294568
# 547                   4.235273                     2.578925  0.322303
# 442                   4.490190                     2.722785  0.275241
# 240                   4.537100                     2.639152  0.267155
# 361                   4.310996                     2.620116  0.171968
# 95                    4.146130                     2.402658  0.287996
# 435                   4.417420                     2.507958  0.234789
# 130                   2.682217                     1.594570  0.777358
# 232                   3.625919                     2.223188  0.267570
# 312                   3.902491                     2.368677  0.166998
# 523                   2.573150                     1.451503  0.582164
# 211                   4.246282                     2.412489  0.219380
# 38                    3.976707                     2.299997  0.250811
#
#      dream_team_appearances
# 498                      72
# 386                      68
# 360                      66
# 70                       52
# 294                      43
# 67                       30
# 455                      24
# 381                      23
# 547                      21
# 442                      15
# 240                      14
# 361                      13
# 95                        7
# 435                       3
# 130                       3
# 232                       2
# 312                       1
# 523                       1
# 211                       1
# 38                        1

# %%
print('FORWARDS')
display(my_df[my_df['position']=='FWD'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# FORWARDS
#                      name             team position  price  minutes  \
# 208            Ivan Toney        Brentford      FWD    7.6     1881
# 187            Harry Kane        Tottenham      FWD   11.7     2236
# 162        Erling Haaland  Manchester City      FWD   11.8     1931
# 14    Aleksandar Mitrovic           Fulham      FWD    6.8     1636
# 175         Gabriel Jesus          Arsenal      FWD    7.9     1220
# 117          Darwin Nunez        Liverpool      FWD    8.8     1200
# 419         Ollie Watkins      Aston Villa      FWD    7.3     1885
# 103     Cristiano Ronaldo   Manchester Utd      FWD   10.2      519
# 380       Michail Antonio         West Ham      FWD    7.0     1120
# 281           Kai Havertz          Chelsea      FWD    7.6     1705
# 291     Kelechi Iheanacho   Leicester City      FWD    6.2      565
# 298         Kieffer Moore      Bournemouth      FWD    5.1     1113
# 5          Adam Armstrong      Southampton      FWD    5.4     1060
# 408           Neal Maupay          Everton      FWD    5.9      932
# 244  Jean-Philippe Mateta   Crystal Palace      FWD    5.1      646
# 416       Odsonne Edouard   Crystal Palace      FWD    5.1     1114
# 428       Patrick Bamford     Leeds United      FWD    7.2      819
# 429           Patson Daka   Leicester City      FWD    5.6      710
# 446          Raul Jimenez           Wolves      FWD    6.7      495
# 452           Richarlison        Tottenham      FWD    8.4      649
#
#      projected_points_per_game  projected_points_with_decay       std  \
# 208                   4.780048                     3.015145  0.205603
# 187                   5.445996                     3.305258  0.354251
# 162                   5.038960                     2.852106  0.654890
# 14                    4.733273                     2.650365  0.339496
# 175                   4.457621                     2.724801  0.224548
# 117                   3.861633                     2.234032  0.345111
# 419                   4.033670                     2.416553  0.205978
# 103                   4.098137                     2.368969  0.174523
# 380                   2.785202                     1.614074  0.129757
# 281                   3.466799                     2.096478  0.136697
# 291                   3.023123                     1.795561  0.137105
# 298                   2.579055                     1.515603  0.173312
# 5                     2.354662                     1.439590  0.161938
# 408                   2.606591                     1.541049  0.211104
# 244                   2.467280                     1.496453  0.107003
# 416                   2.385520                     1.446058  0.148023
# 428                   3.357158                     1.998352  0.220617
# 429                   2.583783                     1.536578  0.150782
# 446                   2.493814                     1.457018  0.137566
# 452                   3.165592                     1.893741  0.163552
#
#      dream_team_appearances
# 208                      76
# 187                      72
# 162                      38
# 14                       26
# 175                      18
# 117                       3
# 419                       3
# 103                       1
# 380                       0
# 281                       0
# 291                       0
# 298                       0
# 5                         0
# 408                       0
# 244                       0
# 416                       0
# 428                       0
# 429                       0
# 446                       0
# 452                       0
