# %% [markdown]
# TO DO:
# - Add option to force players into the team, i.e., optimize given certain player are already locked in

# %%
# previous gameweek
gameweek=36

# %%
import pandas as pd
import numpy as np
import json
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable

# %%
# fetch player_dict 
with open('../data/player_name_dict.txt', 'r') as f:
    player_name_dict_as_text = f.read()
    player_name_dict = json.loads(player_name_dict_as_text)

# %% [markdown]
# # Solver definition

# %%
# function to solve the optimization problem
def optimize(df, max_price, expected_column):
    
    # PRELIMINARIES

    # Create the model
    model = LpProblem(name="FPL", sense=LpMaximize)    
    variables = [LpVariable(name=f'{ix}', cat='Binary') for ix in df.index]
    captaincy_variables = [LpVariable(name=f'cap_{ix}', cat='Binary') for ix in df.index]
    prices = [df.loc[ix,'price'] for ix in df.index]
    # measure of player quality
    expected_points = [df.loc[ix,expected_column] for ix in df.index]
    goalkeepers = [1.0 if df.loc[ix,'position']=='GK' else 0.0 for ix in df.index]
    defenders = [1.0 if df.loc[ix,'position']=='DEF' else 0.0 for ix in df.index]
    midfielders = [1.0 if df.loc[ix,'position']=='MID' else 0.0 for ix in df.index]
    forwards = [1.0 if df.loc[ix,'position']=='FWD' else 0.0 for ix in df.index]
    teams = []
    for team in df['team'].unique():
        teams.append( [1.0 if df.loc[ix,'team']==team else 0.0 for ix in df.index] )

    # CONSTRAINTS

    # select 11 players
    model += lpSum(variables) == 11
    # select 1 captain
    model += lpSum(captaincy_variables) == 1
    # captain must be one of the 11 players in the team
    for i in range(0,len(variables)):
        model += captaincy_variables[i] <= variables[i]
    # set maximum price for starting 11
    model += np.dot(prices,variables) <= max_price
    # only 1 goalkeeper
    model += np.dot(goalkeepers,variables) == 1
    # at least 3 defenders
    model += np.dot(defenders,variables) >= 3
    # at most 5 defenders
    model += np.dot(defenders,variables) <= 5
    # at most 5 midfielders
    model += np.dot(midfielders,variables) <= 5
    # at least 1 forward
    model += np.dot(forwards,variables) >= 1
    # at most 3 forwards
    model += np.dot(forwards,variables) <= 3
    # max 3 players from any given team
    for team in teams:
        model += np.dot(team,variables) <= 3

    # OBJECTIVE
    # the second part doubles the captain's points
    model += np.dot(expected_points,variables) + np.dot(expected_points,captaincy_variables)

    # SOLVE OPTIMIZATION

    status = model.solve()
    print(f'Status: {LpStatus[model.status]}')
    #print(f'Mean total points per gameweek: {model.objective.value()}')

    players = [str(var) for var in model.variables() if var.value()==1]
    captain = [player for player in players if 'cap' in player]
    captain = int(captain[0].replace('cap_', ''))
    players = [int(player) for player in players if 'cap' not in player]
    dream_team = df.loc[players]
    cost = (dream_team['price']).sum()
    exp_points = dream_team[expected_column].sum() + df.loc[captain, expected_column]
    print(f'Cost: {cost}')
    print(f'Expected points per week: {exp_points}')
    
    display(dream_team[['position','name', 'team', 'price',expected_column]].sort_values('position'))
    
    return players

# %% [markdown]
# # Data

# %%
#projections = pd.read_csv(f'../point_projections/xP_projections_week{gameweek}.csv', index_col=0)
projections = pd.read_csv(f'../point_projections/collective_xP_projections_week{gameweek}.csv', index_col=0)
projections = projections.rename(columns={'xP':'projected_points'})
projections.head(5)
# Out:
#              name     team           opp_team  was_home  gameweek  \
# 0    Granit Xhaka  Arsenal  Nottingham Forest         0        37
# 1    Granit Xhaka  Arsenal             Wolves         1        38
# 2  Mohamed Elneny  Arsenal  Nottingham Forest         0        37
# 3  Mohamed Elneny  Arsenal             Wolves         1        38
# 4     Rob Holding  Arsenal  Nottingham Forest         0        37
#
#    projected_points       std
# 0          3.273749  0.247492
# 1          3.621738  0.277285
# 2          2.473593  0.159062
# 3          2.708667  0.119983
# 4          2.805570  0.125769

# %%
# decay for future projected points to model uncertainty increasing over time
decay_coeff = 0.875
projections['projected_points_with_decay'] = ( projections['projected_points']*decay_coeff
                                              **(projections['gameweek']-(gameweek+1)) )
projections.head(5)
# Out:
#              name     team           opp_team  was_home  gameweek  \
# 0    Granit Xhaka  Arsenal  Nottingham Forest         0        37
# 1    Granit Xhaka  Arsenal             Wolves         1        38
# 2  Mohamed Elneny  Arsenal  Nottingham Forest         0        37
# 3  Mohamed Elneny  Arsenal             Wolves         1        38
# 4     Rob Holding  Arsenal  Nottingham Forest         0        37
#
#    projected_points       std  projected_points_with_decay
# 0          3.273749  0.247492                     3.273749
# 1          3.621738  0.277285                     3.169021
# 2          2.473593  0.159062                     2.473593
# 3          2.708667  0.119983                     2.370083
# 4          2.805570  0.125769                     2.805570

# %%
fpl_df = pd.read_csv(f'../data/fpl_data/fpl_week_{gameweek}.csv', index_col=0)
fpl_df['name'] = fpl_df['name'].map(player_name_dict).fillna(fpl_df['name'])
fpl_df.head(5)
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                         100.0                         100.0   84450
# 1                           0.0                           0.0  153256
# 2                           NaN                           NaN  156074
# 3                         100.0                         100.0  167199
# 4                         100.0                         100.0  184029
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                 -2
# 1                  0                       0                 -4
# 2                  0                       0                 -3
# 3                  0                       0                 -3
# 4                  1                      -1                  3
#
#    cost_change_start_fall  dreamteam_count  element_type  ep_next  ...  \
# 0                       2                1             3      4.1  ...
# 1                       4                1             3      0.0  ...
# 2                       3                0             2      2.1  ...
# 3                       3                0             3      1.5  ...
# 4                      -3                5             3      7.7  ...
#
#     season            name position  GW  value     selected transfers_balance  \
# 0  2022-23    Granit Xhaka      MID  36    4.8   297310.624              3066
# 1  2022-23  Mohamed Elneny      MID  36    4.1    68610.144               124
# 2  2022-23     Rob Holding      DEF  36    4.2    22870.048              -268
# 3  2022-23   Thomas Partey      MID  36    4.7    45740.096              -123
# 4  2022-23  Martin degaard      MID  36    6.8  3533422.416             64328
#
#   opp_team_name          kickoff_time was_home
# 0      Brighton  2023-05-14T15:30:00Z      1.0
# 1      Brighton  2023-05-14T15:30:00Z      1.0
# 2      Brighton  2023-05-14T15:30:00Z      1.0
# 3      Brighton  2023-05-14T15:30:00Z      1.0
# 4      Brighton  2023-05-14T15:30:00Z      1.0
#
# [5 rows x 98 columns]

# %%
# choose time horizon for optimization
#horizon = 10

# create dataframe to be given as input for optimization
#df = projections[projections['gameweek']<=gameweek+horizon].groupby(by=['name']).mean()\
#                                                        [['projected_points','projected_points_with_decay', 'std']] 

# OPTIMIZE FOR GIVEN GAMEWEEKS
my_gameweeks = [37,38]
df = projections[projections['gameweek'].isin(my_gameweeks)].groupby(by=['name']).sum()\
                                                        [['projected_points','projected_points_with_decay']]
df['std'] = projections[projections['gameweek'].isin(my_gameweeks)].groupby(by=['name']).mean()\
                                                        [['std']]
df['number_of_games'] = (projections[projections['gameweek'].isin(my_gameweeks)]
                                     .groupby('name').count()['std'])

#df = df.to_frame()
df = df.reset_index()
#df = df.rename(columns={'projected_points':'projected_points_per_game'})
#df['team'] = [fpl_df.loc[fpl_df['name']==name, 'team'].values[0] for name in df['name']]
df['price'] = [fpl_df.loc[fpl_df['name']==name, 'value'].values[0] for name in df['name']]
df['position'] = [fpl_df.loc[fpl_df['name']==name, 'element_type'].values[0] for name in df['name']]
position_dict={1:'GK', 2:'DEF', 3:'MID', 4:'FWD'}
df['position'] = df['position'].map(position_dict)
df['position'] = pd.Categorical(df['position'], ['GK','DEF','MID','FWD'])
df['team'] = [projections.loc[projections['name']==name, 'team'].head(1).values[0] for name in df['name']]
df['minutes'] = [fpl_df.loc[fpl_df['name']==name, 'minutes'].values[0] for name in df['name']]
# re-order columns
df = df[['name', 'team', 'position', 'price', 'minutes', 'number_of_games', 'projected_points', 'projected_points_with_decay', 'std']]
df.head(5)
# Out:
# /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/ipykernel_47350/2941604232.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = projections[projections['gameweek'].isin(my_gameweeks)].groupby(by=['name']).sum()\
# /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/ipykernel_47350/2941604232.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['std'] = projections[projections['gameweek'].isin(my_gameweeks)].groupby(by=['name']).mean()\
#                  name            team position  price  minutes  \
# 0     Aaron Cresswell        West Ham      DEF    4.7     2165
# 1        Aaron Hickey       Brentford      DEF    4.9     1761
# 2      Aaron Ramsdale         Arsenal       GK    4.8     3240
# 3   Aaron Wan-Bissaka  Manchester Utd      DEF    4.3     1252
# 4  Abdoulaye Doucoure         Everton      MID    5.3     1347
#
#    number_of_games  projected_points  projected_points_with_decay       std
# 0                2          6.129977                     5.778472  0.143585
# 1                2          4.380148                     4.127618  0.106969
# 2                2          7.801205                     7.288740  0.110253
# 3                3          9.986055                     9.528764  0.115264
# 4                2          5.773990                     5.410259  0.153063

# %%
# remove players who do not have enough minutes played
cutoff = 450
df = df[df['minutes']>=cutoff]

# edit some player prices according to my selling price
df.loc[df['name']=='Erling Haaland', 'price'] = 11.8
df.loc[df['name']=='Martinelli', 'price'] = 6.3

# %% [markdown]
# # Optimization

# %%
team_value = 102
money_in_the_bank = 0.2
allowed_bench_value = 17.5
max_price = team_value + money_in_the_bank - allowed_bench_value

# %% [markdown]
# ## Without decay

# %%
players = optimize(df, max_price, 'projected_points_per_game')

# %%
ban = []
# ban some cheap keepers in good teams who don't actually play
cheap_keepers = ['Scott Carson', 'Zack Steffen', 'Jason Steele', 'Caoimhin Kelleher', 'Wayne Hennessey', 
                 'Karl Darlow', 'Darren Randolph']
cheap_keepers_ix = df[df['name'].isin(cheap_keepers)].index
ban = ban + list(cheap_keepers_ix)
# ban given players
ban_field = ['Marcos Alonso', 'Ben Chilwell', 'Riyad Mahrez', 'Darwin Nunez', 'Aymeric Laporte', 'Emil Krafth', 
             'Sergio Gomez', 'Nathaniel Phillips']
ban_field_ix = df[df['name'].isin(ban_field)].index
ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
players = optimize(my_df, max_price, 'projected_points_per_game')

# %% [markdown]
# ## With decay

# %%
#players = optimize(df, max_price, 'projected_points_with_decay')

# %%
ban = []

# ban given players
ban_field = ['Aymeric Laporte', 'Riyad Mahrez', 'Solly March']
#ban_field = []

ban_field_ix = df[df['name'].isin(ban_field)].index
ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
players = optimize(my_df, max_price, 'projected_points_with_decay')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/9bf6fb7e80f542b89024842206ffd8ae-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/9bf6fb7e80f542b89024842206ffd8ae-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 407 COLUMNS
# At line 5438 RHS
# At line 5841 BOUNDS
# At line 6588 ENDATA
# Problem MODEL has 402 rows, 746 columns and 2792 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 146.418 - 0.01 seconds
# Cgl0004I processed model has 400 rows, 746 columns (746 integer (746 of which binary)) and 2611 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.62963
# Cbc0038I Pass   1: suminf.    0.47312 (2) obj. -145.091 iterations 12
# Cbc0038I Solution found of -137.851
# Cbc0038I Before mini branch and bound, 740 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 400 rows 746 columns, reduced to 5 rows 5 columns
# Cbc0038I Mini branch and bound improved solution from -137.851 to -145.084 (0.04 seconds)
# Cbc0038I Round again with cutoff of -145.218
# Cbc0038I Reduced cost fixing fixed 697 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.53659 (2) obj. -145.67 iterations 2
# Cbc0038I Pass   3: suminf.    0.68242 (2) obj. -145.218 iterations 5
# Cbc0038I Pass   4: suminf.    0.24707 (2) obj. -145.218 iterations 10
# Cbc0038I Solution found of -145.658
# Cbc0038I Before mini branch and bound, 736 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 400 rows 746 columns, reduced to 5 rows 7 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of -145.81
# Cbc0038I Reduced cost fixing fixed 713 variables on major pass 3
# Cbc0038I Pass   5: suminf.    0.56417 (4) obj. -145.81 iterations 5
# Cbc0038I Pass   6: suminf.    0.94800 (2) obj. -145.81 iterations 5
# Cbc0038I Pass   7: suminf.    1.00000 (3) obj. -145.81 iterations 8
# Cbc0038I Pass   8: suminf.    1.00000 (3) obj. -145.81 iterations 3
# Cbc0038I Pass   9: suminf.    0.71968 (3) obj. -145.81 iterations 7
# Cbc0038I Pass  10: suminf.    0.57882 (4) obj. -145.81 iterations 6
# Cbc0038I Pass  11: suminf.    0.65427 (2) obj. -145.81 iterations 5
# Cbc0038I Pass  12: suminf.    1.10656 (5) obj. -145.81 iterations 7
# Cbc0038I Pass  13: suminf.    0.53991 (4) obj. -145.81 iterations 7
# Cbc0038I Pass  14: suminf.    0.95199 (2) obj. -145.81 iterations 8
# Cbc0038I Pass  15: suminf.    0.60224 (4) obj. -145.81 iterations 5
# Cbc0038I Pass  16: suminf.    0.42800 (4) obj. -145.81 iterations 10
# Cbc0038I Pass  17: suminf.    0.32755 (6) obj. -145.81 iterations 3
# Cbc0038I Pass  18: suminf.    1.45565 (7) obj. -145.81 iterations 7
# Cbc0038I Pass  19: suminf.    1.11283 (7) obj. -145.81 iterations 5
# Cbc0038I Pass  20: suminf.    1.86719 (5) obj. -145.81 iterations 6
# Cbc0038I Pass  21: suminf.    1.40104 (4) obj. -145.81 iterations 2
# Cbc0038I Pass  22: suminf.    1.40104 (4) obj. -145.81 iterations 1
# Cbc0038I Pass  23: suminf.    0.56417 (4) obj. -145.81 iterations 6
# Cbc0038I Pass  24: suminf.    0.94800 (2) obj. -145.81 iterations 5
# Cbc0038I Pass  25: suminf.    0.87425 (4) obj. -145.81 iterations 6
# Cbc0038I Pass  26: suminf.    0.72304 (5) obj. -145.81 iterations 4
# Cbc0038I Pass  27: suminf.    1.74198 (4) obj. -145.81 iterations 7
# Cbc0038I Pass  28: suminf.    1.74198 (4) obj. -145.81 iterations 0
# Cbc0038I Pass  29: suminf.    1.40104 (4) obj. -145.81 iterations 9
# Cbc0038I Pass  30: suminf.    1.40104 (4) obj. -145.81 iterations 2
# Cbc0038I Pass  31: suminf.    0.56417 (4) obj. -145.81 iterations 8
# Cbc0038I Pass  32: suminf.    0.94800 (2) obj. -145.81 iterations 7
# Cbc0038I Pass  33: suminf.    0.93651 (4) obj. -145.81 iterations 6
# Cbc0038I Pass  34: suminf.    0.76725 (3) obj. -145.81 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 726 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 400 rows 746 columns, reduced to 8 rows 19 columns
# Cbc0038I Mini branch and bound improved solution from -145.658 to -145.711 (0.07 seconds)
# Cbc0038I Round again with cutoff of -145.992
# Cbc0038I Reduced cost fixing fixed 719 variables on major pass 4
# Cbc0038I Pass  34: suminf.    0.63356 (3) obj. -145.992 iterations 2
# Cbc0038I Pass  35: suminf.    0.83459 (2) obj. -145.992 iterations 6
# Cbc0038I Pass  36: suminf.    1.44889 (5) obj. -145.992 iterations 5
# Cbc0038I Pass  37: suminf.    1.00237 (6) obj. -145.992 iterations 7
# Cbc0038I Pass  38: suminf.    0.68659 (4) obj. -145.992 iterations 6
# Cbc0038I Pass  39: suminf.    0.69445 (2) obj. -145.992 iterations 7
# Cbc0038I Pass  40: suminf.    0.71377 (2) obj. -145.992 iterations 2
# Cbc0038I Pass  41: suminf.    2.01775 (7) obj. -145.992 iterations 10
# Cbc0038I Pass  42: suminf.    1.79339 (6) obj. -145.992 iterations 1
# Cbc0038I Pass  43: suminf.    1.79339 (6) obj. -145.992 iterations 0
# Cbc0038I Pass  44: suminf.    1.09637 (7) obj. -145.992 iterations 5
# Cbc0038I Pass  45: suminf.    0.66467 (6) obj. -145.992 iterations 1
# Cbc0038I Pass  46: suminf.    1.46499 (4) obj. -145.992 iterations 6
# Cbc0038I Pass  47: suminf.    1.46499 (4) obj. -145.992 iterations 0
# Cbc0038I Pass  48: suminf.    0.83459 (2) obj. -145.992 iterations 2
# Cbc0038I Pass  49: suminf.    0.63356 (3) obj. -145.992 iterations 6
# Cbc0038I Pass  50: suminf.    0.83459 (2) obj. -145.992 iterations 5
# Cbc0038I Pass  51: suminf.    0.83459 (2) obj. -145.992 iterations 0
# Cbc0038I Pass  52: suminf.    1.21069 (4) obj. -145.992 iterations 5
# Cbc0038I Pass  53: suminf.    0.64702 (5) obj. -145.992 iterations 7
# Cbc0038I Pass  54: suminf.    1.40842 (5) obj. -145.992 iterations 4
# Cbc0038I Pass  55: suminf.    0.50573 (3) obj. -145.992 iterations 4
# Cbc0038I Pass  56: suminf.    0.52078 (2) obj. -145.992 iterations 5
# Cbc0038I Pass  57: suminf.    0.98075 (7) obj. -145.992 iterations 7
# Cbc0038I Pass  58: suminf.    0.36122 (6) obj. -145.992 iterations 8
# Cbc0038I Pass  59: suminf.    0.32936 (3) obj. -145.992 iterations 3
# Cbc0038I Pass  60: suminf.    0.83858 (2) obj. -145.992 iterations 5
# Cbc0038I Pass  61: suminf.    0.66678 (3) obj. -145.992 iterations 3
# Cbc0038I Pass  62: suminf.    0.83858 (2) obj. -145.992 iterations 5
# Cbc0038I Pass  63: suminf.    0.93429 (4) obj. -145.992 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 725 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 400 rows 746 columns, reduced to 9 rows 21 columns
# Cbc0038I Mini branch and bound improved solution from -145.711 to -146.08 (0.09 seconds)
# Cbc0038I Round again with cutoff of -146.182
# Cbc0038I Reduced cost fixing fixed 729 variables on major pass 5
# Cbc0038I Pass  63: suminf.    0.64889 (3) obj. -146.182 iterations 0
# Cbc0038I Pass  64: suminf.    0.71682 (2) obj. -146.182 iterations 6
# Cbc0038I Pass  65: suminf.    1.22983 (5) obj. -146.182 iterations 5
# Cbc0038I Pass  66: suminf.    1.31039 (4) obj. -146.182 iterations 7
# Cbc0038I Pass  67: suminf.    1.21756 (4) obj. -146.182 iterations 1
# Cbc0038I Pass  68: suminf.    0.77326 (3) obj. -146.182 iterations 9
# Cbc0038I Pass  69: suminf.    0.79811 (2) obj. -146.182 iterations 5
# Cbc0038I Pass  70: suminf.    2.89685 (6) obj. -146.182 iterations 9
# Cbc0038I Pass  71: suminf.    1.69231 (4) obj. -146.386 iterations 4
# Cbc0038I Pass  72: suminf.    0.64889 (3) obj. -146.182 iterations 3
# Cbc0038I Pass  73: suminf.    0.71682 (2) obj. -146.182 iterations 2
# Cbc0038I Pass  74: suminf.    0.71682 (2) obj. -146.182 iterations 1
# Cbc0038I Pass  75: suminf.    1.22983 (5) obj. -146.182 iterations 5
# Cbc0038I Pass  76: suminf.    1.69972 (4) obj. -146.182 iterations 9
# Cbc0038I Pass  77: suminf.    1.69972 (4) obj. -146.182 iterations 1
# Cbc0038I Pass  78: suminf.    0.83986 (5) obj. -146.182 iterations 11
# Cbc0038I Pass  79: suminf.    1.84109 (4) obj. -146.182 iterations 4
# Cbc0038I Pass  80: suminf.    0.77326 (3) obj. -146.182 iterations 7
# Cbc0038I Pass  81: suminf.    0.79811 (2) obj. -146.182 iterations 5
# Cbc0038I Pass  82: suminf.    1.66487 (6) obj. -146.182 iterations 6
# Cbc0038I Pass  83: suminf.    2.95826 (7) obj. -146.182 iterations 2
# Cbc0038I Pass  84: suminf.    1.21756 (4) obj. -146.182 iterations 4
# Cbc0038I Pass  85: suminf.    1.31039 (4) obj. -146.182 iterations 3
# Cbc0038I Pass  86: suminf.    1.21756 (4) obj. -146.182 iterations 3
# Cbc0038I Pass  87: suminf.    1.49720 (7) obj. -146.182 iterations 5
# Cbc0038I Pass  88: suminf.    1.20824 (6) obj. -146.182 iterations 3
# Cbc0038I Pass  89: suminf.    1.97504 (4) obj. -146.182 iterations 4
# Cbc0038I Pass  90: suminf.    0.64889 (3) obj. -146.182 iterations 7
# Cbc0038I Pass  91: suminf.    0.71682 (2) obj. -146.182 iterations 5
# Cbc0038I Pass  92: suminf.    1.08443 (4) obj. -146.182 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 731 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 400 rows 746 columns, reduced to 8 rows 15 columns
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of -146.08 - took 0.08 seconds
# Cbc0012I Integer solution of -146.08044 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0038I Full problem 400 rows 746 columns, reduced to 7 rows 9 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 2 added rows had average density of 15
# Cbc0013I At root node, 2 cuts changed objective from -146.418 to -146.07403 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 5 row cuts average 6.8 elements, 1 column cuts (1 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 10 row cuts average 16.1 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 18.5 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 18.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 12 row cuts average 16.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -146.08044325, took 17 iterations and 0 nodes (0.12 seconds)
# Cbc0035I Maximum depth 0, 736 variables fixed on reduced cost
# Cuts at root node changed objective from -146.418 to -146.074
# Probing was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 2 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 2 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 2 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                146.08044325
# Enumerated nodes:               0
# Total iterations:               17
# Time (CPU seconds):             0.12
# Time (Wallclock seconds):       0.13
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.13   (Wallclock seconds):       0.14
#
# Status: Optimal
# Cost: 84.7
# Expected points per week: 146.08044325
#     position               name             team  price  \
# 152       GK            Ederson  Manchester City    5.4
# 275      DEF        John Stones  Manchester City    5.6
# 443      DEF   Pervis Estupinan         Brighton    4.9
# 457      DEF        Reece James          Chelsea    5.8
# 293      MID       Kaoru Mitoma         Brighton    5.7
# 38       MID             Antony   Manchester Utd    7.3
# 394      MID      Mohamed Salah        Liverpool   13.1
# 435      MID         Pascal Gro         Brighton    5.4
# 68       MID    Bruno Fernandes   Manchester Utd    9.5
# 104      FWD  Cristiano Ronaldo   Manchester Utd   10.2
# 166      FWD     Erling Haaland  Manchester City   11.8
#
#      projected_points_with_decay
# 152                    10.229232
# 275                    10.328787
# 443                     8.941826
# 457                     8.392618
# 293                    11.706538
# 38                     14.128996
# 394                    13.888977
# 435                    11.031224
# 68                     16.051266
# 104                    12.381213
# 166                    12.948499

# %% [markdown]
# # Sensitivity analysis
#
# Here we add small random Gaussian noise to each players' projected points and run the optimization with these new estimates. We repeat the process n times and keep a list of how many times each player appeared in the optimal team.

# %%
ban = []

# ban given players
ban_field = ['Aymeric Laporte', 'Riyad Mahrez', 'Solly March', 'Cristiano Ronaldo']
#ban_field = []

ban_field_ix = df[df['name'].isin(ban_field)].index
ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
metric = 'projected_points_with_decay'
# set the standard deviation of the Gaussian noise to be a fraction of each players' projected points
#sigma_factor = 0.1
simulation_rounds = 100
results = []
for i in range(0,simulation_rounds):
    df_with_noise = my_df.copy()
    #df_with_noise[metric] = df_with_noise[metric] + np.random.normal(0, df_with_noise[metric]*sigma_factor)
    df_with_noise[metric] = df_with_noise[metric] + np.random.normal(0, df_with_noise['std'])*df_with_noise['number_of_games']
    players = optimize(df_with_noise, max_price, metric)
    results.append(players)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/97f6acbf1b9d4d16adc3a8acae9494c4-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/97f6acbf1b9d4d16adc3a8acae9494c4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 406 COLUMNS
# At line 5423 RHS
# At line 5825 BOUNDS
# At line 6570 ENDATA
# Problem MODEL has 401 rows, 744 columns and 2784 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 153.651 - 0.01 seconds
# Cgl0004I processed model has 399 rows, 744 columns (744 integer (744 of which binary)) and 2604 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.507937
# Cbc0038I Solution found of -153.553
# Cbc0038I Before mini branch and bound, 740 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -153.563
# Cbc0038I Reduced cost fixing fixed 733 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.04580 (4) obj. -153.563 iterations 4
# Cbc0038I Pass   2: suminf.    1.70399 (6) obj. -153.563 iterations 4
# Cbc0038I Pass   3: suminf.    0.04580 (4) obj. -153.563 iterations 3
# Cbc0038I Pass   4: suminf.    0.04580 (4) obj. -153.563 iterations 0
# Cbc0038I Pass   5: suminf.    0.57945 (5) obj. -153.563 iterations 3
# Cbc0038I Pass   6: suminf.    0.04580 (4) obj. -153.563 iterations 3
# Cbc0038I Pass   7: suminf.    0.04580 (4) obj. -153.563 iterations 1
# Cbc0038I Pass   8: suminf.    0.04580 (4) obj. -153.563 iterations 1
# Cbc0038I Pass   9: suminf.    0.60826 (5) obj. -153.563 iterations 3
# Cbc0038I Pass  10: suminf.    0.04580 (4) obj. -153.563 iterations 3
# Cbc0038I Pass  11: suminf.    0.05084 (4) obj. -153.563 iterations 1
# Cbc0038I Pass  12: suminf.    0.04580 (4) obj. -153.563 iterations 2
# Cbc0038I Pass  13: suminf.    0.04580 (4) obj. -153.563 iterations 0
# Cbc0038I Pass  14: suminf.    0.04580 (4) obj. -153.563 iterations 0
# Cbc0038I Pass  15: suminf.    0.04580 (4) obj. -153.563 iterations 1
# Cbc0038I Pass  16: suminf.    0.05084 (4) obj. -153.563 iterations 1
# Cbc0038I Pass  17: suminf.    0.13532 (6) obj. -153.563 iterations 3
# Cbc0038I Pass  18: suminf.    0.05084 (4) obj. -153.563 iterations 1
# Cbc0038I Pass  19: suminf.    0.37420 (4) obj. -153.563 iterations 3
# Cbc0038I Pass  20: suminf.    0.59794 (4) obj. -153.563 iterations 1
# Cbc0038I Pass  21: suminf.    2.05086 (6) obj. -153.563 iterations 4
# Cbc0038I Pass  22: suminf.    0.04580 (4) obj. -153.563 iterations 1
# Cbc0038I Pass  23: suminf.    0.04580 (4) obj. -153.563 iterations 0
# Cbc0038I Pass  24: suminf.    2.05086 (6) obj. -153.563 iterations 1
# Cbc0038I Pass  25: suminf.    0.04580 (4) obj. -153.563 iterations 1
# Cbc0038I Pass  26: suminf.    0.04580 (4) obj. -153.563 iterations 0
# Cbc0038I Pass  27: suminf.    0.04580 (4) obj. -153.563 iterations 0
# Cbc0038I Pass  28: suminf.    0.50794 (4) obj. -153.651 iterations 3
# Cbc0038I Pass  29: suminf.    0.04580 (4) obj. -153.563 iterations 3
# Cbc0038I Pass  30: suminf.    0.04580 (4) obj. -153.563 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 736 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 7 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -153.553 - took 0.02 seconds
# Cbc0012I Integer solution of -153.55278 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 1 added rows had average density of 8
# Cbc0013I At root node, 1 cuts changed objective from -153.65052 to -153.55278 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 3.0 elements, 1 column cuts (1 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 8.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -153.552776835294, took 1 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 733 variables fixed on reduced cost
# Cuts at root node changed objective from -153.651 to -153.553
# Probing was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                153.55277684
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.07
#
# Status: Optimal
# Cost: 83.9
# Expected points per week: 153.55277683531017
#     position                 name             team  price  \
# 152       GK              Ederson  Manchester City    5.4
# 351      DEF        Manuel Akanji  Manchester City    5.1
# 443      DEF     Pervis Estupinan         Brighton    4.9
# 547      DEF      Victor Lindelof   Manchester Utd    4.1
# 20       MID  Alexis Mac Allister         Brighton    5.6
# 293      MID         Kaoru Mitoma         Brighton    5.7
# 38       MID               Antony   Manchester Utd    7.3
# 394      MID        Mohamed Salah        Liverpool   13.1
# 68       MID      Bruno Fernandes   Manchester Utd    9.5
# 166      FWD       Erling Haaland  Manchester City   11.8
# 191      FWD           Harry Kane        Tottenham   11.4
#
#      projected_points_with_decay
# 152                    11.198935
# 351                    10.704263
# 443                     9.307656
# 547                    10.477604
# 20                     11.665748
# 293                    11.811063
# 38                     14.331943
# 394                    15.135522
# 68                     17.687781
# 166                    13.105141
# 191                    10.439338
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/0fc348aa6726454ca57ecced71becb45-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/0fc348aa6726454ca57ecced71becb45-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 406 COLUMNS
# At line 5423 RHS
# At line 5825 BOUNDS
# At line 6570 ENDATA
# Problem MODEL has 401 rows, 744 columns and 2784 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 147.6 - 0.00 seconds
# Cgl0004I processed model has 399 rows, 744 columns (744 integer (744 of which binary)) and 2604 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.30303
# Cbc0038I Pass   1: suminf.    0.10870 (2) obj. -147.225 iterations 12
# Cbc0038I Solution found of -138.922
# Cbc0038I Before mini branch and bound, 739 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 5 rows 5 columns
# Cbc0038I Mini branch and bound improved solution from -138.922 to -146.344 (0.04 seconds)
# Cbc0038I Round again with cutoff of -146.469
# Cbc0038I Reduced cost fixing fixed 707 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.11364 (2) obj. -147.416 iterations 3
# Cbc0038I Pass   3: suminf.    0.48924 (2) obj. -146.469 iterations 4
# Cbc0038I Pass   4: suminf.    1.58067 (6) obj. -146.469 iterations 9
# Cbc0038I Pass   5: suminf.    0.75554 (4) obj. -146.469 iterations 3
# Cbc0038I Pass   6: suminf.    0.43804 (4) obj. -146.469 iterations 4
# Cbc0038I Pass   7: suminf.    0.25744 (2) obj. -146.469 iterations 2
# Cbc0038I Pass   8: suminf.    0.29545 (2) obj. -146.732 iterations 8
# Cbc0038I Pass   9: suminf.    0.39958 (2) obj. -146.469 iterations 2
# Cbc0038I Pass  10: suminf.    1.46452 (4) obj. -146.469 iterations 10
# Cbc0038I Pass  11: suminf.    0.72726 (4) obj. -146.469 iterations 3
# Cbc0038I Pass  12: suminf.    0.36972 (4) obj. -146.469 iterations 5
# Cbc0038I Pass  13: suminf.    0.21729 (2) obj. -146.469 iterations 4
# Cbc0038I Pass  14: suminf.    0.29545 (2) obj. -146.755 iterations 8
# Cbc0038I Pass  15: suminf.    0.40878 (2) obj. -146.469 iterations 4
# Cbc0038I Pass  16: suminf.    0.89958 (3) obj. -146.469 iterations 5
# Cbc0038I Pass  17: suminf.    0.91591 (4) obj. -146.469 iterations 7
# Cbc0038I Pass  18: suminf.    0.91591 (4) obj. -146.469 iterations 2
# Cbc0038I Pass  19: suminf.    0.91591 (4) obj. -146.469 iterations 1
# Cbc0038I Pass  20: suminf.    0.91591 (4) obj. -146.469 iterations 1
# Cbc0038I Pass  21: suminf.    0.21729 (2) obj. -146.469 iterations 4
# Cbc0038I Pass  22: suminf.    0.29545 (2) obj. -146.755 iterations 7
# Cbc0038I Pass  23: suminf.    0.40878 (2) obj. -146.469 iterations 2
# Cbc0038I Pass  24: suminf.    0.21729 (2) obj. -146.469 iterations 5
# Cbc0038I Pass  25: suminf.    0.95465 (4) obj. -146.469 iterations 9
# Cbc0038I Pass  26: suminf.    0.07158 (2) obj. -146.469 iterations 4
# Cbc0038I Pass  27: suminf.    1.00000 (3) obj. -146.469 iterations 7
# Cbc0038I Pass  28: suminf.    0.24490 (2) obj. -146.469 iterations 4
# Cbc0038I Solution found of -146.742
# Cbc0038I Before mini branch and bound, 724 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 8 rows 16 columns
# Cbc0038I Mini branch and bound improved solution from -146.742 to -147.004 (0.06 seconds)
# Cbc0038I Round again with cutoff of -147.123
# Cbc0038I Reduced cost fixing fixed 718 variables on major pass 3
# Cbc0038I Pass  29: suminf.    0.12195 (2) obj. -147.183 iterations 3
# Cbc0038I Pass  30: suminf.    0.13603 (2) obj. -147.123 iterations 8
# Cbc0038I Pass  31: suminf.    0.94379 (7) obj. -147.123 iterations 7
# Cbc0038I Pass  32: suminf.    0.91763 (3) obj. -147.123 iterations 7
# Cbc0038I Pass  33: suminf.    1.94816 (4) obj. -147.123 iterations 7
# Cbc0038I Pass  34: suminf.    2.04213 (8) obj. -147.123 iterations 5
# Cbc0038I Pass  35: suminf.    2.04213 (8) obj. -147.123 iterations 1
# Cbc0038I Pass  36: suminf.    0.65451 (5) obj. -147.123 iterations 8
# Cbc0038I Pass  37: suminf.    0.12195 (2) obj. -147.183 iterations 7
# Cbc0038I Pass  38: suminf.    0.13603 (2) obj. -147.123 iterations 5
# Cbc0038I Pass  39: suminf.    1.31567 (6) obj. -147.123 iterations 7
# Cbc0038I Pass  40: suminf.    0.35542 (4) obj. -147.123 iterations 2
# Cbc0038I Pass  41: suminf.    0.27771 (2) obj. -147.123 iterations 7
# Cbc0038I Pass  42: suminf.    0.38889 (5) obj. -147.123 iterations 2
# Cbc0038I Pass  43: suminf.    0.12195 (2) obj. -147.16 iterations 5
# Cbc0038I Pass  44: suminf.    0.13058 (2) obj. -147.123 iterations 3
# Cbc0038I Pass  45: suminf.    0.13058 (2) obj. -147.123 iterations 1
# Cbc0038I Pass  46: suminf.    0.45116 (3) obj. -147.123 iterations 7
# Cbc0038I Pass  47: suminf.    0.33773 (3) obj. -147.123 iterations 2
# Cbc0038I Pass  48: suminf.    1.63822 (4) obj. -147.123 iterations 6
# Cbc0038I Pass  49: suminf.    1.68684 (6) obj. -147.123 iterations 3
# Cbc0038I Pass  50: suminf.    0.63200 (7) obj. -147.123 iterations 9
# Cbc0038I Pass  51: suminf.    0.39482 (6) obj. -147.123 iterations 5
# Cbc0038I Pass  52: suminf.    1.49316 (5) obj. -147.123 iterations 6
# Cbc0038I Pass  53: suminf.    1.28352 (6) obj. -147.123 iterations 1
# Cbc0038I Pass  54: suminf.    1.70654 (4) obj. -147.123 iterations 4
# Cbc0038I Pass  55: suminf.    0.12195 (2) obj. -147.183 iterations 7
# Cbc0038I Pass  56: suminf.    0.13603 (2) obj. -147.123 iterations 6
# Cbc0038I Pass  57: suminf.    2.35686 (8) obj. -147.123 iterations 7
# Cbc0038I Pass  58: suminf.    1.30823 (6) obj. -147.123 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 720 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 9 rows 21 columns
# Cbc0038I Mini branch and bound improved solution from -147.004 to -147.095 (0.07 seconds)
# Cbc0038I Round again with cutoff of -147.266
# Cbc0038I Reduced cost fixing fixed 723 variables on major pass 4
# Cbc0038I Pass  58: suminf.    0.12588 (3) obj. -147.266 iterations 4
# Cbc0038I Pass  59: suminf.    0.20847 (2) obj. -147.266 iterations 4
# Cbc0038I Pass  60: suminf.    0.44748 (5) obj. -147.266 iterations 6
# Cbc0038I Pass  61: suminf.    0.27586 (2) obj. -147.293 iterations 9
# Cbc0038I Pass  62: suminf.    0.26657 (4) obj. -147.266 iterations 6
# Cbc0038I Pass  63: suminf.    0.30343 (2) obj. -147.266 iterations 3
# Cbc0038I Pass  64: suminf.    0.27586 (2) obj. -147.293 iterations 4
# Cbc0038I Pass  65: suminf.    0.71664 (6) obj. -147.266 iterations 6
# Cbc0038I Pass  66: suminf.    1.04561 (6) obj. -147.266 iterations 4
# Cbc0038I Pass  67: suminf.    0.12698 (3) obj. -147.266 iterations 5
# Cbc0038I Pass  68: suminf.    0.19739 (2) obj. -147.266 iterations 2
# Cbc0038I Pass  69: suminf.    0.88897 (6) obj. -147.266 iterations 10
# Cbc0038I Pass  70: suminf.    1.49442 (6) obj. -147.266 iterations 7
# Cbc0038I Pass  71: suminf.    1.33491 (7) obj. -147.266 iterations 2
# Cbc0038I Pass  72: suminf.    0.27586 (2) obj. -147.269 iterations 6
# Cbc0038I Pass  73: suminf.    0.27465 (4) obj. -147.266 iterations 5
# Cbc0038I Pass  74: suminf.    0.27947 (2) obj. -147.266 iterations 2
# Cbc0038I Pass  75: suminf.    0.38038 (4) obj. -147.266 iterations 7
# Cbc0038I Pass  76: suminf.    1.49442 (6) obj. -147.266 iterations 6
# Cbc0038I Pass  77: suminf.    0.68399 (4) obj. -147.266 iterations 3
# Cbc0038I Pass  78: suminf.    0.31029 (6) obj. -147.266 iterations 5
# Cbc0038I Pass  79: suminf.    1.97247 (5) obj. -147.266 iterations 4
# Cbc0038I Pass  80: suminf.    0.12698 (3) obj. -147.266 iterations 8
# Cbc0038I Pass  81: suminf.    0.19739 (2) obj. -147.266 iterations 2
# Cbc0038I Pass  82: suminf.    0.13499 (3) obj. -147.266 iterations 4
# Cbc0038I Pass  83: suminf.    0.13715 (4) obj. -147.266 iterations 1
# Cbc0038I Pass  84: suminf.    0.12698 (3) obj. -147.266 iterations 2
# Cbc0038I Pass  85: suminf.    0.21024 (6) obj. -147.266 iterations 5
# Cbc0038I Pass  86: suminf.    0.21024 (6) obj. -147.266 iterations 0
# Cbc0038I Pass  87: suminf.    0.33884 (5) obj. -147.266 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 724 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 8 rows 16 columns
# Cbc0038I Mini branch and bound did not improve solution (0.09 seconds)
# Cbc0038I After 0.09 seconds - Feasibility pump exiting with objective of -147.095 - took 0.07 seconds
# Cbc0012I Integer solution of -147.09456 found by feasibility pump after 0 iterations and 0 nodes (0.09 seconds)
# Cbc0038I Full problem 399 rows 744 columns, reduced to 6 rows 7 columns
# Cbc0031I 3 added rows had average density of 12.333333
# Cbc0013I At root node, 3 cuts changed objective from -147.59971 to -147.09493 in 11 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 105 row cuts average 16.6 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 14 row cuts average 8.3 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 12 row cuts average 14.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 62 row cuts average 16.7 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -147.094561071008, took 85 iterations and 0 nodes (0.13 seconds)
# Cbc0032I Strong branching done 2 times (6 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 731 variables fixed on reduced cost
# Cuts at root node changed objective from -147.6 to -147.095
# Probing was tried 11 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 11 times and created 105 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Knapsack was tried 11 times and created 14 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Clique was tried 11 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 11 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 11 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 11 times and created 62 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
#
# Result - Optimal solution found
#
# Objective value:                147.09456107
# Enumerated nodes:               0
# Total iterations:               85
# Time (CPU seconds):             0.13
# Time (Wallclock seconds):       0.13
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.13   (Wallclock seconds):       0.14
#
# Status: Optimal
# Cost: 84.2
# Expected points per week: 147.09456107099626
#     position             name             team  price  \
# 124       GK     David de Gea   Manchester Utd    5.1
# 271      DEF     Joel Veltman         Brighton    4.6
# 275      DEF      John Stones  Manchester City    5.6
# 47       DEF     Ben Chilwell          Chelsea    5.6
# 293      MID     Kaoru Mitoma         Brighton    5.7
# 302      MID  Kevin De Bruyne  Manchester City   12.2
# 38       MID           Antony   Manchester Utd    7.3
# 435      MID       Pascal Gro         Brighton    5.4
# 68       MID  Bruno Fernandes   Manchester Utd    9.5
# 166      FWD   Erling Haaland  Manchester City   11.8
# 191      FWD       Harry Kane        Tottenham   11.4
#
#      projected_points_with_decay
# 124                    10.147274
# 271                     9.373034
# 275                    10.833622
# 47                      8.978707
# 293                    12.012051
# 302                    15.422999
# 38                     15.446205
# 435                    12.154893
# 68                     14.097489
# 166                    12.604397
# 191                    10.577685
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/d397f2438936454c98f18b8d68dff1e0-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/d397f2438936454c98f18b8d68dff1e0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 406 COLUMNS
# At line 5423 RHS
# At line 5825 BOUNDS
# At line 6570 ENDATA
# Problem MODEL has 401 rows, 744 columns and 2784 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 153.654 - 0.00 seconds
# Cgl0004I processed model has 399 rows, 744 columns (744 integer (744 of which binary)) and 2604 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.864865
# Cbc0038I Pass   1: suminf.    0.69565 (2) obj. -151.171 iterations 7
# Cbc0038I Solution found of -145.674
# Cbc0038I Before mini branch and bound, 741 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from -145.674 to -153.066 (0.03 seconds)
# Cbc0038I Round again with cutoff of -153.125
# Cbc0038I Reduced cost fixing fixed 722 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.81257 (3) obj. -153.125 iterations 4
# Cbc0038I Pass   3: suminf.    0.28328 (2) obj. -153.125 iterations 4
# Cbc0038I Pass   4: suminf.    0.28328 (2) obj. -153.125 iterations 1
# Cbc0038I Pass   5: suminf.    0.91641 (2) obj. -153.125 iterations 4
# Cbc0038I Pass   6: suminf.    0.91641 (2) obj. -153.125 iterations 2
# Cbc0038I Pass   7: suminf.    0.53415 (3) obj. -153.125 iterations 7
# Cbc0038I Pass   8: suminf.    0.91641 (2) obj. -153.125 iterations 5
# Cbc0038I Pass   9: suminf.    0.79986 (2) obj. -153.125 iterations 3
# Cbc0038I Pass  10: suminf.    0.79986 (2) obj. -153.125 iterations 3
# Cbc0038I Pass  11: suminf.    0.93177 (3) obj. -153.125 iterations 7
# Cbc0038I Pass  12: suminf.    0.90785 (2) obj. -153.125 iterations 6
# Cbc0038I Pass  13: suminf.    0.90785 (2) obj. -153.125 iterations 0
# Cbc0038I Pass  14: suminf.    1.84671 (6) obj. -153.125 iterations 4
# Cbc0038I Pass  15: suminf.    0.42274 (3) obj. -153.125 iterations 6
# Cbc0038I Pass  16: suminf.    0.78556 (2) obj. -153.125 iterations 4
# Cbc0038I Pass  17: suminf.    0.78556 (2) obj. -153.125 iterations 1
# Cbc0038I Pass  18: suminf.    0.48898 (3) obj. -153.125 iterations 5
# Cbc0038I Pass  19: suminf.    1.48691 (5) obj. -153.125 iterations 3
# Cbc0038I Pass  20: suminf.    0.21851 (3) obj. -153.125 iterations 2
# Cbc0038I Pass  21: suminf.    0.58130 (2) obj. -153.125 iterations 2
# Cbc0038I Pass  22: suminf.    0.21851 (3) obj. -153.125 iterations 5
# Cbc0038I Pass  23: suminf.    0.39091 (4) obj. -153.125 iterations 3
# Cbc0038I Pass  24: suminf.    0.25315 (4) obj. -153.125 iterations 13
# Cbc0038I Solution found of -153.317
# Cbc0038I Before mini branch and bound, 728 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 7 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from -153.317 to -153.519 (0.05 seconds)
# Cbc0038I Round again with cutoff of -153.546
# Cbc0038I Reduced cost fixing fixed 731 variables on major pass 3
# Cbc0038I Pass  25: suminf.    0.83117 (2) obj. -153.629 iterations 1
# Cbc0038I Pass  26: suminf.    0.97792 (2) obj. -153.546 iterations 6
# Cbc0038I Pass  27: suminf.    0.97792 (2) obj. -153.546 iterations 0
# Cbc0038I Pass  28: suminf.    0.37773 (2) obj. -153.546 iterations 4
# Cbc0038I Pass  29: suminf.    0.37773 (2) obj. -153.546 iterations 2
# Cbc0038I Pass  30: suminf.    1.39016 (6) obj. -153.546 iterations 2
# Cbc0038I Pass  31: suminf.    0.37773 (2) obj. -153.546 iterations 2
# Cbc0038I Pass  32: suminf.    0.09309 (2) obj. -153.546 iterations 2
# Cbc0038I Pass  33: suminf.    0.09309 (2) obj. -153.546 iterations 1
# Cbc0038I Pass  34: suminf.    0.83117 (2) obj. -153.629 iterations 3
# Cbc0038I Pass  35: suminf.    0.97792 (2) obj. -153.546 iterations 1
# Cbc0038I Pass  36: suminf.    2.51593 (7) obj. -153.546 iterations 3
# Cbc0038I Pass  37: suminf.    0.28102 (7) obj. -153.546 iterations 1
# Cbc0038I Pass  38: suminf.    0.28102 (7) obj. -153.546 iterations 0
# Cbc0038I Pass  39: suminf.    0.92538 (2) obj. -153.546 iterations 3
# Cbc0038I Pass  40: suminf.    0.92538 (2) obj. -153.546 iterations 0
# Cbc0038I Pass  41: suminf.    0.83117 (2) obj. -153.629 iterations 5
# Cbc0038I Pass  42: suminf.    0.97792 (2) obj. -153.546 iterations 3
# Cbc0038I Pass  43: suminf.    2.63881 (7) obj. -153.546 iterations 4
# Cbc0038I Pass  44: suminf.    0.37773 (2) obj. -153.546 iterations 4
# Cbc0038I Pass  45: suminf.    0.37773 (2) obj. -153.546 iterations 1
# Cbc0038I Pass  46: suminf.    0.37773 (2) obj. -153.546 iterations 2
# Cbc0038I Pass  47: suminf.    0.37773 (2) obj. -153.546 iterations 2
# Cbc0038I Pass  48: suminf.    0.83117 (2) obj. -153.629 iterations 3
# Cbc0038I Pass  49: suminf.    0.97792 (2) obj. -153.546 iterations 2
# Cbc0038I Pass  50: suminf.    0.97792 (2) obj. -153.546 iterations 1
# Cbc0038I Pass  51: suminf.    0.87473 (3) obj. -153.546 iterations 3
# Cbc0038I Pass  52: suminf.    0.92538 (2) obj. -153.546 iterations 1
# Cbc0038I Pass  53: suminf.    0.92538 (2) obj. -153.546 iterations 2
# Cbc0038I Pass  54: suminf.    0.92538 (2) obj. -153.546 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 734 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 7 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -153.519 - took 0.05 seconds
# Cbc0012I Integer solution of -153.51852 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 399 rows 744 columns, reduced to 2 rows 3 columns
# Cbc0031I 2 added rows had average density of 7
# Cbc0013I At root node, 15 cuts changed objective from -153.65434 to -153.49302 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 3 row cuts average 5.3 elements, 2 column cuts (2 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 9 row cuts average 10.3 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 6 row cuts average 8.5 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 12.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 14 row cuts average 9.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -153.518519303087, took 12 iterations and 0 nodes (0.09 seconds)
# Cbc0035I Maximum depth 0, 732 variables fixed on reduced cost
# Cuts at root node changed objective from -153.654 to -153.493
# Probing was tried 3 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 3 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 3 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 3 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 3 times and created 14 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                153.51851930
# Enumerated nodes:               0
# Total iterations:               12
# Time (CPU seconds):             0.09
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.10
#
# Status: Optimal
# Cost: 83.89999999999999
# Expected points per week: 153.518519303099
#     position             name             team  price  \
# 247       GK     Jason Steele         Brighton    4.0
# 257      DEF     Joao Cancelo  Manchester City    7.1
# 275      DEF      John Stones  Manchester City    5.6
# 9        DEF     Adam Webster         Brighton    4.5
# 293      MID     Kaoru Mitoma         Brighton    5.7
# 362      MID  Marcus Rashford   Manchester Utd    7.2
# 38       MID           Antony   Manchester Utd    7.3
# 394      MID    Mohamed Salah        Liverpool   13.1
# 68       MID  Bruno Fernandes   Manchester Utd    9.5
# 166      FWD   Erling Haaland  Manchester City   11.8
# 179      FWD    Gabriel Jesus          Arsenal    8.1
#
#      projected_points_with_decay
# 247                    10.219892
# 257                    10.610860
# 275                    10.605983
# 9                       8.745918
# 293                    12.012786
# 362                    13.770000
# 38                     15.032842
# 394                    13.048724
# 68                     17.693603
# 166                    13.258422
# 179                    10.825888
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/8cc9a734b1f041908d8bad90d4ee9751-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/8cc9a734b1f041908d8bad90d4ee9751-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 406 COLUMNS
# At line 5423 RHS
# At line 5825 BOUNDS
# At line 6570 ENDATA
# Problem MODEL has 401 rows, 744 columns and 2784 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 158.84 - 0.00 seconds
# Cgl0004I processed model has 399 rows, 744 columns (744 integer (744 of which binary)) and 2604 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.285714
# Cbc0038I Pass   1: suminf.    0.08696 (2) obj. -158.48 iterations 11
# Cbc0038I Solution found of -149.199
# Cbc0038I Before mini branch and bound, 740 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -149.199 to -158.47 (0.04 seconds)
# Cbc0038I Round again with cutoff of -158.507
# Cbc0038I Reduced cost fixing fixed 726 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.10390 (2) obj. -158.577 iterations 3
# Cbc0038I Pass   3: suminf.    0.12631 (2) obj. -158.507 iterations 4
# Cbc0038I Pass   4: suminf.    0.15310 (3) obj. -158.507 iterations 5
# Cbc0038I Pass   5: suminf.    0.15310 (3) obj. -158.507 iterations 1
# Cbc0038I Pass   6: suminf.    2.60185 (6) obj. -158.507 iterations 3
# Cbc0038I Pass   7: suminf.    2.60185 (6) obj. -158.507 iterations 0
# Cbc0038I Pass   8: suminf.    0.57295 (6) obj. -158.507 iterations 2
# Cbc0038I Pass   9: suminf.    1.43960 (4) obj. -158.507 iterations 7
# Cbc0038I Pass  10: suminf.    0.72034 (7) obj. -158.507 iterations 5
# Cbc0038I Pass  11: suminf.    0.17147 (2) obj. -158.507 iterations 5
# Cbc0038I Pass  12: suminf.    0.17147 (2) obj. -158.507 iterations 2
# Cbc0038I Pass  13: suminf.    0.17147 (2) obj. -158.507 iterations 0
# Cbc0038I Pass  14: suminf.    0.17147 (2) obj. -158.507 iterations 0
# Cbc0038I Pass  15: suminf.    0.17147 (2) obj. -158.507 iterations 0
# Cbc0038I Pass  16: suminf.    0.17147 (2) obj. -158.507 iterations 2
# Cbc0038I Pass  17: suminf.    0.49056 (5) obj. -158.507 iterations 4
# Cbc0038I Pass  18: suminf.    0.54626 (3) obj. -158.507 iterations 6
# Cbc0038I Pass  19: suminf.    0.13399 (3) obj. -158.507 iterations 4
# Cbc0038I Pass  20: suminf.    1.93413 (4) obj. -158.507 iterations 7
# Cbc0038I Pass  21: suminf.    1.93413 (4) obj. -158.507 iterations 0
# Cbc0038I Pass  22: suminf.    0.54626 (3) obj. -158.507 iterations 10
# Cbc0038I Pass  23: suminf.    0.08479 (2) obj. -158.507 iterations 7
# Cbc0038I Solution found of -158.711
# Cbc0038I Before mini branch and bound, 730 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 4 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -158.737
# Cbc0038I Reduced cost fixing fixed 735 variables on major pass 3
# Cbc0038I Pass  24: suminf.    0.27586 (2) obj. -158.827 iterations 2
# Cbc0038I Pass  25: suminf.    0.60543 (2) obj. -158.737 iterations 5
# Cbc0038I Pass  26: suminf.    0.28140 (3) obj. -158.737 iterations 3
# Cbc0038I Pass  27: suminf.    0.27586 (2) obj. -158.827 iterations 2
# Cbc0038I Pass  28: suminf.    0.27586 (2) obj. -158.827 iterations 0
# Cbc0038I Pass  29: suminf.    0.28140 (3) obj. -158.737 iterations 3
# Cbc0038I Pass  30: suminf.    0.34987 (6) obj. -158.737 iterations 1
# Cbc0038I Pass  31: suminf.    0.28140 (3) obj. -158.737 iterations 1
# Cbc0038I Pass  32: suminf.    0.36602 (6) obj. -158.737 iterations 2
# Cbc0038I Pass  33: suminf.    0.36602 (6) obj. -158.737 iterations 0
# Cbc0038I Pass  34: suminf.    0.27586 (2) obj. -158.827 iterations 4
# Cbc0038I Pass  35: suminf.    0.60543 (2) obj. -158.737 iterations 2
# Cbc0038I Pass  36: suminf.    0.60543 (2) obj. -158.737 iterations 0
# Cbc0038I Pass  37: suminf.    0.76286 (2) obj. -158.737 iterations 1
# Cbc0038I Pass  38: suminf.    0.76286 (2) obj. -158.737 iterations 0
# Cbc0038I Pass  39: suminf.    0.76286 (2) obj. -158.737 iterations 0
# Cbc0038I Pass  40: suminf.    0.36602 (6) obj. -158.737 iterations 2
# Cbc0038I Pass  41: suminf.    0.76286 (2) obj. -158.737 iterations 2
# Cbc0038I Pass  42: suminf.    0.76286 (2) obj. -158.737 iterations 0
# Cbc0038I Pass  43: suminf.    0.29233 (3) obj. -158.737 iterations 2
# Cbc0038I Pass  44: suminf.    0.76286 (2) obj. -158.737 iterations 2
# Cbc0038I Pass  45: suminf.    0.60543 (2) obj. -158.737 iterations 2
# Cbc0038I Pass  46: suminf.    0.28140 (3) obj. -158.737 iterations 3
# Cbc0038I Pass  47: suminf.    0.28140 (3) obj. -158.737 iterations 0
# Cbc0038I Pass  48: suminf.    0.29233 (3) obj. -158.737 iterations 2
# Cbc0038I Pass  49: suminf.    0.27586 (2) obj. -158.827 iterations 2
# Cbc0038I Pass  50: suminf.    0.27586 (2) obj. -158.827 iterations 0
# Cbc0038I Pass  51: suminf.    0.60543 (2) obj. -158.737 iterations 3
# Cbc0038I Pass  52: suminf.    0.60543 (2) obj. -158.737 iterations 0
# Cbc0038I Pass  53: suminf.    0.27586 (2) obj. -158.827 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 737 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 2 rows 3 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -158.711 - took 0.05 seconds
# Cbc0012I Integer solution of -158.71141 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 399 rows 744 columns, reduced to 3 rows 4 columns
# Cbc0031I 1 added rows had average density of 8
# Cbc0013I At root node, 6 cuts changed objective from -158.84024 to -158.71141 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -158.711413732577, took 0 iterations and 0 nodes (0.08 seconds)
# Cbc0035I Maximum depth 0, 734 variables fixed on reduced cost
# Cuts at root node changed objective from -158.84 to -158.711
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                158.71141373
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.08
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.09   (Wallclock seconds):       0.09
#
# Status: Optimal
# Cost: 84.60000000000001
# Expected points per week: 158.71141373257166
#     position                    name             team  price  \
# 152       GK                 Ederson  Manchester City    5.4
# 193      DEF           Harry Souttar   Leicester City    4.5
# 351      DEF           Manuel Akanji  Manchester City    5.1
# 538      DEF  Trent Alexander-Arnold        Liverpool    7.7
# 302      MID         Kevin De Bruyne  Manchester City   12.2
# 38       MID                  Antony   Manchester Utd    7.3
# 394      MID           Mohamed Salah        Liverpool   13.1
# 435      MID              Pascal Gro         Brighton    5.4
# 68       MID         Bruno Fernandes   Manchester Utd    9.5
# 179      FWD           Gabriel Jesus          Arsenal    8.1
# 35       FWD         Anthony Martial   Manchester Utd    6.3
#
#      projected_points_with_decay
# 152                    10.942891
# 193                    10.586197
# 351                    10.720419
# 538                     9.316588
# 302                    14.851670
# 38                     13.705497
# 394                    14.677370
# 435                    12.328214
# 68                     19.965464
# 179                    10.076483
# 35                     11.575156
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/22ee735de7f14950abb3898da96284c8-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/22ee735de7f14950abb3898da96284c8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 406 COLUMNS
# At line 5423 RHS
# At line 5825 BOUNDS
# At line 6570 ENDATA
# Problem MODEL has 401 rows, 744 columns and 2784 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 143.848 - 0.00 seconds
# Cgl0004I processed model has 399 rows, 744 columns (744 integer (744 of which binary)) and 2604 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -143.848
# Cbc0038I Before mini branch and bound, 744 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -143.848 - took 0.00 seconds
# Cbc0012I Integer solution of -143.84845 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -143.848453205284, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -143.848 to -143.848
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                143.84845321
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: Optimal
# Cost: 84.2
# Expected points per week: 143.8484532052766
#     position              name             team  price  \
# 247       GK      Jason Steele         Brighton    4.0
# 138      DEF       Diogo Dalot   Manchester Utd    4.8
# 275      DEF       John Stones  Manchester City    5.6
# 383      DEF  Maximilian Wober     Leeds United    4.4
# 293      MID      Kaoru Mitoma         Brighton    5.7
# 302      MID   Kevin De Bruyne  Manchester City   12.2
# 362      MID   Marcus Rashford   Manchester Utd    7.2
# 38       MID            Antony   Manchester Utd    7.3
# 394      MID     Mohamed Salah        Liverpool   13.1
# 166      FWD    Erling Haaland  Manchester City   11.8
# 179      FWD     Gabriel Jesus          Arsenal    8.1
#
#      projected_points_with_decay
# 247                     9.767609
# 138                    10.893408
# 275                    10.623196
# 383                     9.491589
# 293                    11.790873
# 302                    12.911674
# 362                    12.711801
# 38                     14.018410
# 394                    13.242778
# 166                    13.417571
# 179                    10.961134
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/16fc1c4949a345c38cf4e5deec77986c-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/16fc1c4949a345c38cf4e5deec77986c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 406 COLUMNS
# At line 5423 RHS
# At line 5825 BOUNDS
# At line 6570 ENDATA
# Problem MODEL has 401 rows, 744 columns and 2784 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 146.877 - 0.01 seconds
# Cgl0004I processed model has 399 rows, 744 columns (744 integer (744 of which binary)) and 2604 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.28
# Cbc0038I Pass   1: suminf.    0.15217 (2) obj. -146.356 iterations 12
# Cbc0038I Solution found of -138.131
# Cbc0038I Before mini branch and bound, 741 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from -138.131 to -145.913 (0.03 seconds)
# Cbc0038I Round again with cutoff of -146.01
# Cbc0038I Reduced cost fixing fixed 713 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.19178 (2) obj. -146.666 iterations 3
# Cbc0038I Pass   3: suminf.    0.53492 (2) obj. -146.01 iterations 7
# Cbc0038I Pass   4: suminf.    0.92125 (2) obj. -146.01 iterations 3
# Cbc0038I Pass   5: suminf.    0.92125 (2) obj. -146.01 iterations 1
# Cbc0038I Pass   6: suminf.    0.88707 (3) obj. -146.01 iterations 7
# Cbc0038I Pass   7: suminf.    0.19048 (2) obj. -146.358 iterations 9
# Cbc0038I Pass   8: suminf.    0.35075 (2) obj. -146.01 iterations 6
# Cbc0038I Pass   9: suminf.    0.12859 (4) obj. -146.01 iterations 6
# Cbc0038I Pass  10: suminf.    0.03175 (2) obj. -146.171 iterations 8
# Cbc0038I Pass  11: suminf.    0.10605 (2) obj. -146.01 iterations 7
# Cbc0038I Pass  12: suminf.    0.28611 (5) obj. -146.01 iterations 12
# Cbc0038I Pass  13: suminf.    0.17425 (3) obj. -146.01 iterations 7
# Cbc0038I Pass  14: suminf.    0.32266 (2) obj. -146.01 iterations 7
# Cbc0038I Pass  15: suminf.    0.43857 (2) obj. -146.01 iterations 6
# Cbc0038I Pass  16: suminf.    0.58124 (6) obj. -146.01 iterations 8
# Cbc0038I Pass  17: suminf.    0.52409 (5) obj. -146.01 iterations 3
# Cbc0038I Pass  18: suminf.    0.34933 (3) obj. -146.01 iterations 11
# Cbc0038I Pass  19: suminf.    0.19048 (2) obj. -146.358 iterations 8
# Cbc0038I Pass  20: suminf.    0.35075 (2) obj. -146.01 iterations 6
# Cbc0038I Pass  21: suminf.    0.54734 (2) obj. -146.01 iterations 6
# Cbc0038I Pass  22: suminf.    0.54734 (2) obj. -146.01 iterations 0
# Cbc0038I Pass  23: suminf.    0.75421 (3) obj. -146.01 iterations 8
# Cbc0038I Pass  24: suminf.    0.75532 (2) obj. -146.01 iterations 6
# Cbc0038I Pass  25: suminf.    0.75532 (2) obj. -146.01 iterations 1
# Cbc0038I Pass  26: suminf.    1.36826 (6) obj. -146.01 iterations 4
# Cbc0038I Pass  27: suminf.    0.09524 (2) obj. -146.348 iterations 9
# Cbc0038I Pass  28: suminf.    0.25056 (2) obj. -146.01 iterations 8
# Cbc0038I Pass  29: suminf.    0.70841 (2) obj. -146.01 iterations 7
# Cbc0038I Pass  30: suminf.    1.06210 (4) obj. -146.01 iterations 4
# Cbc0038I Pass  31: suminf.    1.00000 (3) obj. -146.01 iterations 6
# Cbc0038I Rounding solution of -146.086 is better than previous of -145.913
#
# Cbc0038I Before mini branch and bound, 721 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 8 rows 22 columns
# Cbc0038I Mini branch and bound improved solution from -146.086 to -146.283 (0.06 seconds)
# Cbc0038I Round again with cutoff of -146.402
# Cbc0038I Reduced cost fixing fixed 720 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.19178 (2) obj. -146.666 iterations 0
# Cbc0038I Pass  32: suminf.    0.33004 (2) obj. -146.402 iterations 7
# Cbc0038I Pass  33: suminf.    0.65192 (3) obj. -146.402 iterations 4
# Cbc0038I Pass  34: suminf.    0.66557 (2) obj. -146.402 iterations 5
# Cbc0038I Pass  35: suminf.    0.75148 (4) obj. -146.402 iterations 12
# Cbc0038I Pass  36: suminf.    0.22267 (3) obj. -146.402 iterations 6
# Cbc0038I Pass  37: suminf.    0.48409 (2) obj. -146.402 iterations 9
# Cbc0038I Pass  38: suminf.    0.48409 (2) obj. -146.402 iterations 1
# Cbc0038I Pass  39: suminf.    0.74363 (3) obj. -146.402 iterations 9
# Cbc0038I Pass  40: suminf.    0.70112 (2) obj. -146.402 iterations 5
# Cbc0038I Pass  41: suminf.    0.82506 (4) obj. -146.402 iterations 5
# Cbc0038I Pass  42: suminf.    0.70112 (2) obj. -146.402 iterations 3
# Cbc0038I Pass  43: suminf.    0.95298 (2) obj. -146.402 iterations 7
# Cbc0038I Pass  44: suminf.    0.95298 (2) obj. -146.402 iterations 3
# Cbc0038I Pass  45: suminf.    0.80041 (4) obj. -146.402 iterations 6
# Cbc0038I Pass  46: suminf.    1.72145 (4) obj. -146.402 iterations 6
# ...
# Cbc0038I Pass  36: suminf.    0.93187 (4) obj. -148.869 iterations 1
# Cbc0038I Pass  37: suminf.    0.76190 (2) obj. -149.578 iterations 6
# Cbc0038I Pass  38: suminf.    0.17070 (2) obj. -148.869 iterations 5
# Cbc0038I Pass  39: suminf.    0.46608 (2) obj. -148.869 iterations 5
# Cbc0038I Pass  40: suminf.    0.46608 (2) obj. -148.869 iterations 5
# Cbc0038I Pass  41: suminf.    1.00000 (3) obj. -148.869 iterations 6
# Cbc0038I Pass  42: suminf.    0.46608 (2) obj. -148.869 iterations 5
# Cbc0038I Pass  43: suminf.    0.79837 (5) obj. -148.869 iterations 5
# Cbc0038I Pass  44: suminf.    0.55160 (4) obj. -148.869 iterations 5
# Cbc0038I Pass  45: suminf.    0.48665 (4) obj. -148.869 iterations 3
# Cbc0038I Pass  46: suminf.    0.76190 (2) obj. -149.578 iterations 4
# Cbc0038I Pass  47: suminf.    0.17070 (2) obj. -148.869 iterations 5
# Cbc0038I Pass  48: suminf.    0.17070 (2) obj. -148.869 iterations 2
# Cbc0038I Pass  49: suminf.    0.17070 (2) obj. -148.869 iterations 2
# Cbc0038I Pass  50: suminf.    0.17070 (2) obj. -148.869 iterations 5
# Cbc0038I Pass  51: suminf.    0.17070 (2) obj. -148.869 iterations 4
# Cbc0038I Pass  52: suminf.    1.59655 (4) obj. -148.869 iterations 9
# Cbc0038I Pass  53: suminf.    1.59655 (4) obj. -148.869 iterations 2
# Cbc0038I Pass  54: suminf.    1.36088 (4) obj. -148.869 iterations 2
# Cbc0038I Pass  55: suminf.    1.59655 (4) obj. -148.869 iterations 2
# Cbc0038I Pass  56: suminf.    1.59655 (4) obj. -148.869 iterations 1
# Cbc0038I Pass  57: suminf.    0.76190 (2) obj. -149.578 iterations 4
# Cbc0038I Pass  58: suminf.    0.76190 (2) obj. -149.578 iterations 3
# Cbc0038I Pass  59: suminf.    0.17070 (2) obj. -148.869 iterations 4
# Cbc0038I Pass  60: suminf.    0.96187 (4) obj. -148.869 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 730 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 7 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from -148.664 to -148.664 (0.07 seconds)
# Cbc0038I Round again with cutoff of -149.115
# Cbc0038I Reduced cost fixing fixed 727 variables on major pass 4
# Cbc0038I Pass  60: suminf.    0.95238 (2) obj. -149.688 iterations 0
# Cbc0038I Pass  61: suminf.    0.51835 (2) obj. -149.115 iterations 7
# Cbc0038I Pass  62: suminf.    1.00000 (3) obj. -149.115 iterations 5
# Cbc0038I Pass  63: suminf.    0.51835 (2) obj. -149.115 iterations 3
# Cbc0038I Pass  64: suminf.    0.51835 (2) obj. -149.115 iterations 0
# Cbc0038I Pass  65: suminf.    1.64320 (5) obj. -149.115 iterations 3
# Cbc0038I Pass  66: suminf.    1.50784 (4) obj. -149.115 iterations 6
# Cbc0038I Pass  67: suminf.    0.61557 (2) obj. -149.115 iterations 4
# Cbc0038I Pass  68: suminf.    0.69841 (2) obj. -149.214 iterations 3
# Cbc0038I Pass  69: suminf.    0.61557 (2) obj. -149.115 iterations 4
# Cbc0038I Pass  70: suminf.    2.54355 (6) obj. -149.115 iterations 8
# Cbc0038I Pass  71: suminf.    1.15371 (4) obj. -149.115 iterations 4
# Cbc0038I Pass  72: suminf.    0.76190 (2) obj. -149.578 iterations 4
# Cbc0038I Pass  73: suminf.    0.37559 (2) obj. -149.115 iterations 3
# Cbc0038I Pass  74: suminf.    1.22724 (4) obj. -149.115 iterations 4
# Cbc0038I Pass  75: suminf.    0.72053 (2) obj. -149.115 iterations 2
# Cbc0038I Pass  76: suminf.    0.92063 (2) obj. -149.355 iterations 4
# Cbc0038I Pass  77: suminf.    0.95238 (2) obj. -149.182 iterations 2
# Cbc0038I Pass  78: suminf.    0.89625 (2) obj. -149.115 iterations 4
# Cbc0038I Pass  79: suminf.    0.95238 (2) obj. -149.182 iterations 3
# Cbc0038I Pass  80: suminf.    0.55131 (2) obj. -149.115 iterations 4
# Cbc0038I Pass  81: suminf.    0.55131 (2) obj. -149.115 iterations 2
# Cbc0038I Pass  82: suminf.    0.79365 (2) obj. -149.405 iterations 3
# Cbc0038I Pass  83: suminf.    0.80945 (3) obj. -149.115 iterations 7
# Cbc0038I Pass  84: suminf.    0.37559 (2) obj. -149.115 iterations 4
# Cbc0038I Pass  85: suminf.    0.76190 (2) obj. -149.578 iterations 3
# Cbc0038I Pass  86: suminf.    0.92063 (2) obj. -149.355 iterations 6
# Cbc0038I Pass  87: suminf.    0.72053 (2) obj. -149.115 iterations 5
# Cbc0038I Pass  88: suminf.    0.92063 (2) obj. -149.355 iterations 6
# Cbc0038I Pass  89: suminf.    0.72053 (2) obj. -149.115 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 733 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 7 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I After 0.08 seconds - Feasibility pump exiting with objective of -148.664 - took 0.06 seconds
# Cbc0012I Integer solution of -148.66417 found by feasibility pump after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0038I Full problem 399 rows 744 columns, reduced to 4 rows 5 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 2 added rows had average density of 17
# Cbc0013I At root node, 2 cuts changed objective from -149.68816 to -148.66625 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 4 column cuts (4 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 16.7 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 2 row cuts average 17.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 8 row cuts average 15.6 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -148.664165867301, took 9 iterations and 0 nodes (0.10 seconds)
# Cbc0035I Maximum depth 0, 731 variables fixed on reduced cost
# Cuts at root node changed objective from -149.688 to -148.666
# Probing was tried 3 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 2 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 2 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                148.66416587
# Enumerated nodes:               0
# Total iterations:               9
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.11   (Wallclock seconds):       0.11
#
# Status: Optimal
# Cost: 82.30000000000001
# Expected points per week: 148.66416586729457
#     position              name             team  price  \
# 466       GK    Robert Sanchez         Brighton    4.5
# 275      DEF       John Stones  Manchester City    5.6
# 344      DEF         Luke Shaw   Manchester Utd    5.2
# 443      DEF  Pervis Estupinan         Brighton    4.9
# 302      MID   Kevin De Bruyne  Manchester City   12.2
# 362      MID   Marcus Rashford   Manchester Utd    7.2
# 368      MID    Martin degaard          Arsenal    6.8
# 38       MID            Antony   Manchester Utd    7.3
# 435      MID        Pascal Gro         Brighton    5.4
# 166      FWD    Erling Haaland  Manchester City   11.8
# 191      FWD        Harry Kane        Tottenham   11.4
#
#      projected_points_with_decay
# 466                     9.225133
# 275                    11.065854
# 344                    10.850452
# 443                     9.379151
# 302                    16.388153
# 362                    12.538031
# 368                    11.148053
# 38                     14.248012
# 435                    11.320688
# 166                    14.392625
# 191                    11.719860
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/dea47fe18494491bb3f167d537e49cc1-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/dea47fe18494491bb3f167d537e49cc1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 406 COLUMNS
# At line 5423 RHS
# At line 5825 BOUNDS
# At line 6570 ENDATA
# Problem MODEL has 401 rows, 744 columns and 2784 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 156.032 - 0.00 seconds
# Cgl0004I processed model has 399 rows, 744 columns (744 integer (744 of which binary)) and 2604 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.23457
# Cbc0038I Solution found of -155.43
# Cbc0038I Before mini branch and bound, 740 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -155.49
# Cbc0038I Reduced cost fixing fixed 727 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.07353 (2) obj. -155.49 iterations 5
# Cbc0038I Pass   2: suminf.    1.00000 (3) obj. -155.49 iterations 5
# Cbc0038I Pass   3: suminf.    0.44150 (2) obj. -155.49 iterations 3
# Cbc0038I Pass   4: suminf.    0.16964 (2) obj. -155.49 iterations 2
# Cbc0038I Pass   5: suminf.    0.28715 (4) obj. -155.49 iterations 2
# Cbc0038I Pass   6: suminf.    0.16964 (2) obj. -155.49 iterations 4
# Cbc0038I Pass   7: suminf.    0.28715 (4) obj. -155.49 iterations 3
# Cbc0038I Pass   8: suminf.    1.36498 (4) obj. -155.49 iterations 3
# Cbc0038I Pass   9: suminf.    1.36498 (4) obj. -155.49 iterations 1
# Cbc0038I Pass  10: suminf.    0.64935 (2) obj. -155.962 iterations 2
# Cbc0038I Pass  11: suminf.    0.07353 (2) obj. -155.49 iterations 3
# Cbc0038I Pass  12: suminf.    1.00000 (3) obj. -155.49 iterations 5
# Cbc0038I Pass  13: suminf.    0.44150 (2) obj. -155.49 iterations 6
# Cbc0038I Pass  14: suminf.    0.16964 (2) obj. -155.49 iterations 4
# Cbc0038I Pass  15: suminf.    0.28715 (4) obj. -155.49 iterations 3
# Cbc0038I Pass  16: suminf.    0.16964 (2) obj. -155.49 iterations 4
# Cbc0038I Pass  17: suminf.    0.16964 (2) obj. -155.49 iterations 0
# Cbc0038I Pass  18: suminf.    0.16964 (2) obj. -155.49 iterations 0
# Cbc0038I Pass  19: suminf.    0.28715 (4) obj. -155.49 iterations 3
# Cbc0038I Pass  20: suminf.    0.20896 (2) obj. -155.49 iterations 7
# Cbc0038I Pass  21: suminf.    0.07353 (2) obj. -155.49 iterations 6
# Cbc0038I Pass  22: suminf.    1.00000 (3) obj. -155.49 iterations 5
# Cbc0038I Pass  23: suminf.    0.44150 (2) obj. -155.49 iterations 4
# Cbc0038I Pass  24: suminf.    0.32436 (4) obj. -155.49 iterations 4
# Cbc0038I Pass  25: suminf.    0.16964 (2) obj. -155.49 iterations 2
# Cbc0038I Pass  26: suminf.    1.49428 (4) obj. -155.49 iterations 6
# Cbc0038I Pass  27: suminf.    1.49428 (4) obj. -155.49 iterations 0
# Cbc0038I Pass  28: suminf.    0.64935 (2) obj. -155.962 iterations 4
# Cbc0038I Pass  29: suminf.    0.07353 (2) obj. -155.49 iterations 3
# Cbc0038I Pass  30: suminf.    1.00000 (3) obj. -155.49 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 737 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 399 rows 744 columns, reduced to 5 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -155.43 - took 0.03 seconds
# Cbc0012I Integer solution of -155.43027 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0031I 1 added rows had average density of 18
# Cbc0013I At root node, 11 cuts changed objective from -156.03232 to -155.43027 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 18.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 21.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 6 row cuts average 17.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -155.430269845856, took 0 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 725 variables fixed on reduced cost
# Cuts at root node changed objective from -156.032 to -155.43
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                155.43026985
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.08
#
# Status: Optimal
# Cost: 82.19999999999999
# Expected points per week: 155.430269845862
#     position              name             team  price  \
# 466       GK    Robert Sanchez         Brighton    4.5
# 383      DEF  Maximilian Wober     Leeds United    4.4
# 476      DEF        Ruben Dias  Manchester City    6.0
# 547      DEF   Victor Lindelof   Manchester Utd    4.1
# 293      MID      Kaoru Mitoma         Brighton    5.7
# 302      MID   Kevin De Bruyne  Manchester City   12.2
# 362      MID   Marcus Rashford   Manchester Utd    7.2
# 435      MID        Pascal Gro         Brighton    5.4
# 68       MID   Bruno Fernandes   Manchester Utd    9.5
# 166      FWD    Erling Haaland  Manchester City   11.8
# 191      FWD        Harry Kane        Tottenham   11.4
#
#      projected_points_with_decay
# 466                     9.037516
# 383                     9.230556
# 476                    11.686353
# 547                    10.630254
# 293                    12.542101
# 302                    15.292317
# 362                    13.266116
# 435                    11.394464
# 68                     18.662371
# 166                    13.385543
# 191                    11.640307

# %%
my_df['dream_team_appearances'] = [sum(team.count(player_id) for team in results) for player_id in my_df.index]
my_df.head(5)
# Out:
#                  name            team position  price  minutes  \
# 0     Aaron Cresswell        West Ham      DEF    4.7     2165
# 1        Aaron Hickey       Brentford      DEF    4.9     1761
# 2      Aaron Ramsdale         Arsenal       GK    4.8     3240
# 3   Aaron Wan-Bissaka  Manchester Utd      DEF    4.3     1252
# 4  Abdoulaye Doucoure         Everton      MID    5.3     1347
#
#    number_of_games  projected_points  projected_points_with_decay       std  \
# 0                2          6.129977                     5.778472  0.143585
# 1                2          4.380148                     4.127618  0.106969
# 2                2          7.801205                     7.288740  0.110253
# 3                3          9.986055                     9.528764  0.115264
# 4                2          5.773990                     5.410259  0.153063
#
#    dream_team_appearances
# 0                       0
# 1                       0
# 2                       0
# 3                       4
# 4                       0

# %%
print('Most appearances, all players:')
display(my_df.sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# Most appearances, all players:
#                     name             team position  price  minutes  \
# 38                Antony   Manchester Utd      MID    7.3     1690
# 394        Mohamed Salah        Liverpool      MID   13.1     3110
# 68       Bruno Fernandes   Manchester Utd      MID    9.5     3059
# 302      Kevin De Bruyne  Manchester City      MID   12.2     2345
# 166       Erling Haaland  Manchester City      FWD   11.8     2661
# 293         Kaoru Mitoma         Brighton      MID    5.7     2108
# 275          John Stones  Manchester City      DEF    5.6     1728
# 179        Gabriel Jesus          Arsenal      FWD    8.1     1884
# 327           Lewis Dunk         Brighton      DEF    4.8     3150
# 476           Ruben Dias  Manchester City      DEF    6.0     1997
# 247         Jason Steele         Brighton       GK    4.0     1080
# 362      Marcus Rashford   Manchester Utd      MID    7.2     2743
# 435           Pascal Gro         Brighton      MID    5.4     2970
# 138          Diogo Dalot   Manchester Utd      DEF    4.8     2062
# 152              Ederson  Manchester City       GK    5.4     3060
# 20   Alexis Mac Allister         Brighton      MID    5.6     2664
# 191           Harry Kane        Tottenham      FWD   11.4     3226
# 443     Pervis Estupinan         Brighton      DEF    4.9     2449
# 344            Luke Shaw   Manchester Utd      DEF    5.2     2417
# 351        Manuel Akanji  Manchester City      DEF    5.1     2228
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 38                 3         14.793062                    14.128996  0.355764
# 394                2         14.845883                    13.888977  0.573837
# 68                 3         16.787146                    16.051266  1.526063
# 302                3         15.216136                    14.616337  0.499332
# 166                3         13.500616                    12.948499  0.671735
# 293                3         12.213921                    11.706538  0.221704
# 275                3         10.770941                    10.328787  0.200847
# 179                2         10.420565                     9.750386  0.306579
# 327                3          9.322449                     8.935411  0.236496
# 476                3         10.623306                    10.184860  0.233331
# 247                3          9.275103                     8.894870  0.241825
# 362                3         13.348294                    12.749986  0.193029
# 435                3         11.494492                    11.031224  0.221296
# 138                3         10.513080                    10.033640  0.142479
# 152                3         10.666924                    10.229232  0.232914
# 20                 3         11.518476                    11.037989  0.421481
# 191                2         10.508918                     9.792924  0.618196
# 443                3          9.329281                     8.941826  0.155669
# 344                3         10.647581                    10.164417  0.144565
# 351                3         10.147077                     9.730799  0.193198
#
#      dream_team_appearances
# 38                       85
# 394                      82
# 68                       73
# 302                      73
# 166                      70
# 293                      63
# 275                      50
# 179                      43
# 327                      41
# 476                      38
# 247                      36
# 362                      34
# 435                      32
# 138                      32
# 152                      31
# 20                       30
# 191                      30
# 443                      28
# 344                      23
# 351                      22

# %%
print('GOALKEEPERS')
display(my_df[my_df['position']=='GK'].sort_values(by='dream_team_appearances', ascending=False).head(10))
# Out:
# GOALKEEPERS
#                   name             team position  price  minutes  \
# 247       Jason Steele         Brighton       GK    4.0     1080
# 152            Ederson  Manchester City       GK    5.4     3060
# 124       David de Gea   Manchester Utd       GK    5.1     3150
# 466     Robert Sanchez         Brighton       GK    4.5     2070
# 301  Kepa Arrizabalaga          Chelsea       GK    4.6     2295
# 2       Aaron Ramsdale          Arsenal       GK    4.8     3240
# 208      Illan Meslier     Leeds United       GK    4.5     3060
# 489      Sam Johnstone   Crystal Palace       GK    4.4      630
# 420          Nick Pope    Newcastle Utd       GK    5.4     3171
# 366       Mark Travers      Bournemouth       GK    4.1      945
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 247                3          9.275103                     8.894870  0.241825
# 152                3         10.666924                    10.229232  0.232914
# 124                3         10.738820                    10.247325  0.122478
# 466                3          9.138793                     8.758200  0.169073
# 301                3          8.482156                     8.094414  0.182784
# 2                  2          7.801205                     7.288740  0.110253
# 208                2          5.522874                     5.189199  0.129024
# 489                2          7.595231                     7.105723  0.109555
# 420                2          6.400853                     6.021583  0.135075
# 366                2          5.283919                     4.935651  0.129015
#
#      dream_team_appearances
# 247                      36
# 152                      31
# 124                      21
# 466                       9
# 301                       3
# 2                         0
# 208                       0
# 489                       0
# 420                       0
# 366                       0

# %%
print('DEFENDERS')
display(my_df[my_df['position']=='DEF'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# DEFENDERS
#                        name             team position  price  minutes  \
# 275             John Stones  Manchester City      DEF    5.6     1728
# 327              Lewis Dunk         Brighton      DEF    4.8     3150
# 476              Ruben Dias  Manchester City      DEF    6.0     1997
# 138             Diogo Dalot   Manchester Utd      DEF    4.8     2062
# 443        Pervis Estupinan         Brighton      DEF    4.9     2449
# 344               Luke Shaw   Manchester Utd      DEF    5.2     2417
# 351           Manuel Akanji  Manchester City      DEF    5.1     2228
# 538  Trent Alexander-Arnold        Liverpool      DEF    7.7     2742
# 193           Harry Souttar   Leicester City      DEF    4.5      901
# 547         Victor Lindelof   Manchester Utd      DEF    4.1     1089
# 308         Kieran Trippier    Newcastle Utd      DEF    6.1     3162
# 271            Joel Veltman         Brighton      DEF    4.6     2050
# 383        Maximilian Wober     Leeds United      DEF    4.4     1115
# 257            Joao Cancelo  Manchester City      DEF    7.1     1273
# 457             Reece James          Chelsea      DEF    5.8     1242
# 47             Ben Chilwell          Chelsea      DEF    5.6     1402
# 3         Aaron Wan-Bissaka   Manchester Utd      DEF    4.3     1252
# 316             Kyle Walker  Manchester City      DEF    4.7     1683
# 147         Duje Caleta-Car      Southampton      DEF    4.4      942
# 29         Andrew Robertson        Liverpool      DEF    6.8     2508
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 275                3         10.770941                    10.328787  0.200847
# 327                3          9.322449                     8.935411  0.236496
# 476                3         10.623306                    10.184860  0.233331
# 138                3         10.513080                    10.033640  0.142479
# 443                3          9.329281                     8.941826  0.155669
# 344                3         10.647581                    10.164417  0.144565
# 351                3         10.147077                     9.730799  0.193198
# 538                2          9.663172                     9.049348  0.332273
# 193                2          6.133935                     5.694443  1.259945
# 547                3          9.905460                     9.449402  0.151584
# 308                2          8.755164                     8.243453  0.323361
# 271                3          8.830995                     8.462840  0.152302
# 383                2          5.751570                     5.393458  1.262922
# 257                3          9.872698                     9.469068  0.282107
# 457                3          8.797916                     8.392618  0.209939
# 47                 3          8.459628                     8.073125  0.204651
# 3                  3          9.986055                     9.528764  0.115264
# 316                3          8.854220                     8.489565  0.218831
# 147                2          4.938017                     4.619039  1.015734
# 29                 2          9.079151                     8.495757  0.167586
#
#      dream_team_appearances
# 275                      50
# 327                      41
# 476                      38
# 138                      32
# 443                      28
# 344                      23
# 351                      22
# 538                      20
# 193                      14
# 547                       9
# 308                       8
# 271                       8
# 383                       7
# 257                       7
# 457                       6
# 47                        5
# 3                         4
# 316                       2
# 147                       1
# 29                        1

# %%
print('MIDFIELDERS')
display(my_df[my_df['position']=='MID'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# MIDFIELDERS
#                     name               team position  price  minutes  \
# 38                Antony     Manchester Utd      MID    7.3     1690
# 394        Mohamed Salah          Liverpool      MID   13.1     3110
# 302      Kevin De Bruyne    Manchester City      MID   12.2     2345
# 68       Bruno Fernandes     Manchester Utd      MID    9.5     3059
# 293         Kaoru Mitoma           Brighton      MID    5.7     2108
# 362      Marcus Rashford     Manchester Utd      MID    7.2     2743
# 435           Pascal Gro           Brighton      MID    5.4     2970
# 20   Alexis Mac Allister           Brighton      MID    5.6     2664
# 368       Martin degaard            Arsenal      MID    6.8     2968
# 71           Bukayo Saka            Arsenal      MID    8.1     3034
# 451      Raheem Sterling            Chelsea      MID    9.7     1728
# 216        Jack Grealish    Manchester City      MID    7.2     2051
# 207       Ilkay Gundogan    Manchester City      MID    7.4     2261
# 444           Phil Foden    Manchester City      MID    8.0     1602
# 109       Dango Ouattara        Bournemouth      MID    5.0     1125
# 393  Mohamed Elyounoussi        Southampton      MID    5.1     2029
# 390     Mikkel Damsgaard          Brentford      MID    5.0      856
# 389       Miguel Almiron      Newcastle Utd      MID    5.4     2310
# 397   Morgan Gibbs-White  Nottingham Forest      MID    5.5     2973
# 396       Moises Caicedo           Brighton      MID    5.0     2913
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 38                 3         14.793062                    14.128996  0.355764
# 394                2         14.845883                    13.888977  0.573837
# 302                3         15.216136                    14.616337  0.499332
# 68                 3         16.787146                    16.051266  1.526063
# 293                3         12.213921                    11.706538  0.221704
# 362                3         13.348294                    12.749986  0.193029
# 435                3         11.494492                    11.031224  0.221296
# 20                 3         11.518476                    11.037989  0.421481
# 368                2         10.889429                    10.180161  0.378619
# 71                 2         11.413318                    10.672855  0.455086
# 451                3         11.283329                    10.777744  0.403805
# 216                3         12.143260                    11.652191  0.238460
# 207                3         11.782814                    11.300792  0.272132
# 444                3         11.899394                    11.415568  0.224904
# 109                2          6.598037                     6.169994  0.943358
# 393                2          4.174809                     3.909716  0.134224
# 390                2          4.404029                     4.144380  0.084587
# 389                2          6.347238                     5.970371  0.273732
# 397                2          6.232168                     5.812267  0.176195
# 396                3          7.943453                     7.621906  0.146767
#
#      dream_team_appearances
# 38                       85
# 394                      82
# 302                      73
# 68                       73
# 293                      63
# 362                      34
# 435                      32
# 20                       30
# 368                       9
# 71                        6
# 451                       5
# 216                       4
# 207                       2
# 444                       1
# 109                       1
# 393                       0
# 390                       0
# 389                       0
# 397                       0
# 396                       0

# %%
print('FORWARDS')
display(my_df[my_df['position']=='FWD'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# FORWARDS
#                           name             team position  price  minutes  \
# 166             Erling Haaland  Manchester City      FWD   11.8     2661
# 179              Gabriel Jesus          Arsenal      FWD    8.1     1884
# 191                 Harry Kane        Tottenham      FWD   11.4     3226
# 35             Anthony Martial   Manchester Utd      FWD    6.3      822
# 117              Danny Welbeck         Brighton      FWD    6.5     1745
# 14         Aleksandar Mitrovic           Fulham      FWD    6.6     1841
# 5               Adam Armstrong      Southampton      FWD    5.3     1294
# 416                Neal Maupay          Everton      FWD    5.6     1096
# 258                 Joao Felix          Chelsea      FWD    7.1      879
# 287             Julian Alvarez  Manchester City      FWD    6.1     1235
# 289                Kai Havertz          Chelsea      FWD    7.4     2360
# 299          Kelechi Iheanacho   Leicester City      FWD    5.8      991
# 306              Kieffer Moore      Bournemouth      FWD    4.9     1210
# 388            Michail Antonio         West Ham      FWD    6.9     1761
# 425            Odsonne Edouard   Crystal Palace      FWD    5.0     1643
# 240                Jamie Vardy   Leicester City      FWD    9.1     1766
# 428              Ollie Watkins      Aston Villa      FWD    7.4     2953
# 437            Patrick Bamford     Leeds United      FWD    7.1     1477
# 438                Patson Daka   Leicester City      FWD    5.6     1142
# 448  Pierre-Emerick Aubameyang          Chelsea      FWD    8.4      546
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 166                3         13.500616                    12.948499  0.671735
# 179                2         10.420565                     9.750386  0.306579
# 191                2         10.508918                     9.792924  0.618196
# 35                 3         10.878690                    10.387376  0.223437
# 117                3          9.271012                     8.881156  0.181437
# 14                 2          8.619952                     8.081419  0.416109
# 5                  2          4.181836                     3.916750  0.188637
# 416                2          5.547979                     5.204697  0.149233
# 258                3          7.962590                     7.614733  0.197622
# 287                3          8.136799                     7.801952  0.240503
# 289                3          9.067927                     8.669115  0.147433
# 299                2          6.143041                     5.714010  0.193066
# 306                2          4.823454                     4.506131  0.124423
# 388                2          6.035615                     5.681365  0.139988
# 425                2          5.331478                     4.988520  0.162294
# 240                2          6.067449                     5.651654  0.172488
# 428                2          7.316071                     6.822097  0.220781
# 437                2          7.110695                     6.689553  0.268712
# 438                2          4.826117                     4.495633  0.136923
# 448                3          7.767381                     7.433314  0.280765
#
#      dream_team_appearances
# 166                      70
# 179                      43
# 191                      30
# 35                       19
# 117                       8
# 14                        2
# 5                         0
# 416                       0
# 258                       0
# 287                       0
# 289                       0
# 299                       0
# 306                       0
# 388                       0
# 425                       0
# 240                       0
# 428                       0
# 437                       0
# 438                       0
# 448                       0
