# %% [markdown]
# TO DO:
# - Add option to force players into the team, i.e., optimize given certain player are already locked in

# %%
# previous gameweek
gameweek=32

# %%
import pandas as pd
import numpy as np
import json
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable

# %%
# fetch player_dict 
with open('../data/player_name_dict.txt', 'r') as f:
    player_name_dict_as_text = f.read()
    player_name_dict = json.loads(player_name_dict_as_text)

# %% [markdown]
# # Solver definition

# %%
# function to solve the optimization problem
def optimize(df, max_price, expected_column):
    
    # PRELIMINARIES

    # Create the model
    model = LpProblem(name="FPL", sense=LpMaximize)    
    variables = [LpVariable(name=f'{ix}', cat='Binary') for ix in df.index]
    captaincy_variables = [LpVariable(name=f'cap_{ix}', cat='Binary') for ix in df.index]
    prices = [df.loc[ix,'price'] for ix in df.index]
    # measure of player quality
    expected_points = [df.loc[ix,expected_column] for ix in df.index]
    goalkeepers = [1.0 if df.loc[ix,'position']=='GK' else 0.0 for ix in df.index]
    defenders = [1.0 if df.loc[ix,'position']=='DEF' else 0.0 for ix in df.index]
    midfielders = [1.0 if df.loc[ix,'position']=='MID' else 0.0 for ix in df.index]
    forwards = [1.0 if df.loc[ix,'position']=='FWD' else 0.0 for ix in df.index]
    teams = []
    for team in df['team'].unique():
        teams.append( [1.0 if df.loc[ix,'team']==team else 0.0 for ix in df.index] )

    # CONSTRAINTS

    # select 11 players
    model += lpSum(variables) == 11
    # select 1 captain
    model += lpSum(captaincy_variables) == 1
    # captain must be one of the 11 players in the team
    for i in range(0,len(variables)):
        model += captaincy_variables[i] <= variables[i]
    # set maximum price for starting 11
    model += np.dot(prices,variables) <= max_price
    # only 1 goalkeeper
    model += np.dot(goalkeepers,variables) == 1
    # at least 3 defenders
    model += np.dot(defenders,variables) >= 3
    # at most 5 defenders
    model += np.dot(defenders,variables) <= 5
    # at most 5 midfielders
    model += np.dot(midfielders,variables) <= 5
    # at least 1 forward
    model += np.dot(forwards,variables) >= 1
    # at most 3 forwards
    model += np.dot(forwards,variables) <= 3
    # max 3 players from any given team
    for team in teams:
        model += np.dot(team,variables) <= 3

    # OBJECTIVE
    # the second part doubles the captain's points
    model += np.dot(expected_points,variables) + np.dot(expected_points,captaincy_variables)

    # SOLVE OPTIMIZATION

    status = model.solve()
    print(f'Status: {LpStatus[model.status]}')
    #print(f'Mean total points per gameweek: {model.objective.value()}')

    players = [str(var) for var in model.variables() if var.value()==1]
    captain = [player for player in players if 'cap' in player]
    captain = int(captain[0].replace('cap_', ''))
    players = [int(player) for player in players if 'cap' not in player]
    dream_team = df.loc[players]
    cost = (dream_team['price']).sum()
    exp_points = dream_team[expected_column].sum() + df.loc[captain, expected_column]
    print(f'Cost: {cost}')
    print(f'Expected points per week: {exp_points}')
    
    display(dream_team[['position','name', 'team', 'price',expected_column]].sort_values('position'))
    
    return players

# %% [markdown]
# # Data

# %%
#projections = pd.read_csv(f'../point_projections/xP_projections_week{gameweek}.csv', index_col=0)
projections = pd.read_csv(f'../point_projections/collective_xP_projections_week{gameweek}.csv', index_col=0)
projections = projections.rename(columns={'xP':'projected_points'})
projections.head(5)
# Out:
#            name     team           opp_team  was_home  gameweek  \
# 0  Granit Xhaka  Arsenal    Manchester City         0        33
# 1  Granit Xhaka  Arsenal            Chelsea         1        34
# 2  Granit Xhaka  Arsenal      Newcastle Utd         0        35
# 3  Granit Xhaka  Arsenal           Brighton         1        36
# 4  Granit Xhaka  Arsenal  Nottingham Forest         0        37
#
#    projected_points       std
# 0          2.235903  0.083235
# 1          2.967286  0.125055
# 2          2.635728  0.115414
# 3          2.787612  0.194947
# 4          3.259109  0.229191

# %%
# decay for future projected points to model uncertainty increasing over time
decay_coeff = 0.875
projections['projected_points_with_decay'] = ( projections['projected_points']*decay_coeff
                                              **(projections['gameweek']-(gameweek+1)) )
projections.head(5)
# Out:
#            name     team           opp_team  was_home  gameweek  \
# 0  Granit Xhaka  Arsenal    Manchester City         0        33
# 1  Granit Xhaka  Arsenal            Chelsea         1        34
# 2  Granit Xhaka  Arsenal      Newcastle Utd         0        35
# 3  Granit Xhaka  Arsenal           Brighton         1        36
# 4  Granit Xhaka  Arsenal  Nottingham Forest         0        37
#
#    projected_points       std  projected_points_with_decay
# 0          2.235903  0.083235                     2.235903
# 1          2.967286  0.125055                     2.596375
# 2          2.635728  0.115414                     2.017979
# 3          2.787612  0.194947                     1.867482
# 4          3.259109  0.229191                     1.910430

# %%
fpl_df = pd.read_csv(f'../data/fpl_data/fpl_week_{gameweek}.csv', index_col=0)
fpl_df['name'] = fpl_df['name'].map(player_name_dict).fillna(fpl_df['name'])
fpl_df.head(5)
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                          75.0                           NaN   84450
# 1                           0.0                           0.0  153256
# 2                           NaN                           NaN  156074
# 3                         100.0                         100.0  167199
# 4                         100.0                         100.0  184029
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                 -1
# 1                  0                       0                 -4
# 2                  0                       0                 -3
# 3                  0                       0                 -3
# 4                  0                       0                  2
#
#    cost_change_start_fall  dreamteam_count  element_type  ep_next  ...  \
# 0                       1                1             3      1.9  ...
# 1                       4                1             3      0.0  ...
# 2                       3                0             2      0.7  ...
# 3                       3                0             3      1.0  ...
# 4                      -2                4             3      5.7  ...
#
#     season            name position  GW  value     selected transfers_balance  \
# 0  2022-23    Granit Xhaka      MID  32    4.9   284480.350             -9648
# 1  2022-23  Mohamed Elneny      MID  32    4.1    68275.284              -122
# 2  2022-23     Rob Holding      DEF  32    4.2    22758.428              -386
# 3  2022-23   Thomas Partey      MID  32    4.7    45516.856              -174
# 4  2022-23  Martin degaard      MID  32    6.7  3356868.130            -67152
#
#   opp_team_name          kickoff_time was_home
# 0   Southampton  2023-04-21T19:00:00Z      1.0
# 1   Southampton  2023-04-21T19:00:00Z      1.0
# 2   Southampton  2023-04-21T19:00:00Z      1.0
# 3   Southampton  2023-04-21T19:00:00Z      1.0
# 4   Southampton  2023-04-21T19:00:00Z      1.0
#
# [5 rows x 98 columns]

# %%
# choose time horizon for optimization
#horizon = 10

# create dataframe to be given as input for optimization
#df = projections[projections['gameweek']<=gameweek+horizon].groupby(by=['name']).mean()\
#                                                        [['projected_points','projected_points_with_decay', 'std']] 

# OPTIMIZE FOR GIVEN GAMEWEEKS
my_gameweeks = [33,34,35,36,37,38]
df = projections[projections['gameweek'].isin(my_gameweeks)].groupby(by=['name']).sum()\
                                                        [['projected_points','projected_points_with_decay']]
df['std'] = projections[projections['gameweek'].isin(my_gameweeks)].groupby(by=['name']).mean()\
                                                        [['std']]
df['number_of_games'] = (projections[projections['gameweek'].isin(my_gameweeks)]
                                     .groupby('name').count()['std'])

#df = df.to_frame()
df = df.reset_index()
#df = df.rename(columns={'projected_points':'projected_points_per_game'})
#df['team'] = [fpl_df.loc[fpl_df['name']==name, 'team'].values[0] for name in df['name']]
df['price'] = [fpl_df.loc[fpl_df['name']==name, 'value'].values[0] for name in df['name']]
df['position'] = [fpl_df.loc[fpl_df['name']==name, 'element_type'].values[0] for name in df['name']]
position_dict={1:'GK', 2:'DEF', 3:'MID', 4:'FWD'}
df['position'] = df['position'].map(position_dict)
df['position'] = pd.Categorical(df['position'], ['GK','DEF','MID','FWD'])
df['team'] = [projections.loc[projections['name']==name, 'team'].head(1).values[0] for name in df['name']]
df['minutes'] = [fpl_df.loc[fpl_df['name']==name, 'minutes'].values[0] for name in df['name']]
# re-order columns
df = df[['name', 'team', 'position', 'price', 'minutes', 'number_of_games', 'projected_points', 'projected_points_with_decay', 'std']]
df.head(5)
# Out:
# /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/ipykernel_4547/2753816863.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = projections[projections['gameweek'].isin(my_gameweeks)].groupby(by=['name']).sum()\
# /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/ipykernel_4547/2753816863.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['std'] = projections[projections['gameweek'].isin(my_gameweeks)].groupby(by=['name']).mean()\
#                  name            team position  price  minutes  \
# 0     Aaron Cresswell        West Ham      DEF    4.7     1850
# 1        Aaron Hickey       Brentford      DEF    4.9     1499
# 2      Aaron Ramsdale         Arsenal       GK    4.9     2880
# 3   Aaron Wan-Bissaka  Manchester Utd      DEF    4.3      916
# 4  Abdoulaye Doucoure         Everton      MID    5.3      987
#
#    number_of_games  projected_points  projected_points_with_decay       std
# 0                7         20.101030                    14.997258  0.143684
# 1                6         14.080973                    10.468797  0.102802
# 2                6         19.403967                    13.798076  0.119285
# 3                8         25.131258                    18.136991  0.140735
# 4                6         13.915958                    10.129604  0.109865

# %%
# remove players who do not have enough minutes played
cutoff = 450
df = df[df['minutes']>=cutoff]

# edit some player prices according to my selling price
df.loc[df['name']=='Erling Haaland', 'price'] = 11.8
df.loc[df['name']=='Martinelli', 'price'] = 6.3

# %% [markdown]
# # Optimization

# %%
team_value = 102
money_in_the_bank = 0.2
allowed_bench_value = 17.5
max_price = team_value + money_in_the_bank - allowed_bench_value

# %% [markdown]
# ## Without decay

# %%
players = optimize(df, max_price, 'projected_points_per_game')

# %%
ban = []
# ban some cheap keepers in good teams who don't actually play
cheap_keepers = ['Scott Carson', 'Zack Steffen', 'Jason Steele', 'Caoimhin Kelleher', 'Wayne Hennessey', 
                 'Karl Darlow', 'Darren Randolph']
cheap_keepers_ix = df[df['name'].isin(cheap_keepers)].index
ban = ban + list(cheap_keepers_ix)
# ban given players
ban_field = ['Marcos Alonso', 'Ben Chilwell', 'Riyad Mahrez', 'Darwin Nunez', 'Aymeric Laporte', 'Emil Krafth', 
             'Sergio Gomez', 'Nathaniel Phillips']
ban_field_ix = df[df['name'].isin(ban_field)].index
ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
players = optimize(my_df, max_price, 'projected_points_per_game')

# %% [markdown]
# ## With decay

# %%
#players = optimize(df, max_price, 'projected_points_with_decay')

# %%
ban = []

# ban given players
ban_field = ['Aleksandar Mitrovic', 'Aymeric Laporte', 'Jason Steele']
#ban_field = []

ban_field_ix = df[df['name'].isin(ban_field)].index
ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
players = optimize(my_df, max_price, 'projected_points_with_decay')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/be166db3a76e4830821bde064c48b78c-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/be166db3a76e4830821bde064c48b78c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 338.198 - 0.01 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.952381
# Cbc0038I Pass   1: suminf.    0.24096 (2) obj. -336.295 iterations 10
# Cbc0038I Solution found of -316.801
# Cbc0038I Before mini branch and bound, 716 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -316.801 to -337.355 (0.03 seconds)
# Cbc0038I Round again with cutoff of -337.439
# Cbc0038I Reduced cost fixing fixed 704 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.95238 (2) obj. -338.198 iterations 3
# Cbc0038I Pass   3: suminf.    0.07198 (2) obj. -337.439 iterations 8
# Cbc0038I Pass   4: suminf.    0.83082 (3) obj. -337.439 iterations 4
# Cbc0038I Pass   5: suminf.    0.90788 (4) obj. -337.439 iterations 4
# Cbc0038I Pass   6: suminf.    0.88969 (3) obj. -337.439 iterations 1
# Cbc0038I Pass   7: suminf.    0.53659 (2) obj. -337.984 iterations 3
# Cbc0038I Pass   8: suminf.    0.24390 (2) obj. -337.682 iterations 3
# Cbc0038I Pass   9: suminf.    0.03665 (2) obj. -337.439 iterations 4
# Cbc0038I Pass  10: suminf.    0.37515 (3) obj. -337.439 iterations 4
# Cbc0038I Pass  11: suminf.    0.03665 (2) obj. -337.439 iterations 3
# Cbc0038I Pass  12: suminf.    0.03665 (2) obj. -337.439 iterations 0
# Cbc0038I Pass  13: suminf.    0.50967 (3) obj. -337.439 iterations 2
# Cbc0038I Pass  14: suminf.    0.03665 (2) obj. -337.439 iterations 1
# Cbc0038I Pass  15: suminf.    1.83000 (4) obj. -337.439 iterations 5
# Cbc0038I Pass  16: suminf.    1.46779 (4) obj. -337.439 iterations 1
# Cbc0038I Pass  17: suminf.    0.07198 (2) obj. -337.439 iterations 4
# Cbc0038I Pass  18: suminf.    0.83082 (3) obj. -337.439 iterations 3
# Cbc0038I Pass  19: suminf.    0.07198 (2) obj. -337.439 iterations 4
# Cbc0038I Pass  20: suminf.    1.00000 (4) obj. -337.545 iterations 8
# Cbc0038I Pass  21: suminf.    0.03665 (2) obj. -337.439 iterations 5
# Cbc0038I Pass  22: suminf.    0.37515 (3) obj. -337.439 iterations 3
# Cbc0038I Pass  23: suminf.    0.50967 (3) obj. -337.439 iterations 5
# Cbc0038I Pass  24: suminf.    0.50967 (3) obj. -337.439 iterations 1
# Cbc0038I Pass  25: suminf.    0.24390 (2) obj. -337.682 iterations 1
# Cbc0038I Pass  26: suminf.    0.33495 (3) obj. -337.439 iterations 4
# Cbc0038I Pass  27: suminf.    1.13381 (4) obj. -337.439 iterations 5
# Cbc0038I Pass  28: suminf.    0.95238 (2) obj. -338.198 iterations 1
# Cbc0038I Pass  29: suminf.    0.07198 (2) obj. -337.439 iterations 5
# Cbc0038I Pass  30: suminf.    0.83082 (3) obj. -337.439 iterations 4
# Cbc0038I Pass  31: suminf.    0.88969 (3) obj. -337.439 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 711 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 5 rows 9 columns
# Cbc0038I Mini branch and bound improved solution from -337.355 to -337.396 (0.05 seconds)
# Cbc0038I Round again with cutoff of -337.591
# Cbc0038I Reduced cost fixing fixed 705 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.95238 (2) obj. -338.198 iterations 0
# Cbc0038I Pass  32: suminf.    0.20154 (2) obj. -337.591 iterations 8
# Cbc0038I Pass  33: suminf.    0.74877 (3) obj. -337.591 iterations 4
# Cbc0038I Pass  34: suminf.    0.75011 (3) obj. -337.591 iterations 2
# Cbc0038I Pass  35: suminf.    1.16405 (4) obj. -337.591 iterations 3
# Cbc0038I Pass  36: suminf.    1.14535 (4) obj. -337.591 iterations 2
# Cbc0038I Pass  37: suminf.    0.16621 (2) obj. -337.591 iterations 8
# Cbc0038I Pass  38: suminf.    0.16621 (2) obj. -337.591 iterations 1
# Cbc0038I Pass  39: suminf.    0.29311 (3) obj. -337.591 iterations 4
# Cbc0038I Pass  40: suminf.    0.51108 (4) obj. -337.591 iterations 5
# Cbc0038I Pass  41: suminf.    1.14535 (4) obj. -337.591 iterations 7
# Cbc0038I Pass  42: suminf.    0.95238 (2) obj. -338.198 iterations 2
# Cbc0038I Pass  43: suminf.    0.20154 (2) obj. -337.591 iterations 5
# Cbc0038I Pass  44: suminf.    0.74877 (3) obj. -337.591 iterations 4
# Cbc0038I Pass  45: suminf.    0.95918 (5) obj. -337.591 iterations 8
# Cbc0038I Pass  46: suminf.    0.16621 (2) obj. -337.591 iterations 5
# Cbc0038I Pass  47: suminf.    0.29311 (3) obj. -337.591 iterations 4
# Cbc0038I Pass  48: suminf.    0.47619 (4) obj. -337.734 iterations 4
# Cbc0038I Pass  49: suminf.    0.51108 (4) obj. -337.591 iterations 4
# Cbc0038I Pass  50: suminf.    0.95918 (5) obj. -337.591 iterations 5
# Cbc0038I Pass  51: suminf.    1.67671 (5) obj. -337.591 iterations 3
# Cbc0038I Pass  52: suminf.    1.67532 (5) obj. -337.591 iterations 2
# Cbc0038I Pass  53: suminf.    0.20154 (2) obj. -337.591 iterations 4
# Cbc0038I Pass  54: suminf.    0.20154 (2) obj. -337.591 iterations 0
# Cbc0038I Pass  55: suminf.    0.74877 (3) obj. -337.591 iterations 4
# Cbc0038I Pass  56: suminf.    0.53659 (2) obj. -337.984 iterations 1
# Cbc0038I Pass  57: suminf.    0.96623 (3) obj. -337.591 iterations 2
# Cbc0038I Pass  58: suminf.    0.74726 (3) obj. -337.591 iterations 1
# Cbc0038I Pass  59: suminf.    0.35514 (4) obj. -337.591 iterations 5
# Cbc0038I Pass  60: suminf.    0.20154 (2) obj. -337.591 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 710 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 5 rows 10 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -337.396 - took 0.05 seconds
# Cbc0012I Integer solution of -337.39618 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 387 rows 720 columns, reduced to 2 rows 3 columns
# Cbc0031I 2 added rows had average density of 8
# Cbc0013I At root node, 6 cuts changed objective from -338.19848 to -337.39618 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 11.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -337.39617951833, took 0 iterations and 0 nodes (0.08 seconds)
# Cbc0035I Maximum depth 0, 703 variables fixed on reduced cost
# Cuts at root node changed objective from -338.198 to -337.396
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                337.39617952
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.09
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.09   (Wallclock seconds):       0.10
#
# Status: Optimal
# Cost: 84.2
# Expected points per week: 337.3961795183319
#     position                    name             team  price  \
# 151       GK                 Ederson  Manchester City    5.4
# 137      DEF             Diogo Dalot   Manchester Utd    4.7
# 29       DEF        Andrew Robertson        Liverpool    6.8
# 534      DEF  Trent Alexander-Arnold        Liverpool    7.5
# 290      MID            Kaoru Mitoma         Brighton    5.6
# 299      MID         Kevin De Bruyne  Manchester City   12.1
# 391      MID           Mohamed Salah        Liverpool   12.9
# 431      MID              Pascal Gro         Brighton    5.4
# 503      MID             Solly March         Brighton    5.2
# 165      FWD          Erling Haaland  Manchester City   11.8
# 19       FWD          Alexander Isak    Newcastle Utd    6.8
#
#      projected_points_with_decay
# 151                    22.213464
# 137                    20.903071
# 29                     22.513803
# 534                    23.812316
# 290                    26.693069
# 299                    32.481290
# 391                    37.697983
# 431                    25.953797
# 503                    33.879272
# 165                    29.998464
# 19                     23.551670

# %% [markdown]
# # Sensitivity analysis
#
# Here we add small random Gaussian noise to each players' projected points and run the optimization with these new estimates. We repeat the process n times and keep a list of how many times each player appeared in the optimal team.

# %%
ban = []

# ban given players
ban_field = ['Aleksandar Mitrovic', 'Aymeric Laporte', 'Jason Steele']
#ban_field = []

ban_field_ix = df[df['name'].isin(ban_field)].index
ban = ban + list(ban_field_ix)
my_df = df.drop(ban).copy()

# %%
metric = 'projected_points_with_decay'
# set the standard deviation of the Gaussian noise to be a fraction of each players' projected points
#sigma_factor = 0.1
simulation_rounds = 100
results = []
for i in range(0,simulation_rounds):
    df_with_noise = my_df.copy()
    #df_with_noise[metric] = df_with_noise[metric] + np.random.normal(0, df_with_noise[metric]*sigma_factor)
    df_with_noise[metric] = df_with_noise[metric] + np.random.normal(0, df_with_noise['std'])*df_with_noise['number_of_games']
    players = optimize(df_with_noise, max_price, metric)
    results.append(players)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/b843d4f475024af490b8d29bb71df21c-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/b843d4f475024af490b8d29bb71df21c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 345.595 - 0.01 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.451613
# Cbc0038I Pass   1: suminf.    0.16867 (2) obj. -344.59 iterations 9
# Cbc0038I Solution found of -321.759
# Cbc0038I Before mini branch and bound, 715 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 6 rows 5 columns
# Cbc0038I Mini branch and bound improved solution from -321.759 to -336.964 (0.04 seconds)
# Cbc0038I Round again with cutoff of -337.827
# Cbc0038I Reduced cost fixing fixed 594 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.17073 (2) obj. -345.097 iterations 2
# Cbc0038I Pass   3: suminf.    0.94835 (2) obj. -337.827 iterations 6
# Cbc0038I Pass   4: suminf.    0.11737 (2) obj. -337.827 iterations 6
# Cbc0038I Pass   5: suminf.    0.11737 (2) obj. -337.827 iterations 4
# Cbc0038I Pass   6: suminf.    0.11737 (2) obj. -337.827 iterations 3
# Cbc0038I Pass   7: suminf.    0.11737 (2) obj. -337.827 iterations 2
# Cbc0038I Pass   8: suminf.    0.17068 (2) obj. -337.827 iterations 8
# Cbc0038I Pass   9: suminf.    0.17068 (2) obj. -337.827 iterations 4
# Cbc0038I Pass  10: suminf.    0.95857 (3) obj. -337.827 iterations 8
# Cbc0038I Pass  11: suminf.    0.55322 (2) obj. -337.827 iterations 2
# Cbc0038I Pass  12: suminf.    0.55322 (2) obj. -337.827 iterations 0
# Cbc0038I Pass  13: suminf.    0.40646 (5) obj. -337.827 iterations 7
# Cbc0038I Pass  14: suminf.    0.30230 (4) obj. -337.827 iterations 4
# Cbc0038I Pass  15: suminf.    0.81654 (3) obj. -337.827 iterations 5
# Cbc0038I Pass  16: suminf.    0.81654 (3) obj. -337.827 iterations 3
# Cbc0038I Pass  17: suminf.    0.00000 (0) obj. -338.66 iterations 5
# Cbc0038I Solution found of -338.66
# Cbc0038I Before mini branch and bound, 706 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 8 rows 14 columns
# Cbc0038I Mini branch and bound improved solution from -338.66 to -344.58 (0.05 seconds)
# Cbc0038I Round again with cutoff of -344.783
# Cbc0038I Reduced cost fixing fixed 707 variables on major pass 3
# Cbc0038I Pass  18: suminf.    0.19718 (2) obj. -345.342 iterations 2
# Cbc0038I Pass  19: suminf.    0.27884 (2) obj. -344.783 iterations 5
# Cbc0038I Pass  20: suminf.    0.63521 (3) obj. -344.783 iterations 5
# Cbc0038I Pass  21: suminf.    0.61706 (3) obj. -344.783 iterations 3
# Cbc0038I Pass  22: suminf.    0.62820 (2) obj. -344.783 iterations 4
# Cbc0038I Pass  23: suminf.    0.53674 (3) obj. -344.783 iterations 8
# Cbc0038I Pass  24: suminf.    0.62820 (2) obj. -344.783 iterations 5
# Cbc0038I Pass  25: suminf.    1.66243 (5) obj. -344.783 iterations 2
# Cbc0038I Pass  26: suminf.    1.66243 (5) obj. -344.783 iterations 0
# Cbc0038I Pass  27: suminf.    0.92903 (5) obj. -344.783 iterations 5
# Cbc0038I Pass  28: suminf.    0.31276 (4) obj. -344.783 iterations 6
# Cbc0038I Pass  29: suminf.    0.31276 (4) obj. -344.783 iterations 1
# Cbc0038I Pass  30: suminf.    0.31276 (4) obj. -344.783 iterations 0
# Cbc0038I Pass  31: suminf.    0.31276 (4) obj. -344.783 iterations 0
# Cbc0038I Pass  32: suminf.    0.38413 (4) obj. -344.783 iterations 1
# Cbc0038I Pass  33: suminf.    0.31276 (4) obj. -344.783 iterations 1
# Cbc0038I Pass  34: suminf.    0.78530 (4) obj. -344.783 iterations 3
# Cbc0038I Pass  35: suminf.    0.19718 (2) obj. -345.342 iterations 5
# Cbc0038I Pass  36: suminf.    0.27884 (2) obj. -344.783 iterations 2
# Cbc0038I Pass  37: suminf.    0.66154 (3) obj. -344.783 iterations 5
# Cbc0038I Pass  38: suminf.    0.66154 (3) obj. -344.783 iterations 1
# Cbc0038I Pass  39: suminf.    0.61467 (5) obj. -344.783 iterations 3
# Cbc0038I Pass  40: suminf.    0.53674 (3) obj. -344.783 iterations 1
# Cbc0038I Pass  41: suminf.    0.62820 (2) obj. -344.783 iterations 4
# Cbc0038I Pass  42: suminf.    0.62820 (2) obj. -344.783 iterations 2
# Cbc0038I Pass  43: suminf.    0.96973 (5) obj. -344.783 iterations 8
# Cbc0038I Pass  44: suminf.    0.98353 (4) obj. -344.783 iterations 2
# Cbc0038I Pass  45: suminf.    0.62820 (2) obj. -344.783 iterations 5
# Cbc0038I Pass  46: suminf.    0.53674 (3) obj. -344.783 iterations 8
# Cbc0038I Pass  47: suminf.    0.62820 (2) obj. -344.783 iterations 7
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 711 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 6 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -344.58 - took 0.05 seconds
# Cbc0012I Integer solution of -344.58014 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 387 rows 720 columns, reduced to 5 rows 5 columns
# Cbc0031I 2 added rows had average density of 4
# Cbc0013I At root node, 7 cuts changed objective from -345.59462 to -342.8592 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2 column cuts (2 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 2 row cuts average 3.5 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 8 row cuts average 6.1 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -344.58013736841, took 8 iterations and 0 nodes (0.09 seconds)
# Cbc0035I Maximum depth 0, 708 variables fixed on reduced cost
# Cuts at root node changed objective from -345.595 to -342.859
# Probing was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 2 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 2 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                344.58013737
# Enumerated nodes:               0
# Total iterations:               8
# Time (CPU seconds):             0.09
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.10
#
# Status: Optimal
# Cost: 84.10000000000001
# Expected points per week: 344.5801373683852
#     position                    name             team  price  \
# 462       GK          Robert Sanchez         Brighton    4.5
# 137      DEF             Diogo Dalot   Manchester Utd    4.7
# 305      DEF         Kieran Trippier    Newcastle Utd    6.2
# 403      DEF              Nathan Ake  Manchester City    5.1
# 534      DEF  Trent Alexander-Arnold        Liverpool    7.5
# 290      MID            Kaoru Mitoma         Brighton    5.6
# 299      MID         Kevin De Bruyne  Manchester City   12.1
# 391      MID           Mohamed Salah        Liverpool   12.9
# 503      MID             Solly March         Brighton    5.2
# 71       MID             Bukayo Saka          Arsenal    8.5
# 165      FWD          Erling Haaland  Manchester City   11.8
#
#      projected_points_with_decay
# 462                    22.410402
# 137                    22.521370
# 305                    24.708733
# 403                    21.561036
# 534                    25.380722
# 290                    25.997199
# 299                    34.925705
# 391                    36.130016
# 503                    29.497589
# 71                     33.326977
# 165                    31.990373
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/5a2ba6c03c214bc1a9ecfcdda1cf5e69-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/5a2ba6c03c214bc1a9ecfcdda1cf5e69-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 362.48 - 0.00 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.47619
# Cbc0038I Solution found of -362.244
# Cbc0038I Before mini branch and bound, 718 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -362.267
# Cbc0038I Reduced cost fixing fixed 713 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.04764 (2) obj. -362.267 iterations 3
# Cbc0038I Pass   2: suminf.    0.47619 (2) obj. -362.48 iterations 3
# Cbc0038I Pass   3: suminf.    0.47619 (2) obj. -362.48 iterations 0
# Cbc0038I Pass   4: suminf.    0.04764 (2) obj. -362.267 iterations 4
# Cbc0038I Pass   5: suminf.    0.04764 (2) obj. -362.267 iterations 1
# Cbc0038I Pass   6: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I Pass   7: suminf.    0.47619 (2) obj. -362.48 iterations 3
# Cbc0038I Pass   8: suminf.    0.47619 (2) obj. -362.48 iterations 0
# Cbc0038I Pass   9: suminf.    0.47619 (2) obj. -362.48 iterations 1
# Cbc0038I Pass  10: suminf.    0.04764 (2) obj. -362.267 iterations 2
# Cbc0038I Pass  11: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I Pass  12: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I Pass  13: suminf.    0.04764 (2) obj. -362.267 iterations 1
# Cbc0038I Pass  14: suminf.    0.04764 (2) obj. -362.267 iterations 1
# Cbc0038I Pass  15: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I Pass  16: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I Pass  17: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I Pass  18: suminf.    0.47619 (2) obj. -362.48 iterations 2
# Cbc0038I Pass  19: suminf.    0.04764 (2) obj. -362.267 iterations 4
# Cbc0038I Pass  20: suminf.    0.04764 (2) obj. -362.267 iterations 1
# Cbc0038I Pass  21: suminf.    0.04764 (2) obj. -362.267 iterations 1
# Cbc0038I Pass  22: suminf.    0.47619 (2) obj. -362.48 iterations 4
# Cbc0038I Pass  23: suminf.    0.47619 (2) obj. -362.48 iterations 1
# Cbc0038I Pass  24: suminf.    0.47619 (2) obj. -362.48 iterations 1
# Cbc0038I Pass  25: suminf.    0.47619 (2) obj. -362.48 iterations 1
# Cbc0038I Pass  26: suminf.    0.04764 (2) obj. -362.267 iterations 4
# Cbc0038I Pass  27: suminf.    0.04764 (2) obj. -362.267 iterations 1
# Cbc0038I Pass  28: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I Pass  29: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I Pass  30: suminf.    0.04764 (2) obj. -362.267 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 718 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -362.244 - took 0.01 seconds
# Cbc0012I Integer solution of -362.24356 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -362.47954 to -362.47954 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -362.24356488041, took 0 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 713 variables fixed on reduced cost
# Cuts at root node changed objective from -362.48 to -362.48
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                362.24356488
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# Status: Optimal
# Cost: 84.2
# Expected points per week: 362.24356488040434
#     position                    name             team  price  \
# 151       GK                 Ederson  Manchester City    5.4
# 305      DEF         Kieran Trippier    Newcastle Utd    6.2
# 472      DEF              Ruben Dias  Manchester City    6.0
# 534      DEF  Trent Alexander-Arnold        Liverpool    7.5
# 290      MID            Kaoru Mitoma         Brighton    5.6
# 38       MID                  Antony   Manchester Utd    7.3
# 391      MID           Mohamed Salah        Liverpool   12.9
# 503      MID             Solly March         Brighton    5.2
# 68       MID         Bruno Fernandes   Manchester Utd    9.5
# 165      FWD          Erling Haaland  Manchester City   11.8
# 19       FWD          Alexander Isak    Newcastle Utd    6.8
#
#      projected_points_with_decay
# 151                    24.471386
# 305                    23.060153
# 472                    24.944475
# 534                    22.830358
# 290                    26.545043
# 38                     28.657809
# 391                    43.500221
# 503                    33.933330
# 68                     31.507103
# 165                    32.533407
# 19                     26.760058
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/7fc5223d3e3b41be829566135947eb43-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/7fc5223d3e3b41be829566135947eb43-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 335.779 - 0.00 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.0833333
# Cbc0038I Pass   1: suminf.    0.02198 (2) obj. -335.582 iterations 9
# Cbc0038I Solution found of -313.862
# Cbc0038I Before mini branch and bound, 716 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 3 rows 4 columns
# Cbc0038I Mini branch and bound improved solution from -313.862 to -334.76 (0.03 seconds)
# Cbc0038I Round again with cutoff of -334.862
# Cbc0038I Reduced cost fixing fixed 705 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.08333 (2) obj. -335.779 iterations 2
# Cbc0038I Pass   3: suminf.    0.19168 (2) obj. -334.862 iterations 8
# Cbc0038I Pass   4: suminf.    0.19168 (2) obj. -334.862 iterations 1
# Cbc0038I Pass   5: suminf.    0.19168 (2) obj. -334.862 iterations 1
# Cbc0038I Pass   6: suminf.    0.19168 (2) obj. -334.862 iterations 1
# Cbc0038I Pass   7: suminf.    0.50126 (2) obj. -334.862 iterations 12
# Cbc0038I Pass   8: suminf.    0.50126 (2) obj. -334.862 iterations 1
# Cbc0038I Solution found of -335.578
# Cbc0038I Before mini branch and bound, 713 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 5 rows 5 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -335.619
# Cbc0038I Reduced cost fixing fixed 713 variables on major pass 3
# Cbc0038I Pass   9: suminf.    0.08333 (2) obj. -335.779 iterations 0
# Cbc0038I Pass  10: suminf.    0.38510 (2) obj. -335.619 iterations 6
# Cbc0038I Pass  11: suminf.    0.08333 (2) obj. -335.779 iterations 2
# Cbc0038I Pass  12: suminf.    0.08333 (2) obj. -335.779 iterations 1
# Cbc0038I Pass  13: suminf.    0.08333 (2) obj. -335.779 iterations 0
# Cbc0038I Pass  14: suminf.    0.08333 (2) obj. -335.779 iterations 1
# Cbc0038I Pass  15: suminf.    0.08333 (2) obj. -335.779 iterations 1
# Cbc0038I Pass  16: suminf.    0.08333 (2) obj. -335.779 iterations 2
# Cbc0038I Pass  17: suminf.    0.38510 (2) obj. -335.619 iterations 3
# Cbc0038I Pass  18: suminf.    0.08333 (2) obj. -335.779 iterations 4
# Cbc0038I Pass  19: suminf.    0.08333 (2) obj. -335.779 iterations 2
# Cbc0038I Pass  20: suminf.    0.38510 (2) obj. -335.619 iterations 3
# Cbc0038I Pass  21: suminf.    0.38510 (2) obj. -335.619 iterations 1
# Cbc0038I Pass  22: suminf.    0.38510 (2) obj. -335.619 iterations 2
# Cbc0038I Pass  23: suminf.    0.38510 (2) obj. -335.619 iterations 0
# Cbc0038I Pass  24: suminf.    0.38510 (2) obj. -335.619 iterations 0
# Cbc0038I Pass  25: suminf.    0.08333 (2) obj. -335.779 iterations 3
# Cbc0038I Pass  26: suminf.    0.38510 (2) obj. -335.619 iterations 3
# Cbc0038I Pass  27: suminf.    0.38510 (2) obj. -335.619 iterations 0
# Cbc0038I Pass  28: suminf.    0.08333 (2) obj. -335.779 iterations 3
# Cbc0038I Pass  29: suminf.    0.08333 (2) obj. -335.779 iterations 0
# Cbc0038I Pass  30: suminf.    0.08333 (2) obj. -335.779 iterations 2
# Cbc0038I Pass  31: suminf.    0.38510 (2) obj. -335.619 iterations 3
# Cbc0038I Pass  32: suminf.    0.08333 (2) obj. -335.779 iterations 2
# Cbc0038I Pass  33: suminf.    0.08333 (2) obj. -335.779 iterations 1
# Cbc0038I Pass  34: suminf.    0.08333 (2) obj. -335.779 iterations 1
# Cbc0038I Pass  35: suminf.    0.08333 (2) obj. -335.779 iterations 0
# Cbc0038I Pass  36: suminf.    0.08333 (2) obj. -335.779 iterations 2
# Cbc0038I Pass  37: suminf.    0.08333 (2) obj. -335.779 iterations 2
# Cbc0038I Pass  38: suminf.    0.08333 (2) obj. -335.779 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 718 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -335.578 - took 0.03 seconds
# Cbc0012I Integer solution of -335.5784 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 387 rows 720 columns, reduced to 5 rows 5 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -335.77896 to -335.77896 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 3 row cuts average 3.0 elements, 2 column cuts (2 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -335.57840174244, took 0 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 712 variables fixed on reduced cost
# Cuts at root node changed objective from -335.779 to -335.779
# Probing was tried 1 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                335.57840174
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.07
#
# Status: Optimal
# Cost: 84.7
# Expected points per week: 335.57840174243563
#     position                    name             team  price  \
# 151       GK                 Ederson  Manchester City    5.4
# 305      DEF         Kieran Trippier    Newcastle Utd    6.2
# 439      DEF        Pervis Estupinan         Brighton    4.8
# 534      DEF  Trent Alexander-Arnold        Liverpool    7.5
# 391      MID           Mohamed Salah        Liverpool   12.9
# 431      MID              Pascal Gro         Brighton    5.4
# 460      MID            Riyad Mahrez  Manchester City    7.3
# 503      MID             Solly March         Brighton    5.2
# 68       MID         Bruno Fernandes   Manchester Utd    9.5
# 119      FWD            Darwin Nunez        Liverpool    8.7
# 165      FWD          Erling Haaland  Manchester City   11.8
#
#      projected_points_with_decay
# 151                    23.076351
# 305                    24.900940
# 439                    23.202943
# 534                    24.118240
# 391                    31.855157
# 431                    25.630708
# 460                    32.268489
# 503                    30.541948
# 68                     32.811360
# 119                    23.410592
# 165                    30.950313
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/a22391d6678b4c67bc7c1f51e2245bc4-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/a22391d6678b4c67bc7c1f51e2245bc4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 348.068 - 0.00 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.68421
# Cbc0038I Solution found of -346.808
# Cbc0038I Before mini branch and bound, 716 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 6 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -346.934
# Cbc0038I Reduced cost fixing fixed 699 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.13547 (4) obj. -346.934 iterations 3
# Cbc0038I Pass   2: suminf.    0.65539 (3) obj. -346.934 iterations 7
# Cbc0038I Pass   3: suminf.    0.50283 (2) obj. -346.934 iterations 4
# Cbc0038I Pass   4: suminf.    0.21388 (2) obj. -346.934 iterations 6
# Cbc0038I Solution found of -347.409
# Cbc0038I Before mini branch and bound, 710 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 6 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -347.541
# Cbc0038I Reduced cost fixing fixed 707 variables on major pass 3
# Cbc0038I Pass   5: suminf.    0.78766 (4) obj. -347.541 iterations 0
# Cbc0038I Pass   6: suminf.    1.29650 (4) obj. -347.541 iterations 4
# Cbc0038I Pass   7: suminf.    1.29650 (4) obj. -347.541 iterations 1
# Cbc0038I Pass   8: suminf.    1.78002 (5) obj. -347.541 iterations 6
# Cbc0038I Pass   9: suminf.    1.81970 (5) obj. -347.541 iterations 5
# Cbc0038I Pass  10: suminf.    1.69718 (4) obj. -347.541 iterations 1
# Cbc0038I Pass  11: suminf.    1.69718 (4) obj. -347.541 iterations 0
# Cbc0038I Pass  12: suminf.    1.69718 (4) obj. -347.541 iterations 0
# Cbc0038I Pass  13: suminf.    1.29650 (4) obj. -347.541 iterations 3
# Cbc0038I Pass  14: suminf.    1.29650 (4) obj. -347.541 iterations 0
# Cbc0038I Pass  15: suminf.    1.78002 (5) obj. -347.541 iterations 4
# Cbc0038I Pass  16: suminf.    0.78766 (4) obj. -347.541 iterations 2
# Cbc0038I Pass  17: suminf.    0.03436 (2) obj. -347.541 iterations 3
# Cbc0038I Solution found of -347.554
# Cbc0038I Before mini branch and bound, 711 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 6 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of -347.708
# Cbc0038I Reduced cost fixing fixed 708 variables on major pass 4
# Cbc0038I Pass  18: suminf.    0.96737 (4) obj. -347.708 iterations 0
# Cbc0038I Pass  19: suminf.    1.52819 (4) obj. -347.708 iterations 5
# Cbc0038I Pass  20: suminf.    1.52819 (4) obj. -347.708 iterations 1
# Cbc0038I Pass  21: suminf.    1.63291 (5) obj. -347.708 iterations 5
# Cbc0038I Pass  22: suminf.    0.96737 (4) obj. -347.708 iterations 1
# Cbc0038I Pass  23: suminf.    1.20280 (4) obj. -347.708 iterations 1
# Cbc0038I Pass  24: suminf.    1.20280 (4) obj. -347.708 iterations 0
# Cbc0038I Pass  25: suminf.    1.90892 (4) obj. -347.708 iterations 3
# Cbc0038I Pass  26: suminf.    1.85079 (4) obj. -347.708 iterations 1
# Cbc0038I Pass  27: suminf.    1.68421 (4) obj. -348.068 iterations 2
# Cbc0038I Pass  28: suminf.    0.96737 (4) obj. -347.708 iterations 3
# Cbc0038I Pass  29: suminf.    1.52819 (4) obj. -347.708 iterations 4
# Cbc0038I Pass  30: suminf.    1.52819 (4) obj. -347.708 iterations 1
# Cbc0038I Pass  31: suminf.    1.63291 (5) obj. -347.708 iterations 5
# Cbc0038I Pass  32: suminf.    1.90892 (4) obj. -347.708 iterations 4
# Cbc0038I Pass  33: suminf.    1.85079 (4) obj. -347.708 iterations 2
# Cbc0038I Pass  34: suminf.    1.68421 (4) obj. -348.068 iterations 3
# Cbc0038I Pass  35: suminf.    0.96737 (4) obj. -347.708 iterations 4
# Cbc0038I Pass  36: suminf.    1.52819 (4) obj. -347.708 iterations 4
# Cbc0038I Pass  37: suminf.    1.52819 (4) obj. -347.708 iterations 2
# Cbc0038I Pass  38: suminf.    1.63291 (5) obj. -347.708 iterations 5
# Cbc0038I Pass  39: suminf.    0.20633 (4) obj. -347.708 iterations 4
# Cbc0038I Pass  40: suminf.    0.20633 (4) obj. -347.708 iterations 0
# Cbc0038I Pass  41: suminf.    1.10148 (5) obj. -347.708 iterations 5
# Cbc0038I Pass  42: suminf.    0.89772 (4) obj. -347.708 iterations 3
# Cbc0038I Pass  43: suminf.    0.20633 (4) obj. -347.708 iterations 1
# Cbc0038I Pass  44: suminf.    1.52819 (4) obj. -347.708 iterations 6
# Cbc0038I Pass  45: suminf.    1.52819 (4) obj. -347.708 iterations 0
# Cbc0038I Pass  46: suminf.    1.63291 (5) obj. -347.708 iterations 5
# Cbc0038I Pass  47: suminf.    0.96737 (4) obj. -347.708 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 711 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 6 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of -347.554 - took 0.04 seconds
# Cbc0012I Integer solution of -347.55383 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 387 rows 720 columns, reduced to 6 rows 6 columns
# Cbc0031I 1 added rows had average density of 8
# Cbc0013I At root node, 8 cuts changed objective from -348.06833 to -347.55383 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 10.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 4 row cuts average 9.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -347.55383089246, took 0 iterations and 0 nodes (0.08 seconds)
# Cbc0035I Maximum depth 0, 708 variables fixed on reduced cost
# Cuts at root node changed objective from -348.068 to -347.554
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                347.55383089
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.08
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.08   (Wallclock seconds):       0.09
#
# Status: Optimal
# Cost: 83.80000000000001
# Expected points per week: 347.55383089245856
#     position                    name             team  price  \
# 151       GK                 Ederson  Manchester City    5.4
# 272      DEF             John Stones  Manchester City    5.5
# 305      DEF         Kieran Trippier    Newcastle Utd    6.2
# 534      DEF  Trent Alexander-Arnold        Liverpool    7.5
# 290      MID            Kaoru Mitoma         Brighton    5.6
# 391      MID           Mohamed Salah        Liverpool   12.9
# 503      MID             Solly March         Brighton    5.2
# 68       MID         Bruno Fernandes   Manchester Utd    9.5
# 96       MID              Cody Gakpo        Liverpool    7.7
# 116      FWD           Danny Welbeck         Brighton    6.5
# 165      FWD          Erling Haaland  Manchester City   11.8
#
#      projected_points_with_decay
# 151                    24.254888
# 272                    22.805456
# 305                    21.724222
# 534                    23.193712
# 290                    26.295694
# 391                    37.640227
# 503                    35.297256
# 68                     34.770467
# 96                     27.826540
# 116                    26.067198
# 165                    30.037942
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/ac3a42fd4bb94d26b565973c1cb6132b-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/ac3a42fd4bb94d26b565973c1cb6132b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 349.949 - 0.01 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -349.949
# Cbc0038I Before mini branch and bound, 720 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -349.949 - took 0.00 seconds
# Cbc0012I Integer solution of -349.9486 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -349.94860471884, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -349.949 to -349.949
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                349.94860472
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: Optimal
# Cost: 84.69999999999999
# Expected points per week: 349.94860471883527
#     position                    name             team  price  \
# 151       GK                 Ederson  Manchester City    5.4
# 137      DEF             Diogo Dalot   Manchester Utd    4.7
# 29       DEF        Andrew Robertson        Liverpool    6.8
# 534      DEF  Trent Alexander-Arnold        Liverpool    7.5
# 299      MID         Kevin De Bruyne  Manchester City   12.1
# 38       MID                  Antony   Manchester Utd    7.3
# 391      MID           Mohamed Salah        Liverpool   12.9
# 503      MID             Solly March         Brighton    5.2
# 68       MID         Bruno Fernandes   Manchester Utd    9.5
# 116      FWD           Danny Welbeck         Brighton    6.5
# 19       FWD          Alexander Isak    Newcastle Utd    6.8
#
#      projected_points_with_decay
# 151                    21.259076
# 137                    22.573770
# 29                     22.670208
# 534                    27.476587
# 299                    36.858245
# 38                     27.504774
# 391                    39.896892
# 503                    33.880934
# 68                     29.321212
# 116                    23.750913
# 19                     24.859104
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/a751797e30364ebcbc59736de61fe4a3-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/a751797e30364ebcbc59736de61fe4a3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 344.951 - 0.00 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.387097
# Cbc0038I Solution found of -344.903
# Cbc0038I Before mini branch and bound, 716 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -344.907
# Cbc0038I Reduced cost fixing fixed 713 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.03878 (4) obj. -344.907 iterations 2
# Cbc0038I Pass   2: suminf.    0.42447 (5) obj. -344.907 iterations 4
# Cbc0038I Pass   3: suminf.    0.03878 (4) obj. -344.907 iterations 3
# Cbc0038I Pass   4: suminf.    0.42447 (5) obj. -344.907 iterations 4
# Cbc0038I Pass   5: suminf.    0.38710 (4) obj. -344.951 iterations 1
# Cbc0038I Pass   6: suminf.    0.32782 (4) obj. -344.907 iterations 2
# Cbc0038I Pass   7: suminf.    0.32782 (4) obj. -344.907 iterations 0
# Cbc0038I Pass   8: suminf.    0.03878 (4) obj. -344.907 iterations 1
# Cbc0038I Pass   9: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  10: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  11: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  12: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  13: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  14: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  15: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  16: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  17: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  18: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  19: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  20: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  21: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  22: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  23: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  24: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  25: suminf.    0.38710 (4) obj. -344.951 iterations 1
# Cbc0038I Pass  26: suminf.    0.03878 (4) obj. -344.907 iterations 1
# Cbc0038I Pass  27: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  28: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  29: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I Pass  30: suminf.    0.03878 (4) obj. -344.907 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 715 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 2 rows 2 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting with objective of -344.903 - took 0.02 seconds
# Cbc0012I Integer solution of -344.9026 found by feasibility pump after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0031I 1 added rows had average density of 5
# Cbc0013I At root node, 10 cuts changed objective from -344.95096 to -338.95805 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 3.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 3 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 4 row cuts average 4.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -344.90259927423, took 1 iterations and 0 nodes (0.05 seconds)
# Cbc0035I Maximum depth 0, 713 variables fixed on reduced cost
# Cuts at root node changed objective from -344.951 to -338.958
# Probing was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                344.90259927
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.07
#
# Status: Optimal
# Cost: 84.4
# Expected points per week: 344.9025992742288
#     position                    name             team  price  \
# 462       GK          Robert Sanchez         Brighton    4.5
# 29       DEF        Andrew Robertson        Liverpool    6.8
# 305      DEF         Kieran Trippier    Newcastle Utd    6.2
# 534      DEF  Trent Alexander-Arnold        Liverpool    7.5
# 214      MID           Jack Grealish  Manchester City    7.2
# 38       MID                  Antony   Manchester Utd    7.3
# 391      MID           Mohamed Salah        Liverpool   12.9
# 460      MID            Riyad Mahrez  Manchester City    7.3
# 503      MID             Solly March         Brighton    5.2
# 165      FWD          Erling Haaland  Manchester City   11.8
# 211      FWD              Ivan Toney        Brentford    7.7
#
#      projected_points_with_decay
# 462                    21.355401
# 29                     22.256409
# 305                    23.822207
# 534                    24.333391
# 214                    29.039342
# 38                     27.958766
# 391                    37.410335
# 460                    28.443266
# 503                    37.058436
# 165                    30.798193
# 211                    25.016518
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/1da653490c09437b92179eb0a8cf63a2-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/1da653490c09437b92179eb0a8cf63a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 351.029 - 0.00 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.0816327
# Cbc0038I Pass   1: suminf.    0.04819 (2) obj. -350.727 iterations 10
# Cbc0038I Solution found of -327.818
# Cbc0038I Before mini branch and bound, 717 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound improved solution from -327.818 to -344.848 (0.02 seconds)
# Cbc0038I Round again with cutoff of -345.466
# Cbc0038I Reduced cost fixing fixed 649 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.04878 (2) obj. -350.85 iterations 1
# Cbc0038I Pass   3: suminf.    0.64225 (2) obj. -345.466 iterations 4
# Cbc0038I Pass   4: suminf.    1.70214 (5) obj. -345.466 iterations 9
# Cbc0038I Pass   5: suminf.    0.49524 (3) obj. -345.466 iterations 4
# Cbc0038I Pass   6: suminf.    0.61086 (2) obj. -345.466 iterations 1
# ...
# 290      MID            Kaoru Mitoma         Brighton    5.6
# 38       MID                  Antony   Manchester Utd    7.3
# 391      MID           Mohamed Salah        Liverpool   12.9
# 415      MID         Neeskens Kebano           Fulham    5.4
# 550      MID         Weston McKennie     Leeds United    4.6
# 104      FWD       Cristiano Ronaldo   Manchester Utd   10.2
# 165      FWD          Erling Haaland  Manchester City   11.8
#
#      projected_points_with_decay
# 151                    24.490471
# 272                    24.303627
# 29                     21.962726
# 534                    26.347100
# 290                    29.267231
# 38                     28.934259
# 391                    37.146817
# 415                    30.233499
# 550                    27.474832
# 104                    24.662320
# 165                    37.992034
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/eec2289922944b7a9bb6b4f6b5fff9a3-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/eec2289922944b7a9bb6b4f6b5fff9a3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 362.408 - 0.01 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.0784314
# Cbc0038I Solution found of -362.379
# Cbc0038I Before mini branch and bound, 716 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 4 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -362.382
# Cbc0038I Reduced cost fixing fixed 711 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.00787 (4) obj. -362.382 iterations 3
# Cbc0038I Pass   2: suminf.    0.09493 (4) obj. -362.382 iterations 3
# Cbc0038I Pass   3: suminf.    0.37464 (4) obj. -362.382 iterations 4
# Cbc0038I Pass   4: suminf.    0.37464 (4) obj. -362.382 iterations 0
# Cbc0038I Pass   5: suminf.    0.39625 (4) obj. -362.382 iterations 3
# Cbc0038I Pass   6: suminf.    0.37464 (4) obj. -362.382 iterations 1
# Cbc0038I Pass   7: suminf.    0.39216 (4) obj. -362.388 iterations 1
# Cbc0038I Pass   8: suminf.    0.39625 (4) obj. -362.382 iterations 1
# Cbc0038I Pass   9: suminf.    0.37464 (4) obj. -362.382 iterations 2
# Cbc0038I Pass  10: suminf.    0.09493 (4) obj. -362.382 iterations 2
# Cbc0038I Pass  11: suminf.    0.00787 (4) obj. -362.382 iterations 2
# Cbc0038I Pass  12: suminf.    0.00787 (4) obj. -362.382 iterations 0
# Cbc0038I Pass  13: suminf.    0.00787 (4) obj. -362.382 iterations 0
# Cbc0038I Pass  14: suminf.    0.39216 (4) obj. -362.388 iterations 3
# Cbc0038I Pass  15: suminf.    0.39625 (4) obj. -362.382 iterations 2
# Cbc0038I Pass  16: suminf.    0.39216 (4) obj. -362.388 iterations 2
# Cbc0038I Pass  17: suminf.    0.37464 (4) obj. -362.382 iterations 3
# Cbc0038I Pass  18: suminf.    0.37464 (4) obj. -362.382 iterations 1
# Cbc0038I Pass  19: suminf.    0.37464 (4) obj. -362.382 iterations 0
# Cbc0038I Pass  20: suminf.    0.37464 (4) obj. -362.382 iterations 1
# Cbc0038I Pass  21: suminf.    0.37464 (4) obj. -362.382 iterations 1
# Cbc0038I Pass  22: suminf.    0.37464 (4) obj. -362.382 iterations 1
# Cbc0038I Pass  23: suminf.    0.39625 (4) obj. -362.382 iterations 3
# Cbc0038I Pass  24: suminf.    0.39216 (4) obj. -362.388 iterations 1
# Cbc0038I Pass  25: suminf.    0.39216 (4) obj. -362.388 iterations 0
# Cbc0038I Pass  26: suminf.    0.37464 (4) obj. -362.382 iterations 3
# Cbc0038I Pass  27: suminf.    0.37464 (4) obj. -362.382 iterations 1
# Cbc0038I Pass  28: suminf.    0.39625 (4) obj. -362.382 iterations 3
# Cbc0038I Pass  29: suminf.    0.37464 (4) obj. -362.382 iterations 3
# Cbc0038I Pass  30: suminf.    0.37464 (4) obj. -362.382 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 714 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 4 rows 5 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -362.379 - took 0.03 seconds
# Cbc0012I Integer solution of -362.37909 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 387 rows 720 columns, reduced to 4 rows 4 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -362.40768 to -362.40768 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 6.0 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -362.37909284777, took 0 iterations and 0 nodes (0.05 seconds)
# Cbc0035I Maximum depth 0, 711 variables fixed on reduced cost
# Cuts at root node changed objective from -362.408 to -362.408
# Probing was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                362.37909285
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.05
# Time (Wallclock seconds):       0.05
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.06
#
# Status: Optimal
# Cost: 84.6
# Expected points per week: 362.37909284777083
#     position              name             team  price  \
# 21        GK           Alisson        Liverpool    5.4
# 268      DEF      Joel Veltman         Brighton    4.6
# 29       DEF  Andrew Robertson        Liverpool    6.8
# 439      DEF  Pervis Estupinan         Brighton    4.8
# 214      MID     Jack Grealish  Manchester City    7.2
# 299      MID   Kevin De Bruyne  Manchester City   12.1
# 391      MID     Mohamed Salah        Liverpool   12.9
# 460      MID      Riyad Mahrez  Manchester City    7.3
# 503      MID       Solly March         Brighton    5.2
# 19       FWD    Alexander Isak    Newcastle Utd    6.8
# 190      FWD        Harry Kane        Tottenham   11.5
#
#      projected_points_with_decay
# 21                     20.857041
# 268                    23.932475
# 29                     23.475004
# 439                    23.179615
# 214                    31.396913
# 299                    37.472538
# 391                    43.906721
# 460                    31.802397
# 503                    31.604775
# 19                     24.224502
# 190                    26.620392
# Welcome to the CBC MILP Solver
# Version: 2.9.0
# Build Date: Feb 12 2015
#
# command line - /Users/jaakkotoivonen/opt/anaconda3/lib/python3.8/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/117ec77eae914918810138280bfe3000-pulp.mps max branch printingOptions all solution /var/folders/ml/jr8p__z97xx1jjb90rwg7hfm0000gn/T/117ec77eae914918810138280bfe3000-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 394 COLUMNS
# At line 5252 RHS
# At line 5642 BOUNDS
# At line 6363 ENDATA
# Problem MODEL has 389 rows, 720 columns and 2697 elements
# Coin0008I MODEL read with 0 errors
# Continuous objective value is 365.605 - 0.00 seconds
# Cgl0004I processed model has 387 rows, 720 columns (720 integer (720 of which binary)) and 2520 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.125
# Cbc0038I Solution found of -365.517
# Cbc0038I Before mini branch and bound, 718 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -365.526
# Cbc0038I Reduced cost fixing fixed 711 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.01251 (2) obj. -365.526 iterations 3
# Cbc0038I Pass   2: suminf.    0.15235 (3) obj. -365.526 iterations 6
# Cbc0038I Pass   3: suminf.    0.01251 (2) obj. -365.526 iterations 2
# Cbc0038I Pass   4: suminf.    0.15235 (3) obj. -365.526 iterations 3
# Cbc0038I Pass   5: suminf.    0.01251 (2) obj. -365.526 iterations 2
# Cbc0038I Pass   6: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass   7: suminf.    0.15279 (3) obj. -365.526 iterations 2
# Cbc0038I Pass   8: suminf.    0.01251 (2) obj. -365.526 iterations 2
# Cbc0038I Pass   9: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  10: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  11: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  12: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  13: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  14: suminf.    0.14469 (4) obj. -365.526 iterations 3
# Cbc0038I Pass  15: suminf.    0.01251 (2) obj. -365.526 iterations 4
# Cbc0038I Pass  16: suminf.    0.01251 (2) obj. -365.526 iterations 1
# Cbc0038I Pass  17: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  18: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  19: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  20: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  21: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  22: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  23: suminf.    0.01251 (2) obj. -365.526 iterations 1
# Cbc0038I Pass  24: suminf.    0.01251 (2) obj. -365.526 iterations 0
# Cbc0038I Pass  25: suminf.    0.01251 (2) obj. -365.526 iterations 2
# Cbc0038I Pass  26: suminf.    0.01251 (2) obj. -365.526 iterations 1
# Cbc0038I Pass  27: suminf.    0.01251 (2) obj. -365.526 iterations 2
# Cbc0038I Pass  28: suminf.    0.15235 (3) obj. -365.526 iterations 3
# Cbc0038I Pass  29: suminf.    0.15254 (4) obj. -365.526 iterations 1
# Cbc0038I Pass  30: suminf.    0.01251 (2) obj. -365.526 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 714 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 387 rows 720 columns, reduced to 4 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting with objective of -365.517 - took 0.02 seconds
# Cbc0012I Integer solution of -365.51694 found by feasibility pump after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0031I 1 added rows had average density of 5
# Cbc0013I At root node, 6 cuts changed objective from -365.60539 to -365.51694 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 5.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -365.51694435106, took 0 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 711 variables fixed on reduced cost
# Cuts at root node changed objective from -365.605 to -365.517
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 1 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                365.51694435
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.07
#
# Status: Optimal
# Cost: 84.4
# Expected points per week: 365.51694435106367
#     position                    name             team  price  \
# 151       GK                 Ederson  Manchester City    5.4
# 137      DEF             Diogo Dalot   Manchester Utd    4.7
# 29       DEF        Andrew Robertson        Liverpool    6.8
# 534      DEF  Trent Alexander-Arnold        Liverpool    7.5
# 38       MID                  Antony   Manchester Utd    7.3
# 391      MID           Mohamed Salah        Liverpool   12.9
# 460      MID            Riyad Mahrez  Manchester City    7.3
# 477      MID           Ryan Christie      Bournemouth    5.3
# 503      MID             Solly March         Brighton    5.2
# 104      FWD       Cristiano Ronaldo   Manchester Utd   10.2
# 165      FWD          Erling Haaland  Manchester City   11.8
#
#      projected_points_with_decay
# 151                    25.106098
# 137                    21.174099
# 29                     23.310718
# 534                    23.014891
# 38                     30.863518
# 391                    46.050024
# 460                    30.762907
# 477                    27.701099
# 503                    33.033297
# 104                    25.605399
# 165                    32.844868

# %%
my_df['dream_team_appearances'] = [sum(team.count(player_id) for team in results) for player_id in my_df.index]
my_df.head(5)
# Out:
#                  name            team position  price  minutes  \
# 0     Aaron Cresswell        West Ham      DEF    4.7     1850
# 1        Aaron Hickey       Brentford      DEF    4.9     1499
# 2      Aaron Ramsdale         Arsenal       GK    4.9     2880
# 3   Aaron Wan-Bissaka  Manchester Utd      DEF    4.3      916
# 4  Abdoulaye Doucoure         Everton      MID    5.3      987
#
#    number_of_games  projected_points  projected_points_with_decay       std  \
# 0                7         20.101030                    14.997258  0.143684
# 1                6         14.080973                    10.468797  0.102802
# 2                6         19.403967                    13.798076  0.119285
# 3                8         25.131258                    18.136991  0.140735
# 4                6         13.915958                    10.129604  0.109865
#
#    dream_team_appearances
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
print('Most appearances, all players:')
display(my_df.sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# Most appearances, all players:
#                        name             team position  price  minutes  \
# 391           Mohamed Salah        Liverpool      MID   12.9     2670
# 503             Solly March         Brighton      MID    5.2     2515
# 165          Erling Haaland  Manchester City      FWD   11.8     2224
# 299         Kevin De Bruyne  Manchester City      MID   12.1     2176
# 534  Trent Alexander-Arnold        Liverpool      DEF    7.5     2292
# 305         Kieran Trippier    Newcastle Utd      DEF    6.2     2712
# 29         Andrew Robertson        Liverpool      DEF    6.8     2133
# 19           Alexander Isak    Newcastle Utd      FWD    6.8      967
# 151                 Ederson  Manchester City       GK    5.4     2700
# 290            Kaoru Mitoma         Brighton      MID    5.6     1624
# 68          Bruno Fernandes   Manchester Utd      MID    9.5     2609
# 38                   Antony   Manchester Utd      MID    7.3     1368
# 460            Riyad Mahrez  Manchester City      MID    7.3     1290
# 137             Diogo Dalot   Manchester Utd      DEF    4.7     1789
# 116           Danny Welbeck         Brighton      FWD    6.5     1469
# 462          Robert Sanchez         Brighton       GK    4.5     2070
# 214           Jack Grealish  Manchester City      MID    7.2     1773
# 439        Pervis Estupinan         Brighton      DEF    4.8     1927
# 431              Pascal Gro         Brighton      MID    5.4     2542
# 324              Lewis Dunk         Brighton      DEF    4.7     2610
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 391                7         50.191732                    37.697983  0.636630
# 503                9         46.178963                    33.879272  0.432701
# 165                8         40.440249                    29.998464  0.717075
# 299                8         43.750162                    32.481290  0.512417
# 534                7         31.673060                    23.812316  0.414687
# 305                7         30.617749                    22.472388  0.302686
# 29                 7         29.950088                    22.513803  0.217227
# 19                 7         31.980165                    23.551670  0.326606
# 151                8         30.125661                    22.213464  0.215111
# 290                9         36.295624                    26.693069  0.209144
# 68                 8         38.942307                    28.298224  0.637978
# 38                 8         35.951874                    26.059229  0.305609
# 460                8         37.187614                    27.503998  0.484324
# 137                8         28.879089                    20.903071  0.121364
# 116                9         31.762505                    23.313033  0.158144
# 462                9         27.789276                    20.458760  0.134685
# 214                8         37.186956                    27.502267  0.313570
# 439                9         29.064635                    21.393733  0.165738
# 431                9         35.330943                    25.953797  0.292970
# 324                9         28.810706                    21.219537  0.128534
#
#      dream_team_appearances
# 391                      98
# 503                      96
# 165                      66
# 299                      65
# 534                      59
# 305                      56
# 29                       53
# 19                       52
# 151                      46
# 290                      39
# 68                       37
# 38                       36
# 460                      34
# 137                      33
# 116                      31
# 462                      30
# 214                      26
# 439                      26
# 431                      20
# 324                      18

# %%
print('GOALKEEPERS')
display(my_df[my_df['position']=='GK'].sort_values(by='dream_team_appearances', ascending=False).head(10))
# Out:
# GOALKEEPERS
#                   name             team position  price  minutes  \
# 151            Ederson  Manchester City       GK    5.4     2700
# 462     Robert Sanchez         Brighton       GK    4.5     2070
# 21             Alisson        Liverpool       GK    5.4     2790
# 123       David de Gea   Manchester Utd       GK    5.0     2700
# 298  Kepa Arrizabalaga          Chelsea       GK    4.7     2025
# 2       Aaron Ramsdale          Arsenal       GK    4.9     2880
# 207      Illan Meslier     Leeds United       GK    4.5     2880
# 417          Nick Pope    Newcastle Utd       GK    5.4     2721
# 363       Mark Travers      Bournemouth       GK    4.2      945
# 337   Lukasz Fabianski         West Ham       GK    4.9     2481
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 151                8         30.125661                    22.213464  0.215111
# 462                9         27.789276                    20.458760  0.134685
# 21                 7         25.907387                    19.457405  0.145472
# 123                8         26.883187                    19.427698  0.174776
# 298                7         22.715687                    16.310151  0.171108
# 2                  6         19.403967                    13.798076  0.119285
# 207                6         15.711466                    11.642908  0.104604
# 417                7         23.256711                    17.147080  0.170045
# 363                6         16.944574                    12.528267  0.134734
# 337                7         21.789126                    16.262091  0.152475
#
#      dream_team_appearances
# 151                      46
# 462                      30
# 21                       12
# 123                      11
# 298                       1
# 2                         0
# 207                       0
# 417                       0
# 363                       0
# 337                       0

# %%
print('DEFENDERS')
display(my_df[my_df['position']=='DEF'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# DEFENDERS
#                        name             team position  price  minutes  \
# 534  Trent Alexander-Arnold        Liverpool      DEF    7.5     2292
# 305         Kieran Trippier    Newcastle Utd      DEF    6.2     2712
# 29         Andrew Robertson        Liverpool      DEF    6.8     2133
# 137             Diogo Dalot   Manchester Utd      DEF    4.7     1789
# 439        Pervis Estupinan         Brighton      DEF    4.8     1927
# 324              Lewis Dunk         Brighton      DEF    4.7     2610
# 272             John Stones  Manchester City      DEF    5.5     1458
# 472              Ruben Dias  Manchester City      DEF    6.0     1637
# 255            Joao Cancelo  Manchester City      DEF    7.1     1273
# 268            Joel Veltman         Brighton      DEF    4.6     1986
# 348           Manuel Akanji  Manchester City      DEF    5.0     1855
# 403              Nathan Ake  Manchester City      DEF    5.1     1680
# 341               Luke Shaw   Manchester Utd      DEF    5.1     1967
# 171            Fabian Schar    Newcastle Utd      DEF    5.1     2577
# 313             Kyle Walker  Manchester City      DEF    4.7     1287
# 544         Virgil van Dijk        Liverpool      DEF    6.6     2295
# 453             Reece James          Chelsea      DEF    5.8     1242
# 412            Nayef Aguerd         West Ham      DEF    4.8     1144
# 422     Oleksandr Zinchenko          Arsenal      DEF    5.2     1900
# 416           Nelson Semedo           Wolves      DEF    5.0     2138
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 534                7         31.673060                    23.812316  0.414687
# 305                7         30.617749                    22.472388  0.302686
# 29                 7         29.950088                    22.513803  0.217227
# 137                8         28.879089                    20.903071  0.121364
# 439                9         29.064635                    21.393733  0.165738
# 324                9         28.810706                    21.219537  0.128534
# 272                8         29.654670                    21.869663  0.130500
# 472                8         30.216530                    22.279662  0.174870
# 255                8         28.518896                    21.055421  0.276590
# 268                9         26.994302                    19.896055  0.179837
# 348                8         28.279719                    20.839045  0.125488
# 403                8         27.437264                    20.212378  0.150994
# 341                8         26.499305                    19.175093  0.147094
# 171                7         26.264378                    19.317379  0.125246
# 313                8         25.887699                    19.083284  0.255996
# 544                7         25.077767                    18.822395  0.196281
# 453                7         23.173085                    16.626618  0.208105
# 412                7         18.903639                    14.081823  0.189669
# 422                6         19.618312                    13.942884  0.158425
# 416                6         14.371615                    10.646199  0.095328
#
#      dream_team_appearances
# 534                      59
# 305                      56
# 29                       53
# 137                      33
# 439                      26
# 324                      18
# 272                      17
# 472                      17
# 255                       8
# 268                       7
# 348                       6
# 403                       3
# 341                       3
# 171                       2
# 313                       1
# 544                       1
# 453                       1
# 412                       0
# 422                       0
# 416                       0

# %%
print('MIDFIELDERS')
display(my_df[my_df['position']=='MID'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# MIDFIELDERS
#                     name             team position  price  minutes  \
# 391        Mohamed Salah        Liverpool      MID   12.9     2670
# 503          Solly March         Brighton      MID    5.2     2515
# 299      Kevin De Bruyne  Manchester City      MID   12.1     2176
# 290         Kaoru Mitoma         Brighton      MID    5.6     1624
# 68       Bruno Fernandes   Manchester Utd      MID    9.5     2609
# 38                Antony   Manchester Utd      MID    7.3     1368
# 460         Riyad Mahrez  Manchester City      MID    7.3     1290
# 214        Jack Grealish  Manchester City      MID    7.2     1773
# 431           Pascal Gro         Brighton      MID    5.4     2542
# 71           Bukayo Saka          Arsenal      MID    8.5     2706
# 96            Cody Gakpo        Liverpool      MID    7.7      979
# 109       Dango Ouattara      Bournemouth      MID    5.0      872
# 415      Neeskens Kebano           Fulham      MID    5.4      712
# 20   Alexis Mac Allister         Brighton      MID    5.5     2245
# 440           Phil Foden  Manchester City      MID    8.0     1399
# 477        Ryan Christie      Bournemouth      MID    5.3     1374
# 550      Weston McKennie     Leeds United      MID    4.6      952
# 386       Miguel Almiron    Newcastle Utd      MID    5.4     2035
# 528          Tom Cairney           Fulham      MID    4.7      536
# 396       Moussa Djenepo      Southampton      MID    5.0      622
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 391                7         50.191732                    37.697983  0.636630
# 503                9         46.178963                    33.879272  0.432701
# 299                8         43.750162                    32.481290  0.512417
# 290                9         36.295624                    26.693069  0.209144
# 68                 8         38.942307                    28.298224  0.637978
# 38                 8         35.951874                    26.059229  0.305609
# 460                8         37.187614                    27.503998  0.484324
# 214                8         37.186956                    27.502267  0.313570
# 431                9         35.330943                    25.953797  0.292970
# 71                 6         32.344815                    23.196122  0.712804
# 96                 7         33.685124                    25.301279  0.246619
# 109                6         22.212118                    16.399332  1.297861
# 415                7         19.168763                    14.339887  1.187931
# 20                 9         32.363332                    23.739260  0.282796
# 440                8         35.441136                    26.194686  0.167372
# 477                6         18.211351                    13.448447  1.266027
# 550                6         15.603183                    11.545517  0.997619
# 386                7         27.209778                    19.952607  0.505320
# 528                7         18.157283                    13.594529  0.946427
# 396                6         13.935246                    10.362166  0.150191
#
#      dream_team_appearances
# 391                      98
# 503                      96
# 299                      65
# 290                      39
# 68                       37
# 38                       36
# 460                      34
# 214                      26
# 431                      20
# 71                       10
# 96                        8
# 109                       8
# 415                       6
# 20                        6
# 440                       5
# 477                       3
# 550                       1
# 386                       1
# 528                       1
# 396                       0

# %%
print('FORWARDS')
display(my_df[my_df['position']=='FWD'].sort_values(by='dream_team_appearances', ascending=False).head(20))
# Out:
# FORWARDS
#                           name             team position  price  minutes  \
# 165             Erling Haaland  Manchester City      FWD   11.8     2224
# 19              Alexander Isak    Newcastle Utd      FWD    6.8      967
# 116              Danny Welbeck         Brighton      FWD    6.5     1469
# 104          Cristiano Ronaldo   Manchester Utd      FWD   10.2      519
# 211                 Ivan Toney        Brentford      FWD    7.7     2691
# 138                 Diogo Jota        Liverpool      FWD    8.8      828
# 190                 Harry Kane        Tottenham      FWD   11.5     2866
# 119               Darwin Nunez        Liverpool      FWD    8.7     1509
# 5               Adam Armstrong      Southampton      FWD    5.3     1177
# 421            Odsonne Edouard   Crystal Palace      FWD    5.0     1567
# 286                Kai Havertz          Chelsea      FWD    7.4     2215
# 296          Kelechi Iheanacho   Leicester City      FWD    5.9      910
# 303              Kieffer Moore      Bournemouth      FWD    4.9     1159
# 385            Michail Antonio         West Ham      FWD    7.0     1447
# 413                Neal Maupay          Everton      FWD    5.7     1031
# 424              Ollie Watkins      Aston Villa      FWD    7.7     2593
# 256                 Joao Felix          Chelsea      FWD    7.4      790
# 433            Patrick Bamford     Leeds United      FWD    7.1     1148
# 434                Patson Daka   Leicester City      FWD    5.6     1050
# 444  Pierre-Emerick Aubameyang          Chelsea      FWD    8.4      456
#
#      number_of_games  projected_points  projected_points_with_decay       std  \
# 165                8         40.440249                    29.998464  0.717075
# 19                 7         31.980165                    23.551670  0.326606
# 116                9         31.762505                    23.313033  0.158144
# 104                8         32.971763                    23.919161  0.159102
# 211                6         29.298496                    21.682054  0.361097
# 138                7         29.983260                    22.522003  0.253050
# 190                6         31.105774                    22.577055  0.368143
# 119                7         28.752087                    21.590252  0.277273
# 5                  6         14.096478                    10.478675  0.153191
# 421                6         15.826433                    11.588027  0.126063
# 286                7         25.766607                    18.487156  0.160305
# 296                6         18.958475                    14.113751  0.218739
# 303                6         15.670944                    11.574789  0.113245
# 385                7         19.071151                    14.277572  0.158302
# 413                6         14.760886                    10.743299  0.150167
# 424                6         25.060331                    18.728380  0.237717
# 256                7         22.374016                    16.037276  0.204672
# 433                6         18.810174                    13.915474  0.228123
# 434                6         15.701978                    11.683103  0.118531
# 444                7         20.989765                    15.041111  0.370945
#
#      dream_team_appearances
# 165                      66
# 19                       52
# 116                      31
# 104                      15
# 211                       8
# 138                       7
# 190                       5
# 119                       5
# 5                         0
# 421                       0
# 286                       0
# 296                       0
# 303                       0
# 385                       0
# 413                       0
# 424                       0
# 256                       0
# 433                       0
# 434                       0
# 444                       0
