# %%
import pandas as pd
import numpy as np

from pathlib import Path
import os

pd.set_option('display.max_columns', 100)

# %%
path_to_folder = '../../../../season22_23/data/fpl_data/'
data = []
for file in os.listdir(path_to_folder):
    data.append(pd.read_csv(Path(path_to_folder + file), index_col=0))
display(len(data))
# Out:
# 38

# %%
df = pd.concat(data)
display(df.head())
display(df.tail())
display(df.shape)
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                         100.0                         100.0   58822
# 1                           NaN                           NaN   84450
# 2                           0.0                           0.0  153256
# 3                           NaN                           NaN  156074
# 4                         100.0                         100.0  167199
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                 -3
# 1                  0                       0                  1
# 2                 -1                       1                 -3
# 3                  0                       0                 -3
# 4                  0                       0                 -2
#
#    cost_change_start_fall  dreamteam_count  element_type  ep_next  ep_this  \
# 0                       3                0             2      1.0      0.5
# ...
