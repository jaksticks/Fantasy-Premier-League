# %% [markdown]
# # Player evaluation
#
# Here we compare players based on their adjusted points. Also, we calculate some useful metrics using the adjusted points to further evaluate player performance in FPL.

# %%
# recent gameweek
gameweek = 22

# %%
# import basic libraries
import pandas as pd
import numpy as np
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.set_option('max_columns',100)

# %%
# fetch FPL data
filepath = '../data/fpl/data_week' + str(gameweek) + '.csv'
df = pd.read_csv(filepath, index_col=0)

# fetch team data
filepath = '../data/fbref/team_stats_week' + str(gameweek) + '.csv'
teamStats = pd.read_csv(filepath, index_col=0)

# fetch player stats data
filepath = '../data/fbref/player_stats_week' + str(gameweek) + '.csv'
playerStats = pd.read_csv(filepath, index_col=0, skiprows=1)

# %% [markdown]
# ## Value and value points
#
# Here we calculate two interesting metrics: 'value' and 'value points'.
#
# Value is simply adjusted points per game divided by the cost of the player. Essentially, this measures how many 'points per pound(/euro/whatever)' has the player gained on an average game week.
#
# The value points is calculated as the geometric mean of a players adjusted points per game and value. Essentially, in FPL we want to gain the maximum possible amount of points. However, we are restrained by a limited budget, so that in practice we cannot just pick all the best players. Then, we would like to have a squad of players that give the most points given our budget. Thus, we would like to pick players that have high value ('bang for buck'). However, often the players with highest value are very cheap players who somewhat overperform relative to their price. Picking a squad full of these players might leave a part of our budget unused. Calculating the geometric mean of adjusted points and value allows us to weigh both aspects equally, i.e. we want players that both gain a lot of points but also have good value. For example, this metric values equally two players, where one has twice the points per game of the other who in turn has twice the value of the other.

# %%
# value = expected points / cost
df['value'] = df['adjusted points per game'] / (df['now_cost'] / 10.0)
df['value form 5'] = df['form 5'] / (df['now_cost'] / 10.0)
df['value form 10'] = df['form 10'] / (df['now_cost'] / 10.0)
# geometric mean of 'adjusted points per game' and 'value'
df['valuePoints metric'] = np.sqrt(df['adjusted points per game'] * df['value'])

# %%
df['value_next10']  = df['xPoints_next10'] / (df['now_cost'] / 10.0)

# %%
df['xG+xA'] = df['xG'] + df['xA']
df['xG+xA per game'] = df['xG+xA'] / df['games played']

# %%
goalkeepers = df['element_type'] == 1
defenders = df['element_type'] == 2
midfielders = df['element_type'] == 3
forwards = df['element_type'] == 4

minGames = df['games played'] >= 3

# %% [markdown]
# ## Player evaluation
#
# Below we compile lists for each position sorting players based on a given metric.
#
# Notice that 'next1_xP' is currently based on preseason expectations on average player performance!

# %%
metric = 'valuePoints metric'
#metric = 'adjusted points per game'
#metric = 'next1_xP'

numberToShow = 40

print('GOALKEEPERS')
display(df[goalkeepers & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10', 'valuePoints metric']].head(20))
print('DEFENDERS')
display(df[defenders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('MIDFIELDERS')
display(df[midfielders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('FORWARDS')
display(df[forwards & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
# Out:
# GOALKEEPERS
#          web_name        team_name  now_cost  games played  total_points  \
# id
# 156       Butland   Crystal Palace        44           3.0            14
# 333       Forster      Southampton        44           4.0            13
# 475            Sá           Wolves        52          20.0            95
# 376        Foster          Watford        41           9.0            30
# 129  Arrizabalaga          Chelsea        47           3.0            11
# 270        de Gea   Manchester Utd        52          21.0            84
# 353        Lloris        Tottenham        54          19.0            82
# 257       Ederson  Manchester City        61          21.0            94
# 408     Fabianski         West Ham        50          22.0            79
# 134           31.571              2.2                  2.870091  2.400000
# 269           25.500              2.6                  2.833333  2.975000
# 404           31.371              2.2                  2.240786  3.066667
# 310           44.071              2.1                  2.319526  2.900000
# 329           30.700              1.7                  2.046667  3.075000
#
#      xPoints_next10  valuePoints metric
# id
# 177       42.492985            2.267056
# 468       37.987990            1.675662
# 189       38.368009            1.630216
# 450       40.653399            1.622387
# 413       47.431551            1.621647
# 78        39.216981            1.513830
# 307       35.880873            1.509977
# 263       38.739937            1.466231
# 40        37.909032            1.431791
# 455       39.877674            1.422033
# 579       44.090280            1.410104
# 63        36.452775            1.394737
# 518       33.705184            1.368262
# 315       29.351693            1.364852
# 205       34.569094            1.352898
# 235       22.647018            1.338877
# 357       42.754167            1.328435
# 296       29.581185            1.324746
# 583       26.374010            1.315585
# 525       32.364206            1.310573
# 228       30.728269            1.291513
# 180       32.574175            1.278722
# 187       26.748027            1.276501
# 345       30.769253            1.241000
# 109       27.211425            1.206220
# 149       32.802626            1.198223
# 430       32.456627            1.194395
# 337       33.969786            1.176312
# 4         24.095110            1.162149
# 213       28.215690            1.144365
# 529       29.874271            1.143579
# 153       27.449918            1.101729
# 577       28.299353            1.086568
# 6         30.655570            1.052419
# 447       25.443803            0.982918
# 134       20.031141            0.978693
# 269       31.959562            0.977593
# 404       22.476199            0.964281
# 310       24.914210            0.963131
# 329       22.538396            0.924590

# %% [markdown]
# Below we compile a list sorting players based on a given metric (irrespective of position).

# %%
metric = 'adjusted points per game'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 233             Salah        Liverpool       127          20.0           177
# 237  Alexander-Arnold        Liverpool        84          19.0           142
# 177     Calvert-Lewin          Everton        79           5.0            25
# 544       Branthwaite          Everton        40           1.0             9
# 268            Torres  Manchester City        67           4.0            26
# 135          Chilwell          Chelsea        56           6.0            54
# 253             Mendy  Manchester City        52           1.0             3
# 256           Cancelo  Manchester City        70          21.0           132
# 359               Son        Tottenham       107          17.0           108
# 156           Butland   Crystal Palace        44           3.0            14
# 240              Jota        Liverpool        84          20.0           104
# 265             Foden  Manchester City        80          14.0            76
# 230              Mané        Liverpool       117          20.0            97
# 420             Bowen         West Ham        68          22.0           122
# 681          Coutinho      Aston Villa        70           1.0             6
# 142             James          Chelsea        62          16.0            91
# 246        N.Williams        Liverpool        38           1.0             4
# 260           Steffen  Manchester City        44           1.0             7
# 250          Gündogan  Manchester City        73          15.0            71
# 579           Ronaldo   Manchester Utd       125          17.0            84
# 266           Rodrigo  Manchester City        55          13.0            63
# 255          Sterling  Manchester City       107          18.0            80
# 196          Raphinha     Leeds United        65          18.0            90
# 679           Kayembe          Watford        50           1.0             3
# 234         Robertson        Liverpool        70          15.0            81
# 122            Alonso          Chelsea        57          17.0            73
# 138             Mount          Chelsea        77          20.0            98
# 144         Gallagher   Crystal Palace        61          18.0           100
# 259           Laporte  Manchester City        56          18.0            91
# 357              Kane        Tottenham       123          18.0            64
# 254            Mahrez  Manchester City        86          16.0            77
# 262              Dias  Manchester City        63          20.0            96
# 251         De Bruyne  Manchester City       121          16.0            78
# 252            Stones  Manchester City        52           7.0            39
# 413           Antonio         West Ham        79          21.0            98
# 501              Sarr          Chelsea        49           2.0            10
# 189           Bamford     Leeds United        77           6.0            25
# 33           Grealish  Manchester City        76          15.0            55
# 277         Fernandes   Manchester Utd       117          20.0            95
# 261          Bernardo  Manchester City        75          21.0           106
#
#      adjusted points  points_per_game  adjusted points per game  \
# id
#
# 389        26.557761              2.1                  2.655776
# 263        77.397000              3.9                  4.299833
# 419        77.562240              4.5                  3.878112
# 259        83.918040              5.1                  4.662113
# 210        66.139251              4.8                  4.409283
# 212        79.066185              4.7                  4.161378
# 262        91.882045              4.8                  4.594102
# 558        60.085661              4.0                  3.338092
# 200        60.044740              3.2                  3.160249
# 513        11.671363              2.2                  2.917841
# 584        72.685519              3.9                  4.038084
#
#      gameweek 23 prediction  valuePoints metric
# id
# 233                5.872264            2.155032
# 196                5.240425            1.899655
# 413                4.873412            1.621647
# 22                 4.795498            1.571524
# 256                4.722038            2.239710
# 450                4.708110            1.622387
# 237                4.664402            2.368675
# 21                 4.576803            1.480145
# 240                4.524239            1.988596
# 26                 4.505908            1.604509
# 189                4.470533            1.630216
# 468                4.458150            1.675662
# 455                4.406546            1.422033
# 359                4.388209            1.792258
# 199                4.373462            1.305951
# 16                 4.352972            1.728699
# 579                4.338711            1.410104
# 559                4.311935            1.680557
# 63                 4.292642            1.394737
# 251                4.291921            1.320592
# 257                4.284510            1.709632
# 265                4.266643            2.020204
# 64                 4.261211            1.560631
# 69                 4.258730            1.701679
# 135                4.212816            2.606844
# 261                4.159433            1.612774
# 1                  4.151314            1.086604
# 679                4.149254            2.164042
# 295                4.101607            1.271843
# 389                4.089707            1.280729
# 263                4.062341            1.466231
# 419                4.052745            1.596593
# 259                4.046907            1.970102
# 210                4.045879            1.742922
# 212                4.036958            1.572853
# 262                4.028766            1.830334
# 558                4.023926            1.410601
# 200                4.015891            1.442450
# 513                4.014304            1.407108
# 584                4.003418            1.788094

# %%
metric = 'xG'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game',\
                      'valuePoints metric', 'xG', 'xA', 'xG+xA', 'xG+xA per game']].head(numberToShow))
# Out:
#           web_name        team_name  now_cost  games played  points_per_game  \
# id
# 233          Salah        Liverpool       127          20.0              8.8
# 240           Jota        Liverpool        84          20.0              5.2
# 230           Mané        Liverpool       117          20.0              4.8
# 579        Ronaldo   Manchester Utd       125          17.0              4.9
# 357           Kane        Tottenham       123          18.0              3.6
# 420          Bowen         West Ham        68          22.0              5.5
# 413        Antonio         West Ham        79          21.0              4.7
# 255       Sterling  Manchester City       107          18.0              4.4
# 359            Son        Tottenham       107          17.0              6.4
# 468           King          Watford        58          17.0              3.8
# 196       Raphinha     Leeds United        65          18.0              5.0
# 205          Vardy   Leicester City       103          16.0              4.9
# 40         Watkins      Aston Villa        77          17.0              3.8
# 96          Mbeumo        Brentford        53          19.0              3.3
# 138          Mount          Chelsea        77          20.0              4.9
# 4       Aubameyang          Arsenal        96          14.0              3.1
# 78           Toney        Brentford        66          20.0              3.5
# 63          Maupay         Brighton        65          19.0              3.9
# 149        Benteke   Crystal Palace        62          20.0              2.6
# 263          Jesus  Manchester City        86          18.0              3.9
# 265          Foden  Manchester City        80          14.0              5.4
# 250       Gündogan  Manchester City        73          15.0              4.7
# 254         Mahrez  Manchester City        86          16.0              4.8
# 177  Calvert-Lewin          Everton        79           5.0              5.0
# 123       Jorginho          Chelsea        59          19.0              4.3
# 315          Pukki     Norwich City        58          20.0              3.2
# 109           Wood    Newcastle Utd        67          18.0              2.7
# 468        0.517647
# 196        0.561111
# 205        0.468750
# 40         0.411765
# 96         0.394737
# 138        0.500000
# 4          0.471429
# 78         0.460000
# 63         0.368421
# 149        0.325000
# 263        0.477778
# 265        0.628571
# 250        0.506667
# 254        0.506250
# 177        1.020000
# 123        0.363158
# 315        0.280000
# 109        0.283333
# 212        0.368421
# 22         0.380000
# 277        0.515000
# 296        0.320000
# 289        0.352941
# 450        0.355556
# 529        0.426667
# 430        0.310526
# 261        0.361905
# 6          0.340000
# 64         0.290000
# 525        0.322222
# 228        0.508333

# %% [markdown]
# ## Player Visualizations

# %%
game_weeks = np.arange(1,gameweek+1)
column_xPoints = []
column_xG = []
column_xA = []
column_xGA = []
for i in range(1,gameweek+1):
    column_xPoints.append('xPoints week ' + str(i))
    column_xG.append('xG_week' + str(i))
    column_xA.append('xA_week' + str(i))
    column_xGA.append('xGA_week' + str(i))

#display(game_weeks)
#display(column_xPoints)

# %%
# find player index
name_string = 'Antonio'
playersFound = df[df['web_name'].str.contains(name_string)]
display(playersFound[['web_name','team_name','now_cost','games played','total_points','adjusted points',\
                      'points_per_game','adjusted points per game',f'gameweek {gameweek+1} prediction',\
                      'xPoints_next10', 'valuePoints metric']])
# plot xPoints over time
ix = playersFound.index[0]
#ix = 468

fig,ax = plt.subplots(2,2,figsize=(15,10))

ax[0,0].plot(game_weeks, df.loc[ix,column_xPoints], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,0].set_title(title_string)
ax[0,0].set_xlabel('gameweek')
ax[0,0].set_ylabel('xPoints')
ax[0,0].set_xticks(game_weeks)

ax[0,1].plot(game_weeks, df.loc[ix,column_xG], marker='o')
ax[0,1].plot(game_weeks, df.loc[ix,column_xA], marker='o')
ax[0,1].legend(('xG','xA'))
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,1].set_title(title_string)
ax[0,1].set_xlabel('gameweek')
ax[0,1].set_ylabel('xG and xA')
ax[0,1].set_xticks(game_weeks)

ax[1,0].plot(game_weeks, df.loc[ix,column_xGA], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[1,0].set_title(title_string)
ax[1,0].set_xlabel('gameweek')
ax[1,0].set_ylabel('xGA')
ax[1,0].set_xticks(game_weeks)

plt.show()
# Out:
#     web_name team_name  now_cost  games played  total_points  adjusted points  \
# id
# 413  Antonio  West Ham        79          21.0            98           95.717
#
#      points_per_game  adjusted points per game  gameweek 23 prediction  \
# id
# 413              4.7                  4.557952                4.873412
#
#      xPoints_next10  valuePoints metric
# id
# 413       47.431551            1.621647

# %% [markdown]
# ## My team

# %%
session = requests.session()

# %%
filepath = Path('../../../access_control/FPL_access.txt')
with open(filepath) as file:
    text = file.read().splitlines()
    email = text[0]
    password = text[1]

# %%
url = 'https://users.premierleague.com/accounts/login/'

payload = {
'password': password,
'login': email,
'redirect_uri': 'https://fantasy.premierleague.com/a/login', 'app': 'plfpl-web'
}
session.post(url, data=payload)
# Out:
# <Response [200]>

# %%
response = session.get('https://fantasy.premierleague.com/api/my-team/3202682')
team = response.json()['picks']

# %%
my_player_ix = [player['element'] for player in team]
my_starting11 = my_player_ix[:-4]
my_subs = my_player_ix[-4:]

# %%
exp_avg = df.loc[my_starting11,'adjusted points per game'].sum() + \
                df.loc[my_starting11,'adjusted points per game'].max()
exp_next = df.loc[my_starting11, f'gameweek {gameweek+1} prediction'].sum() + \
                df.loc[my_starting11,f'gameweek {gameweek+1} prediction'].max()

print('STARTING 11')
print('Expected points on average: ' + str(exp_avg))
print('Predicted points next gameweek: ' + str(exp_next))
display(df.loc[my_starting11, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
           f'gameweek {gameweek+1} prediction','xPoints_next10', 'valuePoints metric']].head(numberToShow))
print('\nSUBSTITUTES')
display(df.loc[my_subs, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
         f'gameweek {gameweek+1} prediction', 'xPoints_next10', 'valuePoints metric']].head(numberToShow))
# Out:
# STARTING 11
# Expected points on average: 58.88825332964596
# Predicted points next gameweek: 49.94576716423035
#              web_name        team_name  now_cost  games played  \
# id
# 559          Ramsdale          Arsenal        51          17.0
# 256           Cancelo  Manchester City        70          21.0
# 237  Alexander-Arnold        Liverpool        84          19.0
# 76            Jansson        Brentford        46          22.0
# 138             Mount          Chelsea        77          20.0
# 250          Gündogan  Manchester City        73          15.0
# 212          Maddison   Leicester City        70          19.0
# 420             Bowen         West Ham        68          22.0
# 450            Dennis          Watford        61          18.0
# 40            Watkins      Aston Villa        77          17.0
# 579           Ronaldo   Manchester Utd       125          17.0
#
#      points_per_game  adjusted points per game    form 5   form 10  \
# id
# 559              4.9                  3.795232  3.299393  4.522793
# 256              6.3                  5.925717  5.934565  5.715032
# 237              7.5                  6.865073  6.193007  6.998804
# 76               3.0                  3.230168  2.713985  3.277675
# 138              4.9                  4.686571  4.097266  5.043202
# 250              4.7                  4.993601  1.863573  4.541433
# 212              4.7                  4.161378  5.467790  6.492637
# 420              5.5                  5.399912  9.779926  6.554284
# 450              5.2                  4.007000  2.933333  4.467286
# 40               3.8                  3.973059  3.400000  4.681571
# 579              4.9                  4.985471  4.467750  5.271375
#
#      gameweek 23 prediction  xPoints_next10  valuePoints metric
# id
# 559                4.311935       32.043197            1.680557
# 256                4.722038       45.080410            2.239710
# 237                4.664402       42.917403            2.368675
# 76                 3.389240       30.629377            1.506073
# 138                3.929460       32.876079            1.688923
# 250                3.435300       31.911306            1.848214
# 212                4.036958       36.983294            1.572853
# 420                3.979560       39.148150            2.070772
# 450                4.708110       40.653399            1.622387
# 40                 3.708015       37.909032            1.431791
# 579                4.338711       44.090280            1.410104
# SUBSTITUTES
#        web_name     team_name  now_cost  games played  points_per_game  \
# id
# 376      Foster       Watford        41           9.0              3.3
# 145     Gilmour  Norwich City        43          12.0              2.2
# 425     Johnson      West Ham        40          11.0              2.7
# 491  Livramento   Southampton        43          18.0              3.0
#
#      adjusted points per game    form 5   form 10  gameweek 23 prediction  \
# id
# 376                  3.674776  2.892521  2.892521                3.767861
# 145                  2.557611  2.258710  2.458718                2.584150
# 425                  2.726557  1.602388  1.650179                2.267327
# 491                  2.819106  1.661196  2.003110                1.750160
#
#      xPoints_next10  valuePoints metric
# id
# 376       33.629147            1.814843
# 145       22.724222            1.233390
# 425       26.710590            1.363279
# 491       26.816645            1.359494

# %% [markdown]
# ## Save data

# %%
# save data
filepath = '../data/fpl/data_week' + str(gameweek) + str('.csv')
df.to_csv(filepath)
