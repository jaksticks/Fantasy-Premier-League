# %% [markdown]
# # Player evaluation
#
# Here we compare players based on their adjusted points. Also, we calculate some useful metrics using the adjusted points to further evaluate player performance in FPL.

# %%
# recent gameweek
gameweek = 4

# %%
# import basic libraries
import pandas as pd
import numpy as np
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.set_option('max_columns',100)

# %%
# fetch FPL data
filepath = '../data/fpl/data_week' + str(gameweek) + '.csv'
df = pd.read_csv(filepath, index_col=0)

# fetch team data
filepath = '../data/fbref/team_stats_week' + str(gameweek) + '.csv'
teamStats = pd.read_csv(filepath, index_col=0)

# fetch player stats data
filepath = '../data/fbref/player_stats_week' + str(gameweek) + '.csv'
playerStats = pd.read_csv(filepath, index_col=0, skiprows=1)

# %% [markdown]
# ## Value and value points
#
# Here we calculate two interesting metrics: 'value' and 'value points'.
#
# Value is simply adjusted points per game divided by the cost of the player. Essentially, this measures how many 'points per pound(/euro/whatever)' has the player gained on an average game week.
#
# The value points is calculated as the geometric mean of a players adjusted points per game and value. Essentially, in FPL we want to gain the maximum possible amount of points. However, we are restrained by a limited budget, so that in practice we cannot just pick all the best players. Then, we would like to have a squad of players that give the most points given our budget. Thus, we would like to pick players that have high value ('bang for buck'). However, often the players with highest value are very cheap players who somewhat overperform relative to their price. Picking a squad full of these players might leave a part of our budget unused. Calculating the geometric mean of adjusted points and value allows us to weigh both aspects equally, i.e. we want players that both gain a lot of points but also have good value. For example, this metric values equally two players, where one has twice the points per game of the other who in turn has twice the value of the other.

# %%
# value = expected points / cost
df['value'] = df['adjusted points per game'] / (df['now_cost'] / 10.0)
df['value form 5'] = df['form 5'] / (df['now_cost'] / 10.0)
df['value form 10'] = df['form 10'] / (df['now_cost'] / 10.0)
# geometric mean of 'adjusted points per game' and 'value'
df['valuePoints metric'] = np.sqrt(df['adjusted points per game'] * df['value'])

# %%
df['value_next10']  = df['xPoints_next10'] / (df['now_cost'] / 10.0)

# %%
df['xG+xA'] = df['xG'] + df['xA']
df['xG+xA per game'] = df['xG+xA'] / df['games played']

# %%
goalkeepers = df['element_type'] == 1
defenders = df['element_type'] == 2
midfielders = df['element_type'] == 3
forwards = df['element_type'] == 4

minGames = df['games played'] >= 1

# %% [markdown]
# ## Player evaluation
#
# Below we compile lists for each position sorting players based on a given metric.
#
# Notice that 'next1_xP' is currently based on preseason expectations on average player performance!

# %%
metric = 'valuePoints metric'
#metric = 'adjusted points per game'
#metric = 'next1_xP'

numberToShow = 40

print('GOALKEEPERS')
display(df[goalkeepers & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10', 'valuePoints metric']].head(20))
print('DEFENDERS')
display(df[defenders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('MIDFIELDERS')
display(df[midfielders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('FORWARDS')
display(df[forwards & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
# Out:
# GOALKEEPERS
#        web_name        team_name  now_cost  games played  total_points  \
# id
# 408   Fabianski         West Ham        50           1.0            10
# 80         Raya        Brentford        46           4.0            19
# 353      Lloris        Tottenham        56           4.0            28
# 146      Guaita   Crystal Palace        45           4.0            18
# 231     Alisson        Liverpool        60           4.0            26
# 475          Sá           Wolves        50           4.0            14
# 143       Mendy          Chelsea        60           4.0            26
# 270      de Gea   Manchester Utd        50           4.0            14
# 257     Ederson  Manchester City        60           4.0            20
# 200  Schmeichel   Leicester City        50           4.0            17
# 69      Sánchez         Brighton        45           4.0            16
# 170    Pickford          Everton        50           4.0            12
# 389    Bachmann          Watford        45           4.0             8
# 334    McCarthy      Southampton        45           4.0            12
# 30     Martínez      Aston Villa        55           3.0             9
# 112        Pope          Burnley        55           4.0             9
# 513     Woodman    Newcastle Utd        45           4.0             9
# 28        Steer      Aston Villa        40           1.0             1
# 559    Ramsdale          Arsenal        45           1.0             6
# 199     Meslier     Leeds United        50           4.0             8
#
#      adjusted points  points_per_game  adjusted points per game  form 5  \
# id
# 408         7.586126              2.5                  7.586126     NaN
# 80         18.749193              4.8                  4.687298     NaN
# 353        19.612121              7.0                  4.903030     NaN
# 146        17.557865              4.5                  4.389466     NaN
# 231        19.599004              6.5                  4.899751     NaN
# 475        17.371260              3.5                  4.342815     NaN
# 143        18.819107              6.5                  4.704777     NaN
# 270        16.035078              3.5                  4.008769     NaN
# 257        17.003278              5.0                  4.250819     NaN
# 200        15.111901              4.2                  3.777975     NaN
# 69         14.199004              4.0                  3.549751     NaN
# 170        13.325937              3.0                  3.331484     NaN
# 389        12.045434              2.0                  3.011358     NaN
# 334        11.660460              3.0                  2.915115     NaN
# 30          9.199253              3.0                  3.066418     NaN
# 112        11.780383              2.2                  2.945096     NaN
# 513        10.644751              2.2                  2.661188     NaN
# 28          2.399751              1.0                  2.399751     NaN
# 559         2.454433              6.0                  2.454433     NaN
# 199         9.686388              2.0                  2.421597     NaN
#
#      xPoints_next10  valuePoints metric
# id
# 408       42.420281            3.392619
# 80        40.602476            2.185464
# 353       37.756966            2.071908
# 146       41.639638            2.069214
# 231       37.083267            2.000315
# 475       43.806964            1.942166
# 143       40.728593            1.920717
# 270       39.825663            1.792776
# 257       40.127693            1.735390
# 200       37.252543            1.689562
# 69        40.305383            1.673369
# 170       42.495761            1.489885
# 389       36.665876            1.419568
# 334       43.344556            1.374198
# 30        41.555222            1.307525
# 112       41.628804            1.255793
# 513       40.903028            1.254496
# 28        32.279326            1.199875
# 559       34.539387            1.157031
# 199       40.899217            1.082971
# DEFENDERS
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 237  Alexander-Arnold        Liverpool        75           4.0            34
# 256           Cancelo  Manchester City        60           4.0            26
# 253             Mendy  Manchester City        53           1.0             3
# 76            Jansson        Brentford        46           4.0            24
# 259           Laporte  Manchester City        56           3.0            25
# 555            Varane   Manchester Utd        55           2.0            14
# 258               Aké  Manchester City        49           1.0             2
# 262              Dias  Manchester City        60           4.0            26
# 437            Semedo           Wolves        49           3.0            10
# 245          Tsimikas        Liverpool        41           3.0            18
# 23            Gabriel          Arsenal        50           1.0             8
# 224             Matip        Liverpool        50           4.0            20
# 91            Pinnock        Brentford        46           4.0            21
# 432            Marçal           Wolves        46           4.0            18
# 142             James          Chelsea        56           3.0            20
# 431             Saïss           Wolves        50           4.0            11
# 83              Henry        Brentford        45           4.0            16
# 584         Cucurella         Brighton        50           1.0             7
# 229          van Dijk        Liverpool        65           4.0            21
# 234         Robertson        Liverpool        70           2.0             9
# 483              Ajer        Brentford        45           4.0            15
# 411         Cresswell         West Ham        55           4.0            22
# 275              Shaw   Manchester Utd        55           4.0            16
# 302         Manquillo    Newcastle Utd        40           1.0             7
# 418            Coufal         West Ham        50           4.0            13
# 284          Lindelöf   Manchester Utd        49           2.0             7
# 429             Coady           Wolves        45           4.0            12
# 56              Duffy         Brighton        42           4.0            22
# 122            Alonso          Chelsea        57           4.0            28
# 477             Guéhi   Crystal Palace        45           4.0            14
# 150           Kouyaté   Crystal Palace        45           4.0            15
# 38              Mings      Aston Villa        50           3.0            15
# 273           Maguire   Manchester Utd        54           4.0            12
# 439            Kilman           Wolves        45           4.0            11
# 288       Wan-Bissaka   Manchester Utd        54           4.0            14
# 249            Walker  Manchester City        55           3.0            13
# 169             Keane          Everton        50           4.0            18
# 45              Konsa      Aston Villa        49           4.0            10
# 414            Dawson         West Ham        50           4.0            10
# 409           Ogbonna         West Ham        50           4.0            13
#
#      adjusted points  points_per_game  adjusted points per game  form 5  \
# id
# 237        32.741004              8.5                  8.185251     NaN
# 256        27.074278              6.5                  6.768569     NaN
# 253         6.150819              3.0                  6.150819     NaN
# 76         22.420193              6.0                  5.605048     NaN
# 259        18.252458              8.3                  6.084153     NaN
# 555        11.988539              7.0                  5.994269     NaN
# 258         5.450819              2.0                  5.450819     NaN
# 262        23.774278              6.5                  5.943569     NaN
# 437        16.028445              3.3                  5.342815     NaN
# 245        13.770253              6.0                  4.590084     NaN
# 23          5.054433              8.0                  5.054433     NaN
# 224        20.199004              5.0                  5.049751     NaN
# 91         19.120193              5.2                  4.780048     NaN
# 432        19.013260              4.5                  4.753315     NaN
# 142        15.456331              6.7                  5.152110     NaN
# 431        19.471260              2.8                  4.867815     NaN
# 83         17.549193              4.0                  4.387298     NaN
# 584         4.399751              7.0                  4.399751     NaN
# 229        19.999004              5.2                  4.999751     NaN
# 234        10.199502              4.5                  5.099751     NaN
# 483        16.249193              3.8                  4.062298     NaN
# 411        17.915503              5.5                  4.478876     NaN
# 275        17.906078              4.0                  4.476519     NaN
# 302         3.811188              7.0                  3.811188     NaN
# 418        17.015503              3.2                  4.253876     NaN
# 284         8.388539              3.5                  4.194269     NaN
# 429        15.971260              3.0                  3.992815     NaN
# 56         15.399004              5.5                  3.849751     NaN
# 122        17.819107              7.0                  4.454777     NaN
# 477        15.357865              3.5                  3.839466     NaN
# 150        15.157865              3.8                  3.789466     NaN
# 38         11.941253              5.0                  3.980418     NaN
# 273        16.435078              3.0                  4.108769     NaN
# 439        14.971260              2.8                  3.742815     NaN
# 288        16.335078              3.5                  4.083769     NaN
# 249        12.352458              4.3                  4.117486     NaN
# 169        15.425937              4.5                  3.856484     NaN
# 45         15.199004              2.5                  3.799751     NaN
# 414        15.344503              2.5                  3.836126     NaN
# 409        15.344503              3.2                  3.836126     NaN
#
#      xPoints_next10  valuePoints metric
# id
# 237       51.513196            2.988831
# 256       38.810328            2.763257
# 253       37.548809            2.671745
# 233        35.261751              9.5                  8.815438     NaN
# 517        11.257557              5.5                  5.628779     NaN
# 268        25.021819              6.5                  6.255455     NaN
# 230        30.870751              6.0                  7.717688     NaN
# 419        22.128126              7.2                  5.532031     NaN
# 272        22.905769              7.8                  5.726442     NaN
# 17         16.111824              3.3                  5.370608     NaN
# 173        18.244484              6.2                  4.561121     NaN
# 186         9.010798              5.5                  4.505399     NaN
# 484        17.931484              6.5                  4.482871     NaN
# 289        20.779769              7.8                  5.194942     NaN
# 250        20.150819              4.0                  5.037705     NaN
# 435        18.242815              2.2                  4.560704     NaN
# 138        15.145583              4.7                  5.048528     NaN
# 154        19.380466              4.8                  4.845117     NaN
# 125        16.546777              5.8                  4.136694     NaN
# 240        20.199751              5.0                  5.049938     NaN
# 369        13.363023              5.0                  4.454341     NaN
# 423        17.757126              5.8                  4.439281     NaN
# 55         13.191813              4.7                  4.397271     NaN
# 33         20.221819              4.5                  5.055455     NaN
# 96         16.737298              2.2                  4.184325     NaN
# 461        17.042815              2.5                  4.260704     NaN
# 261        13.659115              5.7                  4.553038     NaN
# 426        15.342815              2.5                  3.835704     NaN
# 482        15.873484              5.2                  3.968371     NaN
# 287         4.105399              1.3                  4.105399     NaN
# 341        16.835115              3.8                  4.208779     NaN
# 254        14.359115              4.0                  4.786372     NaN
# 453         7.025410              1.5                  3.512705     NaN
# 74         14.470751              4.2                  3.617688     NaN
# 420        15.486126              2.2                  3.871531     NaN
# 422        15.086126              3.8                  3.771531     NaN
# 64         15.499751              4.5                  3.874938     NaN
# 137         4.301194              8.0                  4.301194     NaN
# 81         14.337298              4.5                  3.584325     NaN
# 399        14.811358              3.8                  3.702840     NaN
# 107        10.492322              3.7                  3.497441     NaN
# 70         12.870751              3.5                  3.217688     NaN
#
#      xPoints_next10  valuePoints metric
# id
# 144       49.370507            2.797334
# 233       63.415733            2.493382
# 517       51.089037            2.400119
# 268       39.088652            2.331270
# 230       46.805486            2.237246
# 419       44.305571            2.186727
# 272       48.474924            2.050395
# 17        41.661177            2.001507
# 173       37.711081            1.944869
# 186       42.343459            1.921109
# 484       39.877662            1.877668
# 289       43.117805            1.872127
# 250       40.216330            1.864538
# 435       43.055610            1.861900
# 138       47.516456            1.855876
# 154       42.184097            1.844504
# 125       41.288987            1.831759
# 240       50.660350            1.819871
# 369       37.086796            1.818477
# 423       42.248707            1.812329
# 55        36.996130            1.795178
# 33        45.105722            1.787373
# 96        34.620844            1.784202
# 461       42.551547            1.754104
# 261       41.288778            1.733312
# 426       39.803765            1.715379
# 482       37.524503            1.707715
# 287       31.994058            1.676022
# 341       42.214402            1.650819
# 254       40.793543            1.613486
# 453       29.468595            1.586878
# 74        40.296588            1.542587
# 420       37.940572            1.542455
# 422       42.347134            1.539721
# 64        34.500036            1.531704
# 137       42.635086            1.530296
# 81        35.261206            1.528361
# 399       34.149372            1.511678
# 107       34.065857            1.505059
# 70        33.361238            1.500255
# FORWARDS
#           web_name        team_name  now_cost  games played  total_points  \
# id
# 583          Hwang           Wolves        55           1.0             8
# 177  Calvert-Lewin          Everton        82           3.0            23
# 579        Ronaldo   Manchester Utd       126           1.0            13
# 413        Antonio         West Ham        79           4.0            39
# 529         Lukaku          Chelsea       116           3.0            23
# 263          Jesus  Manchester City        86           4.0            26
# 296         Wilson    Newcastle Utd        74           3.0            16
# 189        Bamford     Leeds United        79           4.0            16
# 109           Wood          Burnley        69           4.0            15
# 450         Dennis          Watford        52           4.0            16
# 525    A.Armstrong      Southampton        60           4.0            15
# 307  Saint-Maximin    Newcastle Utd        65           4.0            19
# 180    Richarlison          Everton        75           4.0            16
# 315          Pukki     Norwich City        59           4.0            13
# 345          Adams      Southampton        70           3.0            12
# 78           Toney        Brentford        64           4.0            12
# 337           Ings      Aston Villa        80           4.0            21
# 4       Aubameyang          Arsenal        99           3.0            11
# 205          Vardy   Leicester City       104           4.0            21
# 40         Watkins      Aston Villa        73           2.0             3
# 63          Maupay         Brighton        65           4.0            15
# 72        Connolly         Brighton        54           1.0             1
# 430        Jiménez           Wolves        74           4.0             6
# 105         Barnes          Burnley        55           4.0             6
# 228        Firmino        Liverpool        88           3.0             9
# 104      Rodriguez          Burnley        54           3.0             4
# 153           Ayew   Crystal Palace        59           4.0             7
# 149        Benteke   Crystal Palace        64           4.0             9
# 380         Deeney          Watford        54           2.0             2
# 329           Idah     Norwich City        50           3.0             3
# 518          Broja      Southampton        50           2.0             2
# 187        Rodrigo     Leeds United        63           3.0             3
# 468           King          Watford        55           3.0             4
# 530        Balogun          Arsenal        49           2.0             2
# 447        Welbeck         Brighton        60           2.0             3
# 310      Joelinton    Newcastle Utd        58           4.0             5
# 472          Cucho          Watford        50           4.0             9
# 213      Iheanacho   Leicester City        71           4.0             4
# 357           Kane        Tottenham       122           3.0             3
# 111          Vydra          Burnley        53           3.0             3
#
#      adjusted points  points_per_game  adjusted points per game  form 5  \
# id
# 583            7.200              8.0                  7.200000     NaN
# 177           25.540              7.7                  8.513333     NaN
# 579           10.200             13.0                 10.200000     NaN
# 413           28.004              9.8                  7.001000     NaN
# 529           22.600              7.7                  7.533333     NaN
# 263           23.213              6.5                  5.803250     NaN
# 296           15.200              5.3                  5.066667     NaN
# 189           19.671              4.0                  4.917750     NaN
# 109           17.700              3.8                  4.425000     NaN
# 450           14.671              4.0                  3.667750     NaN
# 525           15.071              3.8                  3.767750     NaN
# 307           15.542              4.8                  3.885500     NaN
# 180           15.971              4.0                  3.992750     NaN
# 315           14.020              3.2                  3.505000     NaN
# 345           11.442              4.0                  3.814000     NaN
# 78            14.100              3.0                  3.525000     NaN
# 337           15.391              5.2                  3.847750     NaN
# 4             12.500              3.7                  4.166667     NaN
# 205           16.871              5.2                  4.217750     NaN
# 40             6.900              1.5                  3.450000     NaN
# 63            12.400              3.8                  3.100000     NaN
# 72             2.600              1.0                  2.600000     NaN
# 430           11.300              1.5                  2.825000     NaN
# 105            9.600              1.5                  2.400000     NaN
# 228            8.500              3.0                  2.833333     NaN
# 104            6.100              1.3                  2.033333     NaN
# 153            8.400              1.8                  2.100000     NaN
# 149            8.571              2.2                  2.142750     NaN
# 380            3.900              1.0                  1.950000     NaN
# 329            5.600              1.0                  1.866667     NaN
# 518            3.600              1.0                  1.800000     NaN
# 187            6.000              1.0                  2.000000     NaN
# 468            5.600              1.3                  1.866667     NaN
# 530            3.200              1.0                  1.600000     NaN
# 447            3.400              1.5                  1.700000     NaN
# 310            6.400              1.2                  1.600000     NaN
# 472            5.400              2.2                  1.350000     NaN
# 213            6.100              1.0                  1.525000     NaN
# 357            5.800              1.0                  1.933333     NaN
# 111            3.800              1.0                  1.266667     NaN
#
#      xPoints_next10  valuePoints metric
# id
# 583       48.783069            3.070090
# 177       53.799304            2.972985
# 579       50.534150            2.873524
# 413       57.891721            2.490844
# 529       63.720317            2.211863
# 263       43.810640            1.978892
# 296       43.686948            1.862544
# 189       42.168401            1.749657
# 109       38.610127            1.684569
# 450       39.088454            1.608415
# 525       40.118791            1.538177
# 307       36.112851            1.524018
# 180       38.091694            1.457946
# 315       34.905974            1.442986
# 345       35.595198            1.441557
# 78        40.463071            1.393379
# 337       37.193496            1.360385
# 4         40.270935            1.324254
# 205       39.702170            1.307869
# 40        29.781737            1.276902
# 63        39.160127            1.215920
# 72        26.689361            1.118862
# 430       35.450370            1.038491
# 105       19.472754            1.023363
# 228       22.746493            0.955116
# 104       22.324335            0.875007
# 153       30.107476            0.864556
# 149       29.129467            0.846996
# 380       26.042821            0.839146
# 329       21.418236            0.834799
# 518       26.790994            0.804984
# 187       23.510383            0.796819
# 468       26.839404            0.795949
# 530       19.257892            0.722806
# 447       24.029712            0.694022
# 310       22.474214            0.664364
# 472       25.282795            0.603738
# 213       20.901316            0.572322
# 357       22.090497            0.553512
# 111       18.486611            0.550205

# %% [markdown]
# Below we compile a list sorting players based on a given metric (irrespective of position).

# %%
metric = 'adjusted points per game'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 579           Ronaldo   Manchester Utd       126           1.0            13
# 233             Salah        Liverpool       125           4.0            38
# 177     Calvert-Lewin          Everton        82           3.0            23
# 237  Alexander-Arnold        Liverpool        75           4.0            34
# 230              Mané        Liverpool       119           4.0            24
# 408         Fabianski         West Ham        50           1.0            10
# 529            Lukaku          Chelsea       116           3.0            23
# 583             Hwang           Wolves        55           1.0             8
# 413           Antonio         West Ham        79           4.0            39
# 256           Cancelo  Manchester City        60           4.0            26
# 144         Gallagher   Crystal Palace        56           3.0            26
# 268            Torres  Manchester City        72           4.0            26
# 253             Mendy  Manchester City        53           1.0             3
# 259           Laporte  Manchester City        56           3.0            25
# 555            Varane   Manchester Utd        55           2.0            14
# 262              Dias  Manchester City        60           4.0            26
# 263             Jesus  Manchester City        86           4.0            26
# 272             Pogba   Manchester Utd        78           4.0            31
# 517       Elyounoussi      Southampton        55           2.0            11
# 76            Jansson        Brentford        46           4.0            24
# 419          Benrahma         West Ham        64           4.0            29
# 258               Aké  Manchester City        49           1.0             2
# 17               Pépé          Arsenal        72           3.0            10
# 437            Semedo           Wolves        49           3.0            10
# 296       43.686948            1.862544
# 33        45.105722            1.787373
# 23        37.279780            2.260411
# 240       50.660350            1.819871
# 224       36.736202            2.258317
# 138       47.516456            1.855876
# 250       40.216330            1.864538
# 229       36.275571            1.961064
# 189       42.168401            1.749657
# 353       37.756966            2.071908
# 231       37.083267            2.000315
# 431       43.038439            2.176953
# 154       42.184097            1.844504

# %%
metric = 'valuePoints metric'

display(df[minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  \
# id
# 408         Fabianski         West Ham        50           1.0
# 583             Hwang           Wolves        55           1.0
# 237  Alexander-Arnold        Liverpool        75           4.0
# 177     Calvert-Lewin          Everton        82           3.0
# 579           Ronaldo   Manchester Utd       126           1.0
# 144         Gallagher   Crystal Palace        56           3.0
# 256           Cancelo  Manchester City        60           4.0
# 253             Mendy  Manchester City        53           1.0
# 76            Jansson        Brentford        46           4.0
# 259           Laporte  Manchester City        56           3.0
# 555            Varane   Manchester Utd        55           2.0
# 233             Salah        Liverpool       125           4.0
# 413           Antonio         West Ham        79           4.0
# 258               Aké  Manchester City        49           1.0
# 262              Dias  Manchester City        60           4.0
# 437            Semedo           Wolves        49           3.0
# 517       Elyounoussi      Southampton        55           2.0
# 268            Torres  Manchester City        72           4.0
# 245          Tsimikas        Liverpool        41           3.0
# 23            Gabriel          Arsenal        50           1.0
# 224             Matip        Liverpool        50           4.0
# 230              Mané        Liverpool       119           4.0
# 91            Pinnock        Brentford        46           4.0
# 432            Marçal           Wolves        46           4.0
# 529            Lukaku          Chelsea       116           3.0
# 419          Benrahma         West Ham        64           4.0
# 80               Raya        Brentford        46           4.0
# 142             James          Chelsea        56           3.0
# 431             Saïss           Wolves        50           4.0
# 353            Lloris        Tottenham        56           4.0
# 146            Guaita   Crystal Palace        45           4.0
# 83              Henry        Brentford        45           4.0
# 272             Pogba   Manchester Utd        78           4.0
# 17               Pépé          Arsenal        72           3.0
# 231           Alisson        Liverpool        60           4.0
# 263             Jesus  Manchester City        86           4.0
# 584         Cucurella         Brighton        50           1.0
# 229          van Dijk        Liverpool        65           4.0
# 173          Doucouré          Everton        55           4.0
# 475                Sá           Wolves        50           4.0
#
#      points_per_game  adjusted points per game  form 5  xPoints_next10  \
# id
# 408              2.5                  7.586126     NaN       42.420281
# 583              8.0                  7.200000     NaN       48.783069
# 237              8.5                  8.185251     NaN       51.513196
# 177              7.7                  8.513333     NaN       53.799304
# 579             13.0                 10.200000     NaN       50.534150
# 144              8.7                  6.619700     NaN       49.370507
# 256              6.5                  6.768569     NaN       38.810328
# 253              3.0                  6.150819     NaN       37.548809
# 76               6.0                  5.605048     NaN       39.113946
# 259              8.3                  6.084153     NaN       41.899855
# 555              7.0                  5.994269     NaN       42.161359
# 233              9.5                  8.815438     NaN       63.415733
# 413              9.8                  7.001000     NaN       57.891721
# 258              2.0                  5.450819     NaN       27.332215
# 262              6.5                  5.943569     NaN       40.894434
# 437              3.3                  5.342815     NaN       43.796145
# 517              5.5                  5.628779     NaN       51.089037
# 268              6.5                  6.255455     NaN       39.088652
# 245              6.0                  4.590084     NaN       38.307743
# 67            White      Arsenal        44           2.0             6
# 466         Tavares      Arsenal        44           2.0             2
# 478   Sambi Lokonga      Arsenal        50           3.0             6
# 530         Balogun      Arsenal        49           2.0             2
# 531          Nelson      Arsenal        50           1.0             1
# 532            Hein      Arsenal        40           NaN             0
# 558        Ødegaard      Arsenal        55           2.0             5
# 559        Ramsdale      Arsenal        45           1.0             6
# 572         Okonkwo      Arsenal        40           NaN             0
# 590        Tomiyasu      Arsenal        45           1.0             6
# 28            Steer  Aston Villa        40           1.0             1
# 29        Hourihane  Aston Villa        49           NaN             0
# 30         Martínez  Aston Villa        55           3.0             9
# 31           Engels  Aston Villa        45           NaN             0
#
#      adjusted points  points_per_game  adjusted points per game  form 10  \
# id
# 1           5.363298              1.3                  1.787766      NaN
# 2                NaN              0.0                       NaN      NaN
# 3                NaN              0.0                       NaN      NaN
# 4          12.500000              3.7                  4.166667      NaN
# 5           2.663298              0.3                  0.887766      NaN
# 6           1.000000              1.0                  1.000000      NaN
# 7           3.140824              0.7                  1.046941      NaN
# 8           4.008865              0.5                  2.004433      NaN
# 9                NaN              0.0                       NaN      NaN
# 10          2.808865              0.5                  1.404433      NaN
# 11         -0.545567             -1.0                 -0.545567      NaN
# 12          1.113608              1.0                  1.113608      NaN
# 13          3.827216              2.0                  1.913608      NaN
# 14          1.508865              0.0                  0.754433      NaN
# 15          0.613608              0.0                  0.613608      NaN
# 16         10.417730              2.2                  2.604433      NaN
# 17         16.111824              3.3                  5.370608      NaN
# 18               NaN              0.0                       NaN      NaN
# 20               NaN              0.0                       NaN      NaN
# 21         10.954433              1.8                  2.738608      NaN
# 22         10.154433              1.8                  2.538608      NaN
# 23          5.054433              8.0                  5.054433      NaN
# 24               NaN              0.0                       NaN      NaN
# 25               NaN              0.0                       NaN      NaN
# 26          5.027216              2.0                  2.513608      NaN
# 27               NaN              0.0                       NaN      NaN
# 67          3.208865              3.0                  1.604433      NaN
# 466         2.908865              1.0                  1.454433      NaN
# 478         6.140824              2.0                  2.046941      NaN
# 530         3.200000              1.0                  1.600000      NaN
# 531         1.113608              1.0                  1.113608      NaN
# 532              NaN              0.0                       NaN      NaN
# 558         4.527216              2.5                  2.263608      NaN
# 559         2.454433              6.0                  2.454433      NaN
# 572              NaN              0.0                       NaN      NaN
# 590         3.054433              6.0                  3.054433      NaN
# 28          2.399751              1.0                  2.399751      NaN
# 29               NaN              0.0                       NaN      NaN
# 30          9.199253              3.0                  3.066418      NaN
# 31               NaN              0.0                       NaN      NaN
#
#      xPoints_next10  valuePoints metric
# id
# 1         42.117248            0.807630
# 2         33.479285                 NaN
# 3         24.931841                 NaN
# 4         40.270935            1.324254
# 5         23.285783            0.423226
# 6         18.607223            0.345033
# 7         20.820041            0.472960
# 8         32.471819            0.955576
# 9         29.358992                 NaN
# 10        28.251761            0.669537
# 11        23.644159            0.260089
# 12        18.324525            0.524960
# 13        23.227836            0.823486
# 14        24.819938            0.363820
# 15        22.141481            0.274414
# 16        30.644791            1.176563
# 17        41.661177            2.001507
# 18        24.931841                 NaN
# 20        26.113623                 NaN
# 21        24.944679            1.189575
# 22        24.944679            1.011406
# 23        37.279780            2.260411
# 24        29.358992                 NaN
# 25        24.931841                 NaN
# 26        26.461321            1.091842
# 27        29.358992                 NaN
# 67        30.021708            0.764883
# 466       21.911687            0.693374
# 478       23.318708            0.915420
# 530       19.257892            0.722806
# 531       18.655928            0.498021
# 532       33.479285                 NaN
# 558       23.705731            0.965206
# 559       34.539387            1.157031
# 572       33.479285                 NaN
# 590       30.973538            1.439873
# 28        32.279326            1.199875
# 29        24.362209                 NaN
# 30        41.555222            1.307525
# 31        26.726798                 NaN

# %%
metric = f'gameweek {gameweek+1} prediction'

display(df[forwards].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game',metric,\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#           web_name        team_name  now_cost  games played  total_points  \
# id
# 529         Lukaku          Chelsea       116           3.0            23
# 413        Antonio         West Ham        79           4.0            39
# 296         Wilson    Newcastle Utd        74           3.0            16
# 177  Calvert-Lewin          Everton        82           3.0            23
# 189        Bamford     Leeds United        79           4.0            16
# 263          Jesus  Manchester City        86           4.0            26
# 63          Maupay         Brighton        65           4.0            15
# 109           Wood          Burnley        69           4.0            15
# 450         Dennis          Watford        52           4.0            16
# 579        Ronaldo   Manchester Utd       126           1.0            13
# 4       Aubameyang          Arsenal        99           3.0            11
# 583          Hwang           Wolves        55           1.0             8
# 307  Saint-Maximin    Newcastle Utd        65           4.0            19
# 205          Vardy   Leicester City       104           4.0            21
# 180    Richarlison          Everton        75           4.0            16
# 72        Connolly         Brighton        54           1.0             1
# 380         Deeney          Watford        54           2.0             2
# 78           Toney        Brentford        64           4.0            12
# 468           King          Watford        55           3.0             4
# 404     João Pedro          Watford        54           NaN             0
# 395       Fletcher          Watford        49           NaN             0
# 393        Success          Watford        50           NaN             0
# 383           Gray          Watford        54           NaN             0
# 469         Mebude          Watford        45           NaN             0
# 388         Perica          Watford        45           NaN             0
# 337           Ings      Aston Villa        80           4.0            21
# 315          Pukki     Norwich City        59           4.0            13
# 523        Cutrone           Wolves        50           NaN             0
# 595        Locadia         Brighton        45           NaN             0
# 535         Zeqiri         Brighton        45           NaN             0
# 500         Andone         Brighton        50           NaN             0
# 525    A.Armstrong      Southampton        60           4.0            15
# 430        Jiménez           Wolves        74           4.0             6
# 472          Cucho          Watford        50           4.0             9
# 95      Dervişoğlu        Brentford        54           NaN             0
# 550      Greenwood     Leeds United        45           NaN             0
# 577       Gelhardt     Leeds United        45           NaN             0
# 300          Gayle    Newcastle Utd        54           NaN             0
# 120         Giroud          Chelsea        65           NaN             0
# 126      Batshuayi          Chelsea        55           NaN             0
#
#      adjusted points  points_per_game  adjusted points per game  \
# id
# 529           22.600              7.7                  7.533333
# 413           28.004              9.8                  7.001000
# 296           15.200              5.3                  5.066667
# 177           25.540              7.7                  8.513333
# 189           19.671              4.0                  4.917750
# 263           23.213              6.5                  5.803250
# 63            12.400              3.8                  3.100000
# 109           17.700              3.8                  4.425000
# 450           14.671              4.0                  3.667750
# 579           10.200             13.0                 10.200000
# 4             12.500              3.7                  4.166667
# 583            7.200              8.0                  7.200000
# 307           15.542              4.8                  3.885500
# 205           16.871              5.2                  4.217750
# 180           15.971              4.0                  3.992750
# 72             2.600              1.0                  2.600000
# 380            3.900              1.0                  1.950000
# 78            14.100              3.0                  3.525000
# 468            5.600              1.3                  1.866667
# 404              NaN              0.0                       NaN
# 395              NaN              0.0                       NaN
# 393              NaN              0.0                       NaN
# 383              NaN              0.0                       NaN
# 469              NaN              0.0                       NaN
# 388              NaN              0.0                       NaN
# 337           15.391              5.2                  3.847750
# 315           14.020              3.2                  3.505000
# 523              NaN              0.0                       NaN
# 595              NaN              0.0                       NaN
# 535              NaN              0.0                       NaN
# 500              NaN              0.0                       NaN
# 525           15.071              3.8                  3.767750
# 430           11.300              1.5                  2.825000
# 472            5.400              2.2                  1.350000
# 95               NaN              0.0                       NaN
# 550              NaN              0.0                       NaN
# 577              NaN              0.0                       NaN
# 300              NaN              0.0                       NaN
# 120              NaN              0.0                       NaN
# 126              NaN              0.0                       NaN
#
#      gameweek 5 prediction  valuePoints metric
# id
# 529               6.568730            2.211863
# 413               5.665780            2.490844
# 296               5.221531            1.862544
# 177               5.186347            2.972985
# 189               4.808599            1.749657
# 263               4.781270            1.978892
# 63                4.708508            1.215920
# 109               4.589958            1.684569
# 450               4.585909            1.608415
# 579               4.492869            2.873524
# 4                 4.488105            1.324254
# 583               4.029186            3.070090
# 307               3.853079            1.524018
# 205               3.824867            1.307869
# 180               3.815131            1.457946
# 72                3.653663            1.118862
# 380               3.613530            0.839146
# 78                3.425319            1.393379
# 468               3.397803            0.795949
# 404               3.375184                 NaN
# 395               3.375184                 NaN
# 393               3.375184                 NaN
# 383               3.375184                 NaN
# 469               3.375184                 NaN
# 388               3.375184                 NaN
# 337               3.360391            1.360385
# 315               3.317928            1.442986
# 523               3.308084                 NaN
# 595               3.201049                 NaN
# 535               3.201049                 NaN
# 500               3.201049                 NaN
# 525               3.188045            1.538177
# 430               3.146939            1.038491
# 472               3.110563            0.603738
# 95                3.074737                 NaN
# 550               3.068363                 NaN
# 577               3.068363                 NaN
# 300               3.020567                 NaN
# 120               2.994946                 NaN
# 126               2.994946                 NaN

# %%
metric = 'xG'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game',\
                      'valuePoints metric', 'xG', 'xA', 'xG+xA', 'xG+xA per game']].head(numberToShow))
# Out:
#           web_name        team_name  now_cost  games played  points_per_game  \
# id
# 230           Mané        Liverpool       119           4.0              6.0
# 177  Calvert-Lewin          Everton        82           3.0              7.7
# 413        Antonio         West Ham        79           4.0              9.8
# 233          Salah        Liverpool       125           4.0              9.5
# 268         Torres  Manchester City        72           4.0              6.5
# 529         Lukaku          Chelsea       116           3.0              7.7
# 189        Bamford     Leeds United        79           4.0              4.0
# 296         Wilson    Newcastle Utd        74           3.0              5.3
# 109           Wood          Burnley        69           4.0              3.8
# 17            Pépé          Arsenal        72           3.0              3.3
# 255       Sterling  Manchester City       109           4.0              2.5
# 240           Jota        Liverpool        77           4.0              5.0
# 350        Djenepo      Southampton        55           4.0              1.5
# 4       Aubameyang          Arsenal        99           3.0              3.7
# 517                  5.628779            2.400119  1.1  0.1    1.2
# 277                  4.777192            1.379057  1.1  0.7    1.8
# 78                   3.525000            1.393379  1.0  0.7    1.7
# 450                  3.667750            1.608415  1.0  0.3    1.3
# 263                  5.803250            1.978892  1.0  1.3    2.3
# 289                  5.194942            1.872127  1.0  0.5    1.5
# 196                  3.705399            1.453377  1.0  0.8    1.8
# 341                  4.208779            1.650819  1.0  0.8    1.8
# 363                  3.337008            1.308882  1.0  0.0    1.0
# 42                   3.556604            1.451978  0.9  0.2    1.1
#
#      xG+xA per game
# id
# 230        1.075000
# 177        1.300000
# 413        0.975000
# 233        1.150000
# 268        0.600000
# 529        1.033333
# 189        0.650000
# 296        0.600000
# 109        0.425000
# 17         0.666667
# 255        0.425000
# 240        0.750000
# 350        0.375000
# 4          0.466667
# 315        0.350000
# 579        1.300000
# 205        0.400000
# 144        0.700000
# 33         0.650000
# 435        0.500000
# 250        0.625000
# 63         0.350000
# 337        0.325000
# 461        0.400000
# 96         0.450000
# 525        0.425000
# 224        0.275000
# 154        0.500000
# 419        0.400000
# 254        0.633333
# 517        0.600000
# 277        0.450000
# 78         0.425000
# 450        0.325000
# 263        0.575000
# 289        0.375000
# 196        0.450000
# 341        0.450000
# 363        0.250000
# 42         0.366667

# %% [markdown]
# ## Player Visualizations

# %%
game_weeks = np.arange(1,gameweek+1)
column_xPoints = []
column_xG = []
column_xA = []
column_xGA = []
for i in range(1,gameweek+1):
    column_xPoints.append('xPoints week ' + str(i))
    column_xG.append('xG_week' + str(i))
    column_xA.append('xA_week' + str(i))
    column_xGA.append('xGA_week' + str(i))

#display(game_weeks)
#display(column_xPoints)

# %%
# find player index
name_string = 'Jota'
playersFound = df[df['web_name'].str.contains(name_string)]
display(playersFound)
# plot xPoints over time
ix = playersFound.index[0]
#ix = 468

fig,ax = plt.subplots(2,2,figsize=(15,10))

ax[0,0].plot(game_weeks, df.loc[ix,column_xPoints], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,0].set_title(title_string)
ax[0,0].set_xlabel('gameweek')
ax[0,0].set_ylabel('xPoints')
ax[0,0].set_xticks(game_weeks)

ax[0,1].plot(game_weeks, df.loc[ix,column_xG], marker='o')
ax[0,1].plot(game_weeks, df.loc[ix,column_xA], marker='o')
ax[0,1].legend(('xG','xA'))
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,1].set_title(title_string)
ax[0,1].set_xlabel('gameweek')
ax[0,1].set_ylabel('xG and xA')
ax[0,1].set_xticks(game_weeks)

ax[1,0].plot(game_weeks, df.loc[ix,column_xGA], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[1,0].set_title(title_string)
ax[1,0].set_xlabel('gameweek')
ax[1,0].set_ylabel('xGA')
ax[1,0].set_xticks(game_weeks)

plt.show()
# Out:
#      adjusted points  adjusted points per game  assists  assists_week1  \
# id
# 240        20.199751                  5.049938        0            0.0
#
#      assists_week2  assists_week3  assists_week4  bonus  bonus_week1  \
# id
# 240            0.0            0.0            0.0      0          0.0
#
#      bonus_week2  bonus_week3  bonus_week4  bps  chance_of_playing_next_round  \
# id
# 240          0.0          0.0          0.0   69                           NaN
#
#      chance_of_playing_this_round  clean_sheet_points  clean_sheets  \
# id
# 240                           NaN            1.399751             3
#
#      cleansheet_week1  cleansheet_week2  cleansheet_week3  cleansheet_week4  \
# id
# 240               1.0               1.0               0.0               1.0
#
#        code  corners_and_indirect_freekicks_order  \
# id
# 240  194634                                   NaN
#
#      corners_and_indirect_freekicks_text  cost_change_event  \
# id
# 240                                  NaN                  1
#
#      cost_change_event_fall  cost_change_start  cost_change_start_fall  \
# id
# 240                      -1                  2                      -2
#
#      creativity  creativity_rank  creativity_rank_type  \
# id
# 240        97.4               31                    21
#
#      direct_freekicks_order  direct_freekicks_text  dreamteam_count  \
# id
# 240                     NaN                    NaN                0
#
#      element_type  ep_next  ep_this  event_points first_name  form  form 10  \
# id
# 240             3      4.5      4.5             3      Diogo   4.0      NaN
#
#      form 15  form 20  form 5  games played  gameweek  gameweek 10 prediction  \
# id
# 240      NaN      NaN     NaN           4.0         4                5.184611
#
#      gameweek 11 prediction  gameweek 12 prediction  gameweek 13 prediction  \
# id
# 240                4.475116                6.132604                5.532344
#
#      ...  second_name  selected_by_percent  special  squad_number  status  \
# id   ...
# 240  ...         Jota                 20.9    False           NaN       a
#
#      team  team_code  team_name  threat  threat_rank  threat_rank_type  \
# id
# 240    11         14  Liverpool   183.0            8                 5
#
#      total_points  transfers_in  transfers_in_event  transfers_out  \
# id
# 240            20       1278800              180647         597767
#
#      transfers_out_event     value  value form 10  value form 5  \
# id
# 240               130390  0.655836            NaN           NaN
#
#      valuePoints metric  value_form  value_next10 value_season web_name   xA  \
# id
# 240            1.819871         0.5      6.579266          2.6     Jota  1.6
#
#      xA_points  xA_week1  xA_week2  xA_week3  xA_week4   xG  xG+xA  \
# id
# 240        4.8       0.0       0.1       0.0       1.5  1.4    3.0
#
#      xG+xA per game  xGA_week1 xGA_week2  xGA_week3  xGA_week4  xG_points  \
# id
# 240            0.75        1.4       0.7        0.8        1.3        7.0
#
#     xG_week1  xG_week2  xG_week3 xG_week4   xPoints  xPoints week 1  \
# id
# 240      0.7       0.2       0.3      0.2  7.772532        5.746597
#
#      xPoints week 2  xPoints week 3  xPoints week 4  xPoints_next10  \
# id
# 240        3.796585             2.5        7.772532        50.66035
#
#      yellow_cards  gameweek 14 prediction
# id
# 240             0                4.842092
#
# [1 rows x 134 columns]

# %% [markdown]
# ## My team

# %%
session = requests.session()

# %%
filepath = Path('../../../access_control/FPL_access.txt')
with open(filepath) as file:
    text = file.read().splitlines()
    email = text[0]
    password = text[1]

# %%
url = 'https://users.premierleague.com/accounts/login/'

payload = {
'password': password,
'login': email,
'redirect_uri': 'https://fantasy.premierleague.com/a/login', 'app': 'plfpl-web'
}
session.post(url, data=payload)
# Out:
# <Response [200]>

# %%
response = session.get('https://fantasy.premierleague.com/api/my-team/3202682')
team = response.json()['picks']

# %%
my_player_ix = [player['element'] for player in team]
my_starting11 = my_player_ix[:-4]
my_subs = my_player_ix[-4:]

# %%
exp_avg = df.loc[my_starting11,'adjusted points per game'].sum() + \
                df.loc[my_starting11,'adjusted points per game'].max()
exp_next = df.loc[my_starting11, f'gameweek {gameweek+1} prediction'].sum() + \
                df.loc[my_starting11,f'gameweek {gameweek+1} prediction'].max()

print('STARTING 11')
print('Expected points on average: ' + str(exp_avg))
print('Predicted points next gameweek: ' + str(exp_next))
display(df.loc[my_starting11, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
           f'gameweek {gameweek+1} prediction','xPoints_next10', 'valuePoints metric']].head(numberToShow))
print('\nSUBSTITUTES')
display(df.loc[my_subs, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
         f'gameweek {gameweek+1} prediction', 'xPoints_next10', 'valuePoints metric']].head(numberToShow))
# Out:
# STARTING 11
# Expected points on average: 63.185751562754774
# Predicted points next gameweek: 55.850061655044556
#              web_name        team_name  now_cost  games played  \
# id
# 69            Sánchez         Brighton        45           4.0
# 275              Shaw   Manchester Utd        55           4.0
# 237  Alexander-Arnold        Liverpool        75           4.0
# 67              White          Arsenal        44           2.0
# 277         Fernandes   Manchester Utd       120           4.0
# 233             Salah        Liverpool       125           4.0
# 33           Grealish  Manchester City        80           4.0
# 21         Smith Rowe          Arsenal        53           4.0
# 413           Antonio         West Ham        79           4.0
# 63             Maupay         Brighton        65           4.0
# 296            Wilson    Newcastle Utd        74           3.0
#
#      points_per_game  adjusted points per game  form 5  form 10  \
# id
# 69               4.0                  3.549751     NaN      NaN
# 275              4.0                  4.476519     NaN      NaN
# 237              8.5                  8.185251     NaN      NaN
# 67               3.0                  1.604433     NaN      NaN
# 277              7.8                  4.777192     NaN      NaN
# 233              9.5                  8.815438     NaN      NaN
# 33               4.5                  5.055455     NaN      NaN
# 21               1.8                  2.738608     NaN      NaN
# 413              9.8                  7.001000     NaN      NaN
# 63               3.8                  3.100000     NaN      NaN
# 296              5.3                  5.066667     NaN      NaN
#
#      gameweek 5 prediction  xPoints_next10  valuePoints metric
# id
# 69                4.472959       40.305383            1.673369
# 275               3.343060       38.612901            1.908794
# 237               5.237071       51.513196            2.988831
# 67                3.302652       30.021708            0.764883
# 277               3.601356       42.058616            1.379057
# 233               6.463675       63.415733            2.493382
# 33                4.832841       45.105722            1.787373
# 21                2.536953       24.944679            1.189575
# 413               5.665780       57.891721            2.490844
# 63                4.708508       39.160127            1.215920
# 296               5.221531       43.686948            1.862544
# SUBSTITUTES
#       web_name      team_name  now_cost  games played  points_per_game  \
# id
# 376     Foster        Watford        40           NaN              0.0
# 361       Dier      Tottenham        46           4.0              5.2
# 115  Brownhill        Burnley        45           4.0              1.2
# 302  Manquillo  Newcastle Utd        40           1.0              7.0
#
#      adjusted points per game  form 5  form 10  gameweek 5 prediction  \
# id
# 376                       NaN     NaN      NaN               4.103781
# 361                  3.303030     NaN      NaN               2.841379
# 115                  1.748774     NaN      NaN               2.311676
# 302                  3.811188     NaN      NaN               4.402215
#
#      xPoints_next10  valuePoints metric
# id
# 376       33.512919                 NaN
# 361       31.180923            1.540046
# 115       20.957865            0.824380
# 302       36.179644            1.905594

# %% [markdown]
# ## Save data

# %%
# save data
filepath = '../data/fpl/data_week' + str(gameweek) + str('.csv')
df.to_csv(filepath)
