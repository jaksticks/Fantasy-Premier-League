# %% [markdown]
# # Player evaluation
#
# Here we compare players based on their adjusted points. Also, we calculate some useful metrics using the adjusted points to further evaluate player performance in FPL.

# %%
# recent gameweek
gameweek = 15

# %%
# import basic libraries
import pandas as pd
import numpy as np
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.set_option('max_columns',100)

# %%
# fetch FPL data
filepath = '../data/fpl/data_week' + str(gameweek) + '.csv'
df = pd.read_csv(filepath, index_col=0)

# fetch team data
filepath = '../data/fbref/team_stats_week' + str(gameweek) + '.csv'
teamStats = pd.read_csv(filepath, index_col=0)

# fetch player stats data
filepath = '../data/fbref/player_stats_week' + str(gameweek) + '.csv'
playerStats = pd.read_csv(filepath, index_col=0, skiprows=1)

# %% [markdown]
# ## Value and value points
#
# Here we calculate two interesting metrics: 'value' and 'value points'.
#
# Value is simply adjusted points per game divided by the cost of the player. Essentially, this measures how many 'points per pound(/euro/whatever)' has the player gained on an average game week.
#
# The value points is calculated as the geometric mean of a players adjusted points per game and value. Essentially, in FPL we want to gain the maximum possible amount of points. However, we are restrained by a limited budget, so that in practice we cannot just pick all the best players. Then, we would like to have a squad of players that give the most points given our budget. Thus, we would like to pick players that have high value ('bang for buck'). However, often the players with highest value are very cheap players who somewhat overperform relative to their price. Picking a squad full of these players might leave a part of our budget unused. Calculating the geometric mean of adjusted points and value allows us to weigh both aspects equally, i.e. we want players that both gain a lot of points but also have good value. For example, this metric values equally two players, where one has twice the points per game of the other who in turn has twice the value of the other.

# %%
# value = expected points / cost
df['value'] = df['adjusted points per game'] / (df['now_cost'] / 10.0)
df['value form 5'] = df['form 5'] / (df['now_cost'] / 10.0)
df['value form 10'] = df['form 10'] / (df['now_cost'] / 10.0)
# geometric mean of 'adjusted points per game' and 'value'
df['valuePoints metric'] = np.sqrt(df['adjusted points per game'] * df['value'])

# %%
df['value_next10']  = df['xPoints_next10'] / (df['now_cost'] / 10.0)

# %%
df['xG+xA'] = df['xG'] + df['xA']
df['xG+xA per game'] = df['xG+xA'] / df['games played']

# %%
goalkeepers = df['element_type'] == 1
defenders = df['element_type'] == 2
midfielders = df['element_type'] == 3
forwards = df['element_type'] == 4

minGames = df['games played'] >= 3

# %% [markdown]
# ## Player evaluation
#
# Below we compile lists for each position sorting players based on a given metric.
#
# Notice that 'next1_xP' is currently based on preseason expectations on average player performance!

# %%
metric = 'valuePoints metric'
#metric = 'adjusted points per game'
#metric = 'next1_xP'

numberToShow = 40

print('GOALKEEPERS')
display(df[goalkeepers & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10', 'valuePoints metric']].head(20))
print('DEFENDERS')
display(df[defenders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('MIDFIELDERS')
display(df[midfielders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('FORWARDS')
display(df[forwards & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
# Out:
# GOALKEEPERS
#       web_name        team_name  now_cost  games played  total_points  \
# id
# 475         Sá           Wolves        50          15.0            67
# 376     Foster          Watford        41           8.0            28
# 353     Lloris        Tottenham        54          14.0            63
# 146     Guaita   Crystal Palace        46          15.0            51
# 556  Fernández        Brentford        45           6.0            19
# 80        Raya        Brentford        44           9.0            34
# 30    Martínez      Aston Villa        55          14.0            57
# 559   Ramsdale          Arsenal        50          12.0            59
# 143      Mendy          Chelsea        63          14.0            66
# 310           31.971              2.2                  2.283643  2.880000
# 269           13.600              2.4                  2.720000       NaN
# 404           21.171              2.0                  2.117100  2.460000
# 516           29.600              1.6                  2.114286  2.260000
# 213           28.642              2.3                  2.386833  1.000000
#
#      xPoints_next10  valuePoints metric
# id
# 177       39.603576            3.028908
# 468       39.861162            1.764173
# 413       51.618702            1.737624
# 450       41.218049            1.691153
# 189       38.057299            1.654241
# 78        36.321478            1.622105
# 263       33.824438            1.570656
# 296       35.886943            1.557524
# 315       37.040285            1.527108
# 525       33.980903            1.506004
# 307       37.238625            1.495173
# 63        34.823464            1.483222
# 228       49.934216            1.473559
# 583       34.782298            1.436762
# 345       36.950279            1.417032
# 518       31.100487            1.357903
# 149       36.970368            1.351109
# 205       40.936404            1.346566
# 180       33.368824            1.343311
# 40        37.582490            1.341808
# 235       25.150799            1.338877
# 187       31.216966            1.338656
# 579       42.663863            1.333811
# 430       36.854363            1.327936
# 109       31.793217            1.225230
# 337       35.168763            1.213094
# 529       30.123218            1.194280
# 447       22.709894            1.193911
# 577       25.471367            1.158241
# 134       28.821563            1.158154
# 4         32.502103            1.156143
# 357       34.869382            1.076287
# 455       29.846446            1.072213
# 472       22.840498            0.958297
# 153       26.909115            0.957129
# 310       22.417924            0.948231
# 269       29.717966            0.938489
# 404       24.023911            0.911055
# 516       24.062330            0.909844
# 213       25.020190            0.902138

# %% [markdown]
# Below we compile a list sorting players based on a given metric (irrespective of position).

# %%
metric = 'adjusted points per game'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 177     Calvert-Lewin          Everton        79           3.0            23
# 233             Salah        Liverpool       131          15.0           152
# 237  Alexander-Arnold        Liverpool        81          13.0            99
# 268            Torres  Manchester City        67           4.0            26
# 265             Foden  Manchester City        81           9.0            48
# 240              Jota        Liverpool        80          14.0            79
# 135          Chilwell          Chelsea        57           6.0            54
# 250          Gündogan  Manchester City        73          10.0            54
# 253             Mendy  Manchester City        53           1.0             3
# 256           Cancelo  Manchester City        68          15.0            84
# 230              Mané        Liverpool       119          15.0            79
# 501              Sarr          Chelsea        49           1.0             8
# 359               Son        Tottenham       104          13.0            81
# 142             James          Chelsea        62          11.0            76
# 138             Mount          Chelsea        75          12.0            71
# 246        N.Williams        Liverpool        39           1.0             4
# 260           Steffen  Manchester City        45           1.0             7
# 413           Antonio         West Ham        79          14.0            71
# 420             Bowen         West Ham        65          15.0            71
# 261          Bernardo  Manchester City        76          14.0            84
# 579           Ronaldo   Manchester Utd       124          12.0            58
# 144         Gallagher   Crystal Palace        61          14.0            72
# 263             Jesus  Manchester City        87          13.0            58
# 196          Raphinha     Leeds United        67          13.0            66
# 189           Bamford     Leeds United        77           6.0            25
# 210         Tielemans   Leicester City        64          11.0            51
# 364            Davies        Tottenham        44           6.0            29
# 122            Alonso          Chelsea        57           9.0            43
# 370          Reguilón        Tottenham        53          13.0            62
# 262              Dias  Manchester City        60          14.0            62
# 33           Grealish  Manchester City        76          11.0            38
# 266           Rodrigo  Manchester City        55          12.0            43
# 205             Vardy   Leicester City       107          15.0            77
# 249            Walker  Manchester City        55          12.0            51
# 119       Azpilicueta          Chelsea        57           9.0            44
# 228           Firmino        Liverpool        87           8.0            35
# 277         Fernandes   Manchester Utd       116          15.0            67
# 229          van Dijk        Liverpool        66          15.0            78
# 475                Sá           Wolves        50          15.0            67
# 296            Wilson    Newcastle Utd        75          11.0            53
#
#      adjusted points  points_per_game  adjusted points per game  \
# id
#
# 527        36.981418              5.9                  4.109046
# 419        57.810285              4.3                  3.854019
# 125        38.000354              5.1                  4.222262
# 529        40.500000              3.4                  4.050000
# 345        44.342000              3.9                  3.695167
# 80         32.348611              3.8                  3.594290
# 91         54.018684              3.5                  3.601246
# 234        46.331287              4.5                  4.211935
# 122        41.052418              4.8                  4.561380
# 422        51.968285              3.3                  3.464552
# 359        69.784862              6.2                  5.368066
#
#      gameweek 16 prediction  valuePoints metric
# id
# 233                5.759519            2.276135
# 240                5.381866            2.144844
# 413                5.293079            1.737624
# 265                5.287307            2.135633
# 228                5.143593            1.473559
# 135                5.135636            2.535831
# 277                5.106208            1.272392
# 237                5.082798            2.454345
# 205                5.029331            1.346566
# 230                4.946879            1.630807
# 270                4.942366            1.654233
# 138                4.920009            1.892751
# 210                4.854860            1.809237
# 579                4.813983            1.333811
# 420                4.745567            1.906099
# 200                4.728181            1.339741
# 423                4.586500            1.521685
# 143                4.579533            1.656055
# 501                4.577699            2.458617
# 127                4.576765            1.722635
# 121                4.567183            1.682546
# 212                4.553696            1.401443
# 411                4.529559            1.746901
# 289                4.484210            1.475382
# 142                4.462455            2.093853
# 78                 4.432366            1.622105
# 408                4.423490            1.615608
# 119                4.413391            1.833390
# 140                4.391105            1.648212
# 527                4.372542            1.895362
# 419                4.314363            1.573397
# 125                4.310864            1.888253
# 529                4.309244            1.194280
# 345                4.289355            1.417032
# 80                 4.270833            1.713511
# 91                 4.269973            1.679089
# 234                4.258997            1.591962
# 122                4.232596            1.910552
# 422                4.209347            1.451141
# 359                4.203011            1.664567

# %%
metric = 'xG'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game',\
                      'valuePoints metric', 'xG', 'xA', 'xG+xA', 'xG+xA per game']].head(numberToShow))
# Out:
#           web_name        team_name  now_cost  games played  points_per_game  \
# id
# 233          Salah        Liverpool       131          15.0             10.1
# 240           Jota        Liverpool        80          14.0              5.6
# 230           Mané        Liverpool       119          15.0              5.3
# 205          Vardy   Leicester City       107          15.0              5.1
# 4       Aubameyang          Arsenal        97          14.0              3.1
# 579        Ronaldo   Manchester Utd       124          12.0              4.8
# 468           King          Watford        58          13.0              4.2
# 413        Antonio         West Ham        79          14.0              5.1
# 63          Maupay         Brighton        63          14.0              3.9
# 149        Benteke   Crystal Palace        64          15.0              3.1
# 315          Pukki     Norwich City        59          15.0              3.7
# 420          Bowen         West Ham        65          15.0              4.7
# 96          Mbeumo        Brentford        55          14.0              3.1
# 250       Gündogan  Manchester City        73          10.0              5.4
# 359            Son        Tottenham       104          13.0              6.2
# 296         Wilson    Newcastle Utd        75          11.0              4.8
# 78           Toney        Brentford        67          14.0              3.9
# 263          Jesus  Manchester City        87          13.0              4.5
# 40         Watkins      Aston Villa        75          13.0              3.7
# 228        Firmino        Liverpool        87           8.0              4.4
# 177  Calvert-Lewin          Everton        79           3.0              7.7
# 196       Raphinha     Leeds United        67          13.0              5.1
# 357           Kane        Tottenham       122          13.0              2.5
# 525    A.Armstrong      Southampton        59          14.0              3.3
# 138          Mount          Chelsea        75          12.0              5.9
# 109           Wood          Burnley        67          14.0              2.9
# 149        0.393333
# 315        0.353333
# 420        0.473333
# 96         0.428571
# 250        0.660000
# 359        0.484615
# 296        0.427273
# 78         0.500000
# 263        0.500000
# 40         0.361538
# 228        0.587500
# 177        1.300000
# 196        0.492308
# 357        0.469231
# 525        0.385714
# 138        0.558333
# 109        0.278571
# 450        0.364286
# 277        0.513333
# 255        0.400000
# 265        0.733333
# 399        0.383333
# 189        0.650000
# 154        0.414286
# 134        0.425000
# 529        0.510000
# 430        0.320000
# 144        0.414286
# 64         0.306667
# 423        0.333333
# 261        0.385714

# %% [markdown]
# ## Player Visualizations

# %%
game_weeks = np.arange(1,gameweek+1)
column_xPoints = []
column_xG = []
column_xA = []
column_xGA = []
for i in range(1,gameweek+1):
    column_xPoints.append('xPoints week ' + str(i))
    column_xG.append('xG_week' + str(i))
    column_xA.append('xA_week' + str(i))
    column_xGA.append('xGA_week' + str(i))

#display(game_weeks)
#display(column_xPoints)

# %%
# find player index
name_string = 'Antonio'
playersFound = df[df['web_name'].str.contains(name_string)]
display(playersFound[['web_name','team_name','now_cost','games played','total_points','adjusted points',\
                      'points_per_game','adjusted points per game',f'gameweek {gameweek+1} prediction',\
                      'xPoints_next10', 'valuePoints metric']])
# plot xPoints over time
ix = playersFound.index[0]
#ix = 468

fig,ax = plt.subplots(2,2,figsize=(15,10))

ax[0,0].plot(game_weeks, df.loc[ix,column_xPoints], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,0].set_title(title_string)
ax[0,0].set_xlabel('gameweek')
ax[0,0].set_ylabel('xPoints')
ax[0,0].set_xticks(game_weeks)

ax[0,1].plot(game_weeks, df.loc[ix,column_xG], marker='o')
ax[0,1].plot(game_weeks, df.loc[ix,column_xA], marker='o')
ax[0,1].legend(('xG','xA'))
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,1].set_title(title_string)
ax[0,1].set_xlabel('gameweek')
ax[0,1].set_ylabel('xG and xA')
ax[0,1].set_xticks(game_weeks)

ax[1,0].plot(game_weeks, df.loc[ix,column_xGA], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[1,0].set_title(title_string)
ax[1,0].set_xlabel('gameweek')
ax[1,0].set_ylabel('xGA')
ax[1,0].set_xticks(game_weeks)

plt.show()
# Out:
#     web_name team_name  now_cost  games played  total_points  adjusted points  \
# id
# 413  Antonio  West Ham        79          14.0            71           68.375
#
#      points_per_game  adjusted points per game  gameweek 16 prediction  \
# id
# 413              5.1                  4.883929                5.293079
#
#      xPoints_next10  valuePoints metric
# id
# 413       51.618702            1.737624

# %% [markdown]
# ## My team

# %%
session = requests.session()

# %%
filepath = Path('../../../access_control/FPL_access.txt')
with open(filepath) as file:
    text = file.read().splitlines()
    email = text[0]
    password = text[1]

# %%
url = 'https://users.premierleague.com/accounts/login/'

payload = {
'password': password,
'login': email,
'redirect_uri': 'https://fantasy.premierleague.com/a/login', 'app': 'plfpl-web'
}
session.post(url, data=payload)
# Out:
# <Response [200]>

# %%
response = session.get('https://fantasy.premierleague.com/api/my-team/3202682')
team = response.json()['picks']

# %%
my_player_ix = [player['element'] for player in team]
my_starting11 = my_player_ix[:-4]
my_subs = my_player_ix[-4:]

# %%
exp_avg = df.loc[my_starting11,'adjusted points per game'].sum() + \
                df.loc[my_starting11,'adjusted points per game'].max()
exp_next = df.loc[my_starting11, f'gameweek {gameweek+1} prediction'].sum() + \
                df.loc[my_starting11,f'gameweek {gameweek+1} prediction'].max()

print('STARTING 11')
print('Expected points on average: ' + str(exp_avg))
print('Predicted points next gameweek: ' + str(exp_next))
display(df.loc[my_starting11, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
           f'gameweek {gameweek+1} prediction','xPoints_next10', 'valuePoints metric']].head(numberToShow))
print('\nSUBSTITUTES')
display(df.loc[my_subs, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
         f'gameweek {gameweek+1} prediction', 'xPoints_next10', 'valuePoints metric']].head(numberToShow))
# Out:
# STARTING 11
# Expected points on average: 67.05755091078524
# Predicted points next gameweek: 55.35355520248413
#              web_name        team_name  now_cost  games played  \
# id
# 559          Ramsdale          Arsenal        50          12.0
# 256           Cancelo  Manchester City        68          15.0
# 237  Alexander-Arnold        Liverpool        81          13.0
# 142             James          Chelsea        62          11.0
# 144         Gallagher   Crystal Palace        61          14.0
# 138             Mount          Chelsea        75          12.0
# 233             Salah        Liverpool       131          15.0
# 250          Gündogan  Manchester City        73          10.0
# 430           Jiménez           Wolves        76          15.0
# 413           Antonio         West Ham        79          14.0
# 205             Vardy   Leicester City       107          15.0
#
#      points_per_game  adjusted points per game    form 5   form 10  \
# id
# 559              4.9                  3.729655  3.930398  4.186448
# 256              5.6                  5.843690  6.652361  5.749702
# 237              7.6                  6.985187  8.484089  6.693316
# 142              6.9                  5.213652  5.877968  5.386812
# 144              5.1                  4.671669  4.683737  4.431850
# 138              5.9                  5.183512  4.692577  5.592340
# 233             10.1                  8.238226  7.344422  8.215108
# 250              5.4                  6.004206  6.743158  7.323846
# 430              3.7                  3.660867  2.740000  4.021300
# 413              5.1                  4.883929  2.794200  4.037100
# 205              5.1                  4.404733  3.220000  4.240000
#
#      gameweek 16 prediction  xPoints_next10  valuePoints metric
# id
# 559                3.949818       35.061560            1.667952
# 256                4.173325       41.727653            2.240953
# 237                5.082798       47.736055            2.454345
# 142                4.462455       31.986726            2.093853
# 144                3.900171       40.119268            1.891503
# 138                4.920009       35.308668            1.892751
# 233                5.759519       54.699742            2.276135
# 250                3.932270       41.191879            2.222256
# 430                3.091262       36.854363            1.327936
# 413                5.293079       51.618702            1.737624
# 205                5.029331       40.936404            1.346566
# SUBSTITUTES
#        web_name     team_name  now_cost  games played  points_per_game  \
# id
# 376      Foster       Watford        41           8.0              3.5
# 491  Livramento   Southampton        45          15.0              3.5
# 145     Gilmour  Norwich City        44           8.0              2.4
# 425     Johnson      West Ham        40           9.0              3.1
#
#      adjusted points per game    form 5   form 10  gameweek 16 prediction  \
# id
# 376                  3.829871  7.696696  3.776371                3.690258
# 491                  3.138244  2.850546  3.599755                3.551737
# 145                  2.581511  2.678616  2.678616                2.341833
# 425                  3.001498  2.047457  3.028395                3.432529
#
#      xPoints_next10  valuePoints metric
# id
# 376       37.646155            1.891439
# 491       34.133857            1.479382
# 145       24.736063            1.230687
# 425       32.945428            1.500749

# %% [markdown]
# ## Save data

# %%
# save data
filepath = '../data/fpl/data_week' + str(gameweek) + str('.csv')
df.to_csv(filepath)
