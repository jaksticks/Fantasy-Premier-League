# %% [markdown]
# # Player evaluation
#
# Here we compare players based on their adjusted points. Also, we calculate some useful metrics using the adjusted points to further evaluate player performance in FPL.

# %%
# recent gameweek
gameweek = 17

# %%
# import basic libraries
import pandas as pd
import numpy as np
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.set_option('max_columns',100)

# %%
# fetch FPL data
filepath = '../data/fpl/data_week' + str(gameweek) + '.csv'
df = pd.read_csv(filepath, index_col=0)

# fetch team data
filepath = '../data/fbref/team_stats_week' + str(gameweek) + '.csv'
teamStats = pd.read_csv(filepath, index_col=0)

# fetch player stats data
filepath = '../data/fbref/player_stats_week' + str(gameweek) + '.csv'
playerStats = pd.read_csv(filepath, index_col=0, skiprows=1)

# %% [markdown]
# ## Value and value points
#
# Here we calculate two interesting metrics: 'value' and 'value points'.
#
# Value is simply adjusted points per game divided by the cost of the player. Essentially, this measures how many 'points per pound(/euro/whatever)' has the player gained on an average game week.
#
# The value points is calculated as the geometric mean of a players adjusted points per game and value. Essentially, in FPL we want to gain the maximum possible amount of points. However, we are restrained by a limited budget, so that in practice we cannot just pick all the best players. Then, we would like to have a squad of players that give the most points given our budget. Thus, we would like to pick players that have high value ('bang for buck'). However, often the players with highest value are very cheap players who somewhat overperform relative to their price. Picking a squad full of these players might leave a part of our budget unused. Calculating the geometric mean of adjusted points and value allows us to weigh both aspects equally, i.e. we want players that both gain a lot of points but also have good value. For example, this metric values equally two players, where one has twice the points per game of the other who in turn has twice the value of the other.

# %%
# value = expected points / cost
df['value'] = df['adjusted points per game'] / (df['now_cost'] / 10.0)
df['value form 5'] = df['form 5'] / (df['now_cost'] / 10.0)
df['value form 10'] = df['form 10'] / (df['now_cost'] / 10.0)
# geometric mean of 'adjusted points per game' and 'value'
df['valuePoints metric'] = np.sqrt(df['adjusted points per game'] * df['value'])

# %%
df['value_next10']  = df['xPoints_next10'] / (df['now_cost'] / 10.0)

# %%
df['xG+xA'] = df['xG'] + df['xA']
df['xG+xA per game'] = df['xG+xA'] / df['games played']

# %%
goalkeepers = df['element_type'] == 1
defenders = df['element_type'] == 2
midfielders = df['element_type'] == 3
forwards = df['element_type'] == 4

minGames = df['games played'] >= 3

# %% [markdown]
# ## Player evaluation
#
# Below we compile lists for each position sorting players based on a given metric.
#
# Notice that 'next1_xP' is currently based on preseason expectations on average player performance!

# %%
metric = 'valuePoints metric'
#metric = 'adjusted points per game'
#metric = 'next1_xP'

numberToShow = 40

print('GOALKEEPERS')
display(df[goalkeepers & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10', 'valuePoints metric']].head(20))
print('DEFENDERS')
display(df[defenders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('MIDFIELDERS')
display(df[midfielders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('FORWARDS')
display(df[forwards & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
# Out:
# GOALKEEPERS
#        web_name        team_name  now_cost  games played  total_points  \
# id
# 376      Foster          Watford        41           8.0            28
# 475          Sá           Wolves        51          17.0            77
# 408   Fabianski         West Ham        50          17.0            64
# 559    Ramsdale          Arsenal        51          14.0            75
# 353      Lloris        Tottenham        54          14.0            63
# 146      Guaita   Crystal Palace        46          16.0            54
# 270      de Gea   Manchester Utd        51          16.0            66
# 80         Raya        Brentford        44           9.0            34
# 257     Ederson  Manchester City        60          16.0            69
# 472           25.971              2.4                  2.164250  3.166667
# 269           13.600              2.4                  2.720000       NaN
# 591           25.000              1.9                  2.272727  3.466667
# 516           32.200              1.6                  2.146667  2.800000
# 310           35.371              2.1                  2.210688  2.140000
# 213           28.642              2.3                  2.386833  1.000000
#
#      xPoints_next10  valuePoints metric
# id
# 177       35.558342            3.028908
# 450       37.561768            1.723515
# 468       35.346737            1.721207
# 189       39.091531            1.654241
# 78        32.801541            1.634347
# 413       43.334966            1.616038
# 263       36.283652            1.542428
# 63        31.402546            1.471588
# 315       30.536252            1.463691
# 525       32.430153            1.456424
# 579       43.036751            1.455160
# 40        40.530087            1.449716
# 307       37.483444            1.431344
# 518       31.053865            1.426215
# 345       33.503126            1.417032
# 296       35.452685            1.411612
# 228       43.425576            1.391612
# 205       34.734798            1.352903
# 235       26.037467            1.338877
# 187       31.790977            1.338656
# 455       32.466280            1.330308
# 583       31.711167            1.291879
# 149       32.254760            1.257261
# 180       28.241802            1.254610
# 430       32.328523            1.216697
# 447       20.611878            1.193911
# 109       30.785290            1.179606
# 4         33.036595            1.162149
# 577       28.897067            1.125627
# 529       30.842250            1.112517
# 134       29.364084            1.105248
# 337       32.831212            1.101006
# 357       33.738715            1.080725
# 153       25.293589            1.046944
# 472       20.707687            0.967882
# 269       27.965456            0.938489
# 591       23.255432            0.927837
# 516       21.341859            0.923778
# 310       23.539707            0.917938
# 213       22.125350            0.908652

# %% [markdown]
# Below we compile a list sorting players based on a given metric (irrespective of position).

# %%
metric = 'adjusted points per game'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 177     Calvert-Lewin          Everton        79           3.0            23
# 233             Salah        Liverpool       131          17.0           168
# 237  Alexander-Arnold        Liverpool        82          15.0           119
# 268            Torres  Manchester City        67           4.0            26
# 544       Branthwaite          Everton        40           1.0             9
# 265             Foden  Manchester City        80          11.0            61
# 135          Chilwell          Chelsea        57           6.0            54
# 253             Mendy  Manchester City        53           1.0             3
# 240              Jota        Liverpool        80          16.0            87
# 256           Cancelo  Manchester City        68          16.0            91
# 250          Gündogan  Manchester City        73          12.0            62
# 230              Mané        Liverpool       119          17.0            87
# 142             James          Chelsea        63          13.0            84
# 501              Sarr          Chelsea        49           1.0             8
# 359               Son        Tottenham       103          13.0            81
# 246        N.Williams        Liverpool        39           1.0             4
# 138             Mount          Chelsea        76          14.0            84
# 260           Steffen  Manchester City        45           1.0             7
# 579           Ronaldo   Manchester Utd       125          13.0            67
# 210         Tielemans   Leicester City        64          12.0            67
# 252            Stones  Manchester City        53           5.0            31
# 261          Bernardo  Manchester City        77          16.0            91
# 144         Gallagher   Crystal Palace        62          16.0            89
# 266           Rodrigo  Manchester City        55          12.0            49
# 420             Bowen         West Ham        65          17.0            76
# 189           Bamford     Leeds United        77           6.0            25
# 33           Grealish  Manchester City        76          13.0            49
# 122            Alonso          Chelsea        57          11.0            53
# 364            Davies        Tottenham        44           6.0            29
# 259           Laporte  Manchester City        55          13.0            56
# 413           Antonio         West Ham        79          16.0            75
# 370          Reguilón        Tottenham        53          13.0            62
# 196          Raphinha     Leeds United        66          15.0            75
# 263             Jesus  Manchester City        86          14.0            60
# 127           Rüdiger          Chelsea        62          16.0            83
# 255          Sterling  Manchester City       106          14.0            53
# 249            Walker  Manchester City        55          12.0            51
# 262              Dias  Manchester City        61          16.0            72
# 234         Robertson        Liverpool        71          13.0            60
# 205             Vardy   Leicester City       106          15.0            77
#
#      adjusted points  points_per_game  adjusted points per game  \
# id
#
Games].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  \
# id
# 177     Calvert-Lewin          Everton        79           3.0
# 135          Chilwell          Chelsea        57           6.0
# 237  Alexander-Arnold        Liverpool        82          15.0
# 268            Torres  Manchester City        67           4.0
# 256           Cancelo  Manchester City        68          16.0
# 233             Salah        Liverpool       131          17.0
# 245          Tsimikas        Liverpool        38           6.0
# 142             James          Chelsea        63          13.0
# 364            Davies        Tottenham        44           6.0
# 265             Foden  Manchester City        80          11.0
# 240              Jota        Liverpool        80          16.0
# 252            Stones  Manchester City        53           5.0
# 250          Gündogan  Manchester City        73          12.0
# 266           Rodrigo  Manchester City        55          12.0
# 210         Tielemans   Leicester City        64          12.0
# 370          Reguilón        Tottenham        53          13.0
# 259           Laporte  Manchester City        55          13.0
# 144         Gallagher   Crystal Palace        62          16.0
# 249            Walker  Manchester City        55          12.0
# 122            Alonso          Chelsea        57          11.0
# 258               Aké  Manchester City        47           6.0
# 96             Mbeumo        Brentford        54          15.0
# 376            Foster          Watford        41           8.0
# 125           Kovacic          Chelsea        50           9.0
# 138             Mount          Chelsea        76          14.0
# 475                Sá           Wolves        51          17.0
# 224             Matip        Liverpool        49          13.0
# 420             Bowen         West Ham        65          17.0
# 147           Tomkins   Crystal Palace        43           6.0
# 527          Chalobah          Chelsea        47          10.0
# 127           Rüdiger          Chelsea        62          16.0
# 262              Dias  Manchester City        61          16.0
# 408         Fabianski         West Ham        50          17.0
# 119       Azpilicueta          Chelsea        57          11.0
# 559          Ramsdale          Arsenal        51          14.0
# 353            Lloris        Tottenham        54          14.0
# 146            Guaita   Crystal Palace        46          16.0
# 196          Raphinha     Leeds United        66          15.0
# 264         Zinchenko  Manchester City        53           5.0
# 261          Bernardo  Manchester City        77          16.0
#
#      points_per_game  adjusted points per game     form 5  xPoints_next10  \
# id
# 177              7.7                  8.513333        NaN       35.558342
# 135              9.0                  6.066141        NaN       38.133428
# 237              7.9                  7.208366   7.699840       43.482055
# 268              6.5                  6.356962        NaN       35.507367
# 256              5.7                  6.041534   5.440616       42.121021
# 233              9.9                  8.252043   8.044810       54.900305
# 245              5.0                  4.317066        NaN       32.253292
# 142              6.5                  5.527769   4.875146       35.473793
# 364              4.8                  4.562445   8.406429       30.546922
# 265              5.5                  6.092303   7.452439       43.864810
# 240              5.4                  6.043246   7.708246       50.219245
# 252              6.2                  4.916847   8.274923       31.130117
# 250              5.2                  5.729545   6.674829       39.337301
# 266              3.3                  4.771795   3.042323       40.742042
# 210              5.6                  5.059603  11.048812       36.754570
# 370              4.8                  4.538496   6.317136       35.163270
# 259              4.3                  4.556847   6.527778       37.136786
# 144              5.6                  4.783559   3.653881       36.024232
# 249              4.2                  4.496097   5.616132       38.408665
# 122              4.8                  4.567216   3.854421       31.092257
# 258              4.0                  4.123513   2.613139       29.964687
# 96               3.5                  4.400594   4.659341       30.216172
# 376              3.5                  3.831539        NaN       34.014313
# 125              5.1                  4.225243        NaN       31.802845
# 138              6.0                  5.197505   5.989138       35.898280
# 475              4.5                  4.161183   4.520713       39.100748
# 224              4.0                  4.055232   5.474179       34.233037
# 420              4.5                  4.662201   3.972492       38.925681
# 147              2.7                  3.787154   4.295524       30.079377
# 527              5.4                  3.954307   1.995447       31.519572
# 17         29.202077              2.6                  3.650260
# 133        37.097380              3.5                  3.372489
# 253         6.056847              3.0                  6.056847
# 199        48.851434              2.9                  2.873614
# 30         63.349171              4.2                  3.959323
# 4          50.411000              3.1                  3.600786
# 22         61.907664              3.8                  3.641627
# 249        53.953161              4.2                  4.496097
# 237       108.125486              7.9                  7.208366
# 1           6.790116              1.3                  2.263372
# 230        95.147738              5.1                  5.596926
#
#      gameweek 18 prediction  valuePoints metric
# id
# 233                5.334622            2.279953
# 265                5.198958            2.153954
# 135                5.086585            2.540827
# 256                5.023324            2.316823
# 250                5.005713            2.120600
# 142                4.970903            2.202316
# 138                4.829995            1.885333
# 266                4.730260            2.034700
# 240                4.691434            2.136610
# 127                4.686001            1.811810
# 143                4.634946            1.638289
# 121                4.460551            1.642959
# 261                4.446767            1.750981
# 559                4.425128            1.771879
# 501                4.420069            2.464005
# 123                4.416328            1.602907
# 21                 4.411392            1.519490
# 119                4.372329            1.778620
# 251                4.343825            1.271133
# 257                4.327049            1.722541
# 129                4.319710            1.593353
# 125                4.246480            1.889586
# 268                4.242626            2.455909
# 527                4.226925            1.823986
# 262                4.212864            1.806321
# 259                4.199991            1.943046
# 122                4.194756            1.912996
# 33                 4.185638            1.664459
# 263                4.185638            1.542428
# 17                 4.177074            1.389630
# 133                4.134737            1.555613
# 253                4.130570            2.630926
# 199                4.125137            1.298166
# 30                 4.120245            1.688261
# 4                  4.108310            1.162149
# 22                 4.095835            1.462513
# 249                4.094194            1.917142
# 237                4.037858            2.517271
# 1                  4.030808            1.055303
# 230                4.020479            1.622468

# %%
metric = 'xG'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game',\
                      'valuePoints metric', 'xG', 'xA', 'xG+xA', 'xG+xA per game']].head(numberToShow))
# Out:
#           web_name        team_name  now_cost  games played  points_per_game  \
# id
# 233          Salah        Liverpool       131          17.0              9.9
# 240           Jota        Liverpool        80          16.0              5.4
# 230           Mané        Liverpool       119          17.0              5.1
# 579        Ronaldo   Manchester Utd       125          13.0              5.2
# 205          Vardy   Leicester City       106          15.0              5.1
# 468           King          Watford        58          14.0              4.0
# 4       Aubameyang          Arsenal        96          14.0              3.1
# 96          Mbeumo        Brentford        54          15.0              3.5
# 413        Antonio         West Ham        79          16.0              4.7
# 40         Watkins      Aston Villa        77          15.0              4.1
# 250       Gündogan  Manchester City        73          12.0              5.2
# 420          Bowen         West Ham        65          17.0              4.5
# 138          Mount          Chelsea        76          14.0              6.0
# 149        Benteke   Crystal Palace        64          17.0              2.9
# 315          Pukki     Norwich City        59          17.0              3.5
# 63          Maupay         Brighton        64          14.0              3.9
# 196       Raphinha     Leeds United        66          15.0              5.0
# 265          Foden  Manchester City        80          11.0              5.5
# 255       Sterling  Manchester City       106          14.0              3.8
# 296         Wilson    Newcastle Utd        74          13.0              4.3
# 263          Jesus  Manchester City        86          14.0              4.3
# 359            Son        Tottenham       103          13.0              6.2
# 78           Toney        Brentford        66          14.0              3.9
# 261       Bernardo  Manchester City        77          16.0              5.7
# 228        Firmino        Liverpool        87           9.0              4.3
# 450         Dennis          Watford        60          15.0              5.6
# 413        0.581250
# 40         0.413333
# 250        0.616667
# 420        0.447059
# 138        0.578571
# 149        0.358824
# 315        0.323529
# 63         0.400000
# 196        0.493333
# 265        0.727273
# 255        0.507143
# 296        0.361538
# 263        0.485714
# 359        0.484615
# 78         0.500000
# 261        0.412500
# 228        0.533333
# 450        0.373333
# 109        0.266667
# 177        1.300000
# 357        0.469231
# 525        0.366667
# 277        0.481250
# 144        0.412500
# 33         0.515385
# 154        0.406250
# 399        0.383333
# 189        0.650000
# 123        0.333333
# 430        0.306250
# 529        0.463636
# 212        0.318750

# %% [markdown]
# ## Player Visualizations

# %%
game_weeks = np.arange(1,gameweek+1)
column_xPoints = []
column_xG = []
column_xA = []
column_xGA = []
for i in range(1,gameweek+1):
    column_xPoints.append('xPoints week ' + str(i))
    column_xG.append('xG_week' + str(i))
    column_xA.append('xA_week' + str(i))
    column_xGA.append('xGA_week' + str(i))

#display(game_weeks)
#display(column_xPoints)

# %%
# find player index
name_string = 'Werner'
playersFound = df[df['web_name'].str.contains(name_string)]
display(playersFound[['web_name','team_name','now_cost','games played','total_points','adjusted points',\
                      'points_per_game','adjusted points per game',f'gameweek {gameweek+1} prediction',\
                      'xPoints_next10', 'valuePoints metric']])
# plot xPoints over time
ix = playersFound.index[0]
#ix = 468

fig,ax = plt.subplots(2,2,figsize=(15,10))

ax[0,0].plot(game_weeks, df.loc[ix,column_xPoints], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,0].set_title(title_string)
ax[0,0].set_xlabel('gameweek')
ax[0,0].set_ylabel('xPoints')
ax[0,0].set_xticks(game_weeks)

ax[0,1].plot(game_weeks, df.loc[ix,column_xG], marker='o')
ax[0,1].plot(game_weeks, df.loc[ix,column_xA], marker='o')
ax[0,1].legend(('xG','xA'))
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,1].set_title(title_string)
ax[0,1].set_xlabel('gameweek')
ax[0,1].set_ylabel('xG and xA')
ax[0,1].set_xticks(game_weeks)

ax[1,0].plot(game_weeks, df.loc[ix,column_xGA], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[1,0].set_title(title_string)
ax[1,0].set_xlabel('gameweek')
ax[1,0].set_ylabel('xGA')
ax[1,0].set_xticks(game_weeks)

plt.show()
# Out:
#     web_name team_name  now_cost  games played  total_points  adjusted points  \
# id
# 134   Werner   Chelsea        86           9.0            22           29.171
#
#      points_per_game  adjusted points per game  gameweek 18 prediction  \
# id
# 134              2.4                  3.241222                3.802925
#
#      xPoints_next10  valuePoints metric
# id
# 134       29.364084            1.105248

# %% [markdown]
# ## My team

# %%
session = requests.session()

# %%
filepath = Path('../../../access_control/FPL_access.txt')
with open(filepath) as file:
    text = file.read().splitlines()
    email = text[0]
    password = text[1]

# %%
url = 'https://users.premierleague.com/accounts/login/'

payload = {
'password': password,
'login': email,
'redirect_uri': 'https://fantasy.premierleague.com/a/login', 'app': 'plfpl-web'
}
session.post(url, data=payload)
# Out:
# <Response [200]>

# %%
response = session.get('https://fantasy.premierleague.com/api/my-team/3202682')
team = response.json()['picks']

# %%
my_player_ix = [player['element'] for player in team]
my_starting11 = my_player_ix[:-4]
my_subs = my_player_ix[-4:]

# %%
exp_avg = df.loc[my_starting11,'adjusted points per game'].sum() + \
                df.loc[my_starting11,'adjusted points per game'].max()
exp_next = df.loc[my_starting11, f'gameweek {gameweek+1} prediction'].sum() + \
                df.loc[my_starting11,f'gameweek {gameweek+1} prediction'].max()

print('STARTING 11')
print('Expected points on average: ' + str(exp_avg))
print('Predicted points next gameweek: ' + str(exp_next))
display(df.loc[my_starting11, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
           f'gameweek {gameweek+1} prediction','xPoints_next10', 'valuePoints metric']].head(numberToShow))
print('\nSUBSTITUTES')
display(df.loc[my_subs, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
         f'gameweek {gameweek+1} prediction', 'xPoints_next10', 'valuePoints metric']].head(numberToShow))
# Out:
# STARTING 11
# Expected points on average: 68.90252256438501
# Predicted points next gameweek: 38.96216535568237
#              web_name        team_name  now_cost  games played  \
# id
# 559          Ramsdale          Arsenal        51          14.0
# 256           Cancelo  Manchester City        68          16.0
# 237  Alexander-Arnold        Liverpool        82          15.0
# 142             James          Chelsea        63          13.0
# 144         Gallagher   Crystal Palace        62          16.0
# 138             Mount          Chelsea        76          14.0
# 233             Salah        Liverpool       131          17.0
# 250          Gündogan  Manchester City        73          12.0
# 450            Dennis          Watford        60          15.0
# 413           Antonio         West Ham        79          16.0
# 579           Ronaldo   Manchester Utd       125          13.0
#
#      points_per_game  adjusted points per game    form 5   form 10  \
# id
# 559              5.4                  4.001467  5.313231  4.770513
# 256              5.7                  6.041534  5.440616  6.051795
# 237              7.9                  7.208366  7.699840  7.636812
# 142              6.5                  5.527769  4.875146  6.330890
# 144              5.6                  4.783559  3.653881  4.951142
# 138              6.0                  5.197505  5.989138  5.699094
# 233              9.9                  8.252043  8.044810  8.287928
# 250              5.2                  5.729545  6.674829  6.280176
# 450              5.6                  4.221733  5.617750  5.181875
# 413              4.7                  4.542187  2.574200  3.157100
# 579              5.2                  5.144769  6.075000  5.115778
#
#      gameweek 18 prediction  xPoints_next10  valuePoints metric
# id
# 559                4.425128       35.493716            1.771879
# 256                5.023324       42.121021            2.316823
# 237                4.037858       43.482055            2.517271
# 142                4.970903       35.473793            2.202316
# 144                0.000000       36.024232            1.921124
# 138                4.829995       35.898280            1.885333
# 233                5.334622       54.900305            2.279953
# 250                5.005713       39.337301            2.120600
# 450                0.000000       37.561768            1.723515
# 413                0.000000       43.334966            1.616038
# 579                0.000000       43.036751            1.455160
# SUBSTITUTES
#        web_name     team_name  now_cost  games played  points_per_game  \
# id
# 376      Foster       Watford        41           8.0              3.5
# 425     Johnson      West Ham        40           9.0              3.1
# 491  Livramento   Southampton        44          17.0              3.1
# 145     Gilmour  Norwich City        44          10.0              2.3
#
#      adjusted points per game    form 5   form 10  gameweek 18 prediction  \
# id
# 376                  3.831539       NaN  4.089013                     0.0
# 425                  2.912908  1.682039  3.028395                     0.0
# 491                  2.949857  2.071493  3.299868                     0.0
# 145                  2.607647  2.535244  2.685850                     0.0
#
#      xPoints_next10  valuePoints metric
# id
# 376       34.014313            1.892262
# 425       26.775551            1.456454
# 491       30.310230            1.406289
# 145       20.430672            1.243147

# %% [markdown]
# ## Save data

# %%
# save data
filepath = '../data/fpl/data_week' + str(gameweek) + str('.csv')
df.to_csv(filepath)
