# %% [markdown]
# # Player evaluation
#
# Here we compare players based on their adjusted points. Also, we calculate some useful metrics using the adjusted points to further evaluate player performance in FPL.

# %%
# recent gameweek
gameweek = 12

# %%
# import basic libraries
import pandas as pd
import numpy as np
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.set_option('max_columns',100)

# %%
# fetch FPL data
filepath = '../data/fpl/data_week' + str(gameweek) + '.csv'
df = pd.read_csv(filepath, index_col=0)

# fetch team data
filepath = '../data/fbref/team_stats_week' + str(gameweek) + '.csv'
teamStats = pd.read_csv(filepath, index_col=0)

# fetch player stats data
filepath = '../data/fbref/player_stats_week' + str(gameweek) + '.csv'
playerStats = pd.read_csv(filepath, index_col=0, skiprows=1)

# %% [markdown]
# ## Value and value points
#
# Here we calculate two interesting metrics: 'value' and 'value points'.
#
# Value is simply adjusted points per game divided by the cost of the player. Essentially, this measures how many 'points per pound(/euro/whatever)' has the player gained on an average game week.
#
# The value points is calculated as the geometric mean of a players adjusted points per game and value. Essentially, in FPL we want to gain the maximum possible amount of points. However, we are restrained by a limited budget, so that in practice we cannot just pick all the best players. Then, we would like to have a squad of players that give the most points given our budget. Thus, we would like to pick players that have high value ('bang for buck'). However, often the players with highest value are very cheap players who somewhat overperform relative to their price. Picking a squad full of these players might leave a part of our budget unused. Calculating the geometric mean of adjusted points and value allows us to weigh both aspects equally, i.e. we want players that both gain a lot of points but also have good value. For example, this metric values equally two players, where one has twice the points per game of the other who in turn has twice the value of the other.

# %%
# value = expected points / cost
df['value'] = df['adjusted points per game'] / (df['now_cost'] / 10.0)
df['value form 5'] = df['form 5'] / (df['now_cost'] / 10.0)
df['value form 10'] = df['form 10'] / (df['now_cost'] / 10.0)
# geometric mean of 'adjusted points per game' and 'value'
df['valuePoints metric'] = np.sqrt(df['adjusted points per game'] * df['value'])

# %%
df['value_next10']  = df['xPoints_next10'] / (df['now_cost'] / 10.0)

# %%
df['xG+xA'] = df['xG'] + df['xA']
df['xG+xA per game'] = df['xG+xA'] / df['games played']

# %%
goalkeepers = df['element_type'] == 1
defenders = df['element_type'] == 2
midfielders = df['element_type'] == 3
forwards = df['element_type'] == 4

minGames = df['games played'] >= 3

# %% [markdown]
# ## Player evaluation
#
# Below we compile lists for each position sorting players based on a given metric.
#
# Notice that 'next1_xP' is currently based on preseason expectations on average player performance!

# %%
metric = 'valuePoints metric'
#metric = 'adjusted points per game'
#metric = 'next1_xP'

numberToShow = 40

print('GOALKEEPERS')
display(df[goalkeepers & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10', 'valuePoints metric']].head(20))
print('DEFENDERS')
display(df[defenders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('MIDFIELDERS')
display(df[midfielders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('FORWARDS')
display(df[forwards & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
# Out:
# GOALKEEPERS
#        web_name        team_name  now_cost  games played  total_points  \
# id
# 376      Foster          Watford        41           8.0            28
# 475          Sá           Wolves        50          12.0            48
# 146      Guaita   Crystal Palace        46          12.0            46
# 353      Lloris        Tottenham        54          12.0            50
# 270      de Gea   Manchester Utd        50          12.0            45
# 80         Raya        Brentford        45           9.0            34
# 30     Martínez      Aston Villa        55          11.0            50
# 143       Mendy          Chelsea        63          11.0            59
# 559    Ramsdale          Arsenal        48           9.0            47
# 310           24.671              2.3                  2.242818  2.100000
# 111           21.171              2.0                  2.117100  2.700000
# 153           24.371              1.8                  2.215545  2.067750
# 404           14.771              2.1                  2.110143  2.474200
# 516           21.000              1.5                  1.909091  2.040000
# 472           16.471              2.1                  1.830111  2.214200
#
#      xPoints_next10  valuePoints metric
# id
# 177       38.883301            3.009918
# 413       50.848431            1.910271
# 468       38.932194            1.897921
# 189       37.729522            1.840940
# 263       35.088900            1.707194
# 450       36.134705            1.613298
# 583       38.741297            1.600932
# 525       34.546335            1.600074
# 307       38.346941            1.590941
# 529       49.148871            1.562885
# 78        39.687399            1.544111
# 228       48.409702            1.465163
# 430       38.297933            1.456488
# 315       34.754618            1.451220
# 345       35.740935            1.416414
# 205       41.565182            1.412136
# 579       45.003230            1.373900
# 187       31.932735            1.355389
# 296       36.235174            1.346362
# 149       37.487414            1.329837
# 109       33.492005            1.319973
# 40        32.804336            1.286932
# 518       33.209734            1.274559
# 337       33.973010            1.213094
# 447       24.027677            1.183920
# 4         36.460299            1.179144
# 63        30.564556            1.161418
# 577       24.784321            1.158241
# 180       35.473838            1.152035
# 455       35.321815            1.132541
# 134       33.002952            1.050807
# 357       34.867535            1.024717
# 213       26.806312            0.949790
# 269       30.312383            0.938489
# 310       23.927320            0.931280
# 111       26.938086            0.928410
# 153       27.692872            0.919955
# 404       22.878152            0.908061
# 516       22.512820            0.821542
# 472       22.206694            0.818451

# %% [markdown]
# Below we compile a list sorting players based on a given metric (irrespective of position).

# %%
metric = 'adjusted points per game'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 177     Calvert-Lewin          Everton        80           3.0            23
# 233             Salah        Liverpool       130          12.0           125
# 237  Alexander-Arnold        Liverpool        78          10.0            79
# 268            Torres  Manchester City        67           4.0            26
# 256           Cancelo  Manchester City        66          12.0            79
# 135          Chilwell          Chelsea        60           6.0            54
# 230              Mané        Liverpool       120          12.0            71
# 253             Mendy  Manchester City        53           1.0             3
# 142             James          Chelsea        61           9.0            75
# 265             Foden  Manchester City        83           8.0            41
# 501              Sarr          Chelsea        49           1.0             8
# 413           Antonio         West Ham        81          11.0            63
# 144         Gallagher   Crystal Palace        60          11.0            67
# 529            Lukaku          Chelsea       115           7.0            31
# 240              Jota        Liverpool        76          11.0            54
# 122            Alonso          Chelsea        56           6.0            39
# 250          Gündogan  Manchester City        72           8.0            35
# 189           Bamford     Leeds United        77           5.0            21
# 263             Jesus  Manchester City        87          10.0            50
# 260           Steffen  Manchester City        45           1.0             7
# 246        N.Williams        Liverpool        39           1.0             4
# 420             Bowen         West Ham        64          12.0            57
# 359               Son        Tottenham       104          11.0            60
# 579           Ronaldo   Manchester Utd       124           9.0            43
# 138             Mount          Chelsea        75           9.0            45
# 196          Raphinha     Leeds United        67          10.0            50
# 33           Grealish  Manchester City        77           9.0            34
# 210         Tielemans   Leicester City        64          11.0            51
# 205             Vardy   Leicester City       106          12.0            62
# 119       Azpilicueta          Chelsea        58           8.0            42
# 468              King          Watford        56          10.0            45
# 527          Chalobah          Chelsea        48           7.0            50
# 262              Dias  Manchester City        60          11.0            49
# 419          Benrahma         West Ham        63          12.0            59
# 127           Rüdiger          Chelsea        59          11.0            67
# 173          Doucouré          Everton        54           8.0            45
# 96             Mbeumo        Brentford        56          11.0            34
# 64           Trossard         Brighton        65          12.0            53
# 277         Fernandes   Manchester Utd       117          12.0            54
# 228           Firmino        Liverpool        88           8.0            35
#
#      adjusted points  points_per_game  adjusted points per game  \
# id
#
# 140        23.396747              4.0                  3.899458
# 125        38.093621              5.1                  4.232625
# 112        35.051760              2.4                  2.920980
# 64         52.416092              4.4                  4.368008
# 475        50.928322              4.0                  4.244027
# 200        38.273157              2.7                  3.189430
# 212        34.268289              2.2                  2.855691
# 439        37.057322              3.1                  3.088110
# 432        28.880215              3.6                  3.610027
# 121        33.854485              5.0                  3.761609
# 429        40.457322              3.2                  3.371444
# 559        33.308212              5.2                  3.700912
#
#      gameweek 13 prediction  valuePoints metric
# id
# 135                5.441405            2.508957
# 529                5.257646            1.562885
# 233                5.026714            2.332570
# 142                4.941642            2.381574
# 205                4.874883            1.412136
# 210                4.731431            1.818175
# 228                4.657183            1.465163
# 122                4.611108            2.216698
# 237                4.596816            2.565147
# 583                4.585413            1.600932
# 119                4.567892            1.883246
# 430                4.489091            1.456488
# 461                4.478855            1.660209
# 230                4.476037            1.731483
# 527                4.389229            2.046580
# 501                4.384357            2.477343
# 455                4.381765            1.132541
# 468                4.376358            1.897921
# 138                4.331882            1.723160
# 133                4.330379            1.692420
# 127                4.311918            1.818680
# 431                4.306755            1.615832
# 199                4.281653            1.337600
# 17                 4.270017            1.499312
# 359                4.247231            1.518674
# 143                4.223115            1.713963
# 1                  4.221966            0.948472
# 129                4.185763            1.590144
# 140                4.180564            1.693816
# 125                4.175058            1.874238
# 112                4.166866            1.256990
# 64                 4.164368            1.713274
# 475                4.159925            1.897987
# 200                4.149738            1.426356
# 212                4.144189            1.111576
# 439                4.127813            1.455749
# 432                4.115871            1.721013
# 121                4.112242            1.603956
# 429                4.110181            1.589314
# 559                4.098909            1.689228

# %%
metric = 'xG'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game',\
                      'valuePoints metric', 'xG', 'xA', 'xG+xA', 'xG+xA per game']].head(numberToShow))
# Out:
#           web_name        team_name  now_cost  games played  points_per_game  \
# id
# 233          Salah        Liverpool       130          12.0             10.4
# 230           Mané        Liverpool       120          12.0              5.9
# 240           Jota        Liverpool        76          11.0              4.9
# 413        Antonio         West Ham        81          11.0              5.7
# 205          Vardy   Leicester City       106          12.0              5.2
# 4       Aubameyang          Arsenal        99          11.0              3.6
# 468           King          Watford        56          10.0              4.5
# 579        Ronaldo   Manchester Utd       124           9.0              4.8
# 96          Mbeumo        Brentford        56          11.0              3.1
# 228        Firmino        Liverpool        88           8.0              4.4
# 177  Calvert-Lewin          Everton        80           3.0              7.7
# 420          Bowen         West Ham        64          12.0              4.8
# 109           Wood          Burnley        67          12.0              3.2
# 315          Pukki     Norwich City        58          12.0              3.8
# 149        Benteke   Crystal Palace        64          12.0              3.5
# 399           Sarr          Watford        60          12.0              4.4
# 263          Jesus  Manchester City        87          10.0              5.0
# 40         Watkins      Aston Villa        73          10.0              3.5
# 78           Toney        Brentford        67          12.0              3.7
# 529         Lukaku          Chelsea       115           7.0              4.4
# 265          Foden  Manchester City        83           8.0              5.1
# 359            Son        Tottenham       104          11.0              5.5
# 144      Gallagher   Crystal Palace        60          11.0              6.1
# 154           Zaha   Crystal Palace        70          11.0              4.5
# 430        Jiménez           Wolves        78          12.0              4.2
# 196       Raphinha     Leeds United        67          10.0              5.0
# 579        0.622222
# 96         0.472727
# 228        0.587500
# 177        1.300000
# 420        0.491667
# 109        0.316667
# 315        0.291667
# 149        0.366667
# 399        0.383333
# 263        0.540000
# 40         0.360000
# 78         0.491667
# 529        0.714286
# 265        0.637500
# 359        0.390909
# 144        0.509091
# 154        0.418182
# 430        0.375000
# 196        0.500000
# 296        0.387500
# 525        0.418182
# 63         0.300000
# 277        0.533333
# 189        0.680000
# 357        0.418182
# 138        0.544444
# 423        0.358333
# 64         0.333333
# 250        0.562500
# 450        0.345455
# 255        0.340000
# 268        0.625000
# 289        0.370000

# %% [markdown]
# ## Player Visualizations

# %%
game_weeks = np.arange(1,gameweek+1)
column_xPoints = []
column_xG = []
column_xA = []
column_xGA = []
for i in range(1,gameweek+1):
    column_xPoints.append('xPoints week ' + str(i))
    column_xG.append('xG_week' + str(i))
    column_xA.append('xA_week' + str(i))
    column_xGA.append('xGA_week' + str(i))

#display(game_weeks)
#display(column_xPoints)

# %%
# find player index
name_string = 'Foden'
playersFound = df[df['web_name'].str.contains(name_string)]
display(playersFound[['web_name','team_name','now_cost','games played','total_points','adjusted points',\
                      'points_per_game','adjusted points per game',f'gameweek {gameweek+1} prediction',\
                      'xPoints_next10', 'valuePoints metric']])
# plot xPoints over time
ix = playersFound.index[0]
#ix = 468

fig,ax = plt.subplots(2,2,figsize=(15,10))

ax[0,0].plot(game_weeks, df.loc[ix,column_xPoints], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,0].set_title(title_string)
ax[0,0].set_xlabel('gameweek')
ax[0,0].set_ylabel('xPoints')
ax[0,0].set_xticks(game_weeks)

ax[0,1].plot(game_weeks, df.loc[ix,column_xG], marker='o')
ax[0,1].plot(game_weeks, df.loc[ix,column_xA], marker='o')
ax[0,1].legend(('xG','xA'))
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,1].set_title(title_string)
ax[0,1].set_xlabel('gameweek')
ax[0,1].set_ylabel('xG and xA')
ax[0,1].set_xticks(game_weeks)

ax[1,0].plot(game_weeks, df.loc[ix,column_xGA], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[1,0].set_title(title_string)
ax[1,0].set_xlabel('gameweek')
ax[1,0].set_ylabel('xGA')
ax[1,0].set_xticks(game_weeks)

plt.show()
# Out:
#     web_name        team_name  now_cost  games played  total_points  \
# id
# 265    Foden  Manchester City        83           8.0            41
#
#      adjusted points  points_per_game  adjusted points per game  \
# id
# 265        44.047926              5.1                  5.505991
#
#      gameweek 13 prediction  xPoints_next10  valuePoints metric
# id
# 265                3.822166       45.419456            1.911157

# %% [markdown]
# ## My team

# %%
session = requests.session()

# %%
filepath = Path('../../../access_control/FPL_access.txt')
with open(filepath) as file:
    text = file.read().splitlines()
    email = text[0]
    password = text[1]

# %%
url = 'https://users.premierleague.com/accounts/login/'

payload = {
'password': password,
'login': email,
'redirect_uri': 'https://fantasy.premierleague.com/a/login', 'app': 'plfpl-web'
}
session.post(url, data=payload)
# Out:
# <Response [200]>

# %%
response = session.get('https://fantasy.premierleague.com/api/my-team/3202682')
team = response.json()['picks']

# %%
my_player_ix = [player['element'] for player in team]
my_starting11 = my_player_ix[:-4]
my_subs = my_player_ix[-4:]

# %%
exp_avg = df.loc[my_starting11,'adjusted points per game'].sum() + \
                df.loc[my_starting11,'adjusted points per game'].max()
exp_next = df.loc[my_starting11, f'gameweek {gameweek+1} prediction'].sum() + \
                df.loc[my_starting11,f'gameweek {gameweek+1} prediction'].max()

print('STARTING 11')
print('Expected points on average: ' + str(exp_avg))
print('Predicted points next gameweek: ' + str(exp_next))
display(df.loc[my_starting11, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
           f'gameweek {gameweek+1} prediction','xPoints_next10', 'valuePoints metric']].head(numberToShow))
print('\nSUBSTITUTES')
display(df.loc[my_subs, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
         f'gameweek {gameweek+1} prediction', 'xPoints_next10', 'valuePoints metric']].head(numberToShow))
# Out:
# STARTING 11
# Expected points on average: 69.4114226738781
# Predicted points next gameweek: 52.33147096633911
#              web_name        team_name  now_cost  games played  \
# id
# 559          Ramsdale          Arsenal        48           9.0
# 256           Cancelo  Manchester City        66          12.0
# 237  Alexander-Arnold        Liverpool        78          10.0
# 142             James          Chelsea        61           9.0
# 144         Gallagher   Crystal Palace        60          11.0
# 196          Raphinha     Leeds United        67          10.0
# 233             Salah        Liverpool       130          12.0
# 265             Foden  Manchester City        83           8.0
# 430           Jiménez           Wolves        78          12.0
# 413           Antonio         West Ham        81          11.0
# 205             Vardy   Leicester City       106          12.0
#
#      points_per_game  adjusted points per game    form 5   form 10  \
# id
# 559              5.2                  3.700912  4.227794  4.294218
# 256              6.6                  6.215880  6.540738  6.527842
# 237              7.9                  7.164064  7.573784  7.190704
# 142              8.3                  5.882054  7.495484  5.321203
# 144              6.1                  5.321502  6.248402  5.551985
# 196              5.0                  4.698559  4.858150  5.145745
# 233             10.4                  8.410199  8.531046  8.610810
# 265              5.1                  5.505991  6.284188  5.328705
# 430              4.2                  4.067750  3.894200  4.361300
# 413              5.7                  5.436727  3.740000  4.385667
# 205              5.2                  4.597583  2.780000  4.947100
#
#      gameweek 13 prediction  xPoints_next10  valuePoints metric
# id
# 559                4.098909       36.337958            1.689228
# 256                3.826500       47.044504            2.419528
# 237                4.596816       47.137964            2.565147
# 142                4.941642       46.790505            2.381574
# 144                4.000969       41.251045            2.172494
# 196                3.723627       37.056489            1.815212
# 233                5.026714       51.139180            2.332570
# 265                3.822166       45.419456            1.911157
# 430                4.489091       38.297933            1.456488
# 413                3.903440       50.848431            1.910271
# 205                4.874883       41.565182            1.412136
# SUBSTITUTES
#        web_name      team_name  now_cost  games played  points_per_game  \
# id
# 376      Foster        Watford        41           8.0              3.5
# 302   Manquillo  Newcastle Utd        40           7.0              2.9
# 491  Livramento    Southampton        46          12.0              4.1
# 145     Gilmour   Norwich City        44           5.0              2.8
#
#      adjusted points per game    form 5   form 10  gameweek 13 prediction  \
# id
# 376                  3.882604  4.089013  3.863264                3.549085
# 302                  2.486810  2.440765  2.619640                3.286527
# 491                  3.357994  4.528242  4.025050                2.454431
# 145                  2.790132  3.438879  3.320327                2.428932
#
#      xPoints_next10  valuePoints metric
# id
# 376       35.222698            1.917482
# 302       28.217248            1.243405
# 491       32.605847            1.565673
# 145       24.936603            1.330143

# %% [markdown]
# ## Save data

# %%
# save data
filepath = '../data/fpl/data_week' + str(gameweek) + str('.csv')
df.to_csv(filepath)
