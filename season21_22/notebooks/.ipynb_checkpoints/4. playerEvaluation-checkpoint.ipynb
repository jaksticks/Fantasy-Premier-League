# %% [markdown]
# # Player evaluation
#
# Here we compare players based on their adjusted points. Also, we calculate some useful metrics using the adjusted points to further evaluate player performance in FPL.

# %%
# recent gameweek
gameweek = 9

# %%
# import basic libraries
import pandas as pd
import numpy as np
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.set_option('max_columns',100)

# %%
# fetch FPL data
filepath = '../data/fpl/data_week' + str(gameweek) + '.csv'
df = pd.read_csv(filepath, index_col=0)

# fetch team data
filepath = '../data/fbref/team_stats_week' + str(gameweek) + '.csv'
teamStats = pd.read_csv(filepath, index_col=0)

# fetch player stats data
filepath = '../data/fbref/player_stats_week' + str(gameweek) + '.csv'
playerStats = pd.read_csv(filepath, index_col=0, skiprows=1)

# %% [markdown]
# ## Value and value points
#
# Here we calculate two interesting metrics: 'value' and 'value points'.
#
# Value is simply adjusted points per game divided by the cost of the player. Essentially, this measures how many 'points per pound(/euro/whatever)' has the player gained on an average game week.
#
# The value points is calculated as the geometric mean of a players adjusted points per game and value. Essentially, in FPL we want to gain the maximum possible amount of points. However, we are restrained by a limited budget, so that in practice we cannot just pick all the best players. Then, we would like to have a squad of players that give the most points given our budget. Thus, we would like to pick players that have high value ('bang for buck'). However, often the players with highest value are very cheap players who somewhat overperform relative to their price. Picking a squad full of these players might leave a part of our budget unused. Calculating the geometric mean of adjusted points and value allows us to weigh both aspects equally, i.e. we want players that both gain a lot of points but also have good value. For example, this metric values equally two players, where one has twice the points per game of the other who in turn has twice the value of the other.

# %%
# value = expected points / cost
df['value'] = df['adjusted points per game'] / (df['now_cost'] / 10.0)
df['value form 5'] = df['form 5'] / (df['now_cost'] / 10.0)
df['value form 10'] = df['form 10'] / (df['now_cost'] / 10.0)
# geometric mean of 'adjusted points per game' and 'value'
df['valuePoints metric'] = np.sqrt(df['adjusted points per game'] * df['value'])

# %%
df['value_next10']  = df['xPoints_next10'] / (df['now_cost'] / 10.0)

# %%
df['xG+xA'] = df['xG'] + df['xA']
df['xG+xA per game'] = df['xG+xA'] / df['games played']

# %%
goalkeepers = df['element_type'] == 1
defenders = df['element_type'] == 2
midfielders = df['element_type'] == 3
forwards = df['element_type'] == 4

minGames = df['games played'] >= 1

# %% [markdown]
# ## Player evaluation
#
# Below we compile lists for each position sorting players based on a given metric.
#
# Notice that 'next1_xP' is currently based on preseason expectations on average player performance!

# %%
metric = 'valuePoints metric'
#metric = 'adjusted points per game'
#metric = 'next1_xP'

numberToShow = 40

print('GOALKEEPERS')
display(df[goalkeepers & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10', 'valuePoints metric']].head(20))
print('DEFENDERS')
display(df[defenders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('MIDFIELDERS')
display(df[midfielders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('FORWARDS')
display(df[forwards & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
# Out:
# GOALKEEPERS
#          web_name        team_name  now_cost  games played  total_points  \
# id
# 260       Steffen  Manchester City        45           1.0             7
# 475            Sá           Wolves        50           9.0            35
# 30       Martínez      Aston Villa        55           8.0            41
# 80           Raya        Brentford        46           9.0            34
# 353        Lloris        Tottenham        55           9.0            39
# 143         Mendy          Chelsea        61           8.0            45
# 146        Guaita   Crystal Palace        45           9.0            30
# 270        de Gea   Manchester Utd        50           9.0            31
# 357           29.271              2.9                  3.658875  4.694200
# 134           21.171              2.6                  3.024429  4.192750
# 153           19.271              2.1                  2.408875  2.717750
# 519            2.200              1.0                  2.200000  2.200000
# 472           12.171              2.7                  2.028500  3.385500
# 516           16.300              1.6                  2.037500  2.520000
# 591           12.600              1.7                  2.100000  2.320000
# 380            3.900              1.0                  1.950000       NaN
# 310           17.571              1.7                  1.952333  2.234200
#
#      xPoints_next10  valuePoints metric
# id
# 177       45.642834            3.009918
# 413       67.815620            2.226421
# 468       42.476658            1.938603
# 583       42.782954            1.898804
# 189       39.180643            1.886390
# 263       42.651795            1.771267
# 307       37.659309            1.721964
# 78        41.014136            1.719704
# 205       45.761318            1.625282
# 296       40.091976            1.606306
# 529       54.965116            1.562885
# 518       38.100587            1.550340
# 450       35.495229            1.525740
# 228       48.178979            1.473495
# 187       36.500226            1.415350
# 455       44.311432            1.384957
# 63        37.502870            1.382401
# 109       32.252819            1.365046
# 430       37.558263            1.362807
# 180       37.878183            1.343311
# 4         45.138093            1.292225
# 579       45.323180            1.282220
# 337       37.041167            1.259646
# 149       34.937971            1.255920
# 525       35.385788            1.243677
# 315       28.045684            1.228150
# 40        35.520798            1.198702
# 447       23.140503            1.183920
# 345       26.177816            1.165915
# 577       28.020942            1.124535
# 213       30.142968            1.076863
# 357       36.875627            1.051853
# 134       37.194469            1.031322
# 153       28.786463            0.991718
# 519       23.395651            0.946729
# 472       23.188039            0.907173
# 516       20.939708            0.876800
# 591       21.564767            0.857321
# 380       16.147831            0.839146
# 310       20.254836            0.810662

# %% [markdown]
# Below we compile a list sorting players based on a given metric (irrespective of position).

# %%
metric = 'adjusted points per game'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 233             Salah        Liverpool       129           9.0           107
# 177     Calvert-Lewin          Everton        80           3.0            23
# 237  Alexander-Arnold        Liverpool        76           7.0            51
# 265             Foden  Manchester City        81           5.0            35
# 413           Antonio         West Ham        82           8.0            57
# 268            Torres  Manchester City        68           4.0            26
# 135          Chilwell          Chelsea        58           3.0            35
# 230              Mané        Liverpool       119           9.0            50
# 253             Mendy  Manchester City        53           1.0             3
# 256           Cancelo  Manchester City        64           9.0            51
# 240              Jota        Liverpool        75           8.0            43
# 359               Son        Tottenham       102           8.0            53
# 250          Gündogan  Manchester City        72           6.0            29
# 138             Mount          Chelsea        75           7.0            41
# 205             Vardy   Leicester City       108           9.0            57
# 529            Lukaku          Chelsea       115           7.0            31
# 501              Sarr          Chelsea        49           1.0             8
# 189           Bamford     Leeds United        78           5.0            21
# 263             Jesus  Manchester City        86           8.0            46
# 419          Benrahma         West Ham        65           9.0            50
# 260           Steffen  Manchester City        45           1.0             7
# 122            Alonso          Chelsea        58           6.0            39
# 246        N.Williams        Liverpool        39           1.0             4
# 33           Grealish  Manchester City        79           8.0            32
# 277         Fernandes   Manchester Utd       117           9.0            44
# 210         Tielemans   Leicester City        65           9.0            47
# 96             Mbeumo        Brentford        56           9.0            30
# 259           Laporte  Manchester City        55           7.0            38
# 262              Dias  Manchester City        62           9.0            42
# 482          Townsend          Everton        57           9.0            47
# 468              King          Watford        56           7.0            36
# 418        24.907306              2.4                  3.558187
# 483        24.286806              3.4                  3.469544
# 256        51.021536              5.7                  5.669060
# 229        38.790999              5.2                  4.310111
# 190        14.733889              4.0                  2.946778
# 83         30.797323              3.0                  3.421925
# 608              NaN              0.0                       NaN
# 562              NaN              0.0                       NaN
# 351        24.776680              2.4                  2.752964
# 87               NaN              0.0                       NaN
# 498              NaN              0.0                       NaN
# 569              NaN              0.0                       NaN
# 555        19.733396              4.0                  3.946679
# 224        26.815555              4.0                  3.830794
# 414        21.636306              1.9                  3.090901
# 184        19.332000              2.0                  2.148000
# 343        16.984453              3.2                  2.830742
# 169        33.660497              3.9                  3.740055
# 139              NaN              0.0                       NaN
# 243         6.904444              6.0                  3.452222
# 431        34.362427              3.0                  3.818047
# 429        30.662427              3.2                  3.406936
#
#      gameweek 10 prediction  valuePoints metric
# id
# 135                5.879055            2.486312
# 237                5.765970            2.478463
# 119                5.007898            1.742768
# 122                4.829319            2.055237
# 501                4.725876            2.388799
# 127                4.707460            1.638781
# 527                4.624109            2.012338
# 121                4.552093            1.536964
# 234                4.387340            1.548667
# 411                4.383200            1.882398
# 425                4.310079            1.811089
# 142                4.306898            1.836027
# 409                4.276570            1.649201
# 133                4.226923            1.522298
# 76                 4.204650            2.106975
# 91                 4.200086            2.012570
# 128                4.074715            1.418637
# 491                4.047567            1.628709
# 418                4.033476            1.624083
# 483                4.024671            1.635559
# 256                3.955867            2.240893
# 229                3.925936            1.677708
# 190                3.874356            1.389124
# 83                 3.846616            1.613111
# 608                3.775373                 NaN
# 562                3.775373                 NaN
# 351                3.686368            1.297760
# 87                 3.685054                 NaN
# 498                3.685054                 NaN
# 569                3.685054                 NaN
# 555                3.681537            1.682870
# 224                3.624580            1.713183
# 414                3.620028            1.396327
# 184                3.617012            1.012577
# 343                3.613985            1.349503
# 169                3.591614            1.672604
# 139                3.527889                 NaN
# 243                3.510787            1.528670
# 431                3.440660            1.707483
# 429                3.408108            1.606045

# %%
metric = 'xG'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game',\
                      'valuePoints metric', 'xG', 'xA', 'xG+xA', 'xG+xA per game']].head(numberToShow))
# Out:
#           web_name        team_name  now_cost  games played  points_per_game  \
# id
# 233          Salah        Liverpool       129           9.0             11.9
# 230           Mané        Liverpool       119           9.0              5.6
# 413        Antonio         West Ham        82           8.0              7.1
# 205          Vardy   Leicester City       108           9.0              6.3
# 240           Jota        Liverpool        75           8.0              5.4
# 96          Mbeumo        Brentford        56           9.0              3.3
# 177  Calvert-Lewin          Everton        80           3.0              7.7
# 228        Firmino        Liverpool        89           7.0              4.7
# 579        Ronaldo   Manchester Utd       125           6.0              4.2
# 529         Lukaku          Chelsea       115           7.0              4.4
# 189        Bamford     Leeds United        78           5.0              4.2
# 63          Maupay         Brighton        65           9.0              3.9
# 4       Aubameyang          Arsenal       100           8.0              4.6
# 109           Wood          Burnley        67           9.0              2.7
# 359            Son        Tottenham       102           8.0              6.6
# 468           King          Watford        56           7.0              5.1
# 138          Mount          Chelsea        75           7.0              5.9
# 517                  3.735066            1.592638  2.1  0.3    2.4
# 337                  3.518000            1.259646  2.1  0.4    2.5
# 357                  3.658875            1.051853  2.0  1.5    3.5
# 289                  4.012120            1.455349  2.0  1.2    3.2
# 583                  4.533333            1.898804  2.0  0.4    2.4
#
#      xG+xA per game
# id
# 233        1.111111
# 230        0.766667
# 413        0.937500
# 205        0.611111
# 240        0.812500
# 96         0.522222
# 177        1.300000
# 228        0.600000
# 579        0.600000
# 529        0.714286
# 189        0.720000
# 63         0.377778
# 4          0.475000
# 109        0.333333
# 359        0.487500
# 468        0.571429
# 138        0.685714
# 277        0.644444
# 265        0.760000
# 268        0.625000
# 196        0.500000
# 40         0.400000
# 263        0.512500
# 450        0.355556
# 78         0.566667
# 399        0.388889
# 149        0.344444
# 250        0.666667
# 154        0.437500
# 134        0.342857
# 315        0.255556
# 17         0.483333
# 419        0.366667
# 423        0.355556
# 296        0.440000
# 517        0.342857
# 337        0.277778
# 357        0.437500
# 289        0.355556
# 583        0.400000

# %% [markdown]
# ## Player Visualizations

# %%
game_weeks = np.arange(1,gameweek+1)
column_xPoints = []
column_xG = []
column_xA = []
column_xGA = []
for i in range(1,gameweek+1):
    column_xPoints.append('xPoints week ' + str(i))
    column_xG.append('xG_week' + str(i))
    column_xA.append('xA_week' + str(i))
    column_xGA.append('xGA_week' + str(i))

#display(game_weeks)
#display(column_xPoints)

# %%
# find player index
name_string = 'Antonio'
playersFound = df[df['web_name'].str.contains(name_string)]
display(playersFound)
# plot xPoints over time
ix = playersFound.index[0]
#ix = 468

fig,ax = plt.subplots(2,2,figsize=(15,10))

ax[0,0].plot(game_weeks, df.loc[ix,column_xPoints], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,0].set_title(title_string)
ax[0,0].set_xlabel('gameweek')
ax[0,0].set_ylabel('xPoints')
ax[0,0].set_xticks(game_weeks)

ax[0,1].plot(game_weeks, df.loc[ix,column_xG], marker='o')
ax[0,1].plot(game_weeks, df.loc[ix,column_xA], marker='o')
ax[0,1].legend(('xG','xA'))
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,1].set_title(title_string)
ax[0,1].set_xlabel('gameweek')
ax[0,1].set_ylabel('xG and xA')
ax[0,1].set_xticks(game_weeks)

ax[1,0].plot(game_weeks, df.loc[ix,column_xGA], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[1,0].set_title(title_string)
ax[1,0].set_xlabel('gameweek')
ax[1,0].set_ylabel('xGA')
ax[1,0].set_xticks(game_weeks)

plt.show()
# Out:
#      adjusted points  adjusted points per game  assists  assists_week1  \
# id
# 413           51.004                    6.3755        4            2.0
#
#      assists_week2  assists_week3  assists_week4  assists_week5  \
# id
# 413            1.0            1.0            0.0            NaN
#
#      assists_week6  assists_week7  assists_week8  assists_week9  bonus  \
# id
# 413            0.0            0.0            0.0            0.0     12
#
#      bonus_week1  bonus_week2  bonus_week3  bonus_week4  bonus_week5  \
# id
# 413          3.0          3.0          2.0          0.0          NaN
#
#      bonus_week6  bonus_week7  bonus_week8  bonus_week9  bps  \
# id
# 413          3.0          0.0          0.0          1.0  218
#
#      chance_of_playing_next_round  chance_of_playing_this_round  \
# id
# 413                         100.0                         100.0
#
#      clean_sheet_points  clean_sheets  cleansheet_week1  cleansheet_week2  \
# id
# 413                 0.0             3               0.0               0.0
#
#      cleansheet_week3  cleansheet_week4  cleansheet_week5  cleansheet_week6  \
# id
# 413               0.0               1.0               0.0               0.0
#
#      cleansheet_week7  cleansheet_week8  cleansheet_week9   code  \
# id
# 413               0.0               1.0               1.0  57531
#
#      corners_and_indirect_freekicks_order  \
# id
# 413                                   NaN
#
#      corners_and_indirect_freekicks_text  cost_change_event  \
# id
# 413                                  NaN                  1
#
#      cost_change_event_fall  cost_change_start  cost_change_start_fall  \
# id
# 413                      -1                  7                      -7
#
#      creativity  creativity_rank  creativity_rank_type  \
# id
# 413       260.0                9                     1
#
#      direct_freekicks_order  direct_freekicks_text  dreamteam_count  \
# id
# 413                     NaN                    NaN                3
#
#      element_type  ...  value_form  value_next10  value_season web_name   xA  \
# id                 ...
# 413             4  ...         0.4      8.270198           7.0  Antonio  2.6
#
#      xA_points  xA_week1  xA_week2  xA_week3  xA_week4  xA_week5  xA_week6  \
# id
# 413        7.8       0.1       0.6       0.5       0.0       NaN       0.6
#
#      xA_week7  xA_week8  xA_week9   xG  xG+xA  xG+xA per game  xGA_week1  \
# id
# 413       0.3       0.2       0.3  4.9    7.5          0.9375        1.4
#
#      xGA_week2  xGA_week3  xGA_week4  xGA_week5  xGA_week6  xGA_week7  \
# id
# 413        0.8        0.7        0.8        1.8        1.2        1.3
#
#      xGA_week8  xGA_week9  xG_points  xG_week1  xG_week2  xG_week3  xG_week4  \
# id
# 413        0.8        0.8      19.12       1.1       1.0       0.4       0.2
#
#      xG_week5  xG_week6  xG_week7  xG_week8  xG_week9  xPoints  \
# id
# 413       NaN       0.9       0.2       0.7       0.4      5.5
#
#      xPoints week 1  xPoints week 2  xPoints week 3  xPoints week 4  \
# id
# 413           9.242          11.571           7.871            -0.2
#
#      xPoints week 5  xPoints week 6  xPoints week 7  xPoints week 8  \
# id
# 413             NaN             9.4             3.7             4.4
#
#      xPoints week 9 xPoints_next10 yellow_cards  gameweek 19 prediction
# id
# 413             5.5       67.81562            2                6.876847
#
# [1 rows x 179 columns]

# %% [markdown]
# ## My team

# %%
session = requests.session()

# %%
filepath = Path('../../../access_control/FPL_access.txt')
with open(filepath) as file:
    text = file.read().splitlines()
    email = text[0]
    password = text[1]

# %%
url = 'https://users.premierleague.com/accounts/login/'

payload = {
'password': password,
'login': email,
'redirect_uri': 'https://fantasy.premierleague.com/a/login', 'app': 'plfpl-web'
}
session.post(url, data=payload)
# Out:
# <Response [200]>

# %%
response = session.get('https://fantasy.premierleague.com/api/my-team/3202682')
team = response.json()['picks']

# %%
my_player_ix = [player['element'] for player in team]
my_starting11 = my_player_ix[:-4]
my_subs = my_player_ix[-4:]

# %%
exp_avg = df.loc[my_starting11,'adjusted points per game'].sum() + \
                df.loc[my_starting11,'adjusted points per game'].max()
exp_next = df.loc[my_starting11, f'gameweek {gameweek+1} prediction'].sum() + \
                df.loc[my_starting11,f'gameweek {gameweek+1} prediction'].max()

print('STARTING 11')
print('Expected points on average: ' + str(exp_avg))
print('Predicted points next gameweek: ' + str(exp_next))
display(df.loc[my_starting11, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
           f'gameweek {gameweek+1} prediction','xPoints_next10', 'valuePoints metric']].head(numberToShow))
print('\nSUBSTITUTES')
display(df.loc[my_subs, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
         f'gameweek {gameweek+1} prediction', 'xPoints_next10', 'valuePoints metric']].head(numberToShow))
# Out:
# STARTING 11
# Expected points on average: 66.36824032401789
# Predicted points next gameweek: 59.24392008781433
#              web_name        team_name  now_cost  games played  \
# id
# 559          Ramsdale          Arsenal        46           6.0
# 256           Cancelo  Manchester City        64           9.0
# 237  Alexander-Arnold        Liverpool        76           7.0
# 249            Walker  Manchester City        56           7.0
# 491        Livramento      Southampton        44           9.0
# 196          Raphinha     Leeds United        67           8.0
# 233             Salah        Liverpool       129           9.0
# 419          Benrahma         West Ham        65           9.0
# 413           Antonio         West Ham        82           8.0
# 430           Jiménez           Wolves        76           9.0
# 205             Vardy   Leicester City       108           9.0
#
#      points_per_game  adjusted points per game    form 5   form 10  \
# id
# 559              4.8                  3.614444  4.242497  4.199804
# 256              5.7                  5.669060  4.968995  5.893569
# 237              7.3                  6.832651  5.162639  6.927156
# 249              4.0                  3.850107  3.925615  3.817018
# 491              4.0                  3.416409  4.197235  3.824800
# 196              4.0                  4.301694  4.956649  4.354637
# 233             11.9                  9.119556  9.400534  9.201079
# 419              5.6                  4.971043  4.547537  4.991280
# 413              7.1                  6.375500  5.750000  6.375500
# 430              3.6                  3.757000  4.502600  3.757000
# 205              6.3                  5.341222  6.240000  5.341222
#
#      gameweek 10 prediction  xPoints_next10  valuePoints metric
# id
# 559                3.472399       36.207765            1.685243
# 256                3.955867       42.671073            2.240893
# 237                5.765970       55.566423            2.478463
# 249                3.333971       33.062470            1.626967
# 491                4.047567       34.471865            1.628709
# 196                4.922253       38.601323            1.661890
# 233                6.543743       62.639530            2.539094
# 419                4.609010       42.359376            1.949803
# 413                7.166888       67.815620            2.226421
# 430                3.231748       37.558263            1.362807
# 205                5.027617       45.761318            1.625282
# SUBSTITUTES
#       web_name       team_name  now_cost  games played  points_per_game  \
# id
# 376     Foster         Watford        40           5.0              2.0
# 144  Gallagher  Crystal Palace        57           8.0              4.8
# 302  Manquillo   Newcastle Utd        40           6.0              3.2
# 115  Brownhill         Burnley        44           9.0              1.7
#
#      adjusted points per game    form 5   form 10  gameweek 10 prediction  \
# id
# 376                  2.625464  2.594277  2.594277                3.667463
# 144                  4.180818  2.811351  4.277577                3.247273
# 302                  2.549131  2.600889  2.807943                2.227013
# 115                  2.137564  2.506693  2.186679                2.387648
#
#      xPoints_next10  valuePoints metric
# id
# 376       37.505875            1.312732
# 144       38.774151            1.751152
# 302       27.786321            1.274565
# 115       24.441045            1.019044

# %% [markdown]
# ## Save data

# %%
# save data
filepath = '../data/fpl/data_week' + str(gameweek) + str('.csv')
df.to_csv(filepath)
