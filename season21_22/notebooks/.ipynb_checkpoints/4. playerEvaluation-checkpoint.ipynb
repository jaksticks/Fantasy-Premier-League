# %% [markdown]
# # Player evaluation
#
# Here we compare players based on their adjusted points. Also, we calculate some useful metrics using the adjusted points to further evaluate player performance in FPL.

# %%
# recent gameweek
gameweek = 16

# %%
# import basic libraries
import pandas as pd
import numpy as np
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.set_option('max_columns',100)

# %%
# fetch FPL data
filepath = '../data/fpl/data_week' + str(gameweek) + '.csv'
df = pd.read_csv(filepath, index_col=0)

# fetch team data
filepath = '../data/fbref/team_stats_week' + str(gameweek) + '.csv'
teamStats = pd.read_csv(filepath, index_col=0)

# fetch player stats data
filepath = '../data/fbref/player_stats_week' + str(gameweek) + '.csv'
playerStats = pd.read_csv(filepath, index_col=0, skiprows=1)

# %% [markdown]
# ## Value and value points
#
# Here we calculate two interesting metrics: 'value' and 'value points'.
#
# Value is simply adjusted points per game divided by the cost of the player. Essentially, this measures how many 'points per pound(/euro/whatever)' has the player gained on an average game week.
#
# The value points is calculated as the geometric mean of a players adjusted points per game and value. Essentially, in FPL we want to gain the maximum possible amount of points. However, we are restrained by a limited budget, so that in practice we cannot just pick all the best players. Then, we would like to have a squad of players that give the most points given our budget. Thus, we would like to pick players that have high value ('bang for buck'). However, often the players with highest value are very cheap players who somewhat overperform relative to their price. Picking a squad full of these players might leave a part of our budget unused. Calculating the geometric mean of adjusted points and value allows us to weigh both aspects equally, i.e. we want players that both gain a lot of points but also have good value. For example, this metric values equally two players, where one has twice the points per game of the other who in turn has twice the value of the other.

# %%
# value = expected points / cost
df['value'] = df['adjusted points per game'] / (df['now_cost'] / 10.0)
df['value form 5'] = df['form 5'] / (df['now_cost'] / 10.0)
df['value form 10'] = df['form 10'] / (df['now_cost'] / 10.0)
# geometric mean of 'adjusted points per game' and 'value'
df['valuePoints metric'] = np.sqrt(df['adjusted points per game'] * df['value'])

# %%
df['value_next10']  = df['xPoints_next10'] / (df['now_cost'] / 10.0)

# %%
df['xG+xA'] = df['xG'] + df['xA']
df['xG+xA per game'] = df['xG+xA'] / df['games played']

# %%
goalkeepers = df['element_type'] == 1
defenders = df['element_type'] == 2
midfielders = df['element_type'] == 3
forwards = df['element_type'] == 4

minGames = df['games played'] >= 3

# %% [markdown]
# ## Player evaluation
#
# Below we compile lists for each position sorting players based on a given metric.
#
# Notice that 'next1_xP' is currently based on preseason expectations on average player performance!

# %%
metric = 'valuePoints metric'
#metric = 'adjusted points per game'
#metric = 'next1_xP'

numberToShow = 40

print('GOALKEEPERS')
display(df[goalkeepers & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10', 'valuePoints metric']].head(20))
print('DEFENDERS')
display(df[defenders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('MIDFIELDERS')
display(df[midfielders & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
print('FORWARDS')
display(df[forwards & minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 5',\
                                                  'xPoints_next10','valuePoints metric']].head(numberToShow))
# Out:
# GOALKEEPERS
#        web_name        team_name  now_cost  games played  total_points  \
# id
# 376      Foster          Watford        41           8.0            28
# 475          Sá           Wolves        51          16.0            71
# 559    Ramsdale          Arsenal        50          13.0            70
# 353      Lloris        Tottenham        54          14.0            63
# 146      Guaita   Crystal Palace        46          16.0            54
# 270      de Gea   Manchester Utd        51          16.0            66
# 80         Raya        Brentford        44           9.0            34
# 556   Fernández        Brentford        45           7.0            21
# 257     Ederson  Manchester City        60          15.0            62
# 30     Martínez      Aston Villa        55          15.0            60
# 231     Alisson        Liverpool        60          15.0            72
# 143       Mendy          Chelsea        63          15.0            68
# 408   Fabianski         West Ham        50          16.0            53
# 69      Sánchez         Brighton        46          14.0            50
# 334    McCarthy      Southampton        45          15.0            53
# 294      Darlow    Newcastle Utd        45           8.0            20
# 112        Pope          Burnley        54          15.0            47
# 513     Woodman    Newcastle Utd        44           4.0             9
# 200  Schmeichel   Leicester City        49          16.0            44
# 314        Krul     Norwich City        45          16.0            47
#
#      adjusted points  points_per_game  adjusted points per game    form 5  \
# id
# 376        30.652314              3.5                  3.831539  3.732196
# 475        67.551914              4.4                  4.221995  5.118807
# 559        53.245789              5.4                  4.095830  4.730398
# 353        57.609561              4.5                  4.114969  4.700781
# 146        60.117808              3.4                  3.757363  3.682772
# 270        62.921377              4.1                  3.932586  4.805630
# 80         32.842992              3.8                  3.649221       NaN
# 556        25.433438              3.0                  3.633348  4.134610
# 257        61.519127              4.1                  4.101275  4.887478
# 30         58.520981              4.0                  3.901399  3.893391
# 231        59.941050              4.8                  3.996070  5.145640
# 143        61.127903              4.5                  4.075194  3.771252
# 408        58.039110              3.3                  3.627444  3.653744
# 69         47.405516              3.6                  3.386108  4.783475
# 334        48.361196              3.5                  3.224080  2.564371
# 294        25.701538              2.5                  3.212692  3.195247
# 112        49.258261              3.1                  3.283884  4.483228
# 513        11.850769              2.2                  2.962692       NaN
# 200        49.083908              2.8                  3.067744  2.641444
# 314        46.618900              2.9                  2.913681  3.623040
#
#      xPoints_next10  valuePoints metric
# id
# 376       38.003808            1.892262
# 475       39.784678            1.869531
# 559       35.909127            1.831711
# 353       38.755906            1.770801
# 146       39.707183            1.751880
# 270       42.349780            1.741378
# 80        37.487626            1.739698
# 556       39.193296            1.712777
# 257       41.007106            1.674339
# 30        40.924926            1.663562
# 231       38.665392            1.631389
# 143       33.210503            1.623596
# 408       43.782034            1.622242
# 69        35.279629            1.578781
# 334       38.520441            1.519846
# 294       35.111698            1.514478
# 112       37.168440            1.413159
# 513       38.093735            1.412408
# 200       37.577988            1.385866
# 314       40.540854            1.373523
# DEFENDERS
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 135          Chilwell          Chelsea        57           6.0            54
# 237  Alexander-Arnold        Liverpool        81          14.0           108
# 256           Cancelo  Manchester City        68          16.0            91
# 245          Tsimikas        Liverpool        38           6.0            30
# 364            Davies        Tottenham        44           6.0            29
# 147           Tomkins   Crystal Palace        43           5.0            16
# 142             James          Chelsea        63          12.0            76
# 370          Reguilón        Tottenham        53          13.0            62
# 258               Aké  Manchester City        47           5.0            17
# 249            Walker  Manchester City        55          12.0            51
# 122            Alonso          Chelsea        57          10.0            47
# 259           Laporte  Manchester City        55          12.0            50
# 527          Chalobah          Chelsea        47           9.0            53
# 252            Stones  Manchester City        53           4.0            19
# 262              Dias  Manchester City        60          15.0            67
# 224             Matip        Liverpool        49          12.0            50
# 119       Azpilicueta          Chelsea        57          10.0            46
# 411         Cresswell         West Ham        54          13.0            52
# 127           Rüdiger          Chelsea        61          15.0            81
# 76            Jansson        Brentford        46          16.0            59
# 264         Zinchenko  Manchester City        53           4.0            10
# 361              Dier        Tottenham        45          14.0            54
# 16            Tierney          Arsenal        47          10.0            48
# 91            Pinnock        Brentford        46          15.0            52
# 470         Ait Nouri           Wolves        43           9.0            41
# 477             Guéhi   Crystal Palace        45          16.0            54
# 234         Robertson        Liverpool        70          12.0            58
# 229          van Dijk        Liverpool        67          16.0            83
# 367           Sánchez        Tottenham        45           8.0            40
# 432            Marçal           Wolves        42           8.0            29
# 121      Thiago Silva          Chelsea        56          13.0            63
# 417           Masuaku         West Ham        44           5.0            20
# 584         Cucurella         Brighton        50          12.0            45
# 437            Semedo           Wolves        48          15.0            50
# 71            Lamptey         Brighton        45           8.0            24
# 150           Kouyaté   Crystal Palace        45          14.0            44
# 343          Bednarek      Southampton        44          12.0            45
# 59               Dunk         Brighton        49          14.0            50
# 83              Henry        Brentford        45          16.0            54
# 555            Varane   Manchester Utd        55           6.0            26
#
#      adjusted points  points_per_game  adjusted points per game    form 5  \
# id
# 135        36.122161              9.0                  6.020360  9.352280
# 237       100.341980              7.7                  7.167284  8.908240
# 256        95.775402              5.7                  5.985963  6.461678
# 245        25.547420              5.0                  4.257903  5.863273
# 364        27.374669              4.8                  4.562445  7.314781
# 147        20.511815              3.2                  4.102363  4.670594
# 142        59.586322              6.3                  4.965527  4.338936
# 370        59.000449              4.8                  4.538496  7.255252
# 258        20.706376              3.4                  4.141275  2.313139
# 249        53.286301              4.2                  4.440525  5.935729
# 122        45.127268              4.7                  4.512727  3.411495
# 259        52.915301              4.2                  4.409608  5.902778
# 527        36.676742              5.9                  4.075194  3.222540
# 252        17.205100              4.8                  4.301275  5.274923
# 262        67.390127              4.5                  4.492675  4.690616
# 224        47.752840              4.2                  3.979403  5.324179
# 119        42.798268              4.6                  4.279827  3.678953
# 411        53.236277              4.0                  4.095098  3.173059
# 127        65.040903              5.4                  4.336060  4.879652
# 76         59.789430              3.7                  3.736839  3.434610
# 264        15.905100              2.5                  3.976275  5.200601
# 361        51.180561              3.9                  3.655754  4.991114
# 16         36.992607              4.8                  3.699261  7.904382
# 91         54.842653              3.5                  3.656177  2.611732
# 470        31.416514              4.6                  3.490724  4.338807
# 477        57.117808              3.4                  3.569863  4.042772
# 234        53.236840              4.8                  4.436403  6.369482
# 229        69.008120              5.2                  4.313008  5.305640
# 367        28.276892              5.0                  3.534611  4.023620
# 432        27.282457              3.6                  3.410307       NaN
# 121        50.381849              4.8                  3.875527  3.991149
# 417        17.174722              4.0                  3.434944  3.031921
# 584        43.690442              3.8                  3.640870  4.261418
# 437        53.475857              3.3                  3.565057  4.258807
# 71         27.531295              3.0                  3.441412  4.281038
# 150        47.824082              3.1                  3.416006  3.856972
# 343        40.388956              3.8                  3.365746  3.170589
# 59         49.205516              3.6                  3.514680  3.586428
# 83         53.676430              3.4                  3.354777  3.074610
# 555        22.116516              4.3                  3.686086       NaN
#
#      xPoints_next10  valuePoints metric
# id
# 135       37.615112            2.521651
# 237       48.274954            2.518327
# 256       40.286220            2.295512
# 245       32.318579            2.184258
# 364       29.706649            2.175060
# 147       33.077877            1.978335
# 142       32.128691            1.978313
# 370       35.140882            1.971397
# 258       33.259159            1.910228
# 249       40.200370            1.893446
# 122       31.054656            1.890173
# 259       37.730701            1.880263
# 527       31.892108            1.879747
# 252       31.304861            1.868355
# 262       39.194478            1.834127
# 224       32.491624            1.797711
# 119       32.098838            1.792622
# 411       42.756944            1.762250
# 127       32.500399            1.755619
# 76        35.153604            1.742310
# 264       30.651855            1.727184
# 361       34.376101            1.723339
# 16        31.217588            1.706342
# 91        34.169947            1.704701
# 470       29.109986            1.683376
# 477       37.000766            1.682850
# 234       39.948493            1.676803
# 229       38.989598            1.666260
# 367       31.701312            1.666232
# 432       30.444762            1.664059
# 121       32.081385            1.637709
# 417       36.787059            1.637545
# 584       31.100471            1.628247
# 437       33.696430            1.627218
# 71        28.842422            1.622297
# 150       33.675416            1.610321
# 343       32.352785            1.604557
# 59        32.677227            1.587770
# 83        31.536004            1.581457
# 555       34.757947            1.571752
# MIDFIELDERS
#         web_name        team_name  now_cost  games played  total_points  \
# id
# 268       Torres  Manchester City        67           4.0            26
# 233        Salah        Liverpool       131          16.0           160
# 250     Gündogan  Manchester City        73          11.0            55
# 265        Foden  Manchester City        80          10.0            49
# 240         Jota        Liverpool        80          15.0            80
# 210    Tielemans   Leicester City        64          12.0            67
# 144    Gallagher   Crystal Palace        61          15.0            87
# 266      Rodrigo  Manchester City        55          12.0            45
# 125      Kovacic          Chelsea        50           9.0            46
# 96        Mbeumo        Brentford        55          15.0            52
# 420        Bowen         West Ham        65          16.0            74
# 196     Raphinha     Leeds United        66          14.0            73
# 138        Mount          Chelsea        76          13.0            77
# 261     Bernardo  Manchester City        77          15.0            90
# 399         Sarr          Watford        58          12.0            53
# 173     Doucouré          Everton        54          12.0            55
# 359          Son        Tottenham       103          13.0            81
# 33      Grealish  Manchester City        76          12.0            41
# 123     Jorginho          Chelsea        58          14.0            60
# 64      Trossard         Brighton        64          15.0            60
# 336      Redmond      Southampton        59          13.0            43
# 230         Mané        Liverpool       119          16.0            82
# 222    Henderson        Liverpool        51          15.0            61
# 482     Townsend          Everton        53          16.0            60
# 419     Benrahma         West Ham        60          16.0            67
# 244        Jones        Liverpool        50           5.0            21
# 21    Smith Rowe          Arsenal        60          14.0            69
# 140  Hudson-Odoi          Chelsea        53           9.0            28
# 212     Maddison   Leicester City        68          16.0            69
# 154         Zaha   Crystal Palace        69          15.0            56
# 239        Keita        Liverpool        50           7.0            30
# 423      Fornals         West Ham        60          16.0            62
# 422       Soucek         West Ham        57          16.0            53
# 365     Højbjerg        Tottenham        50          14.0            52
# 131       Ziyech          Chelsea        73           8.0            24
# 484         Gray          Everton        56          16.0            66
# 22          Saka          Arsenal        62          16.0            58
# 506      Elliott        Liverpool        53           4.0             9
# 287        James     Leeds United        60          13.0            42
# 289    Greenwood   Manchester Utd        72          12.0            51
#
#      adjusted points  points_per_game  adjusted points per game     form 5  \
# id
# 268        25.372275              6.5                  6.343069        NaN
# 233       132.834280             10.0                  8.302143   8.524810
# 250        62.720507              5.0                  5.701864   6.244012
# 265        59.666188              4.9                  5.966619   6.022528
# 240        88.556263              5.3                  5.903751   7.708246
# 210        60.715233              5.6                  5.059603  11.048812
# 144        74.038861              5.8                  4.935924   4.364893
# 266        55.323825              3.2                  4.610319   3.591869
# 125        37.924185              5.1                  4.213798        NaN
# 96         66.008913              3.5                  4.400594   4.387852
# 420        76.456777              4.6                  4.778549   4.120569
# 196        66.116556              5.2                  4.722611   5.066974
# 138        64.952712              5.9                  4.996362   5.041896
# 261        72.992782              6.0                  4.866185   6.546069
# 399        49.837993              4.4                  4.153166   4.965299
# 173        47.341102              4.6                  3.945092   3.045489
# 359        69.784862              6.2                  5.368066   5.982195
# 33         55.145825              3.4                  4.595485   4.305105
# 123        54.980844              4.3                  3.927203   6.849046
# 64         61.431763              4.0                  4.095451   3.221605
# 336        50.912259              3.3                  3.916328   3.447364
# 230        88.326280              5.1                  5.520393   5.010610
# 222        54.198263              4.1                  3.613218   3.502446
# 482        58.810135              3.8                  3.675633   2.462243
# 419        61.272777              4.2                  3.829549   2.019795
# 244        17.366088              4.2                  3.473218        NaN
# 21         53.069712              4.9                  3.790694   3.232102
# 140        31.940185              3.1                  3.548909   2.816726
# 212        63.054977              4.3                  3.940936   6.289017
# 154        58.594861              3.7                  3.906324   3.130693
# 239        22.964123              4.3                  3.280589        NaN
# 423        57.372777              3.9                  3.585799   2.101506
# 422        54.930777              3.3                  3.433174   3.473436
# 365        44.948390              3.7                  3.210599   4.825195
# 131        30.959054              3.0                  3.869882   4.555317
# 484        53.961135              4.1                  3.372571   1.896153
# 22         56.444243              3.6                  3.527765   3.743740
# 506        12.996070              2.2                  3.249018        NaN
# 287        44.854302              2.8                  3.450331   3.843493
# 289        44.864758              4.2                  3.738730   1.785500
#
#      xPoints_next10  valuePoints metric
# id
# 268       35.819705            2.450541
# 233       54.940486            2.293795
# 250       39.713968            2.110355
# 265       45.942707            2.109518
# 240       50.670831            2.087291
# 210       42.095698            1.999984
# 144       40.915633            1.998497
# 266       39.172815            1.965847
# 125       31.550831            1.884468
# 96        34.161221            1.876420
# 420       44.154835            1.874301
# 196       38.688583            1.838274
# 138       33.981074            1.812371
# 261       40.629942            1.753652
# 399       38.068590            1.724508
# 173       39.742534            1.697697
# 359       40.968368            1.672628
# 33        34.387363            1.666958
# 123       32.654526            1.630682
# 64        35.307757            1.618869
# 336       34.607944            1.612327
# 230       42.378095            1.600282
# 222       37.742824            1.599960
# 482       37.981031            1.596593
# 419       41.671530            1.563407
# 244       37.265110            1.553270
# 21        34.780982            1.547544
# 140       26.864357            1.541548
# 212       38.382234            1.511280
# 154       37.023456            1.487112
# 239       36.727052            1.467124
# 423       41.960484            1.463896
# 422       40.415861            1.437998
# 365       32.291463            1.435824
# 131       27.406702            1.432307
# 484       37.298172            1.425171
# 22        33.783728            1.416785
# 506       30.408165            1.411283
# 287       30.645131            1.408592
# 289       39.659360            1.393342
# FORWARDS
#           web_name        team_name  now_cost  games played  total_points  \
# id
# 177  Calvert-Lewin          Everton        79           3.0            23
# 450         Dennis          Watford        58          15.0            84
# 468           King          Watford        58          14.0            56
# 413        Antonio         West Ham        79          15.0            73
# 189        Bamford     Leeds United        77           6.0            25
# 78           Toney        Brentford        66          14.0            55
# 263          Jesus  Manchester City        86          14.0            60
# 315          Pukki     Norwich City        59          16.0            58
# 296         Wilson    Newcastle Utd        75          12.0            55
# 63          Maupay         Brighton        63          14.0            55
# 228        Firmino        Liverpool        87           8.0            35
# 579        Ronaldo   Manchester Utd       125          13.0            67
# 525    A.Armstrong      Southampton        59          15.0            47
# 307  Saint-Maximin    Newcastle Utd        68          16.0            62
# 345          Adams      Southampton        68          12.0            47
# 583          Hwang           Wolves        56          13.0            46
# 205          Vardy   Leicester City       106          15.0            77
# 235          Origi        Liverpool        48           3.0            14
# 187        Rodrigo     Leeds United        63          12.0            29
# 455           Daka   Leicester City        71           7.0            28
# 149        Benteke   Crystal Palace        64          16.0            48
# 518          Broja      Southampton        51          12.0            35
# 577       Gelhardt     Leeds United        45           4.0            13
# 40         Watkins      Aston Villa        76          14.0            49
# 180    Richarlison          Everton        74          11.0            39
# 430        Jiménez           Wolves        76          16.0            54
# 447        Welbeck         Brighton        59           4.0            14
# 109           Wood          Burnley        67          15.0            42
# 337           Ings      Aston Villa        77          11.0            42
# 4       Aubameyang          Arsenal        96          14.0            44
# 529         Lukaku          Chelsea       115          11.0            35
# 134         Werner          Chelsea        86           9.0            22
# 357           Kane        Tottenham       121          13.0            33
# 153           Ayew   Crystal Palace        58          15.0            30
# 472          Cucho          Watford        50          12.0            29
# 310      Joelinton    Newcastle Utd        58          15.0            33
# 269         Cavani   Manchester Utd        84           5.0            12
# 591         Rondón          Everton        60          11.0            21
# 516        Sargent     Norwich City        54          15.0            24
# 213      Iheanacho   Leicester City        69          12.0            28
#
#      adjusted points  points_per_game  adjusted points per game    form 5  \
# id
# 177           25.540              7.7                  8.513333       NaN
# 450           63.326              5.6                  4.221733  6.002600
# 468           58.033              4.0                  4.145214  3.600000
# 413           70.375              4.9                  4.691667  2.634200
# 189           27.542              4.2                  4.590333  2.000000
# 78            58.782              3.9                  4.198714  4.833333
# 263           63.326              4.3                  4.523286  3.242750
# 315           58.440              3.6                  3.652500  4.180000
# 296           48.920              4.6                  4.076667  4.860000
# 63            52.120              3.9                  3.722857  5.100000
# 228           34.771              4.4                  4.346375       NaN
# 579           66.882              5.2                  5.144769  6.374200
# 525           52.613              3.1                  3.507533  2.794200
# 307           59.884              3.9                  3.742750  3.014200
# 345           44.342              3.9                  3.695167  4.325000
# 583           41.800              3.5                  3.215385  1.820000
# 205           66.071              5.1                  4.404733  3.425000
# 235            8.800              4.7                  2.933333  6.000000
# 187           40.320              2.4                  3.360000  3.150000
# 455           24.813              4.0                  3.544714  4.247333
# 149           53.071              3.0                  3.316937  4.020000
# 518           35.400              2.9                  2.950000  2.720000
# 577           11.071              3.2                  2.767750  3.150000
# 40            49.571              3.5                  3.540786  3.920000
# 180           37.542              3.5                  3.412909  3.467750
# 430           53.313              3.4                  3.332063  1.940000
# 447           11.600              3.5                  2.900000       NaN
# 109           45.800              2.8                  3.053333  2.000000
# 337           35.662              3.8                  3.242000  2.000000
# 4             50.411              3.1                  3.600786  3.100000
# 529           41.500              3.2                  3.772727  1.100000
# 134           29.171              2.4                  3.241222  3.800000
# 357           48.871              2.5                  3.759308  4.766667
# 153           37.042              2.0                  2.469467  2.854200
# 472           25.971              2.4                  2.164250  2.850000
# 310           34.371              2.2                  2.291400  3.160000
# 269           13.600              2.4                  2.720000       NaN
# 591           25.000              1.9                  2.272727  2.850000
# 516           32.200              1.6                  2.146667  2.520000
# 213           28.642              2.3                  2.386833  1.000000
#
#      xPoints_next10  valuePoints metric
# id
# 177       40.268286            3.028908
# 450       41.437289            1.752979
# 468       39.049525            1.721207
# 413       49.996160            1.669220
# 189       38.845552            1.654241
# 78        36.708347            1.634347
# 263       36.540614            1.542428
# 315       34.484815            1.503710
# 296       34.674300            1.488588
# 63        35.186965            1.483222
# 228       50.328520            1.473559
# 579       46.373477            1.455160
# 525       35.082436            1.444029
# 307       34.857769            1.435279
# 345       36.242331            1.417032
# 583       32.799931            1.358748
# 205       39.866637            1.352903
# 235       25.611477            1.338877
# 187       31.418607            1.338656
# 455       36.803081            1.330308
# 149       36.070693            1.311135
# 518       30.042709            1.306282
# 577       27.930619            1.304730
# 40        38.480844            1.284378
# 180       31.466344            1.254610
# 430       32.996814            1.208666
# 447       22.854406            1.193911
# 109       31.977102            1.179606
# 337       35.296190            1.168336
# 4         32.832950            1.162149
# 529       30.110886            1.112517
# 134       29.115686            1.105248
# 357       34.506883            1.080725
# 153       27.842312            1.025390
# 472       23.009848            0.967882
# 310       22.436647            0.951452
# 269       28.966342            0.938489
# 591       26.223232            0.927837
# 516       23.908761            0.923778
# 213       25.034354            0.908652

# %% [markdown]
# Below we compile a list sorting players based on a given metric (irrespective of position).

# %%
metric = 'adjusted points per game'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 177     Calvert-Lewin          Everton        79           3.0            23
# 233             Salah        Liverpool       131          16.0           160
# 237  Alexander-Arnold        Liverpool        81          14.0           108
# 268            Torres  Manchester City        67           4.0            26
# 135          Chilwell          Chelsea        57           6.0            54
# 253             Mendy  Manchester City        53           1.0             3
# 256           Cancelo  Manchester City        68          16.0            91
# 265             Foden  Manchester City        80          10.0            49
# 240              Jota        Liverpool        80          15.0            80
# 250          Gündogan  Manchester City        73          11.0            55
# 230              Mané        Liverpool       119          16.0            82
# 501              Sarr          Chelsea        49           1.0             8
# 359               Son        Tottenham       103          13.0            81
# 246        N.Williams        Liverpool        39           1.0             4
# 579           Ronaldo   Manchester Utd       125          13.0            67
# 260           Steffen  Manchester City        45           1.0             7
# 210         Tielemans   Leicester City        64          12.0            67
# 138             Mount          Chelsea        76          13.0            77
# 142             James          Chelsea        63          12.0            76
# 144         Gallagher   Crystal Palace        61          15.0            87
# 261          Bernardo  Manchester City        77          15.0            90
# 420             Bowen         West Ham        65          16.0            74
# 196          Raphinha     Leeds United        66          14.0            73
# 413           Antonio         West Ham        79          15.0            73
# 266           Rodrigo  Manchester City        55          12.0            45
# 33           Grealish  Manchester City        76          12.0            41
# 189           Bamford     Leeds United        77           6.0            25
# 364            Davies        Tottenham        44           6.0            29
# 370          Reguilón        Tottenham        53          13.0            62
# 263             Jesus  Manchester City        86          14.0            60
# 122            Alonso          Chelsea        57          10.0            47
# 255          Sterling  Manchester City       106          14.0            53
# 262              Dias  Manchester City        60          15.0            67
# 249            Walker  Manchester City        55          12.0            51
# 234         Robertson        Liverpool        70          12.0            58
# 259           Laporte  Manchester City        55          12.0            50
# 205             Vardy   Leicester City       106          15.0            77
# 96             Mbeumo        Brentford        55          15.0            52
# 228           Firmino        Liverpool        87           8.0            35
# 127           Rüdiger          Chelsea        61          15.0            81
#
#      adjusted points  points_per_game  adjusted points per game  \
# id
# 177        25.540000              7.7                  8.513333
# 233       132.834280             10.0                  8.302143
# 237       100.341980              7.7                  7.167284
# 268        25.372275              6.5                  6.343069
# 135        36.122161              9.0                  6.020360
# 253         6.001275              3.0                  6.001275
# 256        95.775402              5.7                  5.985963
# 265        59.666188              4.9                  5.966619
# 240        88.556263              5.3                  5.903751
# 250        62.720507              5.0                  5.701864
# 230        88.326280              5.1                  5.520393
# 501         5.408527              8.0                  5.408527
# 359        69.784862              6.2                  5.368066
# 246         5.167070              4.0                  5.167070
# 579        66.882000              5.2                  5.144769
# 260         5.101275              7.0                  5.101275
# 210        60.715233              5.6                  5.059603
# 138        64.952712              5.9                  4.996362
# 142        59.586322              6.3                  4.965527
# 144        74.038861              5.8                  4.935924
# 261        72.992782              6.0                  4.866185
# 420        76.456777              4.6                  4.778549
# 196        66.116556              5.2                  4.722611
# 413        70.375000              4.9                  4.691667
# 266        55.323825              3.2                  4.610319
# 33         55.145825              3.4                  4.595485
# 189        27.542000              4.2                  4.590333
# 364        27.374669              4.8                  4.562445
# 370        59.000449              4.8                  4.538496
# 263        63.326000              4.3                  4.523286
# 122        45.127268              4.7                  4.512727
# 255        62.945463              3.8                  4.496104
# 262        67.390127              4.5                  4.492675
# 249        53.286301              4.2                  4.440525
# 234        53.236840              4.8                  4.436403
# 259        52.915301              4.2                  4.409608
# 205        66.071000              5.1                  4.404733
# 96         66.008913              3.5                  4.400594
# 228        34.771000              4.4                  4.346375
# 127        65.040903              5.4                  4.336060
#
#      xPoints_next10  valuePoints metric
# id
# 177       40.268286            3.028908
# 233       54.940486            2.293795
# 237       48.274954            2.518327
# 268       35.819705            2.450541
# 135       37.615112            2.521651
# 253       35.243668            2.606787
# 256       40.286220            2.295512
# 265       45.942707            2.109518
# 240       50.670831            2.087291
# 250       39.713968            2.110355
# 230       42.378095            1.600282
# 501       32.952399            2.443323
# 359       40.968368            1.672628
# 246       33.132291            2.616448
# 579       46.373477            1.455160
# 260       34.865244            2.404764
# 210       42.095698            1.999984
# 138       33.981074            1.812371
# 142       32.128691            1.978313
# 144       40.915633            1.998497
# 261       40.629942            1.753652
# 420       44.154835            1.874301
# 196       38.688583            1.838274
# 413       49.996160            1.669220
# 266       39.172815            1.965847
# 33        34.387363            1.666958
# 189       38.845552            1.654241
# 364       29.706649            2.175060
# 370       35.140882            1.971397
# 263       36.540614            1.542428
# 122       31.054656            1.890173
# 255       31.997736            1.380968
# 262       39.194478            1.834127
# 249       40.200370            1.893446
# 234       39.948493            1.676803
# 259       37.730701            1.880263
# 205       39.866637            1.352903
# 96        34.161221            1.876420
# 228       50.328520            1.473559
# 127       32.500399            1.755619

# %%
metric = 'valuePoints metric'

display(df[minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','xPoints_next10',\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  \
# id
# 177     Calvert-Lewin          Everton        79           3.0
# 135          Chilwell          Chelsea        57           6.0
# 237  Alexander-Arnold        Liverpool        81          14.0
# 268            Torres  Manchester City        67           4.0
# 256           Cancelo  Manchester City        68          16.0
# 233             Salah        Liverpool       131          16.0
# 245          Tsimikas        Liverpool        38           6.0
# 364            Davies        Tottenham        44           6.0
# 250          Gündogan  Manchester City        73          11.0
# 265             Foden  Manchester City        80          10.0
# 240              Jota        Liverpool        80          15.0
# 210         Tielemans   Leicester City        64          12.0
# 144         Gallagher   Crystal Palace        61          15.0
# 147           Tomkins   Crystal Palace        43           5.0
# 142             James          Chelsea        63          12.0
# 370          Reguilón        Tottenham        53          13.0
# 266           Rodrigo  Manchester City        55          12.0
# 258               Aké  Manchester City        47           5.0
# 249            Walker  Manchester City        55          12.0
# 376            Foster          Watford        41           8.0
# 122            Alonso          Chelsea        57          10.0
# 125           Kovacic          Chelsea        50           9.0
# 259           Laporte  Manchester City        55          12.0
# 527          Chalobah          Chelsea        47           9.0
# 96             Mbeumo        Brentford        55          15.0
# 420             Bowen         West Ham        65          16.0
# 475                Sá           Wolves        51          16.0
# 252            Stones  Manchester City        53           4.0
# 196          Raphinha     Leeds United        66          14.0
# 262              Dias  Manchester City        60          15.0
# 559          Ramsdale          Arsenal        50          13.0
# 138             Mount          Chelsea        76          13.0
# 224             Matip        Liverpool        49          12.0
# 119       Azpilicueta          Chelsea        57          10.0
# 353            Lloris        Tottenham        54          14.0
# 411         Cresswell         West Ham        54          13.0
# 127           Rüdiger          Chelsea        61          15.0
# 261          Bernardo  Manchester City        77          15.0
# 450            Dennis          Watford        58          15.0
# 146            Guaita   Crystal Palace        46          16.0
#
#      points_per_game  adjusted points per game     form 5  xPoints_next10  \
# id
# 177              7.7                  8.513333        NaN       40.268286
# 135              9.0                  6.020360   9.352280       37.615112
# 237              7.7                  7.167284   8.908240       48.274954
# 268              6.5                  6.343069        NaN       35.819705
# 256              5.7                  5.985963   6.461678       40.286220
# 233             10.0                  8.302143   8.524810       54.940486
# 245              5.0                  4.257903   5.863273       32.318579
# 364              4.8                  4.562445   7.314781       29.706649
# 250              5.0                  5.701864   6.244012       39.713968
# 265              4.9                  5.966619   6.022528       45.942707
# 240              5.3                  5.903751   7.708246       50.670831
# 210              5.6                  5.059603  11.048812       42.095698
# 144              5.8                  4.935924   4.364893       40.915633
# 147              3.2                  4.102363   4.670594       33.077877
# 142              6.3                  4.965527   4.338936       32.128691
# 370              4.8                  4.538496   7.255252       35.140882
# 266              3.2                  4.610319   3.591869       39.172815
# 258              3.4                  4.141275   2.313139       33.259159
# 249              4.2                  4.440525   5.935729       40.200370
# 376              3.5                  3.831539   3.732196       38.003808
# 122              4.7                  4.512727   3.411495       31.054656
# 125              5.1                  4.213798        NaN       31.550831
# 259              4.2                  4.409608   5.902778       37.730701
# 527              5.9                  4.075194   3.222540       31.892108
# 96               3.5                  4.400594   4.387852       34.161221
# 420              4.6                  4.778549   4.120569       44.154835
# 475              4.4                  4.221995   5.118807       39.784678
# 252              4.8                  4.301275   5.274923       31.304861
# 196              5.2                  4.722611   5.066974       38.688583
# 262              4.5                  4.492675   4.690616       39.194478
# 559              5.4                  4.095830   4.730398       35.909127
# 138              5.9                  4.996362   5.041896       33.981074
# 224              4.2                  3.979403   5.324179       32.491624
# 119              4.6                  4.279827   3.678953       32.098838
# 353              4.5                  4.114969   4.700781       38.755906
# 411              4.0                  4.095098   3.173059       42.756944
# 127              5.4                  4.336060   4.879652       32.500399
# 261              6.0                  4.866185   6.546069       40.629942
# 450              5.6                  4.221733   6.002600       41.437289
# 146              3.4                  3.757363   3.682772       39.707183
#
#      valuePoints metric
# id
# 177            3.028908
# 135            2.521651
# 237            2.518327
# 268            2.450541
# 256            2.295512
# 233            2.293795
# 245            2.184258
# 364            2.175060
# 250            2.110355
# 265            2.109518
# 240            2.087291
# 210            1.999984
# 144            1.998497
# 147            1.978335
# 142            1.978313
# 370            1.971397
# 266            1.965847
# 258            1.910228
# 249            1.893446
# 376            1.892262
# 122            1.890173
# 125            1.884468
# 259            1.880263
# 527            1.879747
# 96             1.876420
# 420            1.874301
# 475            1.869531
# 252            1.868355
# 196            1.838274
# 262            1.834127
# 559            1.831711
# 138            1.812371
# 224            1.797711
# 119            1.792622
# 353            1.770801
# 411            1.762250
# 127            1.755619
# 261            1.753652
# 450            1.752979
# 146            1.751880

# %%
metric = 'adjusted points per game'

display(df[minGames].sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game', 'form 10',\
                                                        'xPoints_next10','valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 177     Calvert-Lewin          Everton        79           3.0            23
# 233             Salah        Liverpool       131          16.0           160
# 237  Alexander-Arnold        Liverpool        81          14.0           108
# 268            Torres  Manchester City        67           4.0            26
# 135          Chilwell          Chelsea        57           6.0            54
# 256           Cancelo  Manchester City        68          16.0            91
# 265             Foden  Manchester City        80          10.0            49
# 240              Jota        Liverpool        80          15.0            80
# 250          Gündogan  Manchester City        73          11.0            55
# 230              Mané        Liverpool       119          16.0            82
# 359               Son        Tottenham       103          13.0            81
# 579           Ronaldo   Manchester Utd       125          13.0            67
# 210         Tielemans   Leicester City        64          12.0            67
# 138             Mount          Chelsea        76          13.0            77
# 142             James          Chelsea        63          12.0            76
# 144         Gallagher   Crystal Palace        61          15.0            87
# 261          Bernardo  Manchester City        77          15.0            90
# 420             Bowen         West Ham        65          16.0            74
# 196          Raphinha     Leeds United        66          14.0            73
# 413           Antonio         West Ham        79          15.0            73
# 266           Rodrigo  Manchester City        55          12.0            45
# 33           Grealish  Manchester City        76          12.0            41
# 189           Bamford     Leeds United        77           6.0            25
# 364            Davies        Tottenham        44           6.0            29
# 370          Reguilón        Tottenham        53          13.0            62
# 263             Jesus  Manchester City        86          14.0            60
# 122            Alonso          Chelsea        57          10.0            47
# 255          Sterling  Manchester City       106          14.0            53
# 262              Dias  Manchester City        60          15.0            67
# 249            Walker  Manchester City        55          12.0            51
# 234         Robertson        Liverpool        70          12.0            58
# 259           Laporte  Manchester City        55          12.0            50
# 205             Vardy   Leicester City       106          15.0            77
# 96             Mbeumo        Brentford        55          15.0            52
# 228           Firmino        Liverpool        87           8.0            35
# 127           Rüdiger          Chelsea        61          15.0            81
# 229          van Dijk        Liverpool        67          16.0            83
# 252            Stones  Manchester City        53           4.0            19
# 119       Azpilicueta          Chelsea        57          10.0            46
# 245          Tsimikas        Liverpool        38           6.0            30
#
#      adjusted points  points_per_game  adjusted points per game   form 10  \
# id
# 177        25.540000              7.7                  8.513333       NaN
# 233       132.834280             10.0                  8.302143  8.404233
# 237       100.341980              7.7                  7.167284  7.567205
# 268        25.372275              6.5                  6.343069       NaN
# 135        36.122161              9.0                  6.020360  6.764222
# 256        95.775402              5.7                  5.985963  5.653767
# 265        59.666188              4.9                  5.966619  6.432051
# 240        88.556263              5.3                  5.903751  5.859568
# 250        62.720507              5.0                  5.701864  6.436538
# 230        88.326280              5.1                  5.520393  4.749320
# 359        69.784862              6.2                  5.368066  5.939289
# 579        66.882000              5.2                  5.144769  4.804200
# 210        60.715233              5.6                  5.059603  5.862816
# 138        64.952712              5.9                  4.996362  5.276146
# 142        59.586322              6.3                  4.965527  5.535110
# 144        74.038861              5.8                  4.935924  5.064529
# 261        72.992782              6.0                  4.866185  5.404817
# 420        76.456777              4.6                  4.778549  5.225344
# 196        66.116556              5.2                  4.722611  5.082634
# 413        70.375000              4.9                  4.691667  3.297100
# 266        55.323825              3.2                  4.610319  4.050617
# 33         55.145825              3.4                  4.595485  4.344779
# 189        27.542000              4.2                  4.590333  2.000000
# 364        27.374669              4.8                  4.562445  5.708873
# 370        59.000449              4.8                  4.538496  5.633556
# 263        63.326000              4.3                  4.523286  3.764125
# 122        45.127268              4.7                  4.512727  3.411495
# 255        62.945463              3.8                  4.496104  5.362278
# 262        67.390127              4.5                  4.492675  3.475359
# 249        53.286301              4.2                  4.440525  4.474707
# 234        53.236840              4.8                  4.436403  4.692340
# 259        52.915301              4.2                  4.409608  3.642567
# 205        66.071000              5.1                  4.404733  3.511111
# 96         66.008913              3.5                  4.400594  4.369747
# 228        34.771000              4.4                  4.346375  6.317750
# 127        65.040903              5.4                  4.336060  5.189977
# 229        69.008120              5.2                  4.313008  4.188133
# 252        17.205100              4.8                  4.301275  3.883195
# 119        42.798268              4.6                  4.279827  5.169704
# 245        25.547420              5.0                  4.257903  3.431636
#
#      xPoints_next10  valuePoints metric
# id
# 177       40.268286            3.028908
# 233       54.940486            2.293795
# 237       48.274954            2.518327
# 268       35.819705            2.450541
# 135       37.615112            2.521651
# 256       40.286220            2.295512
# 265       45.942707            2.109518
# 240       50.670831            2.087291
# 250       39.713968            2.110355
# 230       42.378095            1.600282
# 359       40.968368            1.672628
# 579       46.373477            1.455160
# 210       42.095698            1.999984
# 138       33.981074            1.812371
# 142       32.128691            1.978313
# 144       40.915633            1.998497
# 261       40.629942            1.753652
# 420       44.154835            1.874301
# 196       38.688583            1.838274
# 413       49.996160            1.669220
# 266       39.172815            1.965847
# 33        34.387363            1.666958
# 189       38.845552            1.654241
# 364       29.706649            2.175060
# 370       35.140882            1.971397
# 263       36.540614            1.542428
# 122       31.054656            1.890173
# 255       31.997736            1.380968
# 262       39.194478            1.834127
# 249       40.200370            1.893446
# 234       39.948493            1.676803
# 259       37.730701            1.880263
# 205       39.866637            1.352903
# 96        34.161221            1.876420
# 228       50.328520            1.473559
# 127       32.500399            1.755619
# 229       38.989598            1.666260
# 252       31.304861            1.868355
# 119       32.098838            1.792622
# 245       32.318579            2.184258

# %%
metric = f'gameweek {gameweek+1} prediction'
#metric = f'xPoints_next10'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','total_points','adjusted points','points_per_game','adjusted points per game',metric,\
                                                  'valuePoints metric']].head(numberToShow))
# Out:
#              web_name        team_name  now_cost  games played  total_points  \
# id
# 240              Jota        Liverpool        80          15.0            80
# 233             Salah        Liverpool       131          16.0           160
# 237  Alexander-Arnold        Liverpool        81          14.0           108
# 228           Firmino        Liverpool        87           8.0            35
# 230              Mané        Liverpool       119          16.0            82
# 413           Antonio         West Ham        79          15.0            73
# 135          Chilwell          Chelsea        57           6.0            54
# 234         Robertson        Liverpool        70          12.0            58
# 265             Foden  Manchester City        80          10.0            49
# 138             Mount          Chelsea        76          13.0            77
# 229          van Dijk        Liverpool        67          16.0            83
# 143             Mendy          Chelsea        63          15.0            68
# 127           Rüdiger          Chelsea        61          15.0            81
# 222         Henderson        Liverpool        51          15.0            61
# 30           Martínez      Aston Villa        55          15.0            60
# 142             James          Chelsea        63          12.0            76
# 359               Son        Tottenham       103          13.0            81
# 121      Thiago Silva          Chelsea        56          13.0            63
# 579           Ronaldo   Manchester Utd       125          13.0            67
# 501              Sarr          Chelsea        49           1.0             8
# 420             Bowen         West Ham        65          16.0            74
# 109              Wood          Burnley        67          15.0            42
# 231           Alisson        Liverpool        60          15.0            72
# 261          Bernardo  Manchester City        77          15.0            90
# 119       Azpilicueta          Chelsea        57          10.0            46
# 123          Jorginho          Chelsea        58          14.0            60
# 210         Tielemans   Leicester City        64          12.0            67
# 408         Fabianski         West Ham        50          16.0            53
# 266           Rodrigo  Manchester City        55          12.0            45
# 257           Ederson  Manchester City        60          15.0            62
# 249            Walker  Manchester City        55          12.0            51
# 527          Chalobah          Chelsea        47           9.0            53
# 411         Cresswell         West Ham        54          13.0            52
# 314              Krul     Norwich City        45          16.0            47
# 251         De Bruyne  Manchester City       118          10.0            31
# 239             Keita        Liverpool        50           7.0            30
# 125           Kovacic          Chelsea        50           9.0            46
# 244             Jones        Liverpool        50           5.0            21
# 450            Dennis          Watford        58          15.0            84
# 78              Toney        Brentford        66          14.0            55
#
#      adjusted points  points_per_game  adjusted points per game  \
# id
# 240        88.556263              5.3                  5.903751
# 233       132.834280             10.0                  8.302143
# 237       100.341980              7.7                  7.167284
# 228        34.771000              4.4                  4.346375
# 230        88.326280              5.1                  5.520393
# 413        70.375000              4.9                  4.691667
# 135        36.122161              9.0                  6.020360
# 234        53.236840              4.8                  4.436403
# 265        59.666188              4.9                  5.966619
# 138        64.952712              5.9                  4.996362
# 229        69.008120              5.2                  4.313008
# 143        61.127903              4.5                  4.075194
# 127        65.040903              5.4                  4.336060
# 222        54.198263              4.1                  3.613218
# 30         58.520981              4.0                  3.901399
# 142        59.586322              6.3                  4.965527
# 359        69.784862              6.2                  5.368066
# 121        50.381849              4.8                  3.875527
# 579        66.882000              5.2                  5.144769
# 501         5.408527              8.0                  5.408527
# 420        76.456777              4.6                  4.778549
# 109        45.800000              2.8                  3.053333
# 231        59.941050              4.8                  3.996070
# 261        72.992782              6.0                  4.866185
# 119        42.798268              4.6                  4.279827
# 123        54.980844              4.3                  3.927203
# 210        60.715233              5.6                  5.059603
# 408        58.039110              3.3                  3.627444
# 266        55.323825              3.2                  4.610319
# 257        61.519127              4.1                  4.101275
# 249        53.286301              4.2                  4.440525
# 527        36.676742              5.9                  4.075194
# 411        53.236277              4.0                  4.095098
# 314        46.618900              2.9                  2.913681
# 251        36.953188              3.1                  3.695319
# 239        22.964123              4.3                  3.280589
# 125        37.924185              5.1                  4.213798
# 244        17.366088              4.2                  3.473218
# 450        63.326000              5.6                  4.221733
# 78         58.782000              3.9                  4.198714
#
#      gameweek 17 prediction  valuePoints metric
# id
# 240                6.182234            2.087291
# 233                5.912254            2.293795
# 237                5.794049            2.518327
# 228                5.644767            1.473559
# 230                5.067712            1.600282
# 413                4.956870            1.669220
# 135                4.900419            2.521651
# 234                4.764994            1.676803
# 265                4.687012            2.109518
# 138                4.572797            1.812371
# 229                4.487178            1.666260
# 143                4.475529            1.623596
# 127                4.472761            1.755619
# 222                4.458976            1.599960
# 30                 4.458665            1.663562
# 142                4.418518            1.978313
# 359                4.410779            1.672628
# 121                4.408813            1.637709
# 579                4.405870            1.455160
# 501                4.390831            2.443323
# 420                4.386065            1.874301
# 109                4.381173            1.179606
# 231                4.358112            1.631389
# 261                4.336072            1.753652
# 119                4.325064            1.792622
# 123                4.319190            1.630682
# 210                4.316541            1.999984
# 408                4.306762            1.622242
# 266                4.301797            1.965847
# 257                4.289582            1.674339
# 249                4.289431            1.893446
# 527                4.268538            1.879747
# 411                4.263001            1.762250
# 314                4.253586            1.373523
# 251                4.245926            1.075749
# 239                4.211347            1.467124
# 125                4.206861            1.884468
# 244                4.203276            1.553270
# 450                4.191483            1.752979
# 78                 4.184380            1.634347

# %%
metric = 'xG'

display(df.sort_values(by=[metric], ascending=False)[['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game',\
                      'valuePoints metric', 'xG', 'xA', 'xG+xA', 'xG+xA per game']].head(numberToShow))
# Out:
#           web_name        team_name  now_cost  games played  points_per_game  \
# id
# 233          Salah        Liverpool       131          16.0             10.0
# 240           Jota        Liverpool        80          15.0              5.3
# 230           Mané        Liverpool       119          16.0              5.1
# 579        Ronaldo   Manchester Utd       125          13.0              5.2
# 205          Vardy   Leicester City       106          15.0              5.1
# 468           King          Watford        58          14.0              4.0
# 4       Aubameyang          Arsenal        96          14.0              3.1
# 96          Mbeumo        Brentford        55          15.0              3.5
# 413        Antonio         West Ham        79          15.0              4.9
# 149        Benteke   Crystal Palace        64          16.0              3.0
# 315          Pukki     Norwich City        59          16.0              3.6
# 63          Maupay         Brighton        63          14.0              3.9
# 420          Bowen         West Ham        65          16.0              4.6
# 196       Raphinha     Leeds United        66          14.0              5.2
# 250       Gündogan  Manchester City        73          11.0              5.0
# 255       Sterling  Manchester City       106          14.0              3.8
# 263          Jesus  Manchester City        86          14.0              4.3
# 359            Son        Tottenham       103          13.0              6.2
# 296         Wilson    Newcastle Utd        75          12.0              4.6
# 78           Toney        Brentford        66          14.0              3.9
# 265          Foden  Manchester City        80          10.0              4.9
# 40         Watkins      Aston Villa        76          14.0              3.5
# 138          Mount          Chelsea        76          13.0              5.9
# 228        Firmino        Liverpool        87           8.0              4.4
# 450         Dennis          Watford        58          15.0              5.6
# 357           Kane        Tottenham       121          13.0              2.5
# 109           Wood          Burnley        67          15.0              2.8
# 177  Calvert-Lewin          Everton        79           3.0              7.7
# 525    A.Armstrong      Southampton        59          15.0              3.1
# 277      Fernandes   Manchester Utd       116          16.0              4.4
# 144      Gallagher   Crystal Palace        61          15.0              5.8
# 261       Bernardo  Manchester City        77          15.0              6.0
# 399           Sarr          Watford        58          12.0              4.4
# 154           Zaha   Crystal Palace        69          15.0              3.7
# 430        Jiménez           Wolves        76          16.0              3.4
# 189        Bamford     Leeds United        77           6.0              4.2
# 33        Grealish  Manchester City        76          12.0              3.4
# 123       Jorginho          Chelsea        58          14.0              4.3
# 212       Maddison   Leicester City        68          16.0              4.3
# 134         Werner          Chelsea        86           9.0              2.4
#
#      adjusted points per game  valuePoints metric    xG   xA  xG+xA  \
# id
# 233                  8.302143            2.293795  10.1  6.4   16.5
# 240                  5.903751            2.087291   8.9  3.1   12.0
# 230                  5.520393            1.600282   8.3  2.3   10.6
# 579                  5.144769            1.455160   7.2  1.5    8.7
# 205                  4.404733            1.352903   6.0  1.1    7.1
# 468                  4.145214            1.721207   5.8  2.0    7.8
# 4                    3.600786            1.162149   5.8  0.8    6.6
# 96                   4.400594            1.876420   5.4  1.4    6.8
# 413                  4.691667            1.669220   5.4  3.8    9.2
# 149                  3.316937            1.311135   5.0  1.1    6.1
# 315                  3.652500            1.503710   4.9  0.6    5.5
# 63                   3.722857            1.483222   4.8  0.8    5.6
# 420                  4.778549            1.874301   4.8  2.6    7.4
# 196                  4.722611            1.838274   4.7  2.7    7.4
# 250                  5.701864            2.110355   4.5  2.3    6.8
# 255                  4.496104            1.380968   4.5  2.6    7.1
# 263                  4.523286            1.542428   4.3  2.5    6.8
# 359                  5.368066            1.672628   4.3  2.0    6.3
# 296                  4.076667            1.488588   4.3  0.4    4.7
# 78                   4.198714            1.634347   4.2  2.8    7.0
# 265                  5.966619            2.109518   4.1  3.2    7.3
# 40                   3.540786            1.284378   4.1  0.8    4.9
# 138                  4.996362            1.812371   4.0  3.0    7.0
# 228                  4.346375            1.473559   3.9  0.8    4.7
# 450                  4.221733            1.752979   3.9  1.7    5.6
# 357                  3.759308            1.080725   3.8  2.3    6.1
# 109                  3.053333            1.179606   3.8  0.2    4.0
# 177                  8.513333            3.028908   3.8  0.1    3.9
# 525                  3.507533            1.444029   3.8  1.7    5.5
# 277                  4.210209            1.236160   3.6  4.1    7.7
# 144                  4.935924            1.998497   3.6  3.0    6.6
# 261                  4.866185            1.753652   3.4  2.6    6.0
# 399                  4.153166            1.724508   3.4  1.2    4.6
# 154                  3.906324            1.487112   3.3  2.7    6.0
# 430                  3.332063            1.208666   3.3  1.6    4.9
# 189                  4.590333            1.654241   3.3  0.6    3.9
# 33                   4.595485            1.666958   3.2  3.1    6.3
# 123                  3.927203            1.630682   3.2  1.4    4.6
# 212                  3.940936            1.511280   3.2  1.9    5.1
# 134                  3.241222            1.105248   3.2  0.2    3.4
#
#      xG+xA per game
# id
# 233        1.031250
# 240        0.800000
# 230        0.662500
# 579        0.669231
# 205        0.473333
# 468        0.557143
# 4          0.471429
# 96         0.453333
# 413        0.613333
# 149        0.381250
# 315        0.343750
# 63         0.400000
# 420        0.462500
# 196        0.528571
# 250        0.618182
# 255        0.507143
# 263        0.485714
# 359        0.484615
# 296        0.391667
# 78         0.500000
# 265        0.730000
# 40         0.350000
# 138        0.538462
# 228        0.587500
# 450        0.373333
# 357        0.469231
# 109        0.266667
# 177        1.300000
# 525        0.366667
# 277        0.481250
# 144        0.440000
# 261        0.400000
# 399        0.383333
# 154        0.400000
# 430        0.306250
# 189        0.650000
# 33         0.525000
# 123        0.328571
# 212        0.318750
# 134        0.377778

# %% [markdown]
# ## Player Visualizations

# %%
game_weeks = np.arange(1,gameweek+1)
column_xPoints = []
column_xG = []
column_xA = []
column_xGA = []
for i in range(1,gameweek+1):
    column_xPoints.append('xPoints week ' + str(i))
    column_xG.append('xG_week' + str(i))
    column_xA.append('xA_week' + str(i))
    column_xGA.append('xGA_week' + str(i))

#display(game_weeks)
#display(column_xPoints)

# %%
# find player index
name_string = 'Werner'
playersFound = df[df['web_name'].str.contains(name_string)]
display(playersFound[['web_name','team_name','now_cost','games played','total_points','adjusted points',\
                      'points_per_game','adjusted points per game',f'gameweek {gameweek+1} prediction',\
                      'xPoints_next10', 'valuePoints metric']])
# plot xPoints over time
ix = playersFound.index[0]
#ix = 468

fig,ax = plt.subplots(2,2,figsize=(15,10))

ax[0,0].plot(game_weeks, df.loc[ix,column_xPoints], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,0].set_title(title_string)
ax[0,0].set_xlabel('gameweek')
ax[0,0].set_ylabel('xPoints')
ax[0,0].set_xticks(game_weeks)

ax[0,1].plot(game_weeks, df.loc[ix,column_xG], marker='o')
ax[0,1].plot(game_weeks, df.loc[ix,column_xA], marker='o')
ax[0,1].legend(('xG','xA'))
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[0,1].set_title(title_string)
ax[0,1].set_xlabel('gameweek')
ax[0,1].set_ylabel('xG and xA')
ax[0,1].set_xticks(game_weeks)

ax[1,0].plot(game_weeks, df.loc[ix,column_xGA], marker='o')
title_string = df.loc[ix,'first_name'] + ' ' + df.loc[ix,'second_name'] + ' (' + df.loc[ix,'team_name'] + ')'
ax[1,0].set_title(title_string)
ax[1,0].set_xlabel('gameweek')
ax[1,0].set_ylabel('xGA')
ax[1,0].set_xticks(game_weeks)

plt.show()
# Out:
#     web_name team_name  now_cost  games played  total_points  adjusted points  \
# id
# 134   Werner   Chelsea        86           9.0            22           29.171
#
#      points_per_game  adjusted points per game  gameweek 17 prediction  \
# id
# 134              2.4                  3.241222                3.540611
#
#      xPoints_next10  valuePoints metric
# id
# 134       29.115686            1.105248

# %% [markdown]
# ## My team

# %%
session = requests.session()

# %%
filepath = Path('../../../access_control/FPL_access.txt')
with open(filepath) as file:
    text = file.read().splitlines()
    email = text[0]
    password = text[1]

# %%
url = 'https://users.premierleague.com/accounts/login/'

payload = {
'password': password,
'login': email,
'redirect_uri': 'https://fantasy.premierleague.com/a/login', 'app': 'plfpl-web'
}
session.post(url, data=payload)
# Out:
# <Response [200]>

# %%
response = session.get('https://fantasy.premierleague.com/api/my-team/3202682')
team = response.json()['picks']

# %%
my_player_ix = [player['element'] for player in team]
my_starting11 = my_player_ix[:-4]
my_subs = my_player_ix[-4:]

# %%
exp_avg = df.loc[my_starting11,'adjusted points per game'].sum() + \
                df.loc[my_starting11,'adjusted points per game'].max()
exp_next = df.loc[my_starting11, f'gameweek {gameweek+1} prediction'].sum() + \
                df.loc[my_starting11,f'gameweek {gameweek+1} prediction'].max()

print('STARTING 11')
print('Expected points on average: ' + str(exp_avg))
print('Predicted points next gameweek: ' + str(exp_next))
display(df.loc[my_starting11, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
           f'gameweek {gameweek+1} prediction','xPoints_next10', 'valuePoints metric']].head(numberToShow))
print('\nSUBSTITUTES')
display(df.loc[my_subs, ['web_name','team_name','now_cost',\
          'games played','points_per_game','adjusted points per game','form 5','form 10', \
         f'gameweek {gameweek+1} prediction', 'xPoints_next10', 'valuePoints metric']].head(numberToShow))
# Out:
# STARTING 11
# Expected points on average: 68.51120867927925
# Predicted points next gameweek: 56.02830505371094
#              web_name        team_name  now_cost  games played  \
# id
# 559          Ramsdale          Arsenal        50          13.0
# 256           Cancelo  Manchester City        68          16.0
# 237  Alexander-Arnold        Liverpool        81          14.0
# 142             James          Chelsea        63          12.0
# 144         Gallagher   Crystal Palace        61          15.0
# 138             Mount          Chelsea        76          13.0
# 233             Salah        Liverpool       131          16.0
# 250          Gündogan  Manchester City        73          11.0
# 450            Dennis          Watford        58          15.0
# 413           Antonio         West Ham        79          15.0
# 579           Ronaldo   Manchester Utd       125          13.0
#
#      points_per_game  adjusted points per game    form 5   form 10  \
# id
# 559              5.4                  4.095830  4.730398  4.672824
# 256              5.7                  5.985963  6.461678  5.653767
# 237              7.7                  7.167284  8.908240  7.567205
# 142              6.3                  4.965527  4.338936  5.535110
# 144              5.8                  4.935924  4.364893  5.064529
# 138              5.9                  4.996362  5.041896  5.276146
# 233             10.0                  8.302143  8.524810  8.404233
# 250              5.0                  5.701864  6.244012  6.436538
# 450              5.6                  4.221733  6.002600  4.717222
# 413              4.9                  4.691667  2.634200  3.297100
# 579              5.2                  5.144769  6.374200  4.804200
#
#      gameweek 17 prediction  xPoints_next10  valuePoints metric
# id
# 559                3.775155       35.909127            1.831711
# 256                4.117491       40.286220            2.295512
# 237                5.794049       48.274954            2.518327
# 142                4.418518       32.128691            1.978313
# 144                3.890950       40.915633            1.998497
# 138                4.572797       33.981074            1.812371
# 233                5.912254       54.940486            2.293795
# 250                4.080613       39.713968            2.110355
# 450                4.191483       41.437289            1.752979
# 413                4.956870       49.996160            1.669220
# 579                4.405870       46.373477            1.455160
# SUBSTITUTES
#        web_name     team_name  now_cost  games played  points_per_game  \
# id
# 376      Foster       Watford        41           8.0              3.5
# 491  Livramento   Southampton        45          16.0              3.3
# 425     Johnson      West Ham        40           9.0              3.1
# 145     Gilmour  Norwich City        44           9.0              2.3
#
#      adjusted points per game    form 5   form 10  gameweek 17 prediction  \
# id
# 376                  3.831539  3.732196  3.851043                3.857411
# 491                  3.059767  2.390001  3.366379                3.457590
# 425                  3.037167  2.062724  3.028395                3.024199
# 145                  2.589434  2.669960  2.669960                2.507927
#
#      xPoints_next10  valuePoints metric
# id
# 376       38.003808            1.892262
# 491       32.651663            1.442388
# 425       32.247118            1.518583
# 145       22.575967            1.234464

# %% [markdown]
# ## Save data

# %%
# save data
filepath = '../data/fpl/data_week' + str(gameweek) + str('.csv')
df.to_csv(filepath)
