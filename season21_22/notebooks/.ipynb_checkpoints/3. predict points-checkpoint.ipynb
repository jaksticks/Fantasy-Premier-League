# %%
# give the number of the latest FPL round
latest_gameweek = 5

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import json
import requests
import xgboost
import pickle

# allow more data columns to be shown than by default
pd.set_option('max_columns',500)

# %%
filepath = Path('../data/fpl/data_week' + str(latest_gameweek) + str('.csv'))
players = pd.read_csv(filepath, index_col=0)
players
# Out:
#      adjusted points  adjusted points per game  assists  assists_week1  \
# id
# 1           5.656831                   1.88561        0            0.0
# 2                NaN                       NaN        0            NaN
# 3                NaN                       NaN        0            NaN
# 4          16.100000                   4.02500        0            NaN
# 5           2.956831                   0.98561        0            NaN
# ..               ...                       ...      ...            ...
# 523              NaN                       NaN        0            NaN
# 547              NaN                       NaN        0            NaN
# 548              NaN                       NaN        0            NaN
# 549              NaN                       NaN        0            NaN
# 583         8.600000                   4.30000        0            NaN
#
#      assists_week2  assists_week3  assists_week4  assists_week5  bonus  \
# id
# 1              0.0            0.0            NaN            NaN      0
# 2              NaN            NaN            NaN            NaN      0
# 3              NaN            NaN            NaN            NaN      0
# 4              0.0            0.0            0.0            0.0      3
# 5              0.0            0.0            0.0            NaN      0
# ..             ...            ...            ...            ...    ...
# 523            NaN            NaN            NaN            NaN      0
# 547            NaN            NaN            NaN            NaN      0
# 548            NaN            NaN            NaN            NaN      0
# 549            NaN            NaN            NaN            NaN      0
# 583            NaN            NaN            NaN            0.0      3
#
#      bonus_week1  bonus_week2  bonus_week3  bonus_week4  bonus_week5  bps  \
# id
# 1            0.0          0.0          0.0          NaN          NaN   48
# 2            NaN          NaN          NaN          NaN          NaN    0
# 3            NaN          NaN          NaN          NaN          NaN    0
# 4            NaN          0.0          0.0          3.0          0.0   41
# 5            NaN          0.0          0.0          0.0          NaN   21
# ..           ...          ...          ...          ...          ...  ...
# 523          NaN          NaN          NaN          NaN          NaN    0
# 547          NaN          NaN          NaN          NaN          NaN    0
# 548          NaN          NaN          NaN          NaN          NaN    0
# 549          NaN          NaN          NaN          NaN          NaN    0
# 583          NaN          NaN          NaN          NaN          0.0   30
#
#      chance_of_playing_next_round  chance_of_playing_this_round  \
# id
# 1                             NaN                           NaN
# 2                             0.0                           0.0
# 3                             0.0                           0.0
# 4                           100.0                         100.0
# 5                             NaN                           NaN
# ..                            ...                           ...
# 523                           0.0                           0.0
# 547                           NaN                           NaN
# 548                           NaN                           NaN
# 549                           0.0                           0.0
# 583                           NaN                           NaN
#
#      clean_sheet_points  clean_sheets  cleansheet_week1  cleansheet_week2  \
# id
# 1              1.656831             0               0.0               0.0
# 2                   NaN             0               NaN               NaN
# 3                   NaN             0               NaN               NaN
# 4              0.000000             2               NaN               0.0
# 5              1.656831             0               NaN               0.0
# ..                  ...           ...               ...               ...
# 523                 NaN             0               NaN               NaN
# 547                 NaN             0               NaN               NaN
# 548                 NaN             0               NaN               NaN
# 549                 NaN             0               NaN               NaN
# 583            0.000000             0               NaN               NaN
#
#      cleansheet_week3  cleansheet_week4  cleansheet_week5    code  \
# id
# 1                 0.0               0.0               0.0   80201
# 2                 NaN               NaN               NaN  115918
# 3                 NaN               NaN               NaN   47431
# 4                 0.0               1.0               1.0   54694
# 5                 0.0               0.0               0.0   58822
# ..                ...               ...               ...     ...
# 523               NaN               NaN               NaN  209353
# 547               NaN               NaN               NaN  245923
# 548               NaN               NaN               NaN  461026
# 549               NaN               NaN               NaN  481626
# 583               NaN               NaN               0.0  184754
#
#      corners_and_indirect_freekicks_order  \
# id
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# ..                                    ...
# 523                                   NaN
# 547                                   NaN
# 548                                   NaN
# 549                                   NaN
# 583                                   NaN
#
#      corners_and_indirect_freekicks_text  cost_change_event  \
# id
# 1                                    NaN                  0
# 2                                    NaN                  0
# 3                                    NaN                  0
# 4                                    NaN                  0
# 5                                    NaN                  0
# ..                                   ...                ...
# 523                                  NaN                  0
# 547                                  NaN                  0
# 548                                  NaN                  0
# 549                                  NaN                  0
# 583                                  NaN                  0
#
#      cost_change_event_fall  cost_change_start  cost_change_start_fall  \
# id
# 1                         0                 -1                       1
# 2                         0                  0                       0
# 3                         0                 -2                       2
# 4                         0                 -1                       1
# 5                         0                 -1                       1
# ..                      ...                ...                     ...
# 523                       0                  0                       0
# 547                       0                  0                       0
# 548                       0                  0                       0
# 549                       0                  0                       0
# 583                       0                  0                       0
#
#      creativity  creativity_rank  creativity_rank_type  \
# id
# 1           0.0              533                    54
# 2           0.0              388                    17
# 3           0.0              599                   245
# 4          62.6               89                    14
# 5          36.1              151                    32
# ..          ...              ...                   ...
# 523         0.0              564                    71
# 547         0.0              507                   203
# 548         0.0              514                   207
# 549         0.0              416                   159
# 583         0.9              323                    46
#
#      direct_freekicks_order  direct_freekicks_text  dreamteam_count  \
# id
# 1                       NaN                    NaN                0
# 2                       NaN                    NaN                0
# 3                       NaN                    NaN                0
# 4                       NaN                    NaN                0
# 5                       5.0                    NaN                0
# ..                      ...                    ...              ...
# 523                     NaN                    NaN                0
# 547                     NaN                    NaN                0
# 548                     NaN                    NaN                0
# 549                     NaN                    NaN                0
# 583                     NaN                    NaN                0
#
#      element_type  ep_next  ep_this  event_points      first_name  form  \
# id
# 1               1      0.8      1.8             0           Bernd   0.8
# 2               1      0.0      0.0             0      Rúnar Alex   0.0
# 3               3      0.0      0.0             0         Willian   0.0
# 4               4      3.2      4.2             2  Pierre-Emerick   3.2
# 5               2      0.2      1.2             0          Cédric   0.2
# ..            ...      ...      ...           ...             ...   ...
# 523             4      0.0      0.0             0         Patrick   0.0
# 547             3      0.0      0.5             0            Luke   0.0
# 548             3      0.0      0.5             0            Chem   0.0
# 549             2      0.0      0.0             0       Christian   0.0
# 583             4      4.5      5.0             1        Hee-Chan   4.5
#
#       form 10   form 15   form 20    form 5  games played  gameweek  \
# id
# 1    1.799901  1.799901  1.799901  1.799901           3.0         5
# 2         NaN       NaN       NaN       NaN           NaN         5
# 3         NaN       NaN       NaN       NaN           NaN         5
# 4    4.025000  4.025000  4.025000  4.025000           4.0         5
# 5    0.536525  0.536525  0.536525  0.536525           3.0         5
# ..        ...       ...       ...       ...           ...       ...
# 523       NaN       NaN       NaN       NaN           NaN         5
# 547       NaN       NaN       NaN       NaN           NaN         5
# 548       NaN       NaN       NaN       NaN           NaN         5
# 549       NaN       NaN       NaN       NaN           NaN         5
# 583  0.700000  0.700000  0.700000  0.700000           2.0         5
#
#      gameweek 10 prediction  gameweek 11 prediction  gameweek 12 prediction  \
# id
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# 5                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 523                     NaN                     NaN                     NaN
# 547                     NaN                     NaN                     NaN
# 548                     NaN                     NaN                     NaN
# 549                     NaN                     NaN                     NaN
# 583                     NaN                     NaN                     NaN
#
#      gameweek 13 prediction  gameweek 14 prediction  gameweek 2 prediction  \
# id
# 1                       NaN                     NaN                    NaN
# 2                       NaN                     NaN                    NaN
# 3                       NaN                     NaN                    NaN
# 4                       NaN                     NaN                    NaN
# 5                       NaN                     NaN                    NaN
# ..                      ...                     ...                    ...
# 523                     NaN                     NaN                    NaN
# 547                     NaN                     NaN                    NaN
# 548                     NaN                     NaN                    NaN
# 549                     NaN                     NaN                    NaN
# 583                     NaN                     NaN                    NaN
#
#      gameweek 3 prediction  gameweek 4 prediction  gameweek 5 prediction  \
# id
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                      NaN                    NaN                    NaN
# 5                      NaN                    NaN                    NaN
# ..                     ...                    ...                    ...
# 523                    NaN                    NaN                    NaN
# 547                    NaN                    NaN                    NaN
# 548                    NaN                    NaN                    NaN
# 549                    NaN                    NaN                    NaN
# 583                    NaN                    NaN                    NaN
#
#      gameweek 6 prediction  gameweek 7 prediction  gameweek 8 prediction  \
# id
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                      NaN                    NaN                    NaN
# 5                      NaN                    NaN                    NaN
# ..                     ...                    ...                    ...
# 523                    NaN                    NaN                    NaN
# 547                    NaN                    NaN                    NaN
# 548                    NaN                    NaN                    NaN
# 549                    NaN                    NaN                    NaN
# 583                    NaN                    NaN                    NaN
#
#      gameweek 9 prediction  goals_conceded  goals_scored  goals_week1  \
# id
# 1                      NaN               9             0          0.0
# 2                      NaN               0             0          NaN
# 3                      NaN               0             0          NaN
# 4                      NaN               4             1          NaN
# 5                      NaN               7             0          NaN
# ..                     ...             ...           ...          ...
# 523                    NaN               0             0          NaN
# 547                    NaN               0             0          NaN
# 548                    NaN               0             0          NaN
# 549                    NaN               0             0          NaN
# 583                    NaN               0             1          NaN
#
#      goals_week2  goals_week3  goals_week4  goals_week5  ict_index  \
# id
# 1            0.0          0.0          NaN          NaN        7.9
# 2            NaN          NaN          NaN          NaN        0.0
# 3            NaN          NaN          NaN          NaN        0.0
# 4            0.0          0.0          1.0          0.0       25.0
# 5            0.0          0.0          0.0          NaN        6.8
# ..           ...          ...          ...          ...        ...
# 523          NaN          NaN          NaN          NaN        0.0
# 547          NaN          NaN          NaN          NaN        0.0
# 548          NaN          NaN          NaN          NaN        0.0
# 549          NaN          NaN          NaN          NaN        0.0
# 583          NaN          NaN          NaN          0.0       10.8
#
#      ict_index_rank  ict_index_rank_type  in_dreamteam  influence  \
# id
# 1               242                   18         False       79.0
# 2               410                   37         False        0.0
# 3               600                  245         False        0.0
# 4                64                   18         False       48.0
# 5               258                   88         False       30.8
# ..              ...                  ...           ...        ...
# 523             568                   71         False        0.0
# 547             518                  200         False        0.0
# 548             525                  204         False        0.0
# 549             438                  161         False        0.0
# 583             195                   30         False       41.6
#
#      influence_rank  influence_rank_type  minutes  \
# id
# 1               115                   16      270
# 2               401                   37        0
# 3               600                  245        0
# 4               200                   20      267
# 5               255                  100      188
# ..              ...                  ...      ...
# 523             563                   68        0
# 547             513                  198        0
# 548             520                  202        0
# 549             429                  159        0
# 583             224                   26       72
#
#                                                   news  \
# id
# 1                                                  NaN
# 2    Joined OH Leuven on a season-long loan - Expec...
# 3                           Transferred to Corinthians
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 523                         Season long loan to Empoli
# 547                                                NaN
# 548                                                NaN
# 549                     Season-long loan to Belenenses
# 583                                                NaN
#
#                       news_added  now_cost  own_goals  penalties_missed  \
# id
# 1                            NaN        49          0                 0
# 2    2021-08-31T22:00:09.069158Z        40          0                 0
# 3    2021-08-20T09:30:14.065783Z        63          0                 0
# 4    2021-08-13T14:30:14.477664Z        99          0                 0
# 5                            NaN        44          0                 0
# ..                           ...       ...        ...               ...
# 523  2021-08-15T12:06:51.809579Z        50          0                 0
# 547                          NaN        45          0                 0
# 548                          NaN        45          0                 0
# 549  2021-09-07T09:00:15.908306Z        40          0                 0
# 583                          NaN        55          0                 0
#
#      penalties_order  penalties_saved  penalties_text       photo  \
# id
# 1                NaN                0             NaN   80201.jpg
# 2                NaN                0             NaN  115918.jpg
# 3                NaN                0             NaN   47431.jpg
# 4                1.0                0             NaN   54694.jpg
# 5                NaN                0             NaN   58822.jpg
# ..               ...              ...             ...         ...
# 523              NaN                0             NaN  209353.jpg
# 547              NaN                0             NaN  245923.jpg
# 548              NaN                0             NaN  461026.jpg
# 549              NaN                0             NaN  481626.jpg
# 583              NaN                0             NaN  184754.jpg
#
#      points_per_game  red_cards  saves      second_name  selected_by_percent  \
# id
# 1                1.3          0      9             Leno                  1.5
# 2                0.0          0      0        Rúnarsson                  1.0
# 3                0.0          0      0  Borges Da Silva                  0.1
# 4                3.2          0      0       Aubameyang                  2.2
# 5                0.3          0      0           Soares                  0.2
# ..               ...        ...    ...              ...                  ...
# 523              0.0          0      0          Cutrone                  0.1
# 547              0.0          0      0           Cundle                  0.1
# 548              0.0          0      0         Campbell                  0.3
# 549              0.0          0      0          Marques                  0.3
# 583              4.5          0      0            Hwang                  2.4
#
#      special  squad_number status  team  team_code team_name  threat  \
# id
# 1      False           NaN      a     1          3   Arsenal     0.0
# 2      False           NaN      u     1          3   Arsenal     0.0
# 3      False           NaN      u     1          3   Arsenal     0.0
# 4      False           NaN      a     1          3   Arsenal   140.0
# 5      False           NaN      a     1          3   Arsenal     1.0
# ..       ...           ...    ...   ...        ...       ...     ...
# 523    False           NaN      u    20         39    Wolves     0.0
# 547    False           NaN      a    20         39    Wolves     0.0
# 548    False           NaN      a    20         39    Wolves     0.0
# 549    False           NaN      u    20         39    Wolves     0.0
# 583    False           NaN      a    20         39    Wolves    65.0
#
#      threat_rank  threat_rank_type  total_points  transfers_in  \
# id
# 1            512                52             4         49210
# 2            337                14             0         19017
# 3            597               245             0           914
# 4             38                16            13        159241
# 5            314               105             1          8761
# ..           ...               ...           ...           ...
# 523          549                66             0          1047
# 547          478               190             0          7320
# 548          487               195             0         29068
# 549          367               133             0         24271
# 583           86                24             9        239838
#
#      transfers_in_event  transfers_out  transfers_out_event  value  \
# id
# 1                  1237         114869                 9238    NaN
# 2                     0          43384                 2356    NaN
# 3                     0          18829                  301    NaN
# 4                  3774         211519                16518    NaN
# 5                   225          15305                  917    NaN
# ..                  ...            ...                  ...    ...
# 523                   0          14797                  281    NaN
# 547                 558           4092                  568    NaN
# 548                2002          15549                 1974    NaN
# 549                   0          19334                 1494    NaN
# 583               13083          59617                23216    NaN
#
#      value form 10  value form 5  valuePoints metric  value_form  \
# id
# 1              NaN           NaN                 NaN         0.2
# 2              NaN           NaN                 NaN         0.0
# 3              NaN           NaN                 NaN         0.0
# 4              NaN           NaN                 NaN         0.3
# 5              NaN           NaN                 NaN         0.0
# ..             ...           ...                 ...         ...
# 523            NaN           NaN                 NaN         0.0
# 547            NaN           NaN                 NaN         0.0
# 548            NaN           NaN                 NaN         0.0
# 549            NaN           NaN                 NaN         0.0
# 583            NaN           NaN                 NaN         0.8
#
#      value_next10  value_season    web_name   xA  xA_points  xA_week1  \
# id
# 1             NaN           0.8        Leno  0.0        0.0       0.0
# 2             NaN           0.0   Rúnarsson  NaN        NaN       NaN
# 3             NaN           0.0     Willian  NaN        NaN       NaN
# 4             NaN           1.3  Aubameyang  0.5        1.5       NaN
# 5             NaN           0.2      Cédric  0.1        0.3       NaN
# ..            ...           ...         ...  ...        ...       ...
# 523           NaN           0.0     Cutrone  NaN        NaN       NaN
# 547           NaN           0.0      Cundle  NaN        NaN       NaN
# 548           NaN           0.0    Campbell  NaN        NaN       NaN
# 549           NaN           0.0     Marques  NaN        NaN       NaN
# 583           NaN           1.6       Hwang  0.0        0.0       NaN
#
#      xA_week2  xA_week3  xA_week4  xA_week5   xG  xG+xA  xG+xA per game  \
# id
# 1         0.0       0.0       NaN       NaN  0.0    NaN             NaN
# 2         NaN       NaN       NaN       NaN  NaN    NaN             NaN
# 3         NaN       NaN       NaN       NaN  NaN    NaN             NaN
# 4         0.0       0.0       0.1       0.4  1.4    NaN             NaN
# 5         0.1       0.0       0.0       NaN  0.0    NaN             NaN
# ..        ...       ...       ...       ...  ...    ...             ...
# 523       NaN       NaN       NaN       NaN  NaN    NaN             NaN
# 547       NaN       NaN       NaN       NaN  NaN    NaN             NaN
# 548       NaN       NaN       NaN       NaN  NaN    NaN             NaN
# 549       NaN       NaN       NaN       NaN  NaN    NaN             NaN
# 583       NaN       NaN       NaN       0.0  0.9    NaN             NaN
#
#      xGA_week1  xGA_week2  xGA_week3  xGA_week4  xGA_week5  xG_points  \
# id
# 1          1.3        2.9        3.8        0.7        1.2        0.0
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN        2.9        3.8        0.7        1.2        5.6
# 5          NaN        2.9        3.8        0.7        1.2        0.0
# ..         ...        ...        ...        ...        ...        ...
# 523        NaN        NaN        NaN        NaN        NaN        NaN
# 547        NaN        NaN        NaN        NaN        NaN        NaN
# 548        NaN        NaN        NaN        NaN        NaN        NaN
# 549        NaN        NaN        NaN        NaN        NaN        NaN
# 583        NaN        NaN        NaN        0.2        2.5        3.6
#
#      xG_week1  xG_week2  xG_week3  xG_week4  xG_week5  xPoints  \
# id
# 1         0.0       0.0       0.0       NaN       NaN      NaN
# 2         NaN       NaN       NaN       NaN       NaN      NaN
# 3         NaN       NaN       NaN       NaN       NaN      NaN
# 4         NaN       0.0       0.0       1.3       0.1      3.6
# 5         NaN       0.0       0.0       0.0       NaN      NaN
# ..        ...       ...       ...       ...       ...      ...
# 523       NaN       NaN       NaN       NaN       NaN      NaN
# 547       NaN       NaN       NaN       NaN       NaN      NaN
# 548       NaN       NaN       NaN       NaN       NaN      NaN
# 549       NaN       NaN       NaN       NaN       NaN      NaN
# 583       NaN       NaN       NaN       NaN       0.1      1.4
#
#      xPoints week 1  xPoints week 2  xPoints week 3  xPoints week 4  \
# id
# 1          2.090127        2.220093        1.089483             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN        1.000000        1.000000            10.5
# 5               NaN        1.520093       -0.910517             1.0
# ..              ...             ...             ...             ...
# 523             NaN             NaN             NaN             NaN
# 547             NaN             NaN             NaN             NaN
# 548             NaN             NaN             NaN             NaN
# 549             NaN             NaN             NaN             NaN
# 583             NaN             NaN             NaN             NaN
#
#      xPoints week 5  xPoints_next10  yellow_cards
# id
# 1               NaN             NaN             0
# 2               NaN             NaN             0
# 3               NaN             NaN             0
# 4               3.6             NaN             0
# 5               NaN             NaN             1
# ..              ...             ...           ...
# 523             NaN             NaN             0
# 547             NaN             NaN             0
# 548             NaN             NaN             0
# 549             NaN             NaN             0
# 583             1.4             NaN             0
#
# [606 rows x 142 columns]

# %%
teams = ['Arsenal', 'Aston Villa', 'Brentford', 'Brighton', 'Burnley', 'Chelsea', 'Crystal Palace', 'Everton',
        'Leicester City', 'Leeds United', 'Liverpool', 'Manchester City', 'Manchester Utd', 'Newcastle Utd', 
        'Norwich City', 'Southampton', 'Tottenham', 'Watford', 'West Ham', 'Wolves']

# %%
# get FPL fixtures data
fpl_fixtures_data = json.loads(requests.get('https://fantasy.premierleague.com/api/fixtures/').text)
fpl_fixtures = pd.DataFrame(fpl_fixtures_data)
fpl_fixtures['home team'] = [teams[i] for i in fpl_fixtures['team_h']-1]
fpl_fixtures['away team'] = [teams[i] for i in fpl_fixtures['team_a']-1]
filepath = Path('../data/fpl/fixtures.csv')
fpl_fixtures.to_csv(filepath)
fpl_fixtures
# Out:
#         code  event  finished  finished_provisional   id  \
# 0    2210271      1      True                  True    1
# 1    2210276      1      True                  True    6
# 2    2210272      1      True                  True    2
# 3    2210273      1      True                  True    3
# 4    2210274      1      True                  True    4
# ..       ...    ...       ...                   ...  ...
# 375  2210646     38     False                 False  376
# 376  2210647     38     False                 False  377
# 377  2210648     38     False                 False  378
# 378  2210649     38     False                 False  379
# 379  2210650     38     False                 False  380
#
#              kickoff_time  minutes  provisional_start_time  started  team_a  \
# 0    2021-08-13T19:00:00Z       90                   False     True       1
# 1    2021-08-14T11:30:00Z       90                   False     True      10
# 2    2021-08-14T14:00:00Z       90                   False     True       4
# 3    2021-08-14T14:00:00Z       90                   False     True       7
# 4    2021-08-14T14:00:00Z       90                   False     True      16
# ..                    ...      ...                     ...      ...     ...
# 375  2022-05-22T15:00:00Z        0                   False    False      13
# 376  2022-05-22T15:00:00Z        0                   False    False      16
# 377  2022-05-22T15:00:00Z        0                   False    False      20
# 378  2022-05-22T15:00:00Z        0                   False    False       2
# 379  2022-05-22T15:00:00Z        0                   False    False      17
#
#      team_a_score  team_h  team_h_score  \
# 0             0.0       3           2.0
# 1             1.0      13           5.0
# 2             2.0       5           1.0
# 3             0.0       6           3.0
# 4             1.0       8           3.0
# ..            ...     ...           ...
# 375           NaN       7           NaN
# 376           NaN       9           NaN
# 377           NaN      11           NaN
# 378           NaN      12           NaN
# 379           NaN      15           NaN
#
#                                                  stats  team_h_difficulty  \
# 0    [{'identifier': 'goals_scored', 'a': [], 'h': ...                  3
# 1    [{'identifier': 'goals_scored', 'a': [{'value'...                  3
# 2    [{'identifier': 'goals_scored', 'a': [{'value'...                  2
# 3    [{'identifier': 'goals_scored', 'a': [], 'h': ...                  2
# 4    [{'identifier': 'goals_scored', 'a': [{'value'...                  2
# ..                                                 ...                ...
# 375                                                 []                  4
# 376                                                 []                  2
# 377                                                 []                  2
# 378                                                 []                  2
# 379                                                 []                  3
#
#      team_a_difficulty  pulse_id        home team       away team
# 0                    2     66342        Brentford         Arsenal
# 1                    4     66347   Manchester Utd    Leeds United
# 2                    2     66343          Burnley        Brighton
# 3                    4     66344          Chelsea  Crystal Palace
# 4                    3     66345          Everton     Southampton
# ..                 ...       ...              ...             ...
# 375                  2     66717   Crystal Palace  Manchester Utd
# 376                  3     66718   Leicester City     Southampton
# 377                  4     66719        Liverpool          Wolves
# 378                  5     66720  Manchester City     Aston Villa
# 379                  2     66721     Norwich City       Tottenham
#
# [380 rows x 19 columns]

# %%
filepath = Path(f'../data/fbref/team_stats_week{latest_gameweek}.csv')
team_stats = pd.read_csv(filepath, index_col=0)
team_stats
# Out:
#                  Rk  MP  W  D  L  GF  GA  GD  Pts    xG   xGA  xGD  xGD/90  \
# Squad
# Chelsea           1   5  4  1  0  12   1  11   13   7.6   5.5  2.1    0.42
# Liverpool         2   5  4  1  0  12   1  11   13  14.5   5.1  9.4    1.88
# Manchester Utd    3   5  4  1  0  13   4   9   13   7.6   5.5  2.1    0.41
# Brighton          4   5  4  0  1   7   4   3   12   5.3   6.0 -0.6   -0.13
# Manchester City   5   5  3  1  1  11   1  10   10  12.2   2.7  9.5    1.90
# Everton           6   5  3  1  1  10   7   3   10   8.1   5.8  2.3    0.46
# Tottenham         7   5  3  0  2   3   6  -3    9   4.6   8.2 -3.6   -0.73
# West Ham          8   5  2  2  1  11   7   4    8   8.2   5.5  2.7    0.54
# Brentford         9   5  2  2  1   5   2   3    8   6.5   3.6  2.9    0.58
# Aston Villa      10   5  2  1  2   8   7   1    7   5.6   4.9  0.7    0.14
# Watford          11   5  2  0  3   6   8  -2    6   4.7   6.5 -1.7   -0.34
# Leicester City   12   5  2  0  3   5   8  -3    6   5.5   9.5 -4.0   -0.80
# Arsenal          13   5  2  0  3   2   9  -7    6   6.1   9.9 -3.8   -0.76
# Crystal Palace   14   5  1  2  2   5   8  -3    5   4.8   5.8 -1.0   -0.20
# Southampton      15   5  0  4  1   4   6  -2    4   6.3   7.0 -0.7   -0.13
# Wolves           16   5  1  0  4   2   5  -3    3   7.0   5.6  1.4    0.28
# Leeds United     17   5  0  3  2   5  12  -7    3   7.0  10.3 -3.3   -0.65
# Newcastle Utd    18   5  0  2  3   6  13  -7    2   5.6  11.3 -5.7   -1.14
# Burnley          19   5  0  1  4   3   9  -6    1   5.8   8.2 -2.3   -0.47
# Norwich City     20   5  0  0  5   2  14 -12    0   4.7  10.9 -6.3   -1.25
#
#                     Last 5  Attendance  \
# Squad
# Chelsea          W W D W W       39467
# Liverpool        W W D W W       53296
# Manchester Utd   W D W W W       72732
# Brighton         W W L W W       30370
# Manchester City  L W W W D       52137
# Everton          W D W W L       34244
# Tottenham        W W W L L       58664
# West Ham         W W D D L       59826
# Brentford        W D D L W       16499
# Aston Villa      L W D L W       41966
# Watford          W L L L W       20035
# Leicester City   W L W L L       32035
# Arsenal          L L L W W       58365
# Crystal Palace   L D D W L       24546
# Southampton      L D D D D       31000
# Wolves           L L L W L       30495
# Leeds United     L D D L D       36400
# Newcastle Utd    L L D L D       48366
# Burnley          L L D L L       18455
# Norwich City     L L L L L       26894
#
#                                                 Top Team Scorer  \
# Squad
# Chelsea                                       Romelu Lukaku - 3
# Liverpool                                     Mohamed Salah - 4
# Manchester Utd                              Bruno Fernandes - 4
# Brighton                                        Neal Maupay - 3
# Manchester City                               Ferrán Torres - 2
# Everton                 Demarai Gray, Dominic Calvert-Lewin - 3
# Tottenham                                     Son Heung-min - 2
# West Ham                                    Michail Antonio - 4
# Brentford                                        Ivan Toney - 2
# Aston Villa                                      Danny Ings - 2
# Watford                                        Ismaila Sarr - 3
# Leicester City                                  Jamie Vardy - 3
# Arsenal          Pierre-Emerick Aubameyang, Martin Ødegaard - 1
# Crystal Palace             Conor Gallagher, Odsonne Édouard - 2
# Southampton          Mohamed Elyounoussi, Adam Armstrong... - 1
# Wolves                                       Hwang Hee-chan - 1
# Leeds United                           Raphael Dias Belloli - 2
# Newcastle Utd            Allan Saint-Maximin, Callum Wilson - 2
# Burnley                              Ben Mee, Chris Wood... - 1
# Norwich City                                    Teemu Pukki - 2
#
#                         Goalkeeper  Notes  xG per game  xGA per game  \
# Squad
# Chelsea              Edouard Mendy    NaN         1.52          1.10
# Liverpool                  Alisson    NaN         2.90          1.02
# Manchester Utd        David de Gea    NaN         1.52          1.10
# Brighton            Robert Sánchez    NaN         1.06          1.20
# Manchester City            Ederson    NaN         2.44          0.54
# Everton            Jordan Pickford    NaN         1.62          1.16
# Tottenham              Hugo Lloris    NaN         0.92          1.64
# West Ham          Łukasz Fabiański    NaN         1.64          1.10
# Brentford               David Raya    NaN         1.30          0.72
# Aston Villa      Emiliano Martínez    NaN         1.12          0.98
# Watford            Daniel Bachmann    NaN         0.94          1.30
# Leicester City   Kasper Schmeichel    NaN         1.10          1.90
# Arsenal                 Bernd Leno    NaN         1.22          1.98
# Crystal Palace      Vicente Guaita    NaN         0.96          1.16
# Southampton          Alex McCarthy    NaN         1.26          1.40
# Wolves                     José Sá    NaN         1.40          1.12
# Leeds United         Illan Meslier    NaN         1.40          2.06
# Newcastle Utd      Freddie Woodman    NaN         1.12          2.26
# Burnley                  Nick Pope    NaN         1.16          1.64
# Norwich City              Tim Krul    NaN         0.94          2.18
#
#                  probability no goals allowed
# Squad
# Chelsea                              0.332871
# Liverpool                            0.360595
# Manchester Utd                       0.332871
# Brighton                             0.301194
# Manchester City                      0.582748
# Everton                              0.313486
# Tottenham                            0.193980
# West Ham                             0.332871
# Brentford                            0.486752
# Aston Villa                          0.375311
# Watford                              0.272532
# Leicester City                       0.149569
# Arsenal                              0.138069
# Crystal Palace                       0.313486
# Southampton                          0.246597
# Wolves                               0.326280
# Leeds United                         0.127454
# Newcastle Utd                        0.104350
# Burnley                              0.193980
# Norwich City                         0.113042

# %%
# upload model for making predictions
path = Path('../models/xgboost_predictor_v4_weightsAndBonus.pickle')
with open(path,'rb') as f:
    model = pickle.load(f)

# %%
# pre-allocate for model input
predictions = pd.DataFrame(index=players.index.copy())
input_columns = ['goalkeeper', 'defender', 'midfielder',
       'forward', 'xG90', 'xA90', 'xGA90', 'bonus', 'xPoints90',
       'games played', 'form 5', 'games_form5', 'form 10', 'games form10',
       'team xG per 90', 'team xGA per 90', 'home', 'opponent xG per 90',
       'opponent xGA per 90']
predictions[input_columns] = np.nan
predictions
# Out:
#      goalkeeper  defender  midfielder  forward  xG90  xA90  xGA90  bonus  \
# id
# 1           NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# 2           NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# 3           NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# 4           NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# 5           NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# ..          ...       ...         ...      ...   ...   ...    ...    ...
# 523         NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# 547         NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# 548         NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# 549         NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
# 583         NaN       NaN         NaN      NaN   NaN   NaN    NaN    NaN
#
#      xPoints90  games played  form 5  games_form5  form 10  games form10  \
# id
# 1          NaN           NaN     NaN          NaN      NaN           NaN
# 2          NaN           NaN     NaN          NaN      NaN           NaN
# 3          NaN           NaN     NaN          NaN      NaN           NaN
# 4          NaN           NaN     NaN          NaN      NaN           NaN
# 5          NaN           NaN     NaN          NaN      NaN           NaN
# ..         ...           ...     ...          ...      ...           ...
# 523        NaN           NaN     NaN          NaN      NaN           NaN
# 547        NaN           NaN     NaN          NaN      NaN           NaN
# 548        NaN           NaN     NaN          NaN      NaN           NaN
# 549        NaN           NaN     NaN          NaN      NaN           NaN
# 583        NaN           NaN     NaN          NaN      NaN           NaN
#
#      team xG per 90  team xGA per 90  home  opponent xG per 90  \
# id
# 1               NaN              NaN   NaN                 NaN
# 2               NaN              NaN   NaN                 NaN
# 3               NaN              NaN   NaN                 NaN
# 4               NaN              NaN   NaN                 NaN
# 5               NaN              NaN   NaN                 NaN
# ..              ...              ...   ...                 ...
# 523             NaN              NaN   NaN                 NaN
# 547             NaN              NaN   NaN                 NaN
# 548             NaN              NaN   NaN                 NaN
# 549             NaN              NaN   NaN                 NaN
# 583             NaN              NaN   NaN                 NaN
#
#      opponent xGA per 90
# id
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# ..                   ...
# 523                  NaN
# 547                  NaN
# 548                  NaN
# 549                  NaN
# 583                  NaN
#
# [606 rows x 19 columns]

# %%
# run predictions for all players for a given time horizon
# assumes one match per gameweek at most currently
horizon = 10
output_columns = [f'gameweek {i} prediction' for i in range(latest_gameweek+1,latest_gameweek+horizon+1)]
xGA_columns = [column for column in players.columns if 'xGA_week' in column]
xPoints_columns = [column for column in players.columns if 'xPoints week' in column]

for player_ix in players.index:
    
    # collect base info
    if players.loc[player_ix,'element_type'] == 1:
        predictions.loc[player_ix,'goalkeeper'] = 1
    elif players.loc[player_ix, 'element_type'] == 2:
        predictions.loc[player_ix,'defender'] = 1
    elif players.loc[player_ix, 'element_type'] == 3:
        predictions.loc[player_ix,'midfielder'] = 1
    elif players.loc[player_ix, 'element_type'] == 4:
        predictions.loc[player_ix,'forward'] = 1

    if players.loc[player_ix,'games played'] > 0:
        predictions.loc[player_ix, 'xG90'] = players.loc[player_ix,'xG'] / players.loc[player_ix,'games played']
        predictions.loc[player_ix, 'xA90'] = players.loc[player_ix,'xA'] / players.loc[player_ix,'games played']
        predictions.loc[player_ix, 'xGA90'] = players.loc[player_ix,xGA_columns].sum() / \
                                          players.loc[player_ix,'games played']                                        
        predictions.loc[player_ix, 'bonus'] = players.loc[player_ix, 'bps']
        predictions.loc[player_ix, 'xPoints90'] = players.loc[player_ix,'adjusted points per game']
        predictions.loc[player_ix, 'games played'] = players.loc[player_ix, 'games played']
        
        form5_points = players.loc[player_ix, xPoints_columns[-5:]].sum()
        form5_games = players.loc[player_ix, xPoints_columns[-5:]].notnull().sum()
        predictions.loc[player_ix, 'form 5'] = form5_points
        predictions.loc[player_ix, 'games_form5'] = form5_games
        
        form10_points = players.loc[player_ix, xPoints_columns[-10:]].sum()
        form10_games = players.loc[player_ix, xPoints_columns[-10:]].notnull().sum()
        predictions.loc[player_ix, 'form 10'] = form10_points
        predictions.loc[player_ix, 'games form10'] = form10_games
    else:
        predictions.loc[player_ix, 'xG90'] = 0
        predictions.loc[player_ix, 'xA90'] = 0
        predictions.loc[player_ix, 'xGA90'] = 0                       
        predictions.loc[player_ix, 'bonus'] = 0
        predictions.loc[player_ix, 'xPoints90'] = 0
        predictions.loc[player_ix, 'games played'] = 0
        predictions.loc[player_ix, 'form 5'] = 0
        predictions.loc[player_ix, 'games_form5'] = 0
        predictions.loc[player_ix, 'form 10'] = 0
        predictions.loc[player_ix, 'games form10'] = 0
        
    team = players.loc[player_ix, 'team_name']
    # team xG per 90 
    team_xG90 = team_stats.loc[team,'xG'] / team_stats.loc[team,'MP']
    predictions.loc[player_ix, 'team xG per 90'] = team_xG90
    # team xGA per 90 
    team_xGA90 = team_stats.loc[team,'xGA'] / team_stats.loc[team,'MP']
    predictions.loc[player_ix, 'team xGA per 90'] = team_xGA90
    
    for gameweek in range(latest_gameweek+1,latest_gameweek+horizon+1):

        # home games
        home_fixtures = fpl_fixtures[(fpl_fixtures['event']==gameweek) & (fpl_fixtures['home team']==team)]
        for fixture in home_fixtures.index:
            predictions.loc[player_ix, 'home'] = 1
            opponent = fpl_fixtures.loc[fixture, 'away team']
            # opponent xG per 90
            opponent_xG90 = team_stats.loc[opponent, 'xG'] / team_stats.loc[opponent,'MP']
            predictions.loc[player_ix, 'opponent xG per 90'] = opponent_xG90
            # opponent xGA per 90
            opponent_xGA90 = team_stats.loc[opponent, 'xGA'] / team_stats.loc[opponent,'MP']
            predictions.loc[player_ix, 'opponent xGA per 90'] = opponent_xGA90
            
            # predict player's points
            input_data = predictions.loc[player_ix:player_ix, input_columns]
            input_data = xgboost.DMatrix(input_data)
            prediction = model.predict(input_data)
            players.loc[player_ix, f'gameweek {gameweek} prediction'] = prediction
            
        # away game
        away_fixtures = fpl_fixtures[(fpl_fixtures['event']==gameweek) & (fpl_fixtures['away team']==team)]
        for fixture in away_fixtures.index:
            predictions.loc[player_ix, 'home'] = 0
            opponent = fpl_fixtures.loc[fixture, 'home team']
            # opponent xG per 90
            opponent_xG90 = team_stats.loc[opponent, 'xG'] / team_stats.loc[opponent,'MP']
            predictions.loc[player_ix, 'opponent xG per 90'] = opponent_xG90
            # opponent xGA per 90
            opponent_xGA90 = team_stats.loc[opponent, 'xGA'] / team_stats.loc[opponent,'MP']
            predictions.loc[player_ix, 'opponent xGA per 90'] = opponent_xGA90
            
            # predict player's points
            input_data = predictions.loc[player_ix:player_ix, input_columns]
            input_data = xgboost.DMatrix(input_data)
            prediction = model.predict(input_data)
            players.loc[player_ix, f'gameweek {gameweek} prediction'] = prediction

# %%
# all new predictions
players[output_columns]
# Out:
#      gameweek 6 prediction  gameweek 7 prediction  gameweek 8 prediction  \
# id
# 1                 4.340850               4.096268               4.235878
# 2                 3.651815               3.337238               3.417208
# 3                 2.670633               2.396696               2.417029
# 4                 4.292720               3.638972               3.731075
# 5                 2.662610               2.229051               2.368660
# ..                     ...                    ...                    ...
# 523               2.521257               2.912129               2.565201
# 547               2.384137               2.775009               2.428080
# 548               2.384137               2.775009               2.428080
# 549               2.681601               3.409875               2.874902
# 583               3.702343               4.530964               3.538067
#
#      gameweek 9 prediction  gameweek 10 prediction  gameweek 11 prediction  \
# id
# 1                 4.248686                4.301834                4.235878
# 2                 3.146587                3.787612                3.417208
# 3                 2.279263                2.866067                2.355349
# 4                 3.638972                4.299881                3.808844
# 5                 2.181255                2.657266                2.306980
# ..                     ...                     ...                     ...
# 523               2.893246                2.324723                2.767059
# 547               2.740421                2.260516                2.564450
# 548               2.740421                2.260516                2.564450
# 549               3.013338                2.271759                3.076761
# 583               4.329434                3.242756                3.798155
#
#      gameweek 12 prediction  gameweek 13 prediction  gameweek 14 prediction  \
# id
# 1                  3.795575                4.399228                3.712381
# 2                  2.641918                3.861710                2.636720
# 3                  1.978490                2.909526                2.136439
# 4                  3.342511                4.401132                3.541665
# 5                  1.523844                2.710721                1.681431
# ..                      ...                     ...                     ...
# 523                2.324723                3.113988                2.820845
# 547                2.260516                2.911378                2.683725
# 548                2.260516                2.911378                2.683725
# 549                2.271759                3.611734                3.318591
# 583                3.104692                4.655256                4.491465
#
#      gameweek 15 prediction
# id
# 1                  3.718094
# 2                  2.863113
# 3                  2.042449
# 4                  3.342511
# 5                  1.537365
# ..                      ...
# 523                2.152560
# 547                2.157793
# 548                2.157793
# 549                2.099595
# 583                3.081892
#
# [606 rows x 10 columns]

# %%
players['xPoints_next10'] = players[output_columns].sum(axis=1)

# %%
players.sort_values(f'gameweek {latest_gameweek+1} prediction', ascending=False)[['web_name','now_cost','adjusted points per game', f'gameweek {latest_gameweek+1} prediction']].head(20)
# Out:
#              web_name  now_cost  adjusted points per game  \
# id
# 177     Calvert-Lewin        81                  8.513333
# 413           Antonio        79                  7.001000
# 419          Benrahma        64                  5.601271
# 579           Ronaldo       127                  8.500000
# 484              Gray        57                  4.293486
# 423           Fornals        60                  4.167071
# 529            Lukaku       116                  6.550000
# 237  Alexander-Arnold        76                  8.227880
# 180       Richarlison        75                  3.992750
# 578            Cornet        60                  2.993980
# 422            Soucek        59                  3.532871
# 420             Bowen        63                  4.147071
# 359               Son       100                  4.468980
# 17               Pépé        72                  5.230819
# 170          Pickford        50                  3.253945
# 399              Sarr        61                  5.232532
# 205             Vardy       104                  4.734200
# 109              Wood        69                  4.100000
# 169             Keane        50                  3.713945
# 112              Pope        55                  2.975920
#
#      gameweek 6 prediction
# id
# 177               6.853114
# 413               6.420408
# 419               5.254013
# 579               5.098462
# 484               5.046570
# 423               4.860206
# 529               4.845487
# 237               4.826486
# 180               4.814730
# 578               4.790352
# 422               4.784264
# 420               4.772722
# 359               4.705836
# 17                4.661509
# 170               4.625066
# 399               4.581307
# 205               4.571732
# 109               4.526552
# 169               4.517921
# 112               4.450612

# %%
players.sort_values('xPoints_next10', ascending=False)[['web_name','now_cost','adjusted points per game', 'xPoints_next10']].head(20)
# Out:
#              web_name  now_cost  adjusted points per game  xPoints_next10
# id
# 529            Lukaku       116                  6.550000       59.560102
# 177     Calvert-Lewin        81                  8.513333       57.773018
# 413           Antonio        79                  7.001000       56.761342
# 579           Ronaldo       127                  8.500000       54.749139
# 237  Alexander-Arnold        76                  8.227880       50.481091
# 240              Jota        77                  5.520595       48.410384
# 233             Salah       126                  8.387195       47.678480
# 142             James        56                  5.278818       47.649794
# 78              Toney        63                  4.998200       46.731518
# 259           Laporte        56                  6.164326       45.518750
# 121      Thiago Silva        54                  4.298151       45.317638
# 270            de Gea        50                  5.331484       45.034061
# 122            Alonso        57                  5.405684       44.314309
# 296            Wilson        74                  5.066667       44.117237
# 230              Mané       119                  7.314795       43.290407
# 277         Fernandes       119                  4.832871       43.044153
# 419          Benrahma        64                  5.601271       43.044064
# 189           Bamford        80                  5.268400       42.928177
# 129      Arrizabalaga        49                  3.331484       42.596176
# 256           Cancelo        60                  6.345193       42.584457

# %%
# save data
filepath = Path('../data/fpl/data_week' + str(latest_gameweek) + str('.csv'))
players.to_csv(filepath)
