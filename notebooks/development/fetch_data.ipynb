# %%
import pandas 
pandas.set_option('max_columns',100)

# %%
data = pandas.read_html('https://fbref.com/en/comps/9/Premier-League-Stats')
data
# Out:
# [    Rk            Squad  MP   W   D   L  GF  GA  GD  Pts    xG   xGA   xGD  \
#  0    1  Manchester City  38  27   5   6  83  32  51   86  73.3  31.4  42.0
#  1    2   Manchester Utd  38  21  11   6  73  44  29   74  60.2  42.2  18.0
#  2    3        Liverpool  38  20   9   9  68  42  26   69  72.6  45.3  27.3
#  3    4          Chelsea  38  19  10   9  58  36  22   67  64.0  32.8  31.2
#  4    5   Leicester City  38  20   6  12  68  50  18   66  56.0  47.7   8.3
#  5    6         West Ham  38  19   8  11  62  47  15   65  53.9  48.3   5.6
#  6    7        Tottenham  38  18   8  12  68  45  23   62  54.5  49.5   5.0
#  7    8          Arsenal  38  18   7  13  55  39  16   61  53.5  44.3   9.2
#  8    9     Leeds United  38  18   5  15  62  54   8   59  57.5  62.9  -5.4
#  9   10          Everton  38  17   8  13  47  48  -1   59  47.2  52.0  -4.8
#  10  11      Aston Villa  38  16   7  15  55  46   9   55  52.9  52.9   0.1
# ...

# %%
len(data)
# Out:
# 24

# %%
team_stats_for = data[0]
team_stats_for
# Out:
#     Rk            Squad  MP   W   D   L  GF  GA  GD  Pts    xG   xGA   xGD  \
# 0    1  Manchester City  38  27   5   6  83  32  51   86  73.3  31.4  42.0
# 1    2   Manchester Utd  38  21  11   6  73  44  29   74  60.2  42.2  18.0
# 2    3        Liverpool  38  20   9   9  68  42  26   69  72.6  45.3  27.3
# 3    4          Chelsea  38  19  10   9  58  36  22   67  64.0  32.8  31.2
# 4    5   Leicester City  38  20   6  12  68  50  18   66  56.0  47.7   8.3
# 5    6         West Ham  38  19   8  11  62  47  15   65  53.9  48.3   5.6
# 6    7        Tottenham  38  18   8  12  68  45  23   62  54.5  49.5   5.0
# 7    8          Arsenal  38  18   7  13  55  39  16   61  53.5  44.3   9.2
# 8    9     Leeds United  38  18   5  15  62  54   8   59  57.5  62.9  -5.4
# 9   10          Everton  38  17   8  13  47  48  -1   59  47.2  52.0  -4.8
# 10  11      Aston Villa  38  16   7  15  55  46   9   55  52.9  52.9   0.1
# ...

# %%
data[1]
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Home                             \
#                    Rk              Squad   MP   W  D   L  GF  GA  GD Pts
# 0                   1    Manchester City   19  13  2   4  43  17  26  41
# 1                   2     Manchester Utd   19   9  4   6  38  28  10  31
# 2                   3          Liverpool   19  10  3   6  29  20   9  33
# 3                   4            Chelsea   19   9  6   4  31  18  13  33
# 4                   5     Leicester City   19   9  1   9  34  30   4  28
# 5                   6           West Ham   19  10  4   5  32  22  10  34
# 6                   7          Tottenham   19  10  3   6  35  20  15  33
# 7                   8            Arsenal   19   8  4   7  24  21   3  28
# 8                   9       Leeds United   19   8  5   6  28  21   7  29
# 9                  10            Everton   19   6  4   9  24  28  -4  22
# 10                 11        Aston Villa   19   7  4   8  29  27   2  25
# ...

# %%
data[2]
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             Arsenal                 29               25.9
# 1         Aston Villa                 24               25.2
# 2            Brighton                 27               25.8
# 3             Burnley                 25               28.3
# 4             Chelsea                 27               26.0
# 5      Crystal Palace                 24               29.1
# 6             Everton                 29               26.3
# 7              Fulham                 28               25.2
# 8        Leeds United                 23               26.1
# 9      Leicester City                 27               26.5
# 10          Liverpool                 28               26.8
# 11    Manchester City                 24               26.1
# 12     Manchester Utd                 29               25.6
# 13      Newcastle Utd                 27               27.1
# ...

# %%
data[2].to_csv('../../data/fbref/team_stats_for20_21.csv')

# %%
data[3]
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Squad               # Pl                Age
# 0           vs Arsenal                 29                NaN
# 1       vs Aston Villa                 24                NaN
# 2          vs Brighton                 27                NaN
# 3           vs Burnley                 25                NaN
# 4           vs Chelsea                 27                NaN
# 5    vs Crystal Palace                 24                NaN
# 6           vs Everton                 29                NaN
# 7            vs Fulham                 28                NaN
# 8      vs Leeds United                 23                NaN
# 9    vs Leicester City                 27                NaN
# 10        vs Liverpool                 28                NaN
# 11  vs Manchester City                 24                NaN
# 12   vs Manchester Utd                 29                NaN
# ...

# %%
data[3].to_csv('../../data/fbref/team_stats_against20_21.csv')

# %%
fixtures = pandas.read_html('https://fbref.com/en/comps/9/schedule/Premier-League-Scores-and-Fixtures')
fixtures
# Out:
# [       Wk  Day        Date   Time            Home   xG Score  xG.1  \
#  0     1.0  Sat  2020-09-12  12:30          Fulham  0.2   0–3   1.8
#  1     1.0  Sat  2020-09-12  15:00  Crystal Palace  0.7   1–0   0.8
#  2     1.0  Sat  2020-09-12  17:30       Liverpool  3.3   4–3   0.6
#  3     1.0  Sat  2020-09-12  20:00        West Ham  1.1   0–2   1.5
#  4     1.0  Sun  2020-09-13  14:00       West Brom  0.5   0–3   2.2
#  ..    ...  ...         ...    ...             ...  ...   ...   ...
#  435  38.0  Sun  2021-05-23  16:00        West Ham  1.6   3–0   1.5
#  436  38.0  Sun  2021-05-23  16:00         Arsenal  1.1   2–0   0.4
#  437  38.0  Sun  2021-05-23  16:00          Fulham  0.9   0–2   1.2
#  438  38.0  Sun  2021-05-23  16:00   Sheffield Utd  0.6   1–0   1.0
#  439  38.0  Sun  2021-05-23  16:00       Liverpool  1.8   2–0   0.7
#
#                 Away  Attendance             Venue          Referee  \
#  0           Arsenal         NaN    Craven Cottage   Chris Kavanagh
# ...

# %%
fixture_data = fixtures[0]
fixture_data.rename(columns={'xG':'xG home','xG.1':'xG away'}, inplace=True)
fixture_data
# Out:
#        Wk  Day        Date   Time            Home  xG home Score  xG away  \
# 0     1.0  Sat  2020-09-12  12:30          Fulham      0.2   0–3      1.8
# 1     1.0  Sat  2020-09-12  15:00  Crystal Palace      0.7   1–0      0.8
# 2     1.0  Sat  2020-09-12  17:30       Liverpool      3.3   4–3      0.6
# 3     1.0  Sat  2020-09-12  20:00        West Ham      1.1   0–2      1.5
# 4     1.0  Sun  2020-09-13  14:00       West Brom      0.5   0–3      2.2
# ..    ...  ...         ...    ...             ...      ...   ...      ...
# 435  38.0  Sun  2021-05-23  16:00        West Ham      1.6   3–0      1.5
# 436  38.0  Sun  2021-05-23  16:00         Arsenal      1.1   2–0      0.4
# 437  38.0  Sun  2021-05-23  16:00          Fulham      0.9   0–2      1.2
# 438  38.0  Sun  2021-05-23  16:00   Sheffield Utd      0.6   1–0      1.0
# 439  38.0  Sun  2021-05-23  16:00       Liverpool      1.8   2–0      0.7
#
#                Away  Attendance             Venue          Referee  \
# ...

# %%
fixture_data.to_csv('../../data/fbref/fixtures20_21.csv')
